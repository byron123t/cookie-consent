# %%
from multiprocessing import Pool
from pathlib import Path

from tqdm import tqdm
tqdm.pandas()
import pandas as pd
import dask.dataframe as dd

from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import SCAN_DIRS, FIG_DIR, SCAN_ROOT_DIR
from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
from consent.data.pref_menu_scan.log_reader import read_logs_in_scans
from consent.data.pref_menu_scan.cookie_decl_reader import read_cookie_decls_in_scans
from consent.data.pref_menu_scan.postrej_cookie_reader import read_postrej_sent_cookies_in_scans
from consent.data.pref_menu_scan.cat_pref_reader import read_cat_prefs_in_dirs
from consent.util.default_path import get_data_dir
from ooutil.type_util import hashabledict
from ooutil.url_util import get_suffixed_domain

scan_root_dir = get_data_dir('2021-08-12')
scan_dirs = [scan_root_dir / 'pref_menu_scan_0k_10k',
             scan_root_dir / 'pref_menu_scan_10k_20k',
             scan_root_dir / 'pref_menu_scan_20k_30k']
assert all(scan_dir.exists() for scan_dir in scan_dirs)

fig_dir = Path.home() / 'local_projects/consent/paper/sp22/figures'
assert fig_dir.exists() and fig_dir.is_dir()

# %%
# Read in cookie transfer 
import sys; import importlib; importlib.reload(sys.modules['consent.data.pref_menu_scan.postrej_cookie_reader'])
from consent.data.pref_menu_scan.postrej_cookie_reader import read_postrej_sent_cookies_in_scans


overwrite = False
cookies_cache_file = SCAN_ROOT_DIR / 'raw_postrej_sent_cookies.parquet'

if not overwrite and cookies_cache_file and cookies_cache_file.exists():
    sent_cookies = pd.read_parquet(cookies_cache_file)
else:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Number sent cookies read: 5,196,675
#                domain       expires  httpOnly                   name path  \
# 0  .apachefriends.org  1.629067e+09     False                   _gid    /
# 1  .apachefriends.org  1.660517e+09     False  OptanonAlertBoxClosed    /
# 2  .apachefriends.org  1.660517e+09     False         OptanonConsent    /
#
#   sameSite  secure                                              value  \
# 0     None   False                         GA1.2.720720591.1628980892
# 1      Lax   False                           2021-08-14T22:42:17.927Z
# 2      Lax   False  isIABGlobal=false&datestamp=Sat+Aug+14+2021+22...
#
#                                          request_url               site  \
# 0  https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 1  https://www.apachefriends.org/javascripts/all-...  apachefriends.org
# 2  https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
#
#    load_start_time  load_end_time                                  page_url
# 0     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 1     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 2     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html

# %%
# Just test drop_duplicates()
samples = sent_cookies[:1000]
samples.drop_duplicates().head()
# Out:
#                domain       expires  httpOnly                   name path  \
# 0  .apachefriends.org  1.629067e+09     False                   _gid    /
# 1  .apachefriends.org  1.660517e+09     False  OptanonAlertBoxClosed    /
# 2  .apachefriends.org  1.660517e+09     False         OptanonConsent    /
# 3  .apachefriends.org  1.629067e+09     False                   _gid    /
# 4  .apachefriends.org  1.660517e+09     False  OptanonAlertBoxClosed    /
#
#   sameSite  secure                                              value  \
# 0     None   False                         GA1.2.720720591.1628980892
# 1      Lax   False                           2021-08-14T22:42:17.927Z
# 2      Lax   False  isIABGlobal=false&datestamp=Sat+Aug+14+2021+22...
# 3     None   False                         GA1.2.720720591.1628980892
# 4      Lax   False                           2021-08-14T22:42:17.927Z
#
#                                          request_url               site  \
# 0  https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 1  https://www.apachefriends.org/javascripts/all-...  apachefriends.org
# 2  https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 3  https://www.apachefriends.org/images/flags/hu-...  apachefriends.org
# 4           https://www.apachefriends.org/index.html  apachefriends.org
#
#    load_start_time  load_end_time                                  page_url
# 0     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 1     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 2     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 3     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html
# 4     1.628981e+09   1.628981e+09  https://www.apachefriends.org/index.html

# %%
samples_ddf = dd.from_pandas(samples.dropna(), npartitions=32)
samples_ddf
# Out:
# Dask DataFrame Structure:
#                 domain  expires httpOnly    name    path sameSite secure   value request_url    site load_start_time load_end_time page_url
# npartitions=32
# 0               object  float64     bool  object  object   object   bool  object      object  object         float64       float64   object
# 32                 ...      ...      ...     ...     ...      ...    ...     ...         ...     ...             ...           ...      ...
# ...                ...      ...      ...     ...     ...      ...    ...     ...         ...     ...             ...           ...      ...
# 992                ...      ...      ...     ...     ...      ...    ...     ...         ...     ...             ...           ...      ...
# 999                ...      ...      ...     ...     ...      ...    ...     ...         ...     ...             ...           ...      ...
# Dask Name: from_pandas, 32 tasks

# %%
def afunc(row):
    return 1 if 'apache' in row['domain'] else 0
samples['count'] = samples_ddf.apply(afunc, axis=1, meta=('x', 'int64')).compute() 
samples
# Out:
#                   domain       expires  httpOnly  \
# 0     .apachefriends.org  1.629067e+09     False
# 1     .apachefriends.org  1.660517e+09     False
# 2     .apachefriends.org  1.660517e+09     False
# 3     .apachefriends.org  1.629067e+09     False
# 4     .apachefriends.org  1.660517e+09     False
# ..                   ...           ...       ...
# 995     .appdynamics.com  1.691883e+09     False
# 996     .appdynamics.com  1.628813e+09     False
# 997     .appdynamics.com -1.000000e+00     False
# 998  www.appdynamics.com  1.691883e+09     False
# 999  www.appdynamics.com  1.691883e+09     False
#
#                                          name path sameSite  secure  \
# 0                                        _gid    /     None   False
# 1                       OptanonAlertBoxClosed    /      Lax   False
# 2                              OptanonConsent    /      Lax   False
# 3                                        _gid    /     None   False
# 4                       OptanonAlertBoxClosed    /      Lax   False
# ..                                        ...  ...      ...     ...
# 995  AMCV_B8D07FF4520E94C10A490D4C%40AdobeOrg    /     None   False
# 996                                    _cs_mk    /     None   False
# 997                                     s_ptc    /     None   False
# 998                                 drift_aid    /     None    True
# 999                              _gd_svisitor    /     None    True
#
#                                                  value  \
# 0                           GA1.2.720720591.1628980892
# 1                             2021-08-14T22:42:17.927Z
# 2    isIABGlobal=false&datestamp=Sat+Aug+14+2021+22...
# 3                           GA1.2.720720591.1628980892
# 4                             2021-08-14T22:42:17.927Z
# ..                                                 ...
# 995  281789898%7CMCIDTS%7C18852%7CMCMID%7C185840794...
# 996                    0.648266833031006_1628811382587
# 997                                      %5B%5BB%5D%5D
# 998               98ccb210-ab51-4d1d-8def-d57f3591e4d9
# 999           14cb4d171916000076b01561f5010000261a0b00
#
#                                            request_url               site  \
# 0    https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 1    https://www.apachefriends.org/javascripts/all-...  apachefriends.org
# 2    https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 3    https://www.apachefriends.org/images/flags/hu-...  apachefriends.org
# 4             https://www.apachefriends.org/index.html  apachefriends.org
# ..                                                 ...                ...
# 995  https://www.appdynamics.com/c/r/appdynamics/pr...    appdynamics.com
# 996  https://www.appdynamics.com/etc/designs/cdc/fw...    appdynamics.com
# 997  https://www.appdynamics.com/etc/designs/r/appd...    appdynamics.com
# 998  https://www.appdynamics.com/etc/designs/r/appd...    appdynamics.com
# 999  https://www.appdynamics.com/c/dam/r/appdynamic...    appdynamics.com
#
#      load_start_time  load_end_time  \
# 0       1.628981e+09   1.628981e+09
# 1       1.628981e+09   1.628981e+09
# 2       1.628981e+09   1.628981e+09
# 3       1.628981e+09   1.628981e+09
# 4       1.628981e+09   1.628981e+09
# ..               ...            ...
# 995     1.628811e+09   1.628811e+09
# 996     1.628811e+09   1.628811e+09
# 997     1.628811e+09   1.628811e+09
# 998     1.628811e+09   1.628811e+09
# 999     1.628811e+09   1.628811e+09
#
#                                               page_url  count
# 0             https://www.apachefriends.org/index.html      1
# 1             https://www.apachefriends.org/index.html      1
# 2             https://www.apachefriends.org/index.html      1
# 3             https://www.apachefriends.org/index.html      1
# 4             https://www.apachefriends.org/index.html      1
# ..                                                 ...    ...
# 995  https://www.appdynamics.com/product/end-user-m...      0
# 996  https://www.appdynamics.com/product/end-user-m...      0
# 997  https://www.appdynamics.com/product/end-user-m...      0
# 998  https://www.appdynamics.com/product/end-user-m...      0
# 999  https://www.appdynamics.com/product/end-user-m...      0
#
# [1000 rows x 14 columns]
