# %%
from collections import defaultdict, Counter
from multiprocessing import Pool
from pathlib import Path
from typing import Dict
import json
import re

from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from consent.consistency.util import SCAN_DIRS, FIG_DIR, SCAN_ROOT_DIR
from consent.data.site_pref import read_site_prefs
from consent.data.pref_menu_scan.prerej_cookie_reader import read_prerej_sent_cookies_in_scans
from consent.cmp.consentlib.onetrust import OptanonConsentCookie
from consent.cmp.consentlib.cookiebot import CookiebotConsentCookie
from consent.util.default_path import get_data_dir
from ooutil.cookie_util import get_brower_cookies
from ooutil.type_util import hashabledict
from ooutil.url_util import get_suffixed_domain

# %%
prej_sent_cookies = read_prerej_sent_cookies_in_scans(SCAN_DIRS)
prej_sent_cookies
# Out:
# Num prerej cookie files: 1366
# Error loading cookie for site tevapharm.com/prerej_cookies.json: Expecting value: line 1 column 1 (char 0)
# Error loading cookie for site rockwellautomation.com/prerej_cookies.json: Expecting value: line 1 column 1 (char 0)
# Error loading cookie for site jimmychoo.com/prerej_cookies.json: Extra data: line 531 column 2 (char 74606)
# Error loading cookie for site fortinet.com/prerej_cookies.json: 'utf-8' codec can't decode byte 0xac in position 106069: invalid start byte
# Error loading cookie for site exoclick.com/prerej_cookies.json: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Error loading cookie for site returnpath.com/prerej_cookies.json: Extra data: line 409 column 2 (char 26396)
# Error loading cookie for site asda.com/prerej_cookies.json: 'utf-8' codec can't decode byte 0xc2 in position 16654: invalid continuation byte
# Error loading cookie for site nasdaq.com/prerej_cookies.json: Extra data: line 641 column 2 (char 52420)
# 95 sites with corrupted cookie files: ['aber.ac.uk', 'abus.com', 'adcombo.com', 'adform.com', 'allen-heath.com', 'analyticsmania.com', 'apachefriends.org', 'asda.com', 'atlascopco.com', 'baxter.com', 'bbva.com', 'bitnami.com', 'boroughmarket.org.uk', 'broadcom.com', 'buchmesse.de', 'burlington.com', 'canalrivertrust.org.uk', 'commonsense.org', 'condenast.com', 'condenastdigital.com', 'cookiepro.com', 'cosmopolitan.co.uk', 'deltadna.net', 'demonware.net', 'dfa.ie', 'digital.nhs.uk', 'e-activist.com', 'ecfr.eu', 'equinor.com', 'eurovision.tv', 'exoclick.com', 'extole.com', 'fortinet.com', 'freepikcompany.com', 'futuremark.com', 'gates.com', 'gatwickairport.com', 'getfeedback.com', 'gettingthingsdone.com', 'global.honda', 'haribo.com', 'iop.org', 'ipswitch.com', 'jimmychoo.com', 'kaercher.com', 'ledzeppelin.com', 'lsac.org', 'lvmh.com', 'magna.com', 'mailerlite.com', 'managers.org.uk', 'mathoverflow.net', 'mencap.org.uk', 'mlcdn.com', 'mlsend.com', 'nasdaq.com', 'norden.org', 'notonthehighstreet.com', 'nudatasecurity.com', 'nutella.com', 'olympus-global.com', 'onetrust.com', 'opendns.com', 'ozerov.de', 'partnerize.com', 'pubnative.net', 'returnpath.com', 'rockwellautomation.com', 'satchelone.com', 'schoolwires.com', 'sciam.com', 'scientificamerican.com', 'signifyd.com', 'sika.com', 'skoda-auto.com', 'sportengland.org', 'stackoverflow.com', 'statoil.com', 'stedelijk.nl', 'subscribepage.com', 'survicate.com', 'sweetgreen.com', 'take2games.com', 'tcd.ie', 'technicalseo.com', 'tevapharm.com', 'texasroadhouse.com', 'ucc.ie', 'ucd.ie', 'upcloud.com', 'volvogroup.com', 'wbgames.com', 'webzen.com', 'westminster-abbey.org', 'wwf.org.uk']
#                          domain       expires  httpOnly  \
# 0                    .accor.com  1.644379e+09     False
# 1                    .accor.com -1.000000e+00     False
# 2                    .accor.com  1.660290e+09      True
# 3                    .accor.com -1.000000e+00     False
# 4                    .accor.com -1.000000e+00     False
# ...                         ...           ...       ...
# 266035    .leica-geosystems.com  1.636750e+09     False
# 266036     leica-geosystems.com -1.000000e+00      True
# 266037     leica-geosystems.com -1.000000e+00     False
# 266038     leica-geosystems.com -1.000000e+00     False
# 266039  www.conversionruler.com  1.628976e+09     False
#
#                           name path sameSite  secure  \
# 0               OptanonConsent    /      Lax   False
# 1       incap_ses_8072_2545443    /     None   False
# 2          visid_incap_2545443    /     None   False
# 3                   CSESSIONID    /     None    True
# 4                   CSESSIONID    /     None    True
# ...                        ...  ...      ...     ...
# 266035                 _gcl_au    /     None   False
# 266036       ASP.NET_SessionId    /      Lax   False
# 266037       hexagonleica#lang    /     None   False
# 266038              TS01127c47    /     None   False
# 266039             CRSess_8192    /     None   False
#
#                                                     value  \
# 0       isGpcEnabled=0&datestamp=Fri+Aug+13+2021+04%3A...
# 1       ZsRoKdzUIyNdziAdf4EFcNbuFWEAAAAAosZBwXR4jO7FFT...
# 2       sMAsu37JTTK9mqn+KtdNOtbuFWEAAAAAQUIPAAAAAADVdq...
# 3                      HZ5AD83FBEC4B14A4D81EB6580528231CF
# 4                      HZ5AD83FBEC4B14A4D81EB6580528231CF
# ...                                                   ...
# 266035                          1.1.1689705220.1628974156
# 266036                           rfhjajhbw0r1vc54qk5ioryx
# 266037                                                 en
# 266038  014edcb93343ab3ec57ca1f8d8297819314408c0138658...
# 266039                   1c706d2ac2e9eb3dddaf8e841fe451a7
#
#                                               request_url  \
# 0       https://edg.accor.com/cdx/r20.gif?rnd=1-1-1009...
# 1       https://cdn.accor.com/cdx/r20.gif?rnd=1-1-1009...
# 2       https://all.accor.com/rb_80be963f-a859-4808-9b...
# 3       https://cdn.accor.com/cdx/r20.gif?rnd=1-1-1009...
# 4       https://cdn.accor.com/cdx/r20-100KB.png?rnd=14...
# ...                                                   ...
# 266035  https://leica-geosystems.com/Themes/Leica/Leic...
# 266036  https://leica-geosystems.com/Themes/Leica/Leic...
# 266037  https://leica-geosystems.com/-/media/images/gl...
# 266038  https://leica-geosystems.com/Coveo/Hive/js/Cov...
# 266039  https://www.conversionruler.com/bin/tracker.ph...
#
#                         site  load_start_time  load_end_time  \
# 0                sofitel.com     1.628827e+09   1.628827e+09
# 1                sofitel.com     1.628827e+09   1.628827e+09
# 2                sofitel.com     1.628827e+09   1.628827e+09
# 3                sofitel.com     1.628827e+09   1.628827e+09
# 4                sofitel.com     1.628827e+09   1.628827e+09
# ...                      ...              ...            ...
# 266035  leica-geosystems.com     1.628974e+09   1.628974e+09
# 266036  leica-geosystems.com     1.628974e+09   1.628974e+09
# 266037  leica-geosystems.com     1.628974e+09   1.628974e+09
# 266038  leica-geosystems.com     1.628974e+09   1.628974e+09
# 266039  leica-geosystems.com     1.628974e+09   1.628974e+09
#
#                                                  page_url
# 0       https://sofitel.accor.com/northamerica/index.e...
# 1       https://sofitel.accor.com/northamerica/index.e...
# 2       https://sofitel.accor.com/northamerica/index.e...
# 3       https://sofitel.accor.com/northamerica/index.e...
# 4       https://sofitel.accor.com/northamerica/index.e...
# ...                                                   ...
# 266035                 https://leica-geosystems.com/en-us
# 266036                 https://leica-geosystems.com/en-us
# 266037                 https://leica-geosystems.com/en-us
# 266038                 https://leica-geosystems.com/en-us
# 266039                 https://leica-geosystems.com/en-us
#
# [266040 rows x 13 columns]

# %%
pre_consent_cookies = prej_sent_cookies[prej_sent_cookies.name.isin(['OptanonConsent', 'CookieConsent'])][['domain', 'name', 'value', 'site']].drop_duplicates()
pre_consent_cookies.name.value_counts()
# Out:
# OptanonConsent    675
# CookieConsent       9
# Name: name, dtype: int64

# %%
pre_consent_cookies.head()
# Out:
#                      domain            name  \
# 0                .accor.com  OptanonConsent
# 1316            .acquia.com  OptanonConsent
# 2143      .jackinthebox.com  OptanonConsent
# 2287  .www.conservation.org  OptanonConsent
# 2435           .dialpad.com  OptanonConsent
#
#                                                   value                site
# 0     isGpcEnabled=0&datestamp=Fri+Aug+13+2021+04%3A...         sofitel.com
# 1316  isGpcEnabled=0&datestamp=Thu+Aug+19+2021+10%3A...         agilone.com
# 2143  isIABGlobal=false&datestamp=Thu+Aug+19+2021+10...    jackinthebox.com
# 2287  isIABGlobal=false&datestamp=Fri+Aug+13+2021+03...    conservation.org
# 2435  isIABGlobal=false&datestamp=Thu+Aug+19+2021+14...  uberconference.com

# %%
len(pre_consent_cookies)
# Out:
# 684

# %%
def get_consent(row):
    if row['name'] == 'OptanonConsent':
        cookie_cls = OptanonConsentCookie
    else:
        cookie_cls = CookiebotConsentCookie
    try:
        cookie = cookie_cls(row.to_dict())
        return cookie.get_cat_to_pref()
    except Exception:
        pass
    return None
pre_consent_cookies['consent'] = pre_consent_cookies.apply(get_consent, axis=1)

# %%
pre_cookies = pre_consent_cookies[~pre_consent_cookies.consent.isna()]
assert len(pre_cookies) == pre_cookies.site.nunique(), 'some website has 2 consent cookies?'
print("Number of websites with consent cookies set before submission", pre_cookies.site.nunique())
# Out:
# Number of websites with consent cookies set before submission 672

# %%
# TODO: improve detection by implementing below

# %%
pre_cookies
# Out:
#                       domain            name  \
# 1              .ratebeer.com  OptanonConsent
# 55                .adobe.com  OptanonConsent
# 390            .bethesda.net  OptanonConsent
# 512      .intrepidtravel.com  OptanonConsent
# 629          .perimeterx.com  OptanonConsent
# ...                      ...             ...
# 182319       .ajpmonline.org  OptanonConsent
# 182491       .saatchiart.com  OptanonConsent
# 182508  .www.visitnorway.com  OptanonConsent
# 182859        .webengage.com  OptanonConsent
# 183235     .hybridtheory.com  OptanonConsent
#
#                                                     value                site  \
# 1       isIABGlobal=false&datestamp=Sat+Aug+14+2021+20...        ratebeer.com
# 55      isIABGlobal=false&datestamp=Fri+Aug+13+2021+13...            adobe.ly
# 390     isIABGlobal=false&datestamp=Fri+Aug+13+2021+12...        bethsoft.com
# 512     isIABGlobal=false&datestamp=Fri+Aug+13+2021+13...  intrepidtravel.com
# 629     isIABGlobal=false&datestamp=Thu+Aug+12+2021+23...      perimeterx.net
# ...                                                   ...                 ...
# 182319  isIABGlobal=false&datestamp=Fri+Aug+13+2021+03...      ajpmonline.org
# 182491  isIABGlobal=false&datestamp=Thu+Aug+12+2021+23...      saatchiart.com
# 182508  isIABGlobal=false&datestamp=Fri+Aug+13+2021+04...     visitnorway.com
# 182859  isIABGlobal=false&datestamp=Fri+Aug+13+2021+03...       webengage.com
# 183235  isIABGlobal=false&datestamp=Fri+Aug+13+2021+03...            affec.tv
#
#                                                   consent
# 1       {'1': True, '3': True, 'SPD_BG': False, '4': F...
# 55      {'C0001': True, 'C0002': True, 'C0003': True, ...
# 390     {'C0001': True, 'BG54': True, 'C0003': True, '...
# 512     {'C0003': True, 'C0004': True, 'C0001': True, ...
# 629     {'C0004': True, 'C0003': True, 'BG4': True, 'C...
# ...                                                   ...
# 182319      {'1': True, '2': True, '3': True, '4': False}
# 182491  {'C0001': True, 'C0003': True, 'SPD_BG': True,...
# 182508  {'C0001': True, 'C0003': False, 'C0002': False...
# 182859  {'C0001': True, 'C0002': True, 'C0003': True, ...
# 183235  {'C0001': True, 'C0002': True, 'C0003': True, ...
#
# [485 rows x 5 columns]

# %%
# pre_consent_cookies[~pre_consent_cookies.domain.str.startswith('.')]

# %%
scanned_sites = [site_dir.name for site_dir in data_dir.glob('*') if site_dir.is_dir()]
site_dirs = [data_dir / site for site in scanned_sites]
print("Number of scanned sites:", len(scanned_sites)) # , scanned_sites)
site_prefs = read_site_prefs(site_dirs)
site_prefs
# Out:
# Number of scanned sites: 227
# Contain duplicates: Before 12937, after drop duplicates: 12927
#             duration                       host                   name  \
# 0            Session           healthgrades.com                  _vapi
# 1           365 days  partners.healthgrades.com         OptanonConsent
# 2      a few seconds           healthgrades.com    _dc_gtm_UA-xxxxxxxx
# 3       2914169 days  partners.healthgrades.com           eupubconsent
# 4           365 days           healthgrades.com  OptanonAlertBoxClosed
# ...              ...                        ...                    ...
# 12932       390 days         yieldoptimizer.com                     ph
# 12933       390 days         yieldoptimizer.com                    dph
# 12934       390 days         yieldoptimizer.com                   gcma
# 12935       390 days         yieldoptimizer.com                   ckid
# 12936       390 days         yieldoptimizer.com                   rmxc
#
#       group_id              site  consent
# 0        C0001  healthgrades.com     True
# 1        C0001  healthgrades.com     True
# 2        C0001  healthgrades.com     True
# 3        C0001  healthgrades.com     True
# 4        C0001  healthgrades.com     True
# ...        ...               ...      ...
# 12932   SPD_BG   bestwestern.com    False
# 12933   SPD_BG   bestwestern.com    False
# 12934   SPD_BG   bestwestern.com    False
# 12935   SPD_BG   bestwestern.com    False
# 12936   SPD_BG   bestwestern.com    False
#
# [12927 rows x 6 columns]

# %%
cookielist_sites = sorted(site_prefs.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert site_prefs.site.nunique() == n_cookielist_sites
print("Sites with cookie list:", n_cookielist_sites, cookielist_sites)
# Out:
# Sites with cookie list: 83 ['accorhotels.com', 'adtelligent.com', 'apachefriends.org', 'behance.net', 'bestwestern.com', 'biomedcentral.com', 'bitnami.com', 'bodybuilding.com', 'britishcouncil.org', 'callofduty.com', 'canon.com', 'cell.com', 'chanel.com', 'christies.com', 'cloudflare.com', 'cnet.com', 'commonsensemedia.org', 'corel.com', 'digicert.com', 'digitalspy.com', 'documentforce.com', 'download.com', 'elsevier.com', 'elsevierhealth.com', 'exacttarget.com', 'exoclick.com', 'fairmont.com', 'fendi.com', 'force.com', 'gamespot.com', 'glassdoor.co.in', 'glassdoor.com', 'goal.com', 'healthgrades.com', 'home.kpmg', 'hotjar.com', 'irishtimes.com', 'kpmg.com', 'magento.com', 'mango.com', 'marketo.com', 'mcdonalds.com', 'media.net', 'mendeley.com', 'metacritic.com', 'myportfolio.com', 'nature.com', 'netflix.com', 'news24.com', 'nflxvideo.net', 'oclc.org', 'onetrust.com', 'pardot.com', 'payoneer.com', 'pendo.io', 'rapidssl.com', 'redbull.com', 'rte.ie', 'salesforce.com', 'scientificamerican.com', 'seagate.com', 'soundcloud.com', 'spglobal.com', 'springerlink.com', 'ssrn.com', 'statista.com', 'supersonic.com', 'supersonicads.com', 'thawte.com', 'thelancet.com', 'trustpilot.com', 'tvguide.com', 'typekit.com', 'unity.com', 'unity3d.com', 'urbanairship.com', 'verisign.com', 'vmware.com', 'walkme.com', 'warnerbros.com', 'worldoftanks.eu', 'zapier.com', 'zdnet.com']

# %%
raw_prerej_sent_cookies_file = data_dir / 'raw_prerej_sent_cookies.parquet'
if raw_prerej_sent_cookies_file.exists():
    raw_prerej_sent_cookies = pd.read_parquet(raw_prerej_sent_cookies_file)
else:
    raw_postrej_sent_cookies = parallel_read_prerej_sent_cookies(data_dir)
    raw_postrej_sent_cookies.to_parquet(raw_prerej_sent_cookies_file); print(f"Written to {raw_prerej_sent_cookies_file}")

raw_prerej_sent_cookies.head(3)
# Out:
#          domain       expires  httpOnly            name path sameSite  secure  \
# 0  .siemens.com  1.651627e+09     False  OptanonConsent    /     None    True
# 1  .siemens.com  1.651627e+09     False  OptanonConsent    /     None    True
# 2  .siemens.com  1.651627e+09     False  OptanonConsent    /     None    True
#
#                                                value  \
# 0  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 1  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 2  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
#
#                                          request_url         site  \
# 0  https://www.siemens.com/js/chunk-4d7832bc.7be6...  siemens.com
# 1  https://www.siemens.com/img/arrow_right_black....  siemens.com
# 2    https://www.siemens.com/locales/en-newhome.json  siemens.com
#
#    load_start_time  load_end_time
# 0     1.620091e+09   1.620091e+09
# 1     1.620091e+09   1.620091e+09
# 2     1.620091e+09   1.620091e+09

# %%
prerej_sent_cookies = raw_prerej_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
prerej_br_cookies = prerej_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site', 'value']].drop_duplicates()

# %%
print(f"Num raw captured cookies: {len(raw_prerej_sent_cookies)}")
print(f"Num unique captured cookies: {len(prerej_sent_cookies)}")
print(f"Num unique browser cookies: {len(prerej_br_cookies)}")
# Out:
# Num raw captured cookies: 44861
# Num unique captured cookies: 44861
# Num unique browser cookies: 6707

# %% [markdown]
# ## Analyze cookies compliance

# %%
optanons = prerej_br_cookies[prerej_br_cookies.name == 'OptanonConsent'].copy()

# %%
def get_cookie_consent_groups(consent_cookie_val):
    try:
        return OptanonConsentCookie(consent_cookie_val).get_group_consent()
    except Exception as e:
        print(f"Error decoding {consent_cookie_val} {e}")
    return {}
optanons['consent_groups'] = optanons.value.map(get_cookie_consent_groups)
optanons
# Out:
# Error decoding isIABGlobal=false&datestamp=Mon+May+03+2021+21%3A28%3A04+GMT-0400+(Eastern+Daylight+Time)&version=6.7.0&hosts=&consentId=aaadbed7-a6e8-4561-8e50-4d50b53ac35b&interactionCount=0&landingPath=https%3A%2F%2Fwww.icims.com%2F argument of type 'NoneType' is not iterable
#                      domain       expires            name path sameSite  \
# 0              .siemens.com  1.651627e+09  OptanonConsent    /     None
# 404         .bonappetit.com  1.651627e+09  OptanonConsent    /     None
# 609         .callofduty.com  1.651628e+09  OptanonConsent    /      Lax
# 1069        .www.akamai.com  1.651628e+09  OptanonConsent    /      Lax
# 1479    .britishcouncil.org  1.651628e+09  OptanonConsent    /      Lax
# ...                     ...           ...             ...  ...      ...
# 43151             .self.com  1.651628e+09  OptanonConsent    /     None
# 43224     .bodybuilding.com  1.651628e+09  OptanonConsent    /      Lax
# 43765  .www.instructure.com  1.651628e+09  OptanonConsent    /      Lax
# 44023         .broadcom.com  1.651628e+09  OptanonConsent    /      Lax
# 44771       .sendinblue.com  1.651628e+09  OptanonConsent    /      Lax
#
#        secure                site  \
# 0        True         siemens.com
# 404      True      bonappetit.com
# 609     False      callofduty.com
# 1069    False          akamai.com
# 1479    False  britishcouncil.org
# ...       ...                 ...
# 43151    True            self.com
# 43224   False    bodybuilding.com
# 43765   False     instructure.com
# 44023   False        broadcom.com
# 44771   False      sendinblue.com
#
#                                                    value  \
# 0      isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 404    isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 609    isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 1069   isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 1479   isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# ...                                                  ...
# 43151  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 43224  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 43765  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 44023  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 44771  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
#
#                                           consent_groups
# 0      {'C0001': True, 'C0002': False, 'C0003': False...
# 404    {'C0001': True, 'C0005': True, 'C0003': True, ...
# 609         {'1': True, '2': True, '3': True, '4': True}
# 1069   {'C0001': True, 'C0002': True, 'C0003': True, ...
# 1479   {'C0001': True, 'C0002': True, 'C0003': False,...
# ...                                                  ...
# 43151  {'C0001': True, 'C0005': True, 'C0003': True, ...
# 43224  {'C0001': True, 'C0003': False, 'C0002': False...
# 43765  {'C0002': True, 'C0004': True, 'C0003': True, ...
# 44023       {'1': True, '3': True, '2': True, '4': True}
# 44771  {'C0001': True, 'C0003': False, 'C0002': False...
#
# [95 rows x 9 columns]

# %%
prestore_sites = set(optanons.site.unique())
assert len(optanons) == len(prestore_sites), "There is some sites with duplicate OptanonConsent cookies"
print(f"Num sites with pre-stored pref cookie {len(prestore_sites)}")
# Out:
# Num sites with pre-stored pref cookie 95

# %%
def read_scan_result(site_dir):
    site_name = site_dir.name
    scan_file = site_dir / 'scan.json'
    if not scan_file.exists():
        return {}
    return json.loads(scan_file.read_text())

def read_scan_results(site_dirs):
    scans = []
    for site_dir in site_dirs:
        scans.append(read_scan_result(site_dir))
    return pd.DataFrame(scans)

raw_scans = read_scan_results(site_dirs)
scans = raw_scans[ ~raw_scans.failed.isna() & ~raw_scans['category'].isna() ]
scans = scans[ scans.failed == False ]
scans = scans.explode('category').reset_index(drop=True)
print("Number of domains:", scans.domain.nunique())
scans = scans.join(pd.DataFrame(scans['category'].tolist()))
scans
# Out:
# Number of domains: 206
#                domain  failed failed_reason pref_menu_type  \
# 0         siemens.com   False          None      accordion
# 1         siemens.com   False          None      accordion
# 2         siemens.com   False          None      accordion
# 3         siemens.com   False          None      accordion
# 4    healthgrades.com   False          None            tab
# ..                ...     ...           ...            ...
# 790   bestwestern.com   False          None            tab
# 791    sendinblue.com   False          None            tab
# 792    sendinblue.com   False          None            tab
# 793    sendinblue.com   False          None            tab
# 794    sendinblue.com   False          None            tab
#
#                                               category      id  \
# 0    {'id': 'C0001', 'name': 'Strictly necessary co...   C0001
# 1    {'id': 'C0002', 'name': 'Performance cookies',...   C0002
# 2    {'id': 'C0003', 'name': 'Functionality cookies...   C0003
# 3    {'id': 'C0004', 'name': 'Marketing cookies', '...   C0004
# 4    {'id': 'C0001', 'name': 'Strictly Necessary Co...   C0001
# ..                                                 ...     ...
# 790  {'id': 'SPD_BG', 'name': 'Other Third Party Co...  SPD_BG
# 791  {'id': 'C0001', 'name': 'Strictly Necessary Co...   C0001
# 792  {'id': 'C0003', 'name': 'Functional Cookies', ...   C0003
# 793  {'id': 'C0002', 'name': 'Performance Cookies',...   C0002
# 794  {'id': 'C0004', 'name': 'Targeting Cookies', '...   C0004
#
#                            name    prev_status     cur_status
# 0    Strictly necessary cookies  always_active  always_active
# 1           Performance cookies          false          false
# 2         Functionality cookies          false          false
# 3             Marketing cookies          false          false
# 4    Strictly Necessary Cookies    unavailable    unavailable
# ..                          ...            ...            ...
# 790   Other Third Party Cookies           true          false
# 791  Strictly Necessary Cookies    unavailable    unavailable
# 792          Functional Cookies           true          false
# 793         Performance Cookies           true          false
# 794           Targeting Cookies           true          false
#
# [795 rows x 9 columns]

# %%
# scans[scans.domain == 'eonline.com']

# %%
no_choice_domains = []
for domain, group in scans.groupby('domain'):
    nvalues = group['prev_status'].nunique()
    if nvalues == 1 and group['prev_status'].unique()[0] in ['unavailable', 'always_active']: # , f"{group['prev_status'].unique()=} {domain=}"
        no_choice_domains.append(domain)
n_no_choices = len(no_choice_domains)
domains = set(scans.domain.unique())
n_domains = len(domains)
print(f"Number extracted domains: {n_domains}")
print(f"Number of no choice domains: {n_no_choices} ({n_no_choices / n_domains * 100:.2f}%)")
# Out:
# Number extracted domains: 206
# Number of no choice domains: 48 (23.30%)

# %%
# assert prestore_sites.issubset(domains)
sites_with_prestore = prestore_sites.intersection(domains)
print(f"Num sites with prestore cookies:", len(sites_with_prestore))
# Out:
# Num sites with prestore cookies: 92

# %%
# find domains prestore all accept:
def are_all_accept(consent_groups):
    return all(val == True for val in consent_groups.values())
optanons['all_accept'] = optanons.consent_groups.map(are_all_accept)
optanons
# Out:
#                      domain       expires            name path sameSite  \
# 0              .siemens.com  1.651627e+09  OptanonConsent    /     None
# 404         .bonappetit.com  1.651627e+09  OptanonConsent    /     None
# 609         .callofduty.com  1.651628e+09  OptanonConsent    /      Lax
# 1069        .www.akamai.com  1.651628e+09  OptanonConsent    /      Lax
# 1479    .britishcouncil.org  1.651628e+09  OptanonConsent    /      Lax
# ...                     ...           ...             ...  ...      ...
# 43151             .self.com  1.651628e+09  OptanonConsent    /     None
# 43224     .bodybuilding.com  1.651628e+09  OptanonConsent    /      Lax
# 43765  .www.instructure.com  1.651628e+09  OptanonConsent    /      Lax
# 44023         .broadcom.com  1.651628e+09  OptanonConsent    /      Lax
# 44771       .sendinblue.com  1.651628e+09  OptanonConsent    /      Lax
#
#        secure                site  \
# 0        True         siemens.com
# 404      True      bonappetit.com
# 609     False      callofduty.com
# 1069    False          akamai.com
# 1479    False  britishcouncil.org
# ...       ...                 ...
# 43151    True            self.com
# 43224   False    bodybuilding.com
# 43765   False     instructure.com
# 44023   False        broadcom.com
# 44771   False      sendinblue.com
#
#                                                    value  \
# 0      isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 404    isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 609    isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 1069   isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 1479   isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# ...                                                  ...
# 43151  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 43224  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 43765  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 44023  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
# 44771  isIABGlobal=false&datestamp=Mon+May+03+2021+21...
#
#                                           consent_groups  all_accept
# 0      {'C0001': True, 'C0002': False, 'C0003': False...       False
# 404    {'C0001': True, 'C0005': True, 'C0003': True, ...        True
# 609         {'1': True, '2': True, '3': True, '4': True}        True
# 1069   {'C0001': True, 'C0002': True, 'C0003': True, ...        True
# 1479   {'C0001': True, 'C0002': True, 'C0003': False,...       False
# ...                                                  ...         ...
# 43151  {'C0001': True, 'C0005': True, 'C0003': True, ...        True
# 43224  {'C0001': True, 'C0003': False, 'C0002': False...       False
# 43765  {'C0002': True, 'C0004': True, 'C0003': True, ...        True
# 44023       {'1': True, '3': True, '2': True, '4': True}        True
# 44771  {'C0001': True, 'C0003': False, 'C0002': False...       False
#
# [95 rows x 10 columns]

# %%
all_accept_domains = set(optanons[optanons.all_accept].site.unique())
print("Num all accept domains:", len(all_accept_domains))
# Out:
# Num all accept domains: 77

# %%
choice_domains = set(scans.domain.unique()) - set(no_choice_domains)
print(f"Num domains with choices: {len(choice_domains)}")

sites_with_choice_preaccept = choice_domains.intersection(all_accept_domains)
print(f"Num domains with choices but prestore all accept: {len(sites_with_choice_preaccept)}")
# Out:
# Num domains with choices: 158
# Num domains with choices but prestore all accept: 53
