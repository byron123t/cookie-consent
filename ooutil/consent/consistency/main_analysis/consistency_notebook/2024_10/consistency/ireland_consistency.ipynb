# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from consent.consistency.comply_util import site_to_contras, get_comply
from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import get_scan_root_dir, get_scan_dirs # , FIG_DIR uncomment to save fig.
from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cur_set = '0k_20k' # '20k_100k'
overwrite = True
SCAN_ROOT_DIR = get_scan_root_dir('ireland')
SCAN_DIRS = [SCAN_ROOT_DIR / f'pref_menu_scan_{cur_set}']
# SCAN_DIRS = get_scan_dirs('us')[:]
output_suffix = '_' + cur_set # '0k_20k'  # '20k_100k' #'60k_80k' # '40k_60k' # # '100k_200k'; done: '20k_40k' '0k_20k'
print('Scan root dir:', SCAN_ROOT_DIR)
print('Output suffix:', output_suffix)
print('Scan dirs:', SCAN_DIRS)
# Out:
# Scan root dir: /mnt/sdd/ducbui/projects/data2/consent/2024-10-11
# Output suffix: _0k_20k
# Scan dirs: [PosixPath('/mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k')]

# %%
# Get cookie prefs = cookie decls + prefs
cookie_prefs_file = SCAN_ROOT_DIR / f'cookie_prefs{output_suffix}.parquet'

if not cookie_prefs_file.exists() or overwrite:
    save_cookie_decls_file = SCAN_ROOT_DIR / f'cookie_decls{output_suffix}.parquet'
    print(f'To save to {save_cookie_decls_file}')
    cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS, save_cookie_decls_file)  # took 2.3min for top 50k-site scan
    cookie_prefs.to_parquet(cookie_prefs_file); print(f'Written to {cookie_prefs_file}')
else:
    cookie_prefs = pd.read_parquet(cookie_prefs_file)
cookie_prefs.head()
# TODO: add log_file_checker
# Out:
# To save to /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/cookie_decls_0k_20k.parquet
# WARNING: Consent cookie not found siteground.eu
# WARNING: Consent cookie not found kriesi.at
# WARNING: Found non-unique (not found or >1 instance) apc.com
# WARNING: Consent cookie not found bepress.com
# WARNING: Consent cookie not found mailspamprotection.com
# WARNING: Consent cookie not found siteground.com
# WARNING: Consent cookie not found siteground.asia
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/cloudinary.com/consent_resources.json: malform_resp Failed to extract cookie data from cc.js: invalid syntax (<unknown>, line 1)
# File hivestreaming.com consent_resources.json has no data
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/movavi.com/consent_resources.json: malform_resp Failed to extract cookie data from cc.js: invalid syntax (<unknown>, line 1)
# https://cdn.cookielaw.org/consent/03b96273-0ebc-43cb-8885-cdfaeadad5b9/ea63918d-8f11-4be4-8159-b197f44513ee/en.json WARNING: Cookie list has session cookie but duration > 0
# File sumup.com consent_resources.json has no data
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/gitlab.com/consent_resources.json:consent_js not supported yet.
# https://cdn-ukwest.onetrust.com/consent/86f42b6d-7a31-469c-804c-319643173d42/018dfc06-483a-7d19-9eb2-a34125b8679d/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/gitlab.io/consent_resources.json: consent_js not supported yet.
# https://cdn.cookielaw.org/consent/c570eb43-1169-4222-914c-38a09bd70ca0/018de4cc-f70c-7787-a3c1-7bbec76b67f4/en.json WARNING: Cookie list has session cookie but duration > 0
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/cookie_decls_0k_20k.parquet
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/cookie_prefs_0k_20k.parquet
#                    name           domain duration category_id  \
# 0         .AxcmXFaxAuth  fax.nextiva.com   0 days       C0001
# 1               __cf_bm      nextiva.com   0 days       C0001
# 2               _ce.cch      nextiva.com  Session       C0001
# 3                    ao  sso.nextiva.com   0 days       C0001
# 4  autolaunch_triggered  sso.nextiva.com   0 days       C0001
#
#                      category   consent_mode         site  lib_name  \
# 0  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 1  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 2  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 3  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 4  Strictly Necessary Cookies  always active  nextiva.com  onetrust
#
#   pattern_name consent
# 0      en.json    True
# 1      en.json    True
# 2      en.json    True
# 3      en.json    True
# 4      en.json    True

# %%
print("Found cookie libraries:")
cookie_prefs[['site', 'lib_name']].drop_duplicates().lib_name.value_counts()
# Out:
# Found cookie libraries:
# lib_name
# onetrust     1297
# cookiebot     147
# Name: count, dtype: int64

# %%
cookielist_sites = sorted(cookie_prefs.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert cookie_prefs.site.nunique() == n_cookielist_sites
n=10
print("Sites with cookie prefs:", n_cookielist_sites, f', first {n} sites:' , cookielist_sites[:n])
# Out:
# Sites with cookie prefs: 1444 , first 10 sites: ['2k.com', '2ksports.com', 'aao.org', 'aber.ac.uk', 'abercrombie.com', 'acast.com', 'accedo.tv', 'accenture.com', 'accor.com', 'accorhotels.com']

# %%
site_to_libname = {row['site']: row['lib_name'] for row in cookie_prefs[['site', 'lib_name']].drop_duplicates().to_dict('records')}

# %%
# Quick checking the cookie declaration naming
print(len(cookie_prefs[cookie_prefs.name.str.endswith('#')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('xxx')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('XXX')]) / len(cookie_prefs))
cookie_prefs[cookie_prefs.name.str.endswith('#')]
# Out:
# 0.015672232137056555
# 0.0296859056914546
# 0.0028470648481119564
#                  name                          domain    duration category_id  \
# 101   visitor_id#####                  go.nextiva.com    364 days       C0004
# 24   _gd#############                        j.6sc.co    730 days       C0002
# 30   _gd#############                  www.wework.com    730 days       C0003
# 34   _gd#############            cdnjs.cloudflare.com    730 days       C0003
# 44       AMP_unsent_#  commercial.cdn.aws.placeit.net  Persistent  statistics
# ..                ...                             ...         ...         ...
# 140   visitor_id#####               click.outreach.io   3649 days           4
# 147   visitor_id#####                   pi.pardot.com   3649 days           4
# 170   visitor_id#####                      pardot.com   3649 days           4
# 172  _gd#############                        j.6sc.co    729 days           4
# 220  _gd#############            cdnjs.cloudflare.com    729 days           4
#
#                 category consent_mode         site   lib_name pattern_name  \
# 101    Targeting Cookies     inactive  nextiva.com   onetrust      en.json
# 24   Performance Cookies     inactive   wework.com   onetrust      en.json
# 30    Functional Cookies     inactive   wework.com   onetrust      en.json
# 34    Functional Cookies     inactive   wework.com   onetrust      en.json
# 44            statistics         None  placeit.net  cookiebot        cc.js
# ..                   ...          ...          ...        ...          ...
# 140    Targeting Cookies     inactive  outreach.io   onetrust      en.json
# 147    Targeting Cookies     inactive  outreach.io   onetrust      en.json
# 170    Targeting Cookies     inactive  outreach.io   onetrust      en.json
# 172    Targeting Cookies     inactive  outreach.io   onetrust      en.json
# 220    Targeting Cookies     inactive  outreach.io   onetrust      en.json
#
#     consent
# 101   False
# 24    False
# 30    False
# 34    False
# 44    False
# ..      ...
# 140   False
# 147   False
# 170   False
# 172   False
# 220   False
#
# [4101 rows x 10 columns]

# %%
# # Distribution of errors
# print("Libs in failed-to-crawl sites")
# errors.consent_lib_name.value_counts()
# from ooutil.df_util import expand_dict_col
# ot_errs = errors[errors.consent_lib_name == 'onetrust']
# errors_dict = pd.DataFrame(ot_errs.error.tolist()).explode('reason')
# # Uncomment to show
# # errors_dict.reason.value_counts()

# %% [markdown]
# # Main analysis

# %%
# import sys; import importlib; importlib.reload(sys.modules['consent.data.pref_menu_scan.postrej_cookie_reader'])
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cookies_cache_file = SCAN_ROOT_DIR / f'scan{output_suffix}.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not cookies_cache_file.exists() or overwrite:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")
else:
    sent_cookies = pd.read_parquet(cookies_cache_file)

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Unmatch url and consent cookie domain: page_url='https://www.wework.cn/zh-CN/city/nanjing/?lang=en-us' consent_cookie.cookie['domain']='.www.wework.com' consent_cookie.cookie['path']='/' wework.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, renfe.com/postrej_0.har.xz not have cookie OptanonConsent of .renfe.com on path /
# Post rej cookie not contain consent cookie, skrill.com/postrej_0.har.xz not have cookie OptanonConsent of .skrill.com on path /
# Post rej cookie not contain consent cookie, loggly.com/postrej_0.har.xz not have cookie OptanonConsent of .www.loggly.com on path /
# Post rej cookie not contain consent cookie, lidl.com/postrej_0.har.xz not have cookie OptanonConsent of .lidl.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/pexels.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/pexels.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/pexels.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/pexels.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, arcspire.io/postrej_0.har.xz not have cookie CookieConsent of www.arcspire.io on path /
# Post rej cookie not contain consent cookie, warnerbros.com/postrej_0.har.xz not have cookie OptanonConsent of .warnerbros.com on path /
# Post rej cookie not contain consent cookie, barcap.com/postrej_0.har.xz not have cookie OptanonConsent of .www.ib.barclays on path /
# Post rej cookie not contain consent cookie, twoplayergames.org/postrej_0.har.xz not have cookie CookieConsent of www.twoplayergames.org on path /
# Post rej cookie not contain consent cookie, jixie.io/postrej_0.har.xz not have cookie OptanonConsent of .accenture.com on path /
# Post rej cookie not contain consent cookie, moonactive.net/postrej_0.har.xz not have cookie OptanonConsent of .moonactive.com on path /
# Post rej cookie not contain consent cookie, cloudinary.com/postrej_0.har.xz not have cookie CookieConsent of cloudinary.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/moneris.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, samknows.com/postrej_0.har.xz not have cookie OptanonConsent of .samknows.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/on24.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, booksy.com/postrej_2.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, booksy.com/postrej_5.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, booksy.com/postrej_1.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, booksy.com/postrej_0.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, booksy.com/postrej_3.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, booksy.com/postrej_4.har.xz not have cookie CookieConsent of booksy.com on path /
# Post rej cookie not contain consent cookie, vewd.com/postrej_0.har.xz not have cookie OptanonConsent of .tivo.com on path /
# Domain path mismatch: .www.pwc.com domain's path /us not match url https://www.pwc.com/lr/en/
# Unmatch url and consent cookie domain: page_url='https://www.pwc.com/lr/en/' consent_cookie.cookie['domain']='.www.pwc.com' consent_cookie.cookie['path']='/us' pwc.com/postrej_5.har.xz
# Domain path mismatch: .www.pwc.com domain's path /us not match url https://www.pwc.com/cr/es/
# Unmatch url and consent cookie domain: page_url='https://www.pwc.com/cr/es/' consent_cookie.cookie['domain']='.www.pwc.com' consent_cookie.cookie['path']='/us' pwc.com/postrej_3.har.xz
# Domain path mismatch: .www.pwc.com domain's path /us not match url https://www.pwc.com/bb/en/
# Unmatch url and consent cookie domain: page_url='https://www.pwc.com/bb/en/' consent_cookie.cookie['domain']='.www.pwc.com' consent_cookie.cookie['path']='/us' pwc.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, volvocars.com/postrej_5.har.xz not have cookie OptanonConsent of .www.volvocars.com on path /us
# Post rej cookie not contain consent cookie, volvocars.com/postrej_0.har.xz not have cookie OptanonConsent of .www.volvocars.com on path /us
# Post rej cookie not contain consent cookie, dexcom.com/postrej_0.har.xz not have cookie OptanonConsent of .dexcom.com on path /
# Post rej cookie not contain consent cookie, turnitin.com/postrej_0.har.xz not have cookie OptanonConsent of .turnitin.com on path /
# Post rej cookie not contain consent cookie, sheffield.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .sheffield.ac.uk on path /
# Post rej cookie not contain consent cookie, phenompeople.com/postrej_0.har.xz not have cookie OptanonConsent of .phenom.com on path /
# Domain path mismatch: .klarna.com domain's path /us/ not match url https://app.klarna.com/login?market=us
# Unmatch url and consent cookie domain: page_url='https://app.klarna.com/login?market=us' consent_cookie.cookie['domain']='.klarna.com' consent_cookie.cookie['path']='/us/' usehero.com/postrej_5.har.xz
# Domain path mismatch: .klarna.com domain's path /us/ not match url https://www.klarna.com/ie/
# Unmatch url and consent cookie domain: page_url='https://www.klarna.com/ie/' consent_cookie.cookie['domain']='.klarna.com' consent_cookie.cookie['path']='/us/' usehero.com/postrej_3.har.xz
# Domain path mismatch: .klarna.com domain's path /us/ not match url https://portal.klarna.com/products/signup/basic-info?utm_source=klarnacom&utm_campaign=/us/business/marketing-solutions/&utm_medium=referral&utm_content=klarnacom-link
# Unmatch url and consent cookie domain: page_url='https://portal.klarna.com/products/signup/basic-info?utm_source=klarnacom&utm_campaign=/us/business/marketing-solutions/&utm_medium=referral&utm_content=klarnacom-link' consent_cookie.cookie['domain']='.klarna.com' consent_cookie.cookie['path']='/us/' usehero.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, sonymobile.com/postrej_0.har.xz not have cookie OptanonConsent of .electronics.sony.com on path /
# Unmatch url and consent cookie domain: page_url='https://pentaho.com/download/' consent_cookie.cookie['domain']='.www.hitachivantara.com' consent_cookie.cookie['path']='/' hds.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.salesforce.com/privacy/products/?bc=HB' consent_cookie.cookie['domain']='.quip.com' consent_cookie.cookie['path']='/' quip.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, se.com/postrej_0.har.xz not have cookie OptanonConsent of .se.com on path /
# Post rej cookie not contain consent cookie, accenture.com/postrej_0.har.xz not have cookie OptanonConsent of .accenture.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/movavi.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, schneider-electric.com/postrej_0.har.xz not have cookie OptanonConsent of .se.com on path /
# Post rej cookie not contain consent cookie, gimbal.com/postrej_5.har.xz not have cookie OptanonConsent of .infillion.com on path /
# Unmatch url and consent cookie domain: page_url='https://shop.siriusxm.com/' consent_cookie.cookie['domain']='.www.siriusxm.com' consent_cookie.cookie['path']='/' siriusxm.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, siriusxm.com/postrej_0.har.xz not have cookie OptanonConsent of .www.siriusxm.com on path /
# Unmatch url and consent cookie domain: page_url='https://investors.epam.com/events/default.aspx' consent_cookie.cookie['domain']='.www.epam.com' consent_cookie.cookie['path']='/' epam.com/postrej_5.har.xz
# Domain path mismatch: .verizon.com domain's path /business not match url https://www.verizon.com/about/our-company
# Unmatch url and consent cookie domain: page_url='https://www.verizon.com/about/our-company' consent_cookie.cookie['domain']='.verizon.com' consent_cookie.cookie['path']='/business' cybertrust.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, cybertrust.com/postrej_0.har.xz not have cookie OptanonConsent of .verizon.com on path /business
# Post rej cookie not contain consent cookie, ic.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .imperial.ac.uk on path /
# Unmatch url and consent cookie domain: page_url='https://www.freehandapp.com/' consent_cookie.cookie['domain']='.invisionapp.com' consent_cookie.cookie['path']='/' invisionapp.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, eyeo.com/postrej_0.har.xz not have cookie OptanonConsent of .eyeo.com on path /
# Post rej cookie not contain consent cookie, penguin.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .penguin.co.uk on path /
# Post rej cookie not contain consent cookie, questionpro.com/postrej_0.har.xz not have cookie OptanonConsent of .questionpro.com on path /
# Post rej cookie not contain consent cookie, mancity.com/postrej_0.har.xz not have cookie OptanonConsent of .mancity.com on path /
# Post rej cookie not contain consent cookie, payoneer.com/postrej_0.har.xz not have cookie OptanonConsent of .payoneer.com on path /
# Domain path mismatch: .www.basf.com domain's path /us/ not match url https://www.basf.com/global/en/who-we-are/sustainability/we-produce-safely-and-efficiently/environmental-protection/resources-and-ecosystems/engagement-against-plastic-waste/Alliance-to-end-plastic-waste
# Unmatch url and consent cookie domain: page_url='https://www.basf.com/global/en/who-we-are/sustainability/we-produce-safely-and-efficiently/environmental-protection/resources-and-ecosystems/engagement-against-plastic-waste/Alliance-to-end-plastic-waste' consent_cookie.cookie['domain']='.www.basf.com' consent_cookie.cookie['path']='/us/' basf.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://academy.mentimeter.com/' consent_cookie.cookie['domain']='.www.mentimeter.com' consent_cookie.cookie['path']='/' mentimeter.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, yoti.com/postrej_0.har.xz not have cookie OptanonConsent of www.yoti.com on path /
# Post rej cookie not contain consent cookie, bromium-online.com/postrej_0.har.xz not have cookie OptanonConsent of .hpwolf.com on path /
# Post rej cookie not contain consent cookie, bromium-online.com/postrej_3.har.xz not have cookie OptanonConsent of .hpwolf.com on path /
# Post rej cookie not contain consent cookie, ucc.ie/postrej_0.har.xz not have cookie OptanonConsent of .www.ucc.ie on path /
# Post rej cookie not contain consent cookie, hidemyass.com/postrej_0.har.xz not have cookie OptanonConsent of .hidemyass.com on path /
# Post rej cookie not contain consent cookie, qualys.eu/postrej_0.har.xz not have cookie CookieConsent of www.qualys.com on path /
# Post rej cookie not contain consent cookie, toasttab.com/postrej_0.har.xz not have cookie OptanonConsent of .pos.toasttab.com on path /
# Post rej cookie not contain consent cookie, vfsglobal.com/postrej_0.har.xz not have cookie OptanonConsent of .vfsglobal.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/polycom.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/polycom.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/resources/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/about/leadership/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/product/enterprise/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/mp/likert-scale/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://auth-us.surveymonkey.com/login?state=hKFo2SA0LXVFVUJDMnRQWGlzaUZQYkQ4ekNuYS1MeGQ3R2FsZaFupWxvZ2luo3RpZNkgbkRrLU54WnhHNEZMblNGS3I2UEg0Nmg5c194V19CN1mjY2lk2SBzQTM0RFVtUUE0RUlySkM3cTlRdVBDZjFUNzc4QmZMdg&client=sA34DUmQA4EIrJC7q9QuPCf1T778BfLv&protocol=oauth2&prompt=login&scope=openid%20profile%20email&redirect_uri=https%3A%2F%2Fwww.surveymonkey.com%2Flogin%2Fcallback&ut_ctatext=Sign%20up%20free&ut_source=research_net&ut_source3=logged-out-header&ui_locales=en&sm.show=sign-up&sm.locale=en&sm.country=IE&sm.subdomain=www&sm.social_popup=false&response_type=code&response_mode=query&nonce=MEtQVFhmdmg0WWJ3Y1AwT0s5N2cwQmo2NXdZNH5Bb0VXandqWlpxWVZUdA%3D%3D&code_challenge=QiCekdPXHWSsV2NcCCMxrZ8YltsOkS1GsOWTB0Y5j1s&code_challenge_method=S256&auth0Client=eyJuYW1lIjoiYXV0aDAtc3BhLWpzIiwidmVyc2lvbiI6IjIuMC4xIn0%3D#/sign-up' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_4.har.xz
# Post rej cookie not contain consent cookie, networksolutions.com/postrej_0.har.xz not have cookie OptanonConsent of .networksolutions.com on path /
# Post rej cookie not contain consent cookie, tcs.com/postrej_0.har.xz not have cookie OptanonConsent of .tcs.com on path /
# Post rej cookie not contain consent cookie, imperial.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .imperial.ac.uk on path /
# Post rej cookie not contain consent cookie, siteground.eu/postrej_1.har.xz not have cookie CookieConsent of eu.siteground.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.siteground.com/' consent_cookie.cookie['domain']='eu.siteground.com' consent_cookie.cookie['path']='/' siteground.eu/postrej_0.har.xz
# Post rej cookie not contain consent cookie, cpanel.com/postrej_0.har.xz not have cookie CookieConsent of cpanel.net on path /
# Domain path mismatch: .sage.com domain's path /en-us/ not match url https://www.sage.com/pt-pt/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/pt-pt/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-us/' sage.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://eu.wargaming.net/id/signin/?next=%2Fid%2Fopenid%2F4320637557588803208%2F&trust_root=https%3A%2F%2Fworldoftanks.eu%2F' consent_cookie.cookie['domain']='.worldoftanks.eu' consent_cookie.cookie['path']='/' worldoftanks.eu/postrej_5.har.xz
# Post rej cookie not contain consent cookie, hyprmx.com/postrej_0.har.xz not have cookie OptanonConsent of .hyprmx.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/legalzoom.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, pingdom.com/postrej_0.har.xz not have cookie OptanonConsent of .www.pingdom.com on path /
# Post rej cookie not contain consent cookie, kodak.com/postrej_0.har.xz not have cookie OptanonConsent of .www.kodak.com on path /
# Domain path mismatch: .sage.com domain's path /en-za/ not match url https://www.sage.com/en-sg/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/en-sg/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-za/' sageone.co.za/postrej_1.har.xz
# Post rej cookie not contain consent cookie, kaercher.com/postrej_0.har.xz not have cookie OptanonConsent of .kaercher.com on path /int/
# Post rej cookie not contain consent cookie, cognizant.com/postrej_0.har.xz not have cookie OptanonConsent of .cognizant.com on path /
# Unmatch url and consent cookie domain: page_url='https://orion.com/redtail-university-2024' consent_cookie.cookie['domain']='.redtailtechnology.com' consent_cookie.cookie['path']='/' redtailtechnology.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, sanofi-synthelabo.com/postrej_0.har.xz not have cookie OptanonConsent of .www.sanofi.com on path /
# Post rej cookie not contain consent cookie, merck.com/postrej_0.har.xz not have cookie OptanonConsent of .merck.com on path /
# Domain path mismatch: .pitneybowes.com domain's path /us not match url https://www.pitneybowes.com/ie
# Unmatch url and consent cookie domain: page_url='https://www.pitneybowes.com/ie' consent_cookie.cookie['domain']='.pitneybowes.com' consent_cookie.cookie['path']='/us' pb.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, pb.com/postrej_0.har.xz not have cookie OptanonConsent of .pitneybowes.com on path /us
# Post rej cookie not contain consent cookie, purechat.com/postrej_0.har.xz not have cookie OptanonConsent of .purechat.com on path /
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/givesmart.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/givesmart.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://www.proximus.com/pxc/our-company/company.html' consent_cookie.cookie['domain']='.proximus.be' consent_cookie.cookie['path']='/' proximus.be/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://kriesi.at/' consent_cookie.cookie['domain']='themeforest.net' consent_cookie.cookie['path']='/' kriesi.at/postrej_0.har.xz
# Post rej cookie not contain consent cookie, smooch.io/postrej_0.har.xz not have cookie OptanonConsent of .www.zendesk.com on path /
# Post rej cookie not contain consent cookie, unaids.org/postrej_0.har.xz not have cookie CookieConsent of www.unaids.org on path /
# Post rej cookie not contain consent cookie, apc.com/postrej_2.har.xz not have cookie OptanonConsent of .apc.com on path /
# Post rej cookie not contain consent cookie, apc.com/postrej_5.har.xz not have cookie OptanonConsent of .apc.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.se.com/pt/pt/brands/apc/' consent_cookie.cookie['domain']='.apc.com' consent_cookie.cookie['path']='/' apc.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.se.com/pk/en/' consent_cookie.cookie['domain']='.apc.com' consent_cookie.cookie['path']='/' apc.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.se.com/africa/fr/brands/apc/' consent_cookie.cookie['domain']='.apc.com' consent_cookie.cookie['path']='/' apc.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.world.rugby/privacy-policy' consent_cookie.cookie['domain']='.rugbyworldcup.com' consent_cookie.cookie['path']='/' rugbyworldcup.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.world.rugby/cookies-policy' consent_cookie.cookie['domain']='.rugbyworldcup.com' consent_cookie.cookie['path']='/' rugbyworldcup.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://jobs.ashbyhq.com/sleeper' consent_cookie.cookie['domain']='.sleeper.com' consent_cookie.cookie['path']='/' sleeper.app/postrej_1.har.xz
# Domain path mismatch: .sage.com domain's path /en-us/ not match url https://www.sage.com/en-gb/sage-business-cloud/intacct/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/en-gb/sage-business-cloud/intacct/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-us/' intacct.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, sumologic.com/postrej_0.har.xz not have cookie OptanonConsent of .sumologic.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about' consent_cookie.cookie['domain']='.hightail.com' consent_cookie.cookie['path']='/' hightail.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, duosecurity.com/postrej_0.har.xz not have cookie OptanonConsent of .duo.com on path /
# Unmatch url and consent cookie domain: page_url='https://nielseniq.com/global/en/solutions/consumer-behavior-and-insights/' consent_cookie.cookie['domain']='.www.gfk.com' consent_cookie.cookie['path']='/' gfk.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://nielseniq.com/global/en/insights/success-story/2023/irobot-putting-intelligence-at-the-heart-of-business-strategy/' consent_cookie.cookie['domain']='.www.gfk.com' consent_cookie.cookie['path']='/' gfk.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://nielseniq.com/global/en/insights/analysis/2023/decoding-campaign-measurement-success-beyond-sales-metrics/' consent_cookie.cookie['domain']='.www.gfk.com' consent_cookie.cookie['path']='/' gfk.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://eab.app.box.com/s/ig1xoav1pag3q3af1k812bdthzfyhcwn' consent_cookie.cookie['domain']='.www.youvisit.com' consent_cookie.cookie['path']='/' youvisit.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.appily.com/virtual-college-tours?utm_source=referral&utm_medium=youvisit' consent_cookie.cookie['domain']='.www.youvisit.com' consent_cookie.cookie['path']='/' youvisit.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, fonts.com/postrej_0.har.xz not have cookie OptanonConsent of .www.fonts.com on path /
# Unmatch url and consent cookie domain: page_url='https://virtualexperience.kent.ac.uk/' consent_cookie.cookie['domain']='www.kent.ac.uk' consent_cookie.cookie['path']='/' kent.ac.uk/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://bepress.com/' consent_cookie.cookie['domain']='.www.elsevier.com' consent_cookie.cookie['path']='/' bepress.com/postrej_0.har.xz
# Post rej cookie not contain consent cookie, fonts.net/postrej_0.har.xz not have cookie OptanonConsent of .www.fonts.com on path /
# Unmatch url and consent cookie domain: page_url='https://trust.salesforce.com/' consent_cookie.cookie['domain']='.tableau.com' consent_cookie.cookie['path']='/' tableau.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_2.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_1.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_0.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, sho.com/postrej_0.har.xz not have cookie OptanonConsent of .paramountpluswithshowtime.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/sunpower.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/pk/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/pk/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, kpmg.com/postrej_0.har.xz not have cookie OptanonConsent of .kpmg.com on path /xx
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/tt/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/tt/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_3.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/al/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/al/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, tide.co/postrej_0.har.xz not have cookie OptanonConsent of .www.tide.co on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/lavasoft.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, lavasoft.com/postrej_0.har.xz not have cookie OptanonConsent of .adaware.com on path /
# Post rej cookie not contain consent cookie, kaspersky-labs.com/postrej_0.har.xz not have cookie CookieConsent of usa.kaspersky.com on path /
# Unmatch url and consent cookie domain: page_url='https://id.atlassian.com/login?application=bitbucket&continue=https%3A%2F%2Fbitbucket.org%2Faccount%2Fsignin%2F%3Fnext%3D%252F%26redirectCount%3D1' consent_cookie.cookie['domain']='.bitbucket.org' consent_cookie.cookie['path']='/' bitbucket.org/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://jobs.ashbyhq.com/sleeper' consent_cookie.cookie['domain']='.sleeper.com' consent_cookie.cookie['path']='/' sleeper.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, ucd.ie/postrej_0.har.xz not have cookie OptanonConsent of .ucd.ie on path /
# Post rej cookie not contain consent cookie, ebscohost.com/postrej_4.har.xz not have cookie OptanonConsent of .ebsco.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.altium365.com/customer-success/converting-mundane-masterpiece-karcher' consent_cookie.cookie['domain']='.altium.com' consent_cookie.cookie['path']='/' altium.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/rosettastone.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, platformsh.site/postrej_0.har.xz not have cookie OptanonConsent of .platform.sh on path /
# Post rej cookie not contain consent cookie, pardot.com/postrej_0.har.xz not have cookie OptanonConsent of .salesforce.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_1.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_0.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_3.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_4.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, mailspamprotection.com/postrej_1.har.xz not have cookie CookieConsent of eu.siteground.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.siteground.com/' consent_cookie.cookie['domain']='eu.siteground.com' consent_cookie.cookie['path']='/' mailspamprotection.com/postrej_0.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/hp.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/hp.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.shudder.com/tivo' consent_cookie.cookie['domain']='.tivo.com' consent_cookie.cookie['path']='/' tivo.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, qualys.com/postrej_0.har.xz not have cookie CookieConsent of www.qualys.com on path /
# Unmatch url and consent cookie domain: page_url='https://lp.provenexpert.com/en/provenexpert-demo-tour' consent_cookie.cookie['domain']='www.provenexpert.com' consent_cookie.cookie['path']='/' provenexpert.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, siteground.biz/postrej_0.har.xz not have cookie CookieConsent of eu.siteground.com on path /
# Post rej cookie not contain consent cookie, zopim.com/postrej_0.har.xz not have cookie OptanonConsent of .www.zendesk.com on path /
# Post rej cookie not contain consent cookie, crowdstrike.com/postrej_0.har.xz not have cookie OptanonConsent of .crowdstrike.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.ralphlauren.com/' consent_cookie.cookie['domain']='.www.ralphlauren.ie' consent_cookie.cookie['path']='/' ralphlauren.com/postrej_0.har.xz
# Unmatch url and consent cookie domain: page_url='https://steamcommunity.com/openid/loginform/?goto=%2Fopenid%2Flogin%3Fopenid.ns%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%26openid.mode%3Dcheckid_setup%26openid.return_to%3Dhttps%253A%252F%252Fwww.warframe.com%252Fit%252Flogin%252Fsteam_callback%26openid.realm%3Dhttps%253A%252F%252Fwww.warframe.com%26openid.identity%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%26openid.claimed_id%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%3Fopenid.ns%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%26openid.mode%3Dcheckid_setup%26openid.return_to%3Dhttps%253A%252F%252Fwww.warframe.com%252Fit%252Flogin%252Fsteam_callback%26openid.realm%3Dhttps%253A%252F%252Fwww.warframe.com%26openid.identity%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%26openid.claimed_id%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select' consent_cookie.cookie['domain']='.www.warframe.com' consent_cookie.cookie['path']='/' warframe.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://steamcommunity.com/openid/loginform/?goto=%2Fopenid%2Flogin%3Fopenid.ns%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%26openid.mode%3Dcheckid_setup%26openid.return_to%3Dhttps%253A%252F%252Fwww.warframe.com%252Flogin%252Fsteam_callback%26openid.realm%3Dhttps%253A%252F%252Fwww.warframe.com%26openid.identity%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%26openid.claimed_id%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%3Fopenid.ns%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%26openid.mode%3Dcheckid_setup%26openid.return_to%3Dhttps%253A%252F%252Fwww.warframe.com%252Flogin%252Fsteam_callback%26openid.realm%3Dhttps%253A%252F%252Fwww.warframe.com%26openid.identity%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select%26openid.claimed_id%3Dhttp%253A%252F%252Fspecs.openid.net%252Fauth%252F2.0%252Fidentifier_select' consent_cookie.cookie['domain']='.www.warframe.com' consent_cookie.cookie['path']='/' warframe.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, nngroup.com/postrej_0.har.xz not have cookie CookieConsent of www.nngroup.com on path /
# Post rej cookie not contain consent cookie, auctollo.com/postrej_0.har.xz not have cookie CookieConsent of auctollo.com on path /
# Post rej cookie not contain consent cookie, duo.com/postrej_0.har.xz not have cookie OptanonConsent of .duo.com on path /
# Post rej cookie not contain consent cookie, siteground.com/postrej_1.har.xz not have cookie CookieConsent of eu.siteground.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.siteground.com/' consent_cookie.cookie['domain']='eu.siteground.com' consent_cookie.cookie['path']='/' siteground.com/postrej_0.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/accessibility/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/about/media-kit/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/industry/manufacturing/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/learning-services/learning-paths' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/partners/find-an-opentext-partner' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/contact' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://play.google.com/store/apps/details?id=com.mentormate.android.inboxdollars&hl=en_US&gl=US' consent_cookie.cookie['domain']='.inboxdollars.com' consent_cookie.cookie['path']='/' inboxdollars.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://accounts.ucas.com/account/login?returnUrl=https%3A//www.ucas.com/dashboard%23/' consent_cookie.cookie['domain']='www.ucas.com' consent_cookie.cookie['path']='/' ucas.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, voicemod.net/postrej_0.har.xz not have cookie OptanonConsent of .www.voicemod.net on path /
# Post rej cookie not contain consent cookie, kraken.com/postrej_0.har.xz not have cookie OptanonConsent of .kraken.com on path /
# Post rej cookie not contain consent cookie, bintray.com/postrej_0.har.xz not have cookie OptanonConsent of .jfrog.com on path /
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/funcom.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/funcom.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://learn.englandfootball.com/articles-and-resources/coaching' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://learn.englandfootball.com/news' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, thefa.com/postrej_0.har.xz not have cookie OptanonConsent of .www.thefa.com on path /
# Post rej cookie not contain consent cookie, nielsen.com/postrej_0.har.xz not have cookie OptanonConsent of .nielsen.com on path /
# Unmatch url and consent cookie domain: page_url='https://app.squareup.com/signup?app=weebly&country_code=ie&return_to=https%3A%2F%2Fwww.weebly.com%2Fapp%2Ffront-door%2Flogin%2Fsquare%3Fsso_intent%3Dsignup&v=weebly-sso&weebly_sso_enabled=true' consent_cookie.cookie['domain']='.weebly.com' consent_cookie.cookie['path']='/' weebly.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_2.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_5.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_1.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_0.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_3.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_4.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Unmatch url and consent cookie domain: page_url='https://centres.weforum.org/centre-nature-and-climate/home' consent_cookie.cookie['domain']='www.weforum.org' consent_cookie.cookie['path']='/' weforum.org/postrej_4.har.xz
# Post rej cookie not contain consent cookie, malwarebytes.com/postrej_0.har.xz not have cookie OptanonConsent of .malwarebytes.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.chemistryworld.com/chemistryworld' consent_cookie.cookie['domain']='.www.rsc.org' consent_cookie.cookie['path']='/' rsc.org/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://login3.id.hp.com/login3/sign-up' consent_cookie.cookie['domain']='.hpsmart.com' consent_cookie.cookie['path']='/' hpsmart.com/postrej_4.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/sharechat.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/sharechat.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://download.battle.net/en-us?product=bnetdesk' consent_cookie.cookie['domain']='.blizzard.com' consent_cookie.cookie['path']='/' blizzard.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, amplifi.com/postrej_0.har.xz not have cookie OptanonConsent of .amplifi.com on path /
# Post rej cookie not contain consent cookie, riskified.com/postrej_1.har.xz not have cookie OptanonConsent of .www.riskified.com on path /
# Post rej cookie not contain consent cookie, uic.edu/postrej_0.har.xz not have cookie OptanonConsent of .uic.edu on path /
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://www.chubb.com/benelux-nl/
# Unmatch url and consent cookie domain: page_url='https://www.chubb.com/benelux-nl/' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_2.har.xz
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://life.chubb-insurance.ru/
# Unmatch url and consent cookie domain: page_url='https://life.chubb-insurance.ru/' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_3.har.xz
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://about.chubb.com/citizenship.html
# Unmatch url and consent cookie domain: page_url='https://about.chubb.com/citizenship.html' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, kaspersky.com/postrej_0.har.xz not have cookie CookieConsent of usa.kaspersky.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.kaspersky.com/about/policy-blog' consent_cookie.cookie['domain']='usa.kaspersky.com' consent_cookie.cookie['path']='/' kaspersky.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, namecheap.com/postrej_0.har.xz not have cookie OptanonConsent of .namecheap.com on path /
# Post rej cookie not contain consent cookie, codecanyon.net/postrej_0.har.xz not have cookie CookieConsent of codecanyon.net on path /
# Post rej cookie not contain consent cookie, forter.com/postrej_0.har.xz not have cookie OptanonConsent of .forter.com on path /
# Post rej cookie not contain consent cookie, stitcher.com/postrej_3.har.xz not have cookie OptanonConsent of .www.stitcher.com on path /
# Unmatch url and consent cookie domain: page_url='https://careers.gene.com/us/en' consent_cookie.cookie['domain']='.www.gene.com' consent_cookie.cookie['path']='/' gene.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://accounts.icc-cricket.com/4ba9f276-2497-440e-a6ba-d05d4831b967/b2c_1a_signinsignup/oauth2/v2.0/authorize?client_id=36da6054-8552-4015-a6b2-b7b6906fd4ab&scope=profile%20openid%20offline_access%20https%3A%2F%2Ficcprdlogin.onmicrosoft.com%2Fapi%2Fcatalogue.read%20openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fwww.icc-cricket.com%2Fsignin&client-request-id=0ab5bd50-7a0a-4840-bef1-2c558313f463&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.38.4&client_info=1&code_challenge=YUZhZcqUtHkasqvkSuWlkGNt2sr1gsVF43HPxmXEKWU&code_challenge_method=S256&nonce=162f3428-237e-4440-bb1e-c6e9401c0c0e&state=eyJpZCI6IjgxZjMwMThiLTIxYTQtNGQwYi04NzMwLTUyNzJlNjNkNWU5ZiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D' consent_cookie.cookie['domain']='.www.icc-cricket.com' consent_cookie.cookie['path']='/' icc-cricket.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://apply.commonapp.org/login?ma=93' consent_cookie.cookie['domain']='.newschool.edu' consent_cookie.cookie['path']='/' newschool.edu/postrej_3.har.xz
# Domain path mismatch: .www.intimissimi.com domain's path /us/ not match url https://www.intimissimi.com/ie/
# Unmatch url and consent cookie domain: page_url='https://www.intimissimi.com/ie/' consent_cookie.cookie['domain']='.www.intimissimi.com' consent_cookie.cookie['path']='/us/' intimissimi.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/trust/terms/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/about/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/resources/webinars' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/about/customer-success-stories' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/about/mobile-apps/uptodate' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, adyen.com/postrej_2.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_1.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_0.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_3.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, natwest.com/postrej_0.har.xz not have cookie OptanonConsent of .natwest.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/paramount.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://global.fujitsu/ko-kr' consent_cookie.cookie['domain']='.www.fujitsu.com' consent_cookie.cookie['path']='/' fujitsu.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://global.fujitsu/et-ee' consent_cookie.cookie['domain']='.www.fujitsu.com' consent_cookie.cookie['path']='/' fujitsu.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='http://validate.perfdrive.com/b708a8fc3776ece65dd51a0e70b3ae8e/?ssa=08245bc1-8413-48c3-ac5f-c8e9365ee68d&ssb=01264210881&ssc=https%3A%2F%2Fwww.redlobster.com%2Faccount%2Flogin%3FReturnUrl%3D%252Faccount%252Flogout%253FreturnUrl%253D%252Forder&ssi=951bd403-94c0-4aca-bda0-82acb6bfbb72&ssk=support@shieldsquare.com&ssm=82360698870189597198073765388414&ssn=d4b35ac38112eed4bb2e174166e6bbd8ca15e514033f-3855-401e-9715e9&sso=79b563ee-8a7ce8a8190eb603083568134a9c8e4333dcce6c1f887c95&ssp=17936224171728403088172840091419067&ssq=07038509908033537290298993742215198251288&ssr=NTQuMjE3LjU1Ljk5&sst=Mozilla/5.0%20(X11;%20Linux%20x86_64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/101.0.4951.64%20Safari/537.36&ssu=VDdQdml4bmlQZm83L1BmQzIwOHkrTHJyL2txUFNMMXVpVXVzRjJyemYxZz0=&ssv=&ssw=&ssx=' consent_cookie.cookie['domain']='.redlobster.com' consent_cookie.cookie['path']='/' redlobster.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='http://validate.perfdrive.com/b708a8fc3776ece65dd51a0e70b3ae8e/?ssa=e7473c04-d3d9-4f14-80d7-9d856a1d4bf3&ssb=13565221788&ssc=https%3A%2F%2Fwww.redlobster.com%2Four-story%2Fseafood-with-standards%2Four-beliefs%2F&ssi=70cafbd1-94c0-4b49-aaa5-1294bd5fd57f&ssk=support@shieldsquare.com&ssm=54448177122652870287354283159295&ssn=6c695ef8b0c56d3d36637d542dc6533c034ce514033f-3855-401e-992e8b&sso=e72043ee-8a7ce8a8190e8a7f98b06d691f0f1977546cdccb79175249&ssp=36845410951728491098172840714396467&ssq=60923619908298582747498993891714770181737&ssr=NTQuMjE3LjU1Ljk5&sst=Mozilla/5.0%20(X11;%20Linux%20x86_64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/101.0.4951.64%20Safari/537.36&ssu=VDdQdml4bmlQZm83L1BmQzIwOHkrTHJyL2txUFNMMXVpVXVzRjJyemYxZz0=&ssv=&ssw=&ssx=' consent_cookie.cookie['domain']='.redlobster.com' consent_cookie.cookie['path']='/' redlobster.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://super6.skysports.com/?AFF_ID=1197321632&dcmp=SL_LOGO_FTP_S6_19' consent_cookie.cookie['domain']='.sportinglife.com' consent_cookie.cookie['path']='/' sportinglife.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, keywee.co/postrej_2.har.xz not have cookie CookieConsent of keywee.co on path /
# Post rej cookie not contain consent cookie, keywee.co/postrej_1.har.xz not have cookie CookieConsent of keywee.co on path /
# Post rej cookie not contain consent cookie, keywee.co/postrej_4.har.xz not have cookie CookieConsent of keywee.co on path /
# Post rej cookie not contain consent cookie, pingdom.net/postrej_0.har.xz not have cookie OptanonConsent of .www.pingdom.com on path /
# Unmatch url and consent cookie domain: page_url='https://gumgum.com/' consent_cookie.cookie['domain']='.playgroundxyz.com' consent_cookie.cookie['path']='/' playground.xyz/postrej_3.har.xz
# Post rej cookie not contain consent cookie, adtelligent.com/postrej_0.har.xz not have cookie OptanonConsent of .adtelligent.com on path /
# Post rej cookie not contain consent cookie, shef.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .sheffield.ac.uk on path /
# Post rej cookie not contain consent cookie, sonymusic.com/postrej_0.har.xz not have cookie OptanonConsent of .sonymusic.com on path /
# Unmatch url and consent cookie domain: page_url='https://status.mcgrawhill.com/#!/' consent_cookie.cookie['domain']='.mheducation.com' consent_cookie.cookie['path']='/' mcgraw-hill.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.highschoolot.com/story/lightning-fast-overtime-strike-sends-east-forsyth-past-mount-tabor/21664453/' consent_cookie.cookie['domain']='.wral.com' consent_cookie.cookie['path']='/' wral.com/postrej_1.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/pt/pt/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/pt/pt/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' home.kpmg/postrej_5.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/co/es/home.html
# ...
# Post rej cookie not contain consent cookie, home.kpmg/postrej_0.har.xz not have cookie OptanonConsent of .kpmg.com on path /xx
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/ve/es/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/ve/es/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' home.kpmg/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.theoregonian.com/' consent_cookie.cookie['domain']='.oregonlive.com' consent_cookie.cookie['path']='/' oregonlive.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, flourish.studio/postrej_0.har.xz not have cookie OptanonConsent of .flourish.studio on path /
# Unmatch url and consent cookie domain: page_url='https://app.drata.com/trust/81f60852-62bb-4ec9-ada9-019fb968c39c' consent_cookie.cookie['domain']='.hyros.com' consent_cookie.cookie['path']='/' hyros.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://developers.cloudflare.com/workers' consent_cookie.cookie['domain']='workers.cloudflare.com' consent_cookie.cookie['path']='/' workers.dev/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.unity.com/' consent_cookie.cookie['domain']='.is.com' consent_cookie.cookie['path']='/' soom.la/postrej_1.har.xz
# Post rej cookie not contain consent cookie, hibob.com/postrej_0.har.xz not have cookie OptanonConsent of .hibob.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/fivem.net/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, fivem.net/postrej_0.har.xz not have cookie OptanonConsent of .fivem.net on path /
# Unmatch url and consent cookie domain: page_url='https://forum.cfx.re/t/technical-support-template/861/7' consent_cookie.cookie['domain']='.fivem.net' consent_cookie.cookie['path']='/' fivem.net/postrej_4.har.xz
# Post rej cookie not contain consent cookie, force.com/postrej_0.har.xz not have cookie OptanonConsent of .salesforce.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/arcticwolf.net/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, cookielaw.org/postrej_0.har.xz not have cookie OptanonConsent of .cookielaw.org on path /
# Unmatch url and consent cookie domain: page_url='https://www.enterprisecarsales.com/locations/?cur=Home_Rental&icid=EnterpriseWebsite-_-header.buy.buy.car-_-find.dealership&mcid=websiteredirect:41819954' consent_cookie.cookie['domain']='.enterprise.com' consent_cookie.cookie['path']='/' enterprise.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.enterprisecarsales.com/schedule/?cur=Home_Rental&mcid=websiteredirect:41819956' consent_cookie.cookie['domain']='.enterprise.com' consent_cookie.cookie['path']='/' enterprise.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.enterprisecarsales.com/locations/?utm_source=Enterprise&utm_medium=Referral&utm_campaign=NavLoc&cm_mmc=EnterpriseWebsite-_-Header-_-carsales.locator-_-ENUS&mcid=websiteredirect:41819955' consent_cookie.cookie['domain']='.enterprise.com' consent_cookie.cookie['path']='/' enterprise.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, getgreenshot.org/postrej_0.har.xz not have cookie CookieConsent of getgreenshot.org on path /
com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/citigroup.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/sonos.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/tickets.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/tickets.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/tickets.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login.fronius.com/authenticationendpoint/login.do?client_id=mf_o9iTAyKemNLQTa6Sp6HYonCIa&commonAuthCallerPath=%2Foauth2%2Fauthorize&forceAuth=false&nonce=638641028401225529.NTU1NTNiMTEtZDc4OS00ODVmLWJmOWQtMjY0NDFjZjAwNDYwYzg3ZWMwZDUtMTEwNy00ZTM2LTlkZjctNTFiZTVjNjMzMjRl&passiveAuth=false&redirect_uri=https%3A%2F%2Fwww.solarweb.com%2FAccount%2FExternalLoginCallback&response_mode=form_post&response_type=code+id_token&scope=openid+profile+solarweb+solweb_browserid_93c65d8e866a6421e43a4e3d7b75f200&state=OpenIdConnect.AuthenticationProperties%3D-jt1pxny-yitWtPeaNkPe9kPfzZomKSw-tHYYUiQmId_T2kUIgHPk-6t9W5Vv9zFZAv7a-vAVXJvsGFTgcU3DtXYeMJELmgbBVDAmPWQDCTLTX-TKlV_ia99k8w_vPFRy66asALPF2kEqsLF8THQYoc6bZfjus5RbigkwiaGOHJ0aHDYXKCZCXa-Es9xRSmzq0JILjcxC6rO_tR2qzSSzhYTHugwHdsziWnsumICoiEf5MT5kRf6mPH_nxI70FXAGf5a6Q&tenantDomain=carbon.super&x-client-SKU=ID_NET461&x-client-ver=6.9.0.0&sessionDataKey=793f6b04-a871-4ae1-b1c1-f9a5d48fc840&relyingParty=mf_o9iTAyKemNLQTa6Sp6HYonCIa&type=oidc&sp=Solar.web+-+Portals&isSaaSApp=false&authenticators=SAMLSSOAuthenticator%3AFronius+Login%3BFroniusBasicAuthenticator%3ALOCAL' consent_cookie.cookie['domain']='www.solarweb.com' consent_cookie.cookie['path']='/' solarweb.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, bsigroup.com/postrej_0.har.xz not have cookie OptanonConsent of .www.bsigroup.com on path /
# Post rej cookie not contain consent cookie, mynewsdesk.com/postrej_0.har.xz not have cookie OptanonConsent of .mynewsdesk.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/poly.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .www.redbull.com domain's path /us-en not match url https://www.redbull.com/ie-en/live-events
# Unmatch url and consent cookie domain: page_url='https://www.redbull.com/ie-en/live-events' consent_cookie.cookie['domain']='.www.redbull.com' consent_cookie.cookie['path']='/us-en' redbull.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, redbull.com/postrej_5.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_1.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_0.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_3.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_4.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/slotomania.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://preview.themeforest.net/item/ecomus-ultimate-html5-template/full_screen_preview/53417990' consent_cookie.cookie['domain']='themeforest.net' consent_cookie.cookie['path']='/' themeforest.net/postrej_2.har.xz
# Post rej cookie not contain consent cookie, themeforest.net/postrej_0.har.xz not have cookie CookieConsent of themeforest.net on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/pref_menu_scan_0k_20k/cookiebot.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, gitlab.io/postrej_0.har.xz not have cookie OptanonConsent of .gitlab.com on path /
# Post rej cookie not contain consent cookie, trustpilot.com/postrej_0.har.xz not have cookie OptanonConsent of .trustpilot.com on path /
# Unmatch url and consent cookie domain: page_url='https://consent.youtube.com/m?continue=https%3A%2F%2Fwww.youtube.com%2F%40Appsflyer%3Fcbrd%3D1&gl=IE&m=0&pc=yt&cm=2&hl=en-GB&src=1' consent_cookie.cookie['domain']='.www.appsflyer.com' consent_cookie.cookie['path']='/' appsflyer.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.instagram.com/accounts/login/?next=https%3A%2F%2Fwww.instagram.com%2Fpeatix%2F&is_from_rle' consent_cookie.cookie['domain']='.peatix.com' consent_cookie.cookie['path']='/' peatix.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://eu.account.battle.net/login/en-us/?ref=https://oauth.battle.net/authorize?response_type%3Dcode%26redirect_uri%3Dhttps%253A%252F%252Fworldofwarcraft.blizzard.com%252Fauth%26scope%3Dwow.profile%2520email%2520primary-address%2520private_flags%2520name%2520account.basic%2520account.standard%2520account.standard%253Amodify%2520account.full%2520commerce.profile.basic%2520commerce.entitlements%26state%3D7QH15x3M-oTl4LKOP69IIPJqQfWmai5AMtGs%26client_id%3De674efa0abaa423cb7805d3c41838416&app=oauth&hostingApp=oauth' consent_cookie.cookie['domain']='.blizzard.com' consent_cookie.cookie['path']='/' worldofwarcraft.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://spring.academy/paths/spring-certified-professional-2023' consent_cookie.cookie['domain']='.spring.io' consent_cookie.cookie['path']='/' spring.io/postrej_3.har.xz
# Post rej cookie not contain consent cookie, empower.com/postrej_0.har.xz not have cookie OptanonConsent of .empower.com on path /
# Post rej cookie not contain consent cookie, katespade.com/postrej_2.har.xz not have cookie OptanonConsent of .katespade.eu on path /
# Post rej cookie not contain consent cookie, katespade.com/postrej_5.har.xz not have cookie OptanonConsent of .katespade.eu on path /
# Post rej cookie not contain consent cookie, katespade.com/postrej_1.har.xz not have cookie OptanonConsent of .katespade.eu on path /
# Post rej cookie not contain consent cookie, katespade.com/postrej_3.har.xz not have cookie OptanonConsent of .katespade.eu on path /
# Post rej cookie not contain consent cookie, katespade.com/postrej_4.har.xz not have cookie OptanonConsent of .katespade.eu on path /
# Unmatch url and consent cookie domain: page_url='https://login.techsmith.com/u/login/identifier?state=hKFo2SBuMFZucWFNMkEyM3BzWEpUdG1xUGdDMjFRLWpYZlJLNqFur3VuaXZlcnNhbC1sb2dpbqN0aWTZIFZudEtZeFhkajdfT1RSTGJoMkVaeEF1UGRYWEg4aW5Ro2NpZNkgMExSQzFJMXhDTFEzajQwSFRUM3ZDMUE4QWh1d2p5MDI&ui_locales=en-US' consent_cookie.cookie['domain']='.screencast.com' consent_cookie.cookie['path']='/' screencast.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, dataseat.com/postrej_4.har.xz not have cookie OptanonConsent of .dataseat.com on path /
# Post rej cookie not contain consent cookie, rubrik.com/postrej_0.har.xz not have cookie OptanonConsent of .www.rubrik.com on path /
# Domain path mismatch: .www2.deloitte.com domain's path /us/ not match url https://www2.deloitte.com/bn/en.html?icid=site_selector_bn
# Unmatch url and consent cookie domain: page_url='https://www2.deloitte.com/bn/en.html?icid=site_selector_bn' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, deloitte.com/postrej_0.har.xz not have cookie OptanonConsent of .www2.deloitte.com on path /us/
# Unmatch url and consent cookie domain: page_url='https://localiq.com/legal/privacy-policy/' consent_cookie.cookie['domain']='.wordstream.com' consent_cookie.cookie['path']='/' wordstream.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, hpdaas.com/postrej_0.har.xz not have cookie OptanonConsent of .hpdaas.com on path /
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/scan_0k_20k.parquet
# Number sent cookies read: 1,785,105
#                     name                                              value  \
# 0         OptanonConsent  isGpcEnabled=0&datestamp=Wed+Oct+09+2024+17%3A...
# 1  OptanonAlertBoxClosed                           2024-10-09T17:21:44.086Z
# 2             customerID                                         1728494521
#
#          domain path       expires  size  httpOnly  secure  session sameSite  \
# 0  .nextiva.com    /  1.731087e+09   357     False   False    False      Lax
# 1  .nextiva.com    /  1.731087e+09    45     False   False    False      Lax
# 2  .nextiva.com    /  1.728927e+09    20     False   False    False      NaN
#
#   priority  sameParty sourceScheme  sourcePort  \
# 0   Medium      False       Secure         443
# 1   Medium      False       Secure         443
# 2   Medium      False       Secure         443
#
#                                          request_url         site  \
# 0  https://www.nextiva.com/cdn-cgi/image/width=68...  nextiva.com
# 1  https://www.nextiva.com/cdn-cgi/image/width=57...  nextiva.com
# 2  https://www.nextiva.com/cdn-cgi/image/width=64...  nextiva.com
#
#                                      page_url partitionKey
# 0  https://www.nextiva.com/industry/nonprofit          NaN
# 1  https://www.nextiva.com/industry/nonprofit          NaN
# 2  https://www.nextiva.com/industry/nonprofit          NaN

# %%
# prj = post-rejection
# Old way: consider all flows
# prj_sent_cookies = sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
# prj_br_cookies = prj_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
# New way: consider cookies only (ignore the request url, which is not nused in get_comply cookie matching anyway)
prj_sent_cookies = sent_cookies[['name', 'domain', 'path', 'site']].drop_duplicates()

# %%
# print(f"Num captured sent cookies: {len(sent_cookies):,d}")
# print(f"Num unique captured cookies: {len(prj_sent_cookies):,d}")
# n_br_cookies = len(prj_br_cookies)
# print(f"Num unique browser cookies: {n_br_cookies:,d} on {prj_br_cookies.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")

# %% [markdown]
# ## Analyze cookies compliance

# %%
sites = set(cookie_prefs.site)
print(f"Num sent cookies in the cookie prefs sites: {len(prj_sent_cookies[prj_sent_cookies.site.isin(sites)]):,d}")
# Out:
# Num sent cookies in the cookie prefs sites: 29,694

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.comply_util'])
]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/D548813802F84F5258ED44284F1C4118"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/67B860F9294C5077FF3778B0E4EFAE57"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/7BDA7E5EDE55687583961CA1EDA0757D"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/F456AE27ED05D35813F692EB7BC03031"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/01E63B504BA1C31F1671E09271D65E62"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/0B9AA35075A84C6017424BC98063D646"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/5EEA4F53028D1E491B255E240506EA97"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/5A024D418CFD5EF039963B9C8627DA66"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/5D098E9330E74C99E3C889672D39AB29"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/B45783A1FC9D5D8FCD6E6B2A7E7C9C57"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/22404887B3FA299F6653D658EE1E432E"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/3CD8692AD2AD4AB1DE710E7B5955A49A"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/4E07C94964199EEBE84CBA95587395CA"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/48307FE69E660BFC87CB217D1A139D02"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/1E34056178D6DEBFA7BE2A6DE8A38EF8"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/F29EB1F704E7928B6673C5879D3AEB45"]' cookie_name='TiPMix' bad character range n-c at position 41
# Error fuzzy name match pref_name='rmEx-stylesheet[href="/assets/css/non-critical/F29C0F0C3AB26AA8113F1116C5EFE4AF"]' cookie_name='TiPMix' bad character range n-c at position 41
#  88%|████████▊ | 1274/1444 [01:22<00:06, 26.05it/s]
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='userCount' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__cf_bm' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='userid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='AWSALBTGCORS' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='aelreadersettings' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='OptanonConsent' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_64H4Z6TSBF' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='OptanonAlertBoxClosed' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_0FHHFDE9TG' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='AWSALBTG' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gcl_au' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pxhd' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_T3MKEZBW59' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ASP.NET_SessionId' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pxcts' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gat_gtag_UA_891249_29' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gat_gtag_UA_891249_13' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pxvid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_px3' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='whereYouLeftOffData' bad character range d-4 at position 20
# 100%|██████████| 1444/1444 [01:40<00:00, 14.40it/s]
#                     name           domain path         site     comply
# 0         OptanonConsent     .nextiva.com    /  nextiva.com     comply
# 1  OptanonAlertBoxClosed     .nextiva.com    /  nextiva.com     comply
# 2             customerID     .nextiva.com    /  nextiva.com     comply
# 3                 __hstc     .nextiva.com    /  nextiva.com       omit
# 4               _omappvp  www.nextiva.com    /  nextiva.com  incorrect

# %%
# Analyze complies here
complies = all_complies[['name', 'domain', 'path', 'site', 'comply']].drop_duplicates()
comply_sites_data = defaultdict(list)
for comply_type, comply_group in complies.groupby('comply'):
    n_sites = comply_group.site.nunique()
    comply_sites_data['comply_type'].append(comply_type)
    comply_sites_data['num_sites'].append(n_sites)
    comply_sites = pd.DataFrame(comply_sites_data).sort_values(by=['num_sites'], ascending=False)

nsites = all_complies.site.nunique()
comply_counts = complies.comply.value_counts()
comply_sites['num_sites_percent'] = comply_sites['num_sites'] / nsites * 100
comply_sites['num_cookies'] = comply_sites['comply_type'].map(comply_counts)
comply_sites['num_cookies_percent'] = comply_sites['num_cookies'] / comply_sites['num_cookies'].sum() * 100  # need to read scan_*.parquet for n_br_cookies, but may be unnecessary
comply_sites['num_cookies_per_site'] = comply_sites['num_cookies'] / comply_sites['num_sites']

# Do not count comply/correct enforcement: which require detecting all possible
comply_sites = comply_sites[comply_sites.comply_type != 'comply']
comply_sites
# Out:
#   comply_type  num_sites  num_sites_percent  num_cookies  num_cookies_percent  \
# 3        omit       1274          88.595271        12445            41.910824
# 2   incorrect       1144          79.554937         9696            32.653061
# 0   ambiguous         48           3.337969           55             0.185223
#
#    num_cookies_per_site
# 3              9.768446
# 2              8.475524
# 0              1.145833

# %%
# Record the analysis results
all_complies_file = SCAN_ROOT_DIR / f'all_complies{output_suffix}.parquet'
all_complies.to_parquet(all_complies_file); print(f"Written {len(all_complies):,d} records of all_complies to {all_complies_file}")
# Out:
# Written 29,694 records of all_complies to /mnt/sdd/ducbui/projects/data2/consent/2024-10-11/all_complies_0k_20k.parquet

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

raise StopExecution
import sys; sys.exit(0)

# %%
complies.comply
# Out:
# 0              omit
# 1              omit
# 2              omit
# 3              omit
# 4              omit
#             ...
# 115682    incorrect
# 115683    incorrect
# 115684         omit
# 115685       comply
# 115686       comply
# Name: comply, Length: 115687, dtype: object

# %%
nsites = all_complies.site.nunique(); nsites
# all_complies.site.unique()
# Out:
# 3412

# %%
detected_contra_sites = [s for s, contras in site_to_contras.items() if len(contras) > 0]; len(detected_contra_sites)
# Out:
# 0

# %%
complies = all_complies[ ['name', 'domain', 'site', 'comply',]].drop_duplicates()
comply_counts = complies.comply.value_counts()
comply_counts
# Out:
# omit         60214
# incorrect    35575
# comply       19067
# ambiguous      271
# Name: comply, dtype: int64

# %%
complies_sites = set(all_complies.site)
sent_cookies_com = sent_cookies[sent_cookies.site.isin(complies_sites)]
prj_sent_cookies_com = sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
prj_br_cookies_com = prj_sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
print(f"Num captured sent cookies: {len(sent_cookies_com):,d}")
print(f"Num unique captured cookies: {len(prj_sent_cookies_com):,d}")

n_br_cookies_com = len(prj_br_cookies_com)
print(f"Num unique browser cookies: {n_br_cookies_com:,d} on {prj_br_cookies_com.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")
# Out:
# Num captured sent cookies: 12,865,663
# Num unique captured cookies: 6,925,444
# Num unique browser cookies: 276,967 on 3,412 websites

# %% [markdown]
# # Analyze contras

# %%
# Way 1: compute contra sites by dynamic analysis: this should be lower than statically analyzing prefs
# because we cannot check all combinations of consent modes.
from consent.consistency.comply_util import get_appr_rej_sets
contra_data = []
for asite in cookie_prefs.site.unique():
    site_prefs = cookie_prefs[cookie_prefs.site == asite]
    _, _, contras = get_appr_rej_sets(site_prefs)
    for contra in contras:
        contra['site'] = asite
        contra_data.append(contra)
contra_sites = pd.DataFrame(contra_data)
contra_sites.head()
# Out:
#                   domain                         name                site
# 0  www.libertylondon.com         dwanonymous_xxxxxxxx   libertylondon.com
# 1      script.hotjar.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 2     tartecosmetics.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 3     tartecosmetics.com                 _hjFirstSeen  tartecosmetics.com
# 4      script.hotjar.com   _hjIncludedInSessionSample  tartecosmetics.com

# %%
assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
#
# AssertionError: this is the same method with above, so the result

# %%
set(detected_contra_sites) - set(contra_sites.site)
set(contra_sites.site) - set(detected_contra_sites)
# This may be the sites excluded due to testing cookies in the preferences.
# Out:
# {'247sports.com',
#  'abbvie.com',
#  'acquia.com',
#  'adobe.io',
#  'adweek.com',
#  'aljazeera.com',
#  'allaboutvision.com',
#  'allegiantair.com',
#  'allergan.com',
#  'alteryx.com',
#  'americanbar.org',
#  'aon.com',
#  'ariel.co.uk',
#  'asos.com',
#  'autosport.com',
#  'avalara.com',
#  'avast.com',
#  'avastbrowser.com',
#  'barnesandnoble.com',
#  'bazaarvoice.com',
#  'bbva.com',
#  'bd.com',
#  'behance.net',
#  'belkin.com',
#  'betsson.com',
#  'bitdefender.com',
#  'bitdefender.net',
#  'bkstr.com',
#  'blackboard.com',
#  'bplans.com',
#  'brightside.me',
#  'bromium-online.com',
#  'callofduty.com',
#  'cambridge.org',
#  'carbonite.com',
#  'cheapoair.com',
#  'chrysler.com',
#  'cisco.com',
#  'citationmachine.net',
#  'clickmeeting.com',
#  'clicktale.net',
#  'cloudbees.com',
#  'cnet.com',
#  'colt.net',
#  'commonsensemedia.org',
#  'contentsquare.com',
#  'conviva.com',
#  'creighton.edu',
#  'curalate.com',
#  'dc.com',
#  'dccomics.com',
#  'discogs.com',
#  'dynamicyield.com',
#  'easybib.com',
#  'eidos.com',
#  'elderscrollsonline.com',
#  'evri.com',
#  'ew.com',
#  'fabfitfun.com',
#  'fotolia.com',
#  'fourseasons.com',
#  'frontlineeducation.com',
#  'geappliances.com',
#  'geforce.com',
#  'genial.ly',
#  'getdbt.com',
#  'glip.com',
#  'gmu.edu',
#  'gopro.com',
#  'grainger.com',
#  'halfords.com',
#  'hallmark.com',
#  'hightail.com',
#  'hm.com',
#  'howstuffworks.com',
#  'hp.com',
#  'illumina.com',
#  'instyle.com',
#  'ipl.org',
#  'irishcentral.com',
#  'ironman.com',
#  'janes.com',
#  'jbl.com',
#  'jeep.com',
#  'jobvite.com',
#  'kew.org',
#  'lastline.com',
#  'launchdarkly.com',
#  'levi.com',
#  'liverpoolfc.com',
#  'logi.com',
#  'logitech.com',
#  'logitechg.com',
#  'mastercard.com',
#  'mastercard.us',
#  'mcgraw-hill.com',
#  'mckesson.com',
#  'meraki.com',
#  'mheducation.com',
#  'michaels.com',
#  'mlb.com',
#  'mongodb.com',
#  'mongodb.org',
#  'morningconsult.com',
#  'morrisons.com',
#  'motorsport.com',
#  'mtv.com',
#  'myportfolio.com',
#  'name.com',
#  'nba.com',
#  'ncaa.com',
#  'newsday.com',
#  'newsweaver.com',
#  'next.co.uk',
#  'nhl.com',
#  'ni.com',
#  'nspcc.org.uk',
#  'nvidia.com',
#  'ocado.com',
#  'omnitracs.com',
#  'onlyinyourstate.com',
#  'paradox.ai',
#  'parents.com',
#  'paypay.ne.jp',
#  'pcapredict.com',
#  'people.com',
#  'pge.com',
#  'phoenix.edu',
#  'pinknews.co.uk',
#  'politico.com',
#  'principal.com',
#  'prweb.com',
#  'rd.com',
#  'realsimple.com',
#  'ringcentral.com',
#  'rollout.io',
#  'royalacademy.org.uk',
#  'salliemae.com',
#  'samaritans.org',
#  'sanofi-synthelabo.com',
#  'sanofi.com',
#  'santander.co.uk',
#  'sciam.com',
#  'scientificamerican.com',
#  'senderscore.com',
#  'seon.io',
#  'sho.com',
#  'shuttercloud.org',
#  'shutterstock.com',
#  'signifyd.com',
#  'solvvy.com',
#  'sonos.com',
#  'sony.co.uk',
#  'sourcefire.com',
#  'sparknotes.com',
#  'square-enix-games.com',
#  'statista.com',
#  'suse.com',
#  'tasteofhome.com',
#  'telerik.com',
#  'thedailybeast.com',
#  'thedodo.com',
#  'thomsonreuters.com',
#  'thomsonreuters.net',
#  'travelandleisure.com',
#  'treasuredata.com',
#  'tripadvisor.in',
#  'typeform.com',
#  'typekit.com',
#  'uipath.com',
#  'ulta.com',
#  'umbrella.com',
#  'universe.com',
#  'urbanairship.com',
#  'vfsglobal.com',
#  'viber.com',
#  'visma.com',
#  'vmware.com',
#  'vmwareidentity.com',
#  'webmd.com',
#  'wfmz.com',
#  'whirlpool.com',
#  'workspaceoneaccess.com',
#  'worldoftanks.com',
#  'wwf.org.uk',
#  'yousendit.com',
#  'zdnet.com',
#  'zebra.com',
#  'zeiss.com',
#  'zennioptical.com',
#  'zoom.com',
#  'zoom.us'}

# %%
# Way 2: compute contra sites by DataFrame group by
contra_cookies_dfs = []
for _, same_cookies in cookie_prefs.groupby(['name', 'domain', 'site']):
    consent_modes = same_cookies.consent_mode.unique()
    if len(consent_modes) >= 2 and same_cookies.category.nunique() > 1: # and 'always active' in consent_modes:
        contra_cookies_dfs.append(same_cookies)
contra_cookies = pd.concat(contra_cookies_dfs).drop_duplicates()

# %%
print("Number sites with contra cookies:", contra_cookies.site.nunique())
# Out:
# Number sites with contra cookies: 184

# %%
# set(contra_cookies.site) - set(contra_sites.site)

# %%
print("Num contra cookie settings (double categories):", len(contra_cookies), f"settings  on {contra_cookies.site.nunique()} sites")
print("Contras with 1 always-active:", contra_sites.site.nunique())
print("Contras with both editable:", len(set(contra_cookies.site) - set(contra_sites.site)))
# Out:
# Num contra cookie settings (double categories): 648 settings  on 184 sites
# Contras with 1 always-active: 192
# Contras with both editable: 0

# %%
contra_cookies[contra_cookies.site == 'elsevier.nl']
# Out:
# Empty DataFrame
# Columns: [name, domain, duration, category_id, category, consent_mode, site, lib_name, pattern_name, consent]
# Index: []

# %%
# assert len(detected_contra_sites) <= contra_sites.site.nunique() < len(detected_contra_sites) + 2

# %%
complies[complies.comply == 'ambiguous']
# Out:
#                  name                  domain                   site  \
# 173        TS013559a7       www.mastercard.us         mastercard.com
# 1236    _qubitTracker         .www.very.co.uk             very.co.uk
# 2365   G_ENABLED_IDPS      .www.glassdoor.com          glassdoor.com
# 2372              trs       www.glassdoor.com          glassdoor.com
# 2375             _gid          .glassdoor.com          glassdoor.com
# ...               ...                     ...                    ...
# 59468         ak_bmsc           .mulesoft.com           mulesoft.com
# 59481      JSESSIONID   training.mulesoft.com           mulesoft.com
# 60397          TLTSID              .bkstr.com              bkstr.com
# 60412            dtSa              .bkstr.com              bkstr.com
# 60622       shortHash  .square-enix-games.com  square-enix-games.com
#
#           comply
# 173    ambiguous
# 1236   ambiguous
# 2365   ambiguous
# 2372   ambiguous
# 2375   ambiguous
# ...          ...
# 59468  ambiguous
# 59481  ambiguous
# 60397  ambiguous
# 60412  ambiguous
# 60622  ambiguous
#
# [116 rows x 4 columns]

# %%
cookie_prefs[ (cookie_prefs.site == 'michaels.com') & (cookie_prefs.name == 'utag_main') ]
# Out:
#           name         domain  duration category_id  \
# 88   utag_main  .michaels.com  365 days       C0001
# 148  utag_main   michaels.com  365 days       C0002
#
#                        category   consent_mode          site  lib_name  \
# 88   Strictly Necessary Cookies  always active  michaels.com  onetrust
# 148         Performance Cookies         active  michaels.com  onetrust
#
#     pattern_name consent
# 88       en.json    True
# 148      en.json   False

# %%
cookie_prefs[ (cookie_prefs.site == 'statista.com') & (cookie_prefs.name == 'id') ]
# Out:
#     name  domain duration category_id           category   consent_mode  \
# 74    id  m6r.eu  90 days       C0001  Necessary Cookies  always active
# 131   id  m6r.eu   0 days       C0004  Targeting Cookies       inactive
#
#              site  lib_name pattern_name consent
# 74   statista.com  onetrust      en.json    True
# 131  statista.com  onetrust      en.json   False

# %%
# contra_cookies.name.value_counts()[:10]
# contra_cookies[contra_cookies.name == '__cf_bm'].reset_index(drop=True) # .site.nunique()

# %% [markdown]
# # Analyze ambiguous flows

# %%
ambi_cookies = complies[complies.comply == 'ambiguous']
print("Num ambiguous cookies:", len(ambi_cookies), "on num sites:", ambi_cookies.site.nunique())
assert len(ambi_cookies) == len(ambi_cookies.drop_duplicates()), "there is some duplicate cookies"

# %% [markdown]
# ## Analyze no-way-to-opt-out

# %%
# Way 1: compute contra sites by DataFrame group by
nwtoo_cookies_dfs = []
for _, site_cookies in cookie_prefs.groupby(['site']):
    consent_modes = site_cookies.consent_mode.unique().tolist()
    if len(consent_modes) == 1 and consent_modes[0] == 'always active':
        nwtoo_cookies_dfs.append(site_cookies)
nwtoo_cookies = pd.concat(nwtoo_cookies_dfs).drop_duplicates()
nwtoo_cookies.head()

# %%
nwtoo_cookies.site.nunique()

# %% [markdown]
# # Analyze inconsistent flows/cookies

# %%
def plot_inconsis_types():
    sns.set(rc={'figure.figsize':(9,9),"font.size":30,"axes.titlesize":30,"axes.labelsize":30},style="white", font_scale = 2.5)

    ax = sns.barplot(x='comply_type', y='num_sites_percent', data=noncomply_sites)
    ax.tick_params(left=True, bottom=True, direction="in")
    ax.set_ylabel('# Websites (%)')
    ax.set_xlabel('Noncompliance Types')
    xticks = [x.get_text().title() for x in ax.get_xticklabels()]
    ax.set(xticklabels=xticks)

    out_file = FIG_DIR / 'noncomply_types_per_site.png'
    # plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
## Plot distribution of omitted cookie declarations

# %%
omit_complies = complies[(complies.comply == 'omit')] #  & ~complies.name.isin(['OptanonAlertBoxClosed', 'OptanonConsent']) ]
omit_complies.site.nunique()

# %%
omit_complies.site.value_counts()[:7]

# %%
omit_cookies = omit_complies.name.value_counts()[:5].to_frame().reset_index().rename(columns={'index': 'cookie_name'})
omit_cookies['num_sites'] = omit_cookies['cookie_name'].map(lambda cookie_name: omit_complies[omit_complies.name == cookie_name].site.nunique())
print(omit_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %%
# set(cookielist_sites) - set(omit_complies.site.unique())
omit_counts = omit_complies.site.value_counts().to_frame().rename(columns={'site': 'num_omit_cookies'})
print("Num omitted sites:", omit_complies.site.nunique())
omit_counts.num_omit_cookies.mean(), omit_counts.num_omit_cookies.std(), omit_counts.num_omit_cookies.min(), omit_counts.num_omit_cookies.max()

# %%
sns.set(rc={'figure.figsize':(12,8),"font.size":35,"axes.titlesize":30,"axes.labelsize":50},style="white", font_scale = 4.5)
sns.set_style("ticks", {"xtick.direction": "in", "ytick.direction": "in"})
plt.rcParams['xtick.major.size'] = 15
plt.rcParams['ytick.major.size'] = 15

ax = sns.ecdfplot(data=omit_counts, x=omit_counts.num_omit_cookies, linewidth=8)
ax.set(xlim=(0, 350))

plt.xlabel('# Omitted Cookies/Website')
plt.ylabel('CDF')
# out_file = FIG_DIR / 'eu_omit_cookie_cdf.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
plot_df = omit_counts[:50]

sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x=plot_df.index, y=plot_df.num_omit_cookies)
ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=False, direction="in")
ax.set_ylabel('# Omitted Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'omit_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
def plot_histogram_omit():
    sns.set(rc={'figure.figsize':(9,6),"font.size":25,"axes.titlesize":25,"axes.labelsize":15},style="white", font_scale = 1)
    omit_counts_histo = omit_complies.site.value_counts().value_counts()
    sns.barplot(x=omit_counts_histo.index, y=omit_counts_histo.values)
    ticks = plt.xticks(rotation=45, ha='right')

# %% [markdown]
# ## Plot distribution of incorrectly enforced cookies

# %%
incor_complies = complies[complies.comply == 'incorrect']
# set(cookielist_sites) - set(omit_complies.site.unique())
incor_counts = incor_complies.site.value_counts().iloc[:50]
incor_counts = incor_counts.to_frame().reset_index().sort_values(by=['site', 'index'], ascending=[False, True])
incor_counts.columns

# %%
sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x='index', y='site', data=incor_counts)

ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=True, direction="in")
ax.set_ylabel('# Incorrectly Enforced Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'incor_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
# len(incor_counts)

# %%
incor_counts[incor_counts.site == 33].reset_index(drop=True)

# %% [markdown]
# ### Top incorrect cookies

# %%
incor_cookies = complies[complies.comply == 'incorrect']

# %%
# site = 'onetrust.com'
# complies[complies.site == site].reset_index(drop=True)
# cookie_prefs[(cookie_prefs.site == site) & (cookie_prefs.name == '_gid')]

# %%
top_incor_cookies = incor_cookies.name.value_counts().sort_values(ascending=False).to_frame().reset_index().rename(columns={'index':'cookie_name', 'name': 'num_occur'})

# %%
top_incor_cookies['num_sites'] = top_incor_cookies.cookie_name.map(lambda cookie_name: incor_cookies[incor_cookies.name == cookie_name].site.nunique())

# %%
print(top_incor_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %% [markdown]
# # Narrow cookie consent preferences

# %%
consent_cookies = sent_cookies[sent_cookies.name.isin(['OptanonConsent', 'CookieConsent'])][['domain', 'name', 'site']].drop_duplicates()
narrow_consent_cookies = consent_cookies[~consent_cookies.domain.str.startswith('.')].reset_index(drop=True)

# %%
set(contra_cookies.site).intersection(set(narrow_consent_cookies.site))

# %%
narrow_consent_cookies

# %% [markdown]
# # Case studies

# %%
incor_df = complies[complies.comply == 'incorrect']
incor_df.site.value_counts().sort_values(ascending=False).head()

# %%
case_site = 'blabbermouth.net'
incor_df[incor_df.site == case_site]

# %%
# cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'MXP_TRACKINGID')]
cookie_prefs[(cookie_prefs.site == case_site) & (cookie_prefs.name == 'IDE')]

# %%
# sent_cookies[(sent_cookies.site == 'scientificamerican.com') & (sent_cookies.name == 'MXP_TRACKINGID')]

# %%
omit_df = complies[complies.comply == 'omit']
omit_df.site.value_counts().sort_values(ascending=False).iloc[20:30]

# %%
print(omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist())

# %%
'uids' in omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist()

# %%
omit_df[(omit_df.site == 'scientificamerican.com') & (omit_df.name == 'cftoken')]

# %%
cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'ADGRX_UID')]

# %%
all_sites = set(complies.site)
nothing_comply_sites = all_sites - set(complies[complies.comply == 'comply'].site)
print("Sites with no compliant cookies:", nothing_comply_sites)

# %%
for site in ['liveperson.com']: # nothing_comply_sites:
    print(site)
site_cookies = postrej_br_cookies[postrej_br_cookies.site == site]

# %%
acookie = site_cookies[site_cookies.name == 'OptanonAlertBoxClosed'].iloc[0]

# %%
site_prefs = cookie_prefs[cookie_prefs.site == site]
consent_cookies = site_prefs[site_prefs.consent]
consent_cookie_names = consent_cookies.name
site_cookies[site_cookies.name.isin(consent_cookie_names)]
# cookie_name = 'OptanonAlertBoxClosed'
# cookie_pref = site_prefs[site_prefs.name == cookie_name].iloc[0]
# cookie_pref

# %%
consent_cookies

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.cookie_pref_match'])
from consent.consistency.cookie_pref_match import cookie_pref_match
cookie_pref_match(acookie, cookie_pref, site, verbose=2)

# %%
# Analyze Contras
