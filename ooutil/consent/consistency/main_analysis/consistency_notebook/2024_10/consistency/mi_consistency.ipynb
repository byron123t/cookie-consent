# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from consent.consistency.comply_util import site_to_contras, get_comply
from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import get_scan_root_dir, get_scan_dirs # , FIG_DIR uncomment to save fig.
from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cur_set = '0k_20k' # '20k_100k'
overwrite = True
SCAN_ROOT_DIR = get_scan_root_dir('mi')
SCAN_DIRS = [SCAN_ROOT_DIR / f'pref_menu_scan_{cur_set}']
# SCAN_DIRS = get_scan_dirs('us')[:]
output_suffix = '_' + cur_set # '0k_20k'  # '20k_100k' #'60k_80k' # '40k_60k' # # '100k_200k'; done: '20k_40k' '0k_20k'
print('Scan root dir:', SCAN_ROOT_DIR)
print('Output suffix:', output_suffix)
print('Scan dirs:', SCAN_DIRS)
# Out:
# Scan root dir: /mnt/sdd/ducbui/projects/data2/consent/2024-10-04
# Output suffix: _0k_20k
# Scan dirs: [PosixPath('/mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k')]

# %%
# Get cookie prefs = cookie decls + prefs
cookie_prefs_file = SCAN_ROOT_DIR / f'cookie_prefs{output_suffix}.parquet'

if not cookie_prefs_file.exists() or overwrite:
    save_cookie_decls_file = SCAN_ROOT_DIR / f'cookie_decls{output_suffix}.parquet'
    print(f'To save to {save_cookie_decls_file}')
    cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS, save_cookie_decls_file)  # took 2.3min for top 50k-site scan
    cookie_prefs.to_parquet(cookie_prefs_file); print(f'Written to {cookie_prefs_file}')
else:
    cookie_prefs = pd.read_parquet(cookie_prefs_file)
cookie_prefs.head()
# TODO: add log_file_checker
# Out:
# To save to /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/cookie_decls_0k_20k.parquet
# WARNING: Consent cookie not found chroniclelive.co.uk
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/constantcontact.com/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/getclockwise.com/consent_resources.json: region_block Received an out-of-region response
# https://cdn.cookielaw.org/consent/03b96273-0ebc-43cb-8885-cdfaeadad5b9/b019db6d-bccf-46f9-bde0-478e3c1f6028/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/scribbr.com/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/redbubble.com/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/conta.cc/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/gitlab.com/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/pressreader.com/consent_resources.json: region_block Received an out-of-region response
# https://cdn-ukwest.onetrust.com/consent/86f42b6d-7a31-469c-804c-319643173d42/018dfc06-450f-70ae-81ef-536da56b2895/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/gitlab.io/consent_resources.json: consent_js not supported yet.
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/cookie_decls_0k_20k.parquet
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/cookie_prefs_0k_20k.parquet
#                    name           domain duration category_id  \
# 0         .AxcmXFaxAuth  fax.nextiva.com   0 days       C0001
# 1               __cf_bm      nextiva.com   0 days       C0001
# 2               _ce.cch      nextiva.com  Session       C0001
# 3                    ao  sso.nextiva.com   0 days       C0001
# 4  autolaunch_triggered  sso.nextiva.com   0 days       C0001
#
#                      category   consent_mode         site  lib_name  \
# 0  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 1  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 2  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 3  Strictly Necessary Cookies  always active  nextiva.com  onetrust
# 4  Strictly Necessary Cookies  always active  nextiva.com  onetrust
#
#   pattern_name consent
# 0      en.json    True
# 1      en.json    True
# 2      en.json    True
# 3      en.json    True
# 4      en.json    True

# %%
print("Found cookie libraries:")
cookie_prefs[['site', 'lib_name']].drop_duplicates().lib_name.value_counts()
# Out:
# Found cookie libraries:
# lib_name
# onetrust     1287
# cookiebot     107
# Name: count, dtype: int64

# %%
cookielist_sites = sorted(cookie_prefs.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert cookie_prefs.site.nunique() == n_cookielist_sites
n=10
print("Sites with cookie prefs:", n_cookielist_sites, f', first {n} sites:' , cookielist_sites[:n])
# Out:
# Sites with cookie prefs: 1394 , first 10 sites: ['247sports.com', '2k.com', '2ksports.com', 'aao.org', 'aber.ac.uk', 'acast.com', 'accedo.tv', 'accenture.com', 'accor.com', 'acehardware.com']

# %%
site_to_libname = {row['site']: row['lib_name'] for row in cookie_prefs[['site', 'lib_name']].drop_duplicates().to_dict('records')}

# %%
# Quick checking the cookie declaration naming
print(len(cookie_prefs[cookie_prefs.name.str.endswith('#')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('xxx')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('XXX')]) / len(cookie_prefs))
cookie_prefs[cookie_prefs.name.str.endswith('#')]
# Out:
# 0.012092432465972924
# 0.029776656823847607
# 0.0029820456760337698
#                  name                          domain    duration category_id  \
# 101   visitor_id#####                  go.nextiva.com    364 days       C0004
# 24   _gd#############                        j.6sc.co    730 days       C0002
# 30   _gd#############                  www.wework.com    730 days       C0003
# 34   _gd#############            cdnjs.cloudflare.com    730 days       C0003
# 44       AMP_unsent_#  commercial.cdn.aws.placeit.net  Persistent  statistics
# ..                ...                             ...         ...         ...
# 140   visitor_id#####               click.outreach.io   3649 days           4
# 147   visitor_id#####                   pi.pardot.com   3649 days           4
# 170   visitor_id#####                      pardot.com   3649 days           4
# 172  _gd#############                        j.6sc.co    729 days           4
# 220  _gd#############            cdnjs.cloudflare.com    729 days           4
#
#                 category   consent_mode         site   lib_name pattern_name  \
# 101    Targeting Cookies         active  nextiva.com   onetrust      en.json
# 24   Performance Cookies  always active   wework.com   onetrust      en.json
# 30    Functional Cookies  always active   wework.com   onetrust      en.json
# 34    Functional Cookies  always active   wework.com   onetrust      en.json
# 44            statistics           None  placeit.net  cookiebot        cc.js
# ..                   ...            ...          ...        ...          ...
# 140    Targeting Cookies         active  outreach.io   onetrust      en.json
# 147    Targeting Cookies         active  outreach.io   onetrust      en.json
# 170    Targeting Cookies         active  outreach.io   onetrust      en.json
# 172    Targeting Cookies         active  outreach.io   onetrust      en.json
# 220    Targeting Cookies         active  outreach.io   onetrust      en.json
#
#     consent
# 101   False
# 24     True
# 30     True
# 34     True
# 44    False
# ..      ...
# 140   False
# 147   False
# 170   False
# 172   False
# 220   False
#
# [3313 rows x 10 columns]

# %%
# # Distribution of errors
# print("Libs in failed-to-crawl sites")
# errors.consent_lib_name.value_counts()
# from ooutil.df_util import expand_dict_col
# ot_errs = errors[errors.consent_lib_name == 'onetrust']
# errors_dict = pd.DataFrame(ot_errs.error.tolist()).explode('reason')
# # Uncomment to show
# # errors_dict.reason.value_counts()

# %% [markdown]
# # Main analysis

# %%
# import sys; import importlib; importlib.reload(sys.modules['consent.data.pref_menu_scan.postrej_cookie_reader'])
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cookies_cache_file = SCAN_ROOT_DIR / f'scan{output_suffix}.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not cookies_cache_file.exists() or overwrite:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")
else:
    sent_cookies = pd.read_parquet(cookies_cache_file)

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Post rej cookie not contain consent cookie, renfe.com/postrej_0.har.xz not have cookie OptanonConsent of .renfe.com on path /
# Post rej cookie not contain consent cookie, skrill.com/postrej_0.har.xz not have cookie OptanonConsent of .skrill.com on path /
# Post rej cookie not contain consent cookie, loggly.com/postrej_0.har.xz not have cookie OptanonConsent of .www.loggly.com on path /
# Post rej cookie not contain consent cookie, lidl.com/postrej_0.har.xz not have cookie OptanonConsent of .lidl.com on path /
# Unmatch url and consent cookie domain: page_url='https://login.microsoftonline.com/44467e6f-462c-4ea2-823f-7800de5434e3/saml2?SAMLRequest=fVLLbtswEPwVgXeJtEzJNmE5cGMUNZA0RqTk0EtBUauYAB8uH0n796VfQXLJeWdndmZ2efNXq%2BwVnJfWNGhSEJSBEXaQ5qVBT933fI5uVkvPtSoPbB3D3jzCnwg%2BZGnReHaeNCg6wyz30jPDNXgWBGvX93esLAg7OBussApla%2B%2FBhSR1a42PGlwL7lUKeHq8a9A%2BhINnGPu97HurIOwLqZQ0VvoChojlcMCJapQK8OkSfFQo8e6h7XDbPqBsk%2B6ShoeTlyudsi%2FSFFoKZ70dgzWJEgphNaaU1jOox5zWpcgp8DKfl9Mxn80JGaCiUwpTfDKIsu2mQb%2F7xTCKNCGkpjMu6p4PC0IJTMSsHoe%2BSjDvI2yND9yEBpWkpPmE5KTuJnNWLVg1LRa0%2BoWy3SWSb9Kco%2F4qv%2F4M8uxH1%2B3yo12UPV8rSwB0KYid1N3HZr4m5tc60OoI01wAk6l9ra1hUUZxzH2JP5K%2F%2F8LPxLbd7KyS4l%2B2Vsq%2B3TrgARoUXASEV5e9z1%2Bz%2Bg8%3D&RelayState=e1s1' consent_cookie.cookie['domain']='.illinois.edu' consent_cookie.cookie['path']='/' uiuc.edu/postrej_3.har.xz
# Post rej cookie not contain consent cookie, warnerbros.com/postrej_0.har.xz not have cookie OptanonConsent of .warnerbros.com on path /
# Post rej cookie not contain consent cookie, foursquare.com/postrej_0.har.xz not have cookie OptanonConsent of .foursquare.com on path /
# Unmatch url and consent cookie domain: page_url='https://apps.apple.com/us/app/lose-it-calorie-counter/id297368629' consent_cookie.cookie['domain']='.loseit.com' consent_cookie.cookie['path']='/' loseit.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, moonactive.net/postrej_0.har.xz not have cookie OptanonConsent of .moonactive.com on path /
# Post rej cookie not contain consent cookie, samknows.com/postrej_0.har.xz not have cookie OptanonConsent of .samknows.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.watchfandangoathome.com/familyfeatures/' consent_cookie.cookie['domain']='.vudu.com' consent_cookie.cookie['path']='/' vudu.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, vewd.com/postrej_0.har.xz not have cookie OptanonConsent of .tivo.com on path /
# Post rej cookie not contain consent cookie, seriouseats.com/postrej_0.har.xz not have cookie OptanonConsent of .seriouseats.com on path /
# Domain path mismatch: .www.pwc.com domain's path /us not match url https://www.pwc.com/hn/es/
# Unmatch url and consent cookie domain: page_url='https://www.pwc.com/hn/es/' consent_cookie.cookie['domain']='.www.pwc.com' consent_cookie.cookie['path']='/us' pwc.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, codashop.com/postrej_2.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_5.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_1.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_3.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_4.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_5.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_1.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_3.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_4.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, geforce.com/postrej_0.har.xz not have cookie OptanonConsent of .nvidia.com on path /
# Post rej cookie not contain consent cookie, dexcom.com/postrej_0.har.xz not have cookie OptanonConsent of .dexcom.com on path /
# Post rej cookie not contain consent cookie, learnreligions.com/postrej_0.har.xz not have cookie OptanonConsent of .learnreligions.com on path /
# Post rej cookie not contain consent cookie, turnitin.com/postrej_0.har.xz not have cookie OptanonConsent of .turnitin.com on path /
# Post rej cookie not contain consent cookie, sheffield.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .sheffield.ac.uk on path /
# Post rej cookie not contain consent cookie, mariadb.org/postrej_2.har.xz not have cookie CookieConsent of mariadb.org on path /
# Unmatch url and consent cookie domain: page_url='https://identity.monster.com/login?state=hKFo2SBSNUFzbmlZY1hCVVVvSXZSaHd2NkFzWTVLV0g5NHFlSKFupWxvZ2luo3RpZNkgWUtON1lGNElCN0FVYmZ0U1JlSnJQSzAxLVFmNzh6QUyjY2lk2SBRZkh3TVY5dHVhM09hb0pJVmE3cThLTVBoUHROTEdMcw&client=QfHwMV9tua3OaoJIVa7q8KMPhPtNLGLs&protocol=oauth2&redirect_uri=https%3A%2F%2Fwww.monster.ca%2Fmessage-center%2Fapi%2Fauth-callback&response_type=code&audience=profiles-profile-app-service&scope=openid%20profile%20email%20offline_access&monsterProps=eyJsYW5ndWFnZVRhZyI6ImVuLUNBIiwicmVjb2duaXplZFVzZXIiOmZhbHNlfQ' consent_cookie.cookie['domain']='.monster.ca' consent_cookie.cookie['path']='/' monster.ca/postrej_3.har.xz
# Post rej cookie not contain consent cookie, phenompeople.com/postrej_0.har.xz not have cookie OptanonConsent of .phenom.com on path /
# Domain path mismatch: .klarna.com domain's path /us/ not match url https://www.klarna.com/ca/
# Unmatch url and consent cookie domain: page_url='https://www.klarna.com/ca/' consent_cookie.cookie['domain']='.klarna.com' consent_cookie.cookie['path']='/us/' usehero.com/postrej_5.har.xz
# Domain path mismatch: .klarna.com domain's path /us/ not match url https://www.klarna.com/ch/en/
# Unmatch url and consent cookie domain: page_url='https://www.klarna.com/ch/en/' consent_cookie.cookie['domain']='.klarna.com' consent_cookie.cookie['path']='/us/' usehero.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, exponential.com/postrej_0.har.xz not have cookie OptanonConsent of .exponential.com on path /
# Post rej cookie not contain consent cookie, sonymobile.com/postrej_0.har.xz not have cookie OptanonConsent of .electronics.sony.com on path /
# Post rej cookie not contain consent cookie, se.com/postrej_0.har.xz not have cookie OptanonConsent of .se.com on path /
# Post rej cookie not contain consent cookie, accenture.com/postrej_0.har.xz not have cookie OptanonConsent of .accenture.com on path /
# Post rej cookie not contain consent cookie, cddbp.net/postrej_0.har.xz not have cookie OptanonConsent of .gracenote.com on path /
# Post rej cookie not contain consent cookie, schneider-electric.com/postrej_0.har.xz not have cookie OptanonConsent of .se.com on path /
# Unmatch url and consent cookie domain: page_url='https://my.bmwusa.com/privacypolicy' consent_cookie.cookie['domain']='.www.bmwusa.com' consent_cookie.cookie['path']='/' bmwusa.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, thoughtco.com/postrej_0.har.xz not have cookie OptanonConsent of .thoughtco.com on path /
# Post rej cookie not contain consent cookie, thoughtco.com/postrej_3.har.xz not have cookie OptanonConsent of .thoughtco.com on path /
# Post rej cookie not contain consent cookie, frontier.com/postrej_0.har.xz not have cookie OptanonConsent of .frontier.com on path /
# Unmatch url and consent cookie domain: page_url='https://welcome.epam.in/' consent_cookie.cookie['domain']='.www.epam.com' consent_cookie.cookie['path']='/' epam.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, flightaware.com/postrej_4.har.xz not have cookie OptanonConsent of .flightaware.com on path /
# Unmatch url and consent cookie domain: page_url='https://id.elsevier.com/as/authorization.oauth2?ui_locales=en-US&client_id=HMM2-PROD&redirect_uri=https%3A%2F%2Fwww.us.elsevierhealth.com%2Fidplus-customer%2Ftoken%2Fexchange%2F&platSite=HMM2%2Fhmm2&response_type=code&prompt=login&state=8ff73bc7a996b3852d0f9e617c4a4dbe&scope=openid+profile+email+phone+address+els_auth_info+els_analytics_info+urn%3Acom%3Aelsevier%3Aidp%3Apolicy%3Aproduct%3Aindv_identity+urn%3Aidp%3Apolicy%3Aproduct%3Aconfirmation%3Aemailconfirmation' consent_cookie.cookie['domain']='.us.elsevierhealth.com' consent_cookie.cookie['path']='/' elsevierhealth.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, ic.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .imperial.ac.uk on path /
# Post rej cookie not contain consent cookie, eyeo.com/postrej_0.har.xz not have cookie OptanonConsent of .eyeo.com on path /
# Post rej cookie not contain consent cookie, penguin.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .penguin.co.uk on path /
# Post rej cookie not contain consent cookie, rackspacecloud.com/postrej_0.har.xz not have cookie OptanonConsent of .rackspace.com on path /
# Post rej cookie not contain consent cookie, questionpro.com/postrej_0.har.xz not have cookie OptanonConsent of .questionpro.com on path /
# Domain path mismatch: .www.hugoboss.com domain's path /us/ not match url https://www.hugoboss.com/on/demandware.store/Sites-US-Site/en_US/Account-RequireLogin?TargetURL=%2fus%2fpreferences
# Unmatch url and consent cookie domain: page_url='https://www.hugoboss.com/on/demandware.store/Sites-US-Site/en_US/Account-RequireLogin?TargetURL=%2fus%2fpreferences' consent_cookie.cookie['domain']='.www.hugoboss.com' consent_cookie.cookie['path']='/us/' hugoboss.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://services.acm.org/public/qj/genpubqj/publist/genpubqj_publist.cfm' consent_cookie.cookie['domain']='www.acm.org' consent_cookie.cookie['path']='/' acm.org/postrej_2.har.xz
# Domain path mismatch: .www.basf.com domain's path /us/ not match url https://www.basf.com/global/en/media/news-releases/2020/07/p-20-260
# Unmatch url and consent cookie domain: page_url='https://www.basf.com/global/en/media/news-releases/2020/07/p-20-260' consent_cookie.cookie['domain']='.www.basf.com' consent_cookie.cookie['path']='/us/' basf.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, yoti.com/postrej_0.har.xz not have cookie OptanonConsent of www.yoti.com on path /
# Post rej cookie not contain consent cookie, ucc.ie/postrej_0.har.xz not have cookie OptanonConsent of .www.ucc.ie on path /
# Post rej cookie not contain consent cookie, hidemyass.com/postrej_0.har.xz not have cookie OptanonConsent of .hidemyass.com on path /
# Post rej cookie not contain consent cookie, qualys.eu/postrej_0.har.xz not have cookie CookieConsent of www.qualys.com on path /
# Post rej cookie not contain consent cookie, toasttab.com/postrej_0.har.xz not have cookie OptanonConsent of .pos.toasttab.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.siriusxm.com/blog/' consent_cookie.cookie['domain']='.pandora.com' consent_cookie.cookie['path']='/' pandora.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, vfsglobal.com/postrej_5.har.xz not have cookie OptanonConsent of .vfsglobal.com on path /
# Post rej cookie not contain consent cookie, vfsglobal.com/postrej_0.har.xz not have cookie OptanonConsent of .vfsglobal.com on path /
# Post rej cookie not contain consent cookie, viasat.com/postrej_0.har.xz not have cookie OptanonConsent of .viasat.com on path /
# Unmatch url and consent cookie domain: page_url='https://apps.apple.com/us/app/vanity-fair-digital-edition/id427270716?ign-mpt=uo%3D4' consent_cookie.cookie['domain']='.vanityfair.com' consent_cookie.cookie['path']='/' vanityfair.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/mp/survey-templates/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/product/forms/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/about/vision-mission/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/about/leadership/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/templates/product-testing-survey-template/' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_4.har.xz
# Post rej cookie not contain consent cookie, tcs.com/postrej_0.har.xz not have cookie OptanonConsent of .tcs.com on path /
# Post rej cookie not contain consent cookie, imperial.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .imperial.ac.uk on path /
# Post rej cookie not contain consent cookie, cpanel.com/postrej_0.har.xz not have cookie CookieConsent of cpanel.net on path /
# Domain path mismatch: .sage.com domain's path /en-us/ not match url https://www.sage.com/de-at/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/de-at/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-us/' sage.com/postrej_2.har.xz
# Domain path mismatch: .sage.com domain's path /en-us/ not match url https://www.sage.com/pt-pt/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/pt-pt/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-us/' sage.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://eu.wargaming.net/id/signin/?next=%2Fid%2Fopenid%2F1948819795793845584%2F&trust_root=https%3A%2F%2Fworldoftanks.eu%2F' consent_cookie.cookie['domain']='.worldoftanks.eu' consent_cookie.cookie['path']='/' worldoftanks.eu/postrej_2.har.xz
# Post rej cookie not contain consent cookie, hyprmx.com/postrej_0.har.xz not have cookie OptanonConsent of .hyprmx.com on path /
# Post rej cookie not contain consent cookie, sc.com/postrej_0.har.xz not have cookie OptanonConsent of .sc.com on path /en/
# Post rej cookie not contain consent cookie, thespruceeats.com/postrej_0.har.xz not have cookie OptanonConsent of .thespruceeats.com on path /
# Unmatch url and consent cookie domain: page_url='https://gt4fpyj4y1.execute-api.us-east-1.amazonaws.com/ProdStage/products/gomi-no-sensei' consent_cookie.cookie['domain']='.viz.com' consent_cookie.cookie['path']='/' viz.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, pingdom.com/postrej_0.har.xz not have cookie OptanonConsent of .www.pingdom.com on path /
# Post rej cookie not contain consent cookie, stylitics.com/postrej_0.har.xz not have cookie OptanonConsent of .stylitics.com on path /
# Post rej cookie not contain consent cookie, kodak.com/postrej_0.har.xz not have cookie OptanonConsent of .www.kodak.com on path /
# Domain path mismatch: .sage.com domain's path /en-za/ not match url https://www.sage.com/fr-ca/sage-business-cloud/comptabilite/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/fr-ca/sage-business-cloud/comptabilite/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-za/' sageone.co.za/postrej_2.har.xz
# Domain path mismatch: .sage.com domain's path /en-za/ not match url https://www.sage.com/pt-pt/
# Unmatch url and consent cookie domain: page_url='https://www.sage.com/pt-pt/' consent_cookie.cookie['domain']='.sage.com' consent_cookie.cookie['path']='/en-za/' sageone.co.za/postrej_3.har.xz
# Post rej cookie not contain consent cookie, kaercher.com/postrej_0.har.xz not have cookie OptanonConsent of .kaercher.com on path /int/
# Post rej cookie not contain consent cookie, cognizant.com/postrej_0.har.xz not have cookie OptanonConsent of .cognizant.com on path /
# Post rej cookie not contain consent cookie, sanofi-synthelabo.com/postrej_0.har.xz not have cookie OptanonConsent of .www.sanofi.com on path /
# Post rej cookie not contain consent cookie, o2.co.uk/postrej_0.har.xz not have cookie OptanonConsent of www.o2.co.uk on path /
# Post rej cookie not contain consent cookie, merck.com/postrej_0.har.xz not have cookie OptanonConsent of .merck.com on path /
# Post rej cookie not contain consent cookie, download.com/postrej_0.har.xz not have cookie OptanonConsent of .download.cnet.com on path /
# Unmatch url and consent cookie domain: page_url='https://gameinsight.helpshift.com/hc/en/24-other-games/' consent_cookie.cookie['domain']='www.game-insight.com' consent_cookie.cookie['path']='/' game-insight.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, pb.com/postrej_0.har.xz not have cookie OptanonConsent of .pitneybowes.com on path /us
# Domain path mismatch: .pitneybowes.com domain's path /us not match url https://careers.pitneybowes.com/global/en?cm_sp=cards_image_homepage_default3_06012024
# Unmatch url and consent cookie domain: page_url='https://careers.pitneybowes.com/global/en?cm_sp=cards_image_homepage_default3_06012024' consent_cookie.cookie['domain']='.pitneybowes.com' consent_cookie.cookie['path']='/us' pb.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, plaid.com/postrej_0.har.xz not have cookie OptanonConsent of .plaid.com on path /
# Post rej cookie not contain consent cookie, purechat.com/postrej_0.har.xz not have cookie OptanonConsent of .purechat.com on path /
# Unmatch url and consent cookie domain: page_url='https://play.google.com/store/apps/details?id=com.avast.android.mobilesecurity&referrer=utm_source%3Davast_com%26amp%3Butm_medium%3Dhomepage%26amp%3Butm_campaign%3Dhomepage_ams&alt=en-us' consent_cookie.cookie['domain']='.avast.com' consent_cookie.cookie['path']='/' avast.com/postrej_4.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/givesmart.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/givesmart.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://www.americanexpress.com/us/credit-cards/card/delta-skymiles-gold-american-express-card/?eep=26129&irgwc=1&veid=TXGXczUkAxyKR4qVtl3h3UtuUkCUraQPVVheUM0&affid=1137073&pid=IR&affname=TPG&sid=12011830006&pmc=113&BUID=CCG&CRTV=controlaffcps&MPR=05' consent_cookie.cookie['domain']='.thepointsguy.com' consent_cookie.cookie['path']='/' thepointsguy.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.americanexpress.com/us/credit-cards/card/gold-card/?eep=26129&extlink=af-us-ccsg-GLDLM&irgwc=1&veid=TXGXcwUkAxyKR4qVtl3h3UtuUkCUraQPVVheUM0&affid=1137073&pid=IR&affname=TPG&sid=12011830006&pmc=784&BUID=CCG&CRTV=controlaffcps&MPR=05' consent_cookie.cookie['domain']='.thepointsguy.com' consent_cookie.cookie['path']='/' thepointsguy.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://policies.warnerbros.com/terms/en-us/html/terms_en-us_1.4.0.html' consent_cookie.cookie['domain']='.adultswim.com' consent_cookie.cookie['path']='/' adultswim.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, smooch.io/postrej_0.har.xz not have cookie OptanonConsent of .www.zendesk.com on path /
# Post rej cookie not contain consent cookie, unaids.org/postrej_0.har.xz not have cookie CookieConsent of www.unaids.org on path /
# Post rej cookie not contain consent cookie, nhl.com/postrej_2.har.xz not have cookie OptanonConsent of .nhl.com on path /
# Post rej cookie not contain consent cookie, nhl.com/postrej_3.har.xz not have cookie OptanonConsent of .nhl.com on path /
# Post rej cookie not contain consent cookie, nhl.com/postrej_4.har.xz not have cookie OptanonConsent of .nhl.com on path /
# Post rej cookie not contain consent cookie, showtime.com/postrej_0.har.xz not have cookie OptanonConsent of .paramountpluswithshowtime.com on path /
# Post rej cookie not contain consent cookie, ew.com/postrej_0.har.xz not have cookie OptanonConsent of .ew.com on path /
# Post rej cookie not contain consent cookie, duosecurity.com/postrej_0.har.xz not have cookie OptanonConsent of .duo.com on path /
# Post rej cookie not contain consent cookie, lifewire.com/postrej_0.har.xz not have cookie OptanonConsent of .lifewire.com on path /
# Unmatch url and consent cookie domain: page_url='https://service.elsevier.com/app/answers/detail/a_id/21591/supporthub/scopus/' consent_cookie.cookie['domain']='.scopus.com' consent_cookie.cookie['path']='/' scopus.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://id.elsevier.com/as/authorization.oauth2?platSite=SC%2Fscopus&ui_locales=en-US&scope=openid+profile+email+els_auth_info+els_analytics_info+urn%3Acom%3Aelsevier%3Aidp%3Apolicy%3Aproduct%3Aindv_identity&els_policy=idp_policy_indv_identity_plus&response_type=code&redirect_uri=https%3A%2F%2Fwww.scopus.com%2Fauthredirect.uri%3FtxGid%3Dd0f1bff067e3be9d0362db1adaf16b58&state=userLogin%7CtxId%3DA68F7F9D3C473F009AF061D417785505.i-012806431274ac8c6%3A10&authType=SINGLE_SIGN_IN&prompt=login&client_id=SCOPUS' consent_cookie.cookie['domain']='.scopus.com' consent_cookie.cookie['path']='/' scopus.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://eab.app.box.com/s/ig1xoav1pag3q3af1k812bdthzfyhcwn' consent_cookie.cookie['domain']='.www.youvisit.com' consent_cookie.cookie['path']='/' youvisit.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.appily.com/virtual-college-tours?utm_source=referral&utm_medium=youvisit' consent_cookie.cookie['domain']='.www.youvisit.com' consent_cookie.cookie['path']='/' youvisit.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, fonts.com/postrej_0.har.xz not have cookie OptanonConsent of .www.fonts.com on path /
# Unmatch url and consent cookie domain: page_url='https://student.kent.ac.uk/careers' consent_cookie.cookie['domain']='www.kent.ac.uk' consent_cookie.cookie['path']='/' kent.ac.uk/postrej_4.har.xz
# Post rej cookie not contain consent cookie, fonts.net/postrej_0.har.xz not have cookie OptanonConsent of .www.fonts.com on path /
# Post rej cookie not contain consent cookie, verywellmind.com/postrej_5.har.xz not have cookie OptanonConsent of .verywellmind.com on path /
# Post rej cookie not contain consent cookie, playboy.com/postrej_0.har.xz not have cookie OptanonConsent of .playboy.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_2.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_1.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_0.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, sho.com/postrej_0.har.xz not have cookie OptanonConsent of .paramountpluswithshowtime.com on path /
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/il/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/il/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_2.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/md/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/md/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, kpmg.com/postrej_0.har.xz not have cookie OptanonConsent of .kpmg.com on path /xx
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/za/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/za/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' kpmg.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://investors.thetradedesk.com/overview/default.aspx' consent_cookie.cookie['domain']='.www.thetradedesk.com' consent_cookie.cookie['path']='/' uidapi.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://auth.thetradedesk.com/Account/Login?ReturnUrl=%2Fconnect%2Fauthorize%2Fcallback%3Fscope%3Dopenid%2520ttdui_refresh%2520profile%2520email%2520offline_access%2520ttdapi_elevated%26state%3D880ee6e1b34d09f71bf733ce25d05111%26redirect_uri%3Dhttps%253A%252F%252Fdesk.thetradedesk.com%252Fsignin-gw%26response_type%3Dcode%26client_id%3Ddesk.refresh%26nonce%3D86fcb122db7feeec75815646a0b2f80d' consent_cookie.cookie['domain']='.www.thetradedesk.com' consent_cookie.cookie['path']='/' uidapi.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, tide.co/postrej_0.har.xz not have cookie OptanonConsent of .www.tide.co on path /
# Unmatch url and consent cookie domain: page_url='https://www.forbusiness.viber.com/en/' consent_cookie.cookie['domain']='.www.viber.com' consent_cookie.cookie['path']='/' viber.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.lseg.com.cn/zh/data-analytics' consent_cookie.cookie['domain']='.www.lseg.com' consent_cookie.cookie['path']='/' refinitiv.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kaspersky.com/about/policy-blog' consent_cookie.cookie['domain']='usa.kaspersky.com' consent_cookie.cookie['path']='/' kaspersky-labs.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, kaspersky-labs.com/postrej_0.har.xz not have cookie CookieConsent of usa.kaspersky.com on path /
# Unmatch url and consent cookie domain: page_url='https://jobs.ashbyhq.com/sleeper' consent_cookie.cookie['domain']='.sleeper.com' consent_cookie.cookie['path']='/' sleeper.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/comenity.net/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, ucd.ie/postrej_0.har.xz not have cookie OptanonConsent of .ucd.ie on path /
# Post rej cookie not contain consent cookie, paramountplus.com/postrej_1.har.xz not have cookie OptanonConsent of .paramountplus.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.altium365.com/customer-success/converting-mundane-masterpiece-karcher' consent_cookie.cookie['domain']='.altium.com' consent_cookie.cookie['path']='/' altium.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.youtube.com/watch?v=HukAIZ5G2Vk' consent_cookie.cookie['domain']='.seagate.com' consent_cookie.cookie['path']='/' seagate.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/grab.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, bet.com/postrej_0.har.xz not have cookie OptanonConsent of .bet.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/paloaltonetworks.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.chroniclelive.co.uk/' consent_cookie.cookie['domain']='www.fish4.co.uk' consent_cookie.cookie['path']='/' chroniclelive.co.uk/postrej_0.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.youtube.com/sixgroup' consent_cookie.cookie['domain']='.six-group.com' consent_cookie.cookie['path']='/' six-group.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, sendbird.com/postrej_2.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_5.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_1.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_3.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, sendbird.com/postrej_4.har.xz not have cookie OptanonConsent of .sendbird.com on path /
# Post rej cookie not contain consent cookie, verywellfit.com/postrej_0.har.xz not have cookie OptanonConsent of .verywellfit.com on path /
# Unmatch url and consent cookie domain: page_url='https://tivo.pactsafe.io/legal.html#privacy-policy' consent_cookie.cookie['domain']='.tivo.com' consent_cookie.cookie['path']='/' tivo.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, prodigygame.com/postrej_0.har.xz not have cookie OptanonConsent of .prodigygame.com on path /
# Post rej cookie not contain consent cookie, qualys.com/postrej_0.har.xz not have cookie CookieConsent of www.qualys.com on path /
# Post rej cookie not contain consent cookie, sothebys.com/postrej_0.har.xz not have cookie OptanonConsent of .www.sothebys.com on path /
# Post rej cookie not contain consent cookie, zopim.com/postrej_0.har.xz not have cookie OptanonConsent of .www.zendesk.com on path /
# Post rej cookie not contain consent cookie, cbsnews.com/postrej_5.har.xz not have cookie OptanonConsent of .cbsnews.com on path /
# Post rej cookie not contain consent cookie, cbsnews.com/postrej_1.har.xz not have cookie OptanonConsent of .cbsnews.com on path /
# Post rej cookie not contain consent cookie, nngroup.com/postrej_0.har.xz not have cookie CookieConsent of www.nngroup.com on path /
# Unmatch url and consent cookie domain: page_url='https://belgium.tomorrowland.com/en/tickets/your-privacy/' consent_cookie.cookie['domain']='www.tomorrowland.com' consent_cookie.cookie['path']='/' tomorrowland.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, auctollo.com/postrej_0.har.xz not have cookie CookieConsent of auctollo.com on path /
# Post rej cookie not contain consent cookie, auctollo.com/postrej_3.har.xz not have cookie CookieConsent of auctollo.com on path /
# Unmatch url and consent cookie domain: page_url='https://about.proquest.com/en/products-services/ProQuest-One-Academic/' consent_cookie.cookie['domain']='.clarivate.com' consent_cookie.cookie['path']='/' clarivate.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://community.contentsquare.com/private/login' consent_cookie.cookie['domain']='.heap.io' consent_cookie.cookie['path']='/' auryc.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, duo.com/postrej_0.har.xz not have cookie OptanonConsent of .duo.com on path /
# Post rej cookie not contain consent cookie, customink.com/postrej_0.har.xz not have cookie OptanonConsent of .customink.com on path /
# Unmatch url and consent cookie domain: page_url='https://eyewiki.org/Main_Page' consent_cookie.cookie['domain']='.aao.org' consent_cookie.cookie['path']='/' aao.org/postrej_3.har.xz
# Post rej cookie not contain consent cookie, ipl.org/postrej_0.har.xz not have cookie OptanonConsent of .ipl.org on path /
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/zoom-ventures/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/customer-stories/all/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/products/virtual-meetings/features/virtual-background-library/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.us/postrej_4.har.xz
# Post rej cookie not contain consent cookie, marthastewart.com/postrej_0.har.xz not have cookie OptanonConsent of .marthastewart.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/services/success-services' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/services/consulting' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/services' consent_cookie.cookie['domain']='.www.microfocus.com' consent_cookie.cookie['path']='/' microfocus.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.visittrinity.ie/' consent_cookie.cookie['domain']='.tcd.ie' consent_cookie.cookie['path']='/' tcd.ie/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.ubs.com/global/en/investment-bank.html' consent_cookie.cookie['domain']='.credit-suisse.com' consent_cookie.cookie['path']='/' credit-suisse.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.ubs.com/global/en/investment-bank.html' consent_cookie.cookie['domain']='.credit-suisse.com' consent_cookie.cookie['path']='/' credit-suisse.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/lokalise.co/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, zendesk.com/postrej_0.har.xz not have cookie OptanonConsent of .www.zendesk.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.inscape.tv/' consent_cookie.cookie['domain']='.www.vizio.com' consent_cookie.cookie['path']='/' vizio.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, vizio.com/postrej_0.har.xz not have cookie OptanonConsent of .www.vizio.com on path /
# Unmatch url and consent cookie domain: page_url='https://accounts.icc-cricket.com/4ba9f276-2497-440e-a6ba-d05d4831b967/b2c_1a_signinsignup/oauth2/v2.0/authorize?client_id=36da6054-8552-4015-a6b2-b7b6906fd4ab&scope=profile%20openid%20offline_access%20https%3A%2F%2Ficcprdlogin.onmicrosoft.com%2Fapi%2Fcatalogue.read%20openid%20profile%20offline_access&redirect_uri=https%3A%2F%2Fwww.icc-cricket.com%2Fsignin&client-request-id=bcf1a595-6664-4838-92e9-ad42ef6ca860&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.38.4&client_info=1&code_challenge=_0tPuTgO4wXGkrTqFu9tUEs7c8U1A9XunNfsTcRzGcA&code_challenge_method=S256&nonce=d4cab1ab-ca1e-4344-9cd1-e49deaf46bd9&state=eyJpZCI6ImYxZTQ2MjMwLThhODUtNDViMS04MjUzLTQ1MmVkY2E1ZGNiMSIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D' consent_cookie.cookie['domain']='.www.icc-cricket.com' consent_cookie.cookie['path']='/' cricketworldcup.com/postrej_5.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/sketchfab.com/postrej_5.har.xz: Expecting ',' delimiter: line 1 column 240760 (char 240759)
# Post rej cookie not contain consent cookie, 2ksports.com/postrej_0.har.xz not have cookie OptanonConsent of .2k.com on path /
# Post rej cookie not contain consent cookie, dow.com/postrej_0.har.xz not have cookie OptanonConsent of .dow.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.jerseysbest.com/events/#/' consent_cookie.cookie['domain']='.nj.com' consent_cookie.cookie['path']='/' nj.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/datto.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, nbc.com/postrej_0.har.xz not have cookie OptanonConsent of .nbc.com on path /
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/funcom.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/funcom.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://www.facebook.com/prezicom/' consent_cookie.cookie['domain']='.prezi.com' consent_cookie.cookie['path']='/' prezi.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, thefa.com/postrej_0.har.xz not have cookie OptanonConsent of .www.thefa.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/lastline.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://app.squareup.com/signup?app=weebly&return_to=https%3A%2F%2Fwww.weebly.com%2Fapp%2Ffront-door%2Flogin%2Fsquare%3Fsso_intent%3Dsignup&v=weebly-sso&weebly_sso_enabled=true' consent_cookie.cookie['domain']='.weebly.com' consent_cookie.cookie['path']='/' weebly.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_2.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_1.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_0.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_3.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Post rej cookie not contain consent cookie, chaosgroup.com/postrej_4.har.xz not have cookie OptanonConsent of .chaos.com on path /
# Unmatch url and consent cookie domain: page_url='https://centres.weforum.org/centre-for-advanced-manufacturing-and-supply-chains/home' consent_cookie.cookie['domain']='www.weforum.org' consent_cookie.cookie['path']='/' weforum.org/postrej_3.har.xz
# Post rej cookie not contain consent cookie, breitbart.com/postrej_0.har.xz not have cookie OptanonConsent of .breitbart.com on path /
# Unmatch url and consent cookie domain: page_url='https://promotions.bankofamerica.com/student-banking' consent_cookie.cookie['domain']='.www.bankofamerica.com' consent_cookie.cookie['path']='/' bac.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://resources.trustyou.com/' consent_cookie.cookie['domain']='www.trustyou.com' consent_cookie.cookie['path']='/' trustyou.com/postrej_1.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/sharechat.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/sharechat.com/log.json'
# Post rej cookie not contain consent cookie, simplyrecipes.com/postrej_0.har.xz not have cookie OptanonConsent of .simplyrecipes.com on path /
# Post rej cookie not contain consent cookie, instyle.com/postrej_0.har.xz not have cookie OptanonConsent of .instyle.com on path /
# Post rej cookie not contain consent cookie, uic.edu/postrej_0.har.xz not have cookie OptanonConsent of .uic.edu on path /
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://auth.chubb.com/auth.chubb.com/b2c_1a_agentportal_signin/oauth2/v2.0/authorize?client_id=d4baa39f-9745-41a3-b0be-9a4d35fe745e&scope=https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Fread%20https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Fwrite%20https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Faccess.operations.allow%20openid%20profile&redirect_uri=https%3A%2F%2Fagentview.chubb.com&client-request-id=fb85cf34-6962-489a-afe8-72ea7590b347&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.11.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=9XxvfSFO-QxcvAHPXdzwnget9BxpZwLrJx6wL3r3bpI&code_challenge_method=S256&nonce=5341a227-f6f7-4c20-87f4-166b1acf501e&state=eyJpZCI6IjZlNmU4YmE2LWE5NDktNGY1YS05NWI2LTQ0MDA3ZjUxY2FjMiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D
# Unmatch url and consent cookie domain: page_url='https://auth.chubb.com/auth.chubb.com/b2c_1a_agentportal_signin/oauth2/v2.0/authorize?client_id=d4baa39f-9745-41a3-b0be-9a4d35fe745e&scope=https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Fread%20https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Fwrite%20https%3A%2F%2Fb2c.chubbdigital.com%2FAtChubbAgentPortalAPI%2Faccess.operations.allow%20openid%20profile&redirect_uri=https%3A%2F%2Fagentview.chubb.com&client-request-id=fb85cf34-6962-489a-afe8-72ea7590b347&response_mode=fragment&response_type=code&x-client-SKU=msal.js.browser&x-client-VER=2.11.0&x-client-OS=&x-client-CPU=&client_info=1&code_challenge=9XxvfSFO-QxcvAHPXdzwnget9BxpZwLrJx6wL3r3bpI&code_challenge_method=S256&nonce=5341a227-f6f7-4c20-87f4-166b1acf501e&state=eyJpZCI6IjZlNmU4YmE2LWE5NDktNGY1YS05NWI2LTQ0MDA3ZjUxY2FjMiIsIm1ldGEiOnsiaW50ZXJhY3Rpb25UeXBlIjoicmVkaXJlY3QifX0%3D' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_5.har.xz
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://prsclientview.chubb.com/#/billing/quickpay
# Unmatch url and consent cookie domain: page_url='https://prsclientview.chubb.com/#/billing/quickpay' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, kaspersky.com/postrej_0.har.xz not have cookie CookieConsent of usa.kaspersky.com on path /
# Post rej cookie not contain consent cookie, namecheap.com/postrej_0.har.xz not have cookie OptanonConsent of .namecheap.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/brightcloud.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://help.surveymonkey.com/en/wufoo/build/' consent_cookie.cookie['domain']='.wufoo.com' consent_cookie.cookie['path']='/' wufoo.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/careers/' consent_cookie.cookie['domain']='.wufoo.com' consent_cookie.cookie['path']='/' wufoo.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://preview.codecanyon.net/item/bookly-booking-plugin-responsive-appointment-booking-and-scheduling/full_screen_preview/7226091' consent_cookie.cookie['domain']='codecanyon.net' consent_cookie.cookie['path']='/' codecanyon.net/postrej_1.har.xz
# Post rej cookie not contain consent cookie, codecanyon.net/postrej_0.har.xz not have cookie CookieConsent of codecanyon.net on path /
# Post rej cookie not contain consent cookie, stitcher.com/postrej_5.har.xz not have cookie OptanonConsent of .www.stitcher.com on path /
# Post rej cookie not contain consent cookie, nvidia.com/postrej_0.har.xz not have cookie OptanonConsent of .nvidia.com on path /
# Post rej cookie not contain consent cookie, cc.com/postrej_0.har.xz not have cookie OptanonConsent of .cc.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.zoom.com/en/zoom-ventures/' consent_cookie.cookie['domain']='.zoom.us' consent_cookie.cookie['path']='/' zoom.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/policies-legal' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/contact' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, adyen.com/postrej_2.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_5.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_0.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Post rej cookie not contain consent cookie, adyen.com/postrej_3.har.xz not have cookie OptanonConsent of .adyen.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/boeing.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, natwest.com/postrej_0.har.xz not have cookie OptanonConsent of .natwest.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/paramount.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='http://validate.perfdrive.com/b708a8fc3776ece65dd51a0e70b3ae8e/?ssa=accbb869-ff8f-4d41-bdf6-51f1edc87257&ssb=59635217161&ssc=https%3A%2F%2Fwww.redlobster.com%2Fcontact-us%2F&ssi=2f57942f-94c0-48fd-b583-de6fe076a7f2&ssk=support@shieldsquare.com&ssm=03535084285592426135646254007834&ssn=f7024ba12aab3b02cb6cf7f0fa94998934188364cafc-548a-4fed-8f4744&sso=29883dca-291769213db51ee21199d181c63e4b11d27b42762edaf4b1&ssp=69780780691728299384172829299442620&ssq=97930334005800988512640056082642268151474&ssr=MTQxLjIxMi4xMTMuMTAx&sst=Mozilla/5.0%20(X11;%20Linux%20x86_64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/101.0.4951.64%20Safari/537.36&ssu=QzcyZDhHVjdLQjZlZWxibFRMSEFQL1J0S0pIZFNZZ1dVeWNzeENldHJYcz0=&ssv=&ssw=&ssx=' consent_cookie.cookie['domain']='.redlobster.com' consent_cookie.cookie['path']='/' redlobster.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, sgn.com/postrej_0.har.xz not have cookie CookieConsent of www.jamcity.com on path /
# Post rej cookie not contain consent cookie, pingdom.net/postrej_0.har.xz not have cookie OptanonConsent of .www.pingdom.com on path /
# Post rej cookie not contain consent cookie, pingdom.net/postrej_3.har.xz not have cookie OptanonConsent of .www.pingdom.com on path /
# Post rej cookie not contain consent cookie, shef.ac.uk/postrej_0.har.xz not have cookie OptanonConsent of .sheffield.ac.uk on path /
# Post rej cookie not contain consent cookie, sonymusic.com/postrej_2.har.xz not have cookie OptanonConsent of .sonymusic.com on path /
# Post rej cookie not contain consent cookie, sonymusic.com/postrej_0.har.xz not have cookie OptanonConsent of .sonymusic.com on path /
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/rs/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/rs/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' home.kpmg/postrej_2.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/lv/lv/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/lv/lv/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' home.kpmg/postrej_1.har.xz
# Post rej cookie not contain consent cookie, home.kpmg/postrej_0.har.xz not have cookie OptanonConsent of .kpmg.com on path /xx
# Domain path mismatch: .kpmg.com domain's path /xx not match url https://kpmg.com/cn/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/cn/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx' home.kpmg/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://developers.cloudflare.com/workers' consent_cookie.cookie['domain']='workers.cloudflare.com' consent_cookie.cookie['path']='/' workers.dev/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/fivem.net/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, fivem.net/postrej_0.har.xz not have cookie OptanonConsent of .fivem.net on path /
# Post rej cookie not contain consent cookie, gracenote.com/postrej_0.har.xz not have cookie OptanonConsent of .gracenote.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/arcticwolf.net/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, cookielaw.org/postrej_0.har.xz not have cookie OptanonConsent of .cookielaw.org on path /
# Post rej cookie not contain consent cookie, cookielaw.org/postrej_4.har.xz not have cookie OptanonConsent of .cookielaw.org on path /
# Post rej cookie not contain consent cookie, nexstardigital.net/postrej_0.har.xz not have cookie OptanonConsent of .nexstardigital.com on path /
# Unmatch url and consent cookie domain: page_url='https://developer.moloco.cloud/' consent_cookie.cookie['domain']='.moloco.com' consent_cookie.cookie['path']='/' moloco.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/docker.io/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, metacritic.com/postrej_0.har.xz not have cookie OptanonConsent of .metacritic.com on path /
# Unmatch url and consent cookie domain: page_url='https://account.cengage.com/login?SAMLRequest=fZJdS8MwFIb%2FSsl926SzXRfWyXAIAx3iF%2BJdSM9qsD2pOenm%2Fr2xc6IXeplwzvO%2BPMn8%2FL1rox04MhYrJhLOIkBta4NNxR7uL%2BOSnS%2FmpLo26%2BVy8C94C28DkI%2BWROB8WLuwSEMH7g7czmh4uL2q2Iv3Pck0VWEj0YCNaiDRtkuJbDrSUm5VVuSl2CJtnvJNs5zkUxatAtqg8mOdb4rWdkD%2FC9TaxiCLLq3TMPaq2Fa1BCxarypmalHwojybTkpRFnzCRThnophNyzxMEA2wRvIKfcUynp3Fgse8uBczmeeST5PZjD%2Bz6PHkJfv0EkwhyaOKig0OpVVkSKLqgKTX8m55fSXDqOyd9Vbbln2Zk2Og%2B0n4H6BObtni5GC%2F3yf21aujxdEgHYXHIW5nanAp9TusO0B1sL1r3lR9qP08%2FVnh%2Byk3IXO9urGt0YdPiZ3yf1cSiRhvTB1vx1E5IPWgzdZAzdLFV8bvD7L4AA%3D%3D&RelayState=%252Foauth2%252Fv1%252Fauthorize%252Fredirect%253Fokta_key%253DkC69EUW6umKYpQD_O5nyHbaKYiqcFsbt7PT66IR90Co&SigAlg=http%3A%2F%2Fwww.w3.org%2F2001%2F04%2Fxmldsig-more%23rsa-sha256&Signature=tfW2w3MJb8lNMhBvJAzDHeQTn3I6VJKzOkUbMEe8iK2rLEVaT73VP3wepiNNtlFQ65%2BxFHiIVm6CJ97L6Pjo%2FjfHIM5cnQR6bGolL6xvf2Joxxricxwr1wbcCIiQjjGez58AfP%2FpyD6t2NAlulag8xnIVID2W%2BvCA63HBlkK2EN6wrwVJ22EZGJHrp4l6K6iVGpqBCf%2BUK3smn5oSrcGuoRnbho84WPUkrAJDW2cvT4ZlgyqifIkLCvXs2xU%2BW8qXbuzq0qMgKe5v4utItd6rCaPSbYj8OINcghYxaGSPLLxDMbfteJBgzRs%2BztQaiwVb4YO5EbTRqZtn8W7qHHKzg%3D%3D' consent_cookie.cookie['domain']='.webassign.net' consent_cookie.cookie['path']='/' webassign.net/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://myjobs.adp.com/ifitcareers/cx?__tx_annotation=false&c=2177119&sor=adprm' consent_cookie.cookie['domain']='.ifit.com' consent_cookie.cookie['path']='/' ifit.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, crazydomains.com/postrej_0.har.xz not have cookie OptanonConsent of .crazydomains.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/bendingspoonsapps.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, videobyte.com/postrej_0.har.xz not have cookie OptanonConsent of .videobyte.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.outbrain.com/privacy/privacy-policy-outbrain-dsp/' consent_cookie.cookie['domain']='.zemanta.com' consent_cookie.cookie['path']='/' zemanta.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.starlinkinternet.info/community-gateway' consent_cookie.cookie['domain']='.starlink.com' consent_cookie.cookie['path']='/' starlink.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, control4.com/postrej_0.har.xz not have cookie OptanonConsent of .control4.com on path /
# Unmatch url and consent cookie domain: page_url='https://maplemedia.io/terms-of-service/' consent_cookie.cookie['domain']='.player.fm' consent_cookie.cookie['path']='/' player.fm/postrej_4.har.xz
# Post rej cookie not contain consent cookie, technologyreview.com/postrej_0.har.xz not have cookie OptanonConsent of .technologyreview.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/tickets.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login.fronius.com/authenticationendpoint/login.do?client_id=mf_o9iTAyKemNLQTa6Sp6HYonCIa&commonAuthCallerPath=%2Foauth2%2Fauthorize&forceAuth=false&nonce=638638424677349744.MWNkZDk2NDctZDFkYS00ZWY3LWFjZWYtMTAzOGQwODM0NWMyOGFhNDZlNGQtNGM0ZS00ODZlLWJmMWItZWM1YjQ0NDQxY2Ix&passiveAuth=false&redirect_uri=https%3A%2F%2Fwww.solarweb.com%2FAccount%2FExternalLoginCallback&response_mode=form_post&response_type=code+id_token&scope=openid+profile+solarweb+solweb_browserid_93c65d8e866a6421e43a4e3d7b75f200&state=OpenIdConnect.AuthenticationProperties%3DkZdh484G3knILohXYcXKtv1EkLL9ifb2WX2gPe12zFxVbrc0Pa2qH8Ww3iBBLZmRfbCFJA2fhE5ncoo7z5FcHz4ATdSfWJ2flJD5JlpHiWlwSoTfVgJCLYg0KIFlb00PzThrNlqELk8_EGy3DHkT8mWMazP5GuP1TcBysBLmEuCjagEEvxRTy2o1GqrUGQhQDuhl5zp5xdbKo3E6RTnsiSvjS-macOfmKy9L1ihsaRbykeSJg6SqylcodsLMfUq4ULuMcw&tenantDomain=carbon.super&x-client-SKU=ID_NET461&x-client-ver=6.9.0.0&sessionDataKey=c28d0bda-eef6-471d-8990-c37db025de06&relyingParty=mf_o9iTAyKemNLQTa6Sp6HYonCIa&type=oidc&sp=Solar.web+-+Portals&isSaaSApp=false&authenticators=SAMLSSOAuthenticator%3AFronius+Login%3BFroniusBasicAuthenticator%3ALOCAL' consent_cookie.cookie['domain']='www.solarweb.com' consent_cookie.cookie['path']='/' solarweb.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, bsigroup.com/postrej_0.har.xz not have cookie OptanonConsent of .www.bsigroup.com on path /
# Post rej cookie not contain consent cookie, mynewsdesk.com/postrej_0.har.xz not have cookie OptanonConsent of .mynewsdesk.com on path /
# Post rej cookie not contain consent cookie, dxc.com/postrej_0.har.xz not have cookie OptanonConsent of .dxc.com on path /
# Post rej cookie not contain consent cookie, redbull.com/postrej_2.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_5.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_1.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_0.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_3.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_4.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, parsec.app/postrej_0.har.xz not have cookie OptanonConsent of .parsec.app on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/slotomania.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, sonypictures.com/postrej_0.har.xz not have cookie OptanonConsent of .www.sonypictures.com on path /
# Post rej cookie not contain consent cookie, sonypictures.com/postrej_4.har.xz not have cookie OptanonConsent of .www.sonypictures.com on path /
# Post rej cookie not contain consent cookie, agora.io/postrej_2.har.xz not have cookie OptanonConsent of .agora.io on path /
# Post rej cookie not contain consent cookie, themeforest.net/postrej_0.har.xz not have cookie CookieConsent of themeforest.net on path /
# Post rej cookie not contain consent cookie, 2k.com/postrej_0.har.xz not have cookie OptanonConsent of .2k.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.airship.com/legal/gdpr-ccpa/' consent_cookie.cookie['domain']='.apptimize.com' consent_cookie.cookie['path']='/' apptimize.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, gitlab.io/postrej_0.har.xz not have cookie OptanonConsent of .gitlab.com on path /
# Post rej cookie not contain consent cookie, trustpilot.com/postrej_0.har.xz not have cookie OptanonConsent of .trustpilot.com on path /
# Unmatch url and consent cookie domain: page_url='https://treasuredata.influitive.com/users/sign_in' consent_cookie.cookie['domain']='.treasuredata.com' consent_cookie.cookie['path']='/' treasuredata.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://community.contentsquare.com/private/login' consent_cookie.cookie['domain']='.heap.io' consent_cookie.cookie['path']='/' heapanalytics.com/postrej_3.har.xz
# Domain path mismatch: .www.carrier.com domain's path /carrier not match url https://www.carrier.com/residential/en/us/products/indoor-air-quality/
# Unmatch url and consent cookie domain: page_url='https://www.carrier.com/residential/en/us/products/indoor-air-quality/' consent_cookie.cookie['domain']='.www.carrier.com' consent_cookie.cookie['path']='/carrier' carrier.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, tvguide.com/postrej_0.har.xz not have cookie OptanonConsent of .tvguide.com on path /
# Post rej cookie not contain consent cookie, empower.com/postrej_0.har.xz not have cookie OptanonConsent of .empower.com on path /
# Post rej cookie not contain consent cookie, mtv.com/postrej_0.har.xz not have cookie OptanonConsent of .mtv.com on path /
# Unmatch url and consent cookie domain: page_url='https://shop.nationalgallery.org.uk/' consent_cookie.cookie['domain']='www.nationalgallery.org.uk' consent_cookie.cookie['path']='/' nationalgallery.org.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.techsmith.com/u/login/identifier?state=hKFo2SBjYUtEbkw5d0I5aDYzTGlEakN0YVlpeElyRFdlOWlJNqFur3VuaXZlcnNhbC1sb2dpbqN0aWTZIFBfN3gxYWVqTjExRXI2ZGZoZU5fdHJXekN3cUNOSlV1o2NpZNkgMExSQzFJMXhDTFEzajQwSFRUM3ZDMUE4QWh1d2p5MDI&ui_locales=en-US' consent_cookie.cookie['domain']='.screencast.com' consent_cookie.cookie['path']='/' screencast.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/pref_menu_scan_0k_20k/playtika.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .www2.deloitte.com domain's path /us/ not match url https://www2.deloitte.com/cl/es.html?icid=site_selector_cl
# Unmatch url and consent cookie domain: page_url='https://www2.deloitte.com/cl/es.html?icid=site_selector_cl' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://my.deloitte.com/us/en/index.html#/registration?site=us_en&action=optin&sub=a0C300000021TZd&nocheck=true&pl=en-US&pc=US&pi=sub' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_5.har.xz
# Domain path mismatch: .www2.deloitte.com domain's path /us/ not match url https://www2.deloitte.com/ch/de.html?icid=site_selector_li
# Unmatch url and consent cookie domain: page_url='https://www2.deloitte.com/ch/de.html?icid=site_selector_li' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, deloitte.com/postrej_0.har.xz not have cookie OptanonConsent of .www2.deloitte.com on path /us/
# Domain path mismatch: .www2.deloitte.com domain's path /us/ not match url https://www2.deloitte.com/la/en.html?icid=site_selector_la
# Unmatch url and consent cookie domain: page_url='https://www2.deloitte.com/la/en.html?icid=site_selector_la' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://trust.narvar.com/' consent_cookie.cookie['domain']='.corp.narvar.com' consent_cookie.cookie['path']='/' narvar.com/postrej_5.har.xz
# Written to /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/scan_0k_20k.parquet
# Number sent cookies read: 2,601,068
#           name                                              value  \
# 0      _vwo_sn                                    0%3A1%3A%3A%3A1
# 1        IR_PI  9695b409-8409-11ef-ba91-9f8d1dd11ba1%7C1728236...
# 2  _gd_visitor               ad71a7cf-f8c9-4e40-84e5-10586a590e75
#
#             domain path       expires  size  httpOnly  secure  session  \
# 0     .nextiva.com    /  1.728238e+09    22     False   False    False
# 1     .nextiva.com    /  1.762796e+09    57     False    True    False
# 2  www.nextiva.com    /  1.762796e+09    47     False    True    False
#
#   sameSite priority  sameParty sourceScheme  sourcePort  \
# 0      NaN   Medium      False       Secure         443
# 1      NaN   Medium      False       Secure         443
# 2     None   Medium      False       Secure         443
#
#                                          request_url         site  \
# 0  https://www.nextiva.com/cdn-cgi/image/width=64...  nextiva.com
# 1  https://www.nextiva.com/cdn-cgi/image/width=32...  nextiva.com
# 2  https://www.nextiva.com/cdn-cgi/image/width=au...  nextiva.com
#
#                                   page_url partitionKey
# 0  https://www.nextiva.com/company/contact          NaN
# 1  https://www.nextiva.com/company/contact          NaN
# 2  https://www.nextiva.com/company/contact          NaN

# %%
# prj = post-rejection
# Old way: consider all flows
# prj_sent_cookies = sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
# prj_br_cookies = prj_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
# New way: consider cookies only (ignore the request url, which is not nused in get_comply cookie matching anyway)
prj_sent_cookies = sent_cookies[['name', 'domain', 'path', 'site']].drop_duplicates()

# %%
# print(f"Num captured sent cookies: {len(sent_cookies):,d}")
# print(f"Num unique captured cookies: {len(prj_sent_cookies):,d}")
# n_br_cookies = len(prj_br_cookies)
# print(f"Num unique browser cookies: {n_br_cookies:,d} on {prj_br_cookies.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")

# %% [markdown]
# ## Analyze cookies compliance

# %%
sites = set(cookie_prefs.site)
print(f"Num sent cookies in the cookie prefs sites: {len(prj_sent_cookies[prj_sent_cookies.site.isin(sites)]):,d}")
# Out:
# Num sent cookies in the cookie prefs sites: 64,341

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.comply_util'])
from consent.consistency.comply_util import get_comply

print("faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:")
all_complies = get_comply(cookie_prefs, prj_sent_cookies)
all_complies.head()
# Out:
# faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:
#   0%|          | 0/1394 [00:00<?, ?it/s]
#  89%|████████▉ | 1241/1394 [04:11<00:07, 19.34it/s]
#  77%|███████▋  | 1080/1394 [03:50<00:17, 18.17it/s]
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_T3MKEZBW59' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pxcts' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_TNYBCQTJ6G' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_64H4Z6TSBF' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__cf_bm' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='AWSALBTG' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='AWSALBTGCORS' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__eoi' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pxvid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__gpi' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gcl_au' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__gads' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_0FHHFDE9TG' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='XID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ar_debug' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='IDE' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gat_gtag_UA_891249_29' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_px3' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ASP.NET_SessionId' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='stickyRandomValue' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_gat_gtag_UA_891249_13' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pxhd' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='UID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ga_0FHHFDE9TG' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='whereYouLeftOffData' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_lr_retry_request' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='panoramaId_expiry' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pubcid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='cto_bundle' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_pubcid_cst' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='lotame_domain_check' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_cc_id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ad-privacy' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='cto_bidid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_lr_env_src_ats' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ad-id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='check' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='33x_ps' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_57' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='wrvUserID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_4' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uis' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='CMID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tluidp' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='adtheorent[cuid]' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='receive-cookie-deprecation' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_632' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='khaos' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='CMPRO' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='receive-cookie-deprecation' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pi' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_377' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='khaos_p' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_1199' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='csync' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_3' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='univ_id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='re_sync' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_0' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='wrvUserID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_1278' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='DPSync4' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='CMPS' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='sd_amuid2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='stx_user_id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_7' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='audit' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='TapAd_3WAY_SYNCS' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='audit_p' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_594' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tluid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_148' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uuid2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='amdt_t' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_279' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_1251' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='mid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uih' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pxrc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_usd_jdpower.com' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uids' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='chkChromeAb67Sec' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ljt_reader' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KADUSERCOOKIE' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uin_bw' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ljtrtb' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_13' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_80' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='intentIQ' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SPugT' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_43' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='TapAd_DID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='did' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='demdex' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_8' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='PugT' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_964' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='AVPUID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_12' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_102' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_904' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='TestIfCookieP' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='vdz_sync' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_cc_dc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='HAPLB8G' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='didts' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pxrc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_22' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='data-ris' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='yieldmo_id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SCMaps' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='bitoIsSecure' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SERVERID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SyncRTB4' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_32' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pubsyncexp' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_sv3_14' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ipc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='nnls' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='i' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uir_bw' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_153' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='data-sy' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_466' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_391' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='receive-cookie-deprecation' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_84' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_699' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='data-r' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='bito' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='amuid2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_188' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uids' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pd' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='sync' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrrc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_92' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_860' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_1323' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_1003' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='visitor-id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='XANDR_PANID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptran' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='anj' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_18' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='oo' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='rlas3' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uir_zt' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_52' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_107' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pt' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='External' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KRTBCOOKIE_27' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='amuid2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='sc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='li_sugr' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pids' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='vdz_sync' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_16' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='__uin_zt' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='mako_uid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='dpm' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='mc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ljtrtbexp' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uids' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_rxuuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='KCCH' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='bcookie' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='IQver' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='TapAd_TS' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='cnx_userId' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ljtrtb_86' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_rxuuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='lidc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='b' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_cc_id' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='id5' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrunl' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='A3' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='mxpim' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SCM' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrc' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='lidid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_li_ss' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ssh' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SCMrise' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ck' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ktcid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='c' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid_lu' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_7' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='V' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_46' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_79' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_50' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_61' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_49' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrcriteo' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_76' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_zora' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='UID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='VP' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_64' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ASDT' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_62' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrpp' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_80' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_88' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_44' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uid_cd' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='C' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_37' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pb_rtb_ev_part' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tads_uidp_82' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='intentIQCDate' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='INGRESSCOOKIE' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='io.narrative.guid.v2' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='CSDT' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ANON_ID' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='SEUNCY' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ab' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='pb_rtb_ev' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='IDSYNC' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='uid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='IQPData' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='t_pt_gid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrt' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ptrpub' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='c' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ss' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='t_gid' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='DotomiTest' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid_lu' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='_ftv' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='tuuid_lu' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='admRtbUidCkey34334Ssp245' bad character range d-4 at position 20
# Error fuzzy name match pref_name='mf_[0cc3b612-a97d-4bd0-b496-3ed0686d4603]' cookie_name='ayl_visitor' bad character range d-4 at position 20
# 100%|██████████| 1394/1394 [04:44<00:00,  4.91it/s]
#           name           domain path         site     comply
# 0      _vwo_sn     .nextiva.com    /  nextiva.com  incorrect
# 1        IR_PI     .nextiva.com    /  nextiva.com  incorrect
# 2  _gd_visitor  www.nextiva.com    /  nextiva.com       omit
# 3      _gcl_au     .nextiva.com    /  nextiva.com  incorrect
# 4    _vwo_uuid     .nextiva.com    /  nextiva.com  incorrect

# %%
# Analyze complies here
complies = all_complies[['name', 'domain', 'path', 'site', 'comply']].drop_duplicates()
comply_sites_data = defaultdict(list)
for comply_type, comply_group in complies.groupby('comply'):
    n_sites = comply_group.site.nunique()
    comply_sites_data['comply_type'].append(comply_type)
    comply_sites_data['num_sites'].append(n_sites)
    comply_sites = pd.DataFrame(comply_sites_data).sort_values(by=['num_sites'], ascending=False)

nsites = all_complies.site.nunique()
comply_counts = complies.comply.value_counts()
comply_sites['num_sites_percent'] = comply_sites['num_sites'] / nsites * 100
comply_sites['num_cookies'] = comply_sites['comply_type'].map(comply_counts)
comply_sites['num_cookies_percent'] = comply_sites['num_cookies'] / comply_sites['num_cookies'].sum() * 100  # need to read scan_*.parquet for n_br_cookies, but may be unnecessary
comply_sites['num_cookies_per_site'] = comply_sites['num_cookies'] / comply_sites['num_sites']

# Do not count comply/correct enforcement: which require detecting all possible
comply_sites = comply_sites[comply_sites.comply_type != 'comply']
comply_sites
# Out:
#   comply_type  num_sites  num_sites_percent  num_cookies  num_cookies_percent  \
# 3        omit       1283          92.235802        35203            54.713169
# 2   incorrect       1133          81.452193        15907            24.722960
# 0   ambiguous         43           3.091301           53             0.082374
#
#    num_cookies_per_site
# 3             27.438036
# 2             14.039718
# 0              1.232558

# %%
# Record the analysis results
all_complies_file = SCAN_ROOT_DIR / f'all_complies{output_suffix}.parquet'
all_complies.to_parquet(all_complies_file); print(f"Written {len(all_complies):,d} records of all_complies to {all_complies_file}")
# Out:
# Written 64,341 records of all_complies to /mnt/sdd/ducbui/projects/data2/consent/2024-10-04/all_complies_0k_20k.parquet

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

raise StopExecution
import sys; sys.exit(0)

# %%
complies.comply
# Out:
# 0              omit
# 1              omit
# 2              omit
# 3              omit
# 4              omit
#             ...
# 115682    incorrect
# 115683    incorrect
# 115684         omit
# 115685       comply
# 115686       comply
# Name: comply, Length: 115687, dtype: object

# %%
nsites = all_complies.site.nunique(); nsites
# all_complies.site.unique()
# Out:
# 3412

# %%
detected_contra_sites = [s for s, contras in site_to_contras.items() if len(contras) > 0]; len(detected_contra_sites)
# Out:
# 0

# %%
complies = all_complies[ ['name', 'domain', 'site', 'comply',]].drop_duplicates()
comply_counts = complies.comply.value_counts()
comply_counts
# Out:
# omit         60214
# incorrect    35575
# comply       19067
# ambiguous      271
# Name: comply, dtype: int64

# %%
complies_sites = set(all_complies.site)
sent_cookies_com = sent_cookies[sent_cookies.site.isin(complies_sites)]
prj_sent_cookies_com = sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
prj_br_cookies_com = prj_sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
print(f"Num captured sent cookies: {len(sent_cookies_com):,d}")
print(f"Num unique captured cookies: {len(prj_sent_cookies_com):,d}")

n_br_cookies_com = len(prj_br_cookies_com)
print(f"Num unique browser cookies: {n_br_cookies_com:,d} on {prj_br_cookies_com.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")
# Out:
# Num captured sent cookies: 12,865,663
# Num unique captured cookies: 6,925,444
# Num unique browser cookies: 276,967 on 3,412 websites

# %% [markdown]
# # Analyze contras

# %%
# Way 1: compute contra sites by dynamic analysis: this should be lower than statically analyzing prefs
# because we cannot check all combinations of consent modes.
from consent.consistency.comply_util import get_appr_rej_sets
contra_data = []
for asite in cookie_prefs.site.unique():
    site_prefs = cookie_prefs[cookie_prefs.site == asite]
    _, _, contras = get_appr_rej_sets(site_prefs)
    for contra in contras:
        contra['site'] = asite
        contra_data.append(contra)
contra_sites = pd.DataFrame(contra_data)
contra_sites.head()
# Out:
#                   domain                         name                site
# 0  www.libertylondon.com         dwanonymous_xxxxxxxx   libertylondon.com
# 1      script.hotjar.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 2     tartecosmetics.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 3     tartecosmetics.com                 _hjFirstSeen  tartecosmetics.com
# 4      script.hotjar.com   _hjIncludedInSessionSample  tartecosmetics.com

# %%
assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
#
# AssertionError: this is the same method with above, so the result

# %%
set(detected_contra_sites) - set(contra_sites.site)
set(contra_sites.site) - set(detected_contra_sites)
# This may be the sites excluded due to testing cookies in the preferences.
# Out:
# {'247sports.com',
#  'abbvie.com',
#  'acquia.com',
#  'adobe.io',
#  'adweek.com',
#  'aljazeera.com',
#  'allaboutvision.com',
#  'allegiantair.com',
#  'allergan.com',
#  'alteryx.com',
#  'americanbar.org',
#  'aon.com',
#  'ariel.co.uk',
#  'asos.com',
#  'autosport.com',
#  'avalara.com',
#  'avast.com',
#  'avastbrowser.com',
#  'barnesandnoble.com',
#  'bazaarvoice.com',
#  'bbva.com',
#  'bd.com',
#  'behance.net',
#  'belkin.com',
#  'betsson.com',
#  'bitdefender.com',
#  'bitdefender.net',
#  'bkstr.com',
#  'blackboard.com',
#  'bplans.com',
#  'brightside.me',
#  'bromium-online.com',
#  'callofduty.com',
#  'cambridge.org',
#  'carbonite.com',
#  'cheapoair.com',
#  'chrysler.com',
#  'cisco.com',
#  'citationmachine.net',
#  'clickmeeting.com',
#  'clicktale.net',
#  'cloudbees.com',
#  'cnet.com',
#  'colt.net',
#  'commonsensemedia.org',
#  'contentsquare.com',
#  'conviva.com',
#  'creighton.edu',
#  'curalate.com',
#  'dc.com',
#  'dccomics.com',
#  'discogs.com',
#  'dynamicyield.com',
#  'easybib.com',
#  'eidos.com',
#  'elderscrollsonline.com',
#  'evri.com',
#  'ew.com',
#  'fabfitfun.com',
#  'fotolia.com',
#  'fourseasons.com',
#  'frontlineeducation.com',
#  'geappliances.com',
#  'geforce.com',
#  'genial.ly',
#  'getdbt.com',
#  'glip.com',
#  'gmu.edu',
#  'gopro.com',
#  'grainger.com',
#  'halfords.com',
#  'hallmark.com',
#  'hightail.com',
#  'hm.com',
#  'howstuffworks.com',
#  'hp.com',
#  'illumina.com',
#  'instyle.com',
#  'ipl.org',
#  'irishcentral.com',
#  'ironman.com',
#  'janes.com',
#  'jbl.com',
#  'jeep.com',
#  'jobvite.com',
#  'kew.org',
#  'lastline.com',
#  'launchdarkly.com',
#  'levi.com',
#  'liverpoolfc.com',
#  'logi.com',
#  'logitech.com',
#  'logitechg.com',
#  'mastercard.com',
#  'mastercard.us',
#  'mcgraw-hill.com',
#  'mckesson.com',
#  'meraki.com',
#  'mheducation.com',
#  'michaels.com',
#  'mlb.com',
#  'mongodb.com',
#  'mongodb.org',
#  'morningconsult.com',
#  'morrisons.com',
#  'motorsport.com',
#  'mtv.com',
#  'myportfolio.com',
#  'name.com',
#  'nba.com',
#  'ncaa.com',
#  'newsday.com',
#  'newsweaver.com',
#  'next.co.uk',
#  'nhl.com',
#  'ni.com',
#  'nspcc.org.uk',
#  'nvidia.com',
#  'ocado.com',
#  'omnitracs.com',
#  'onlyinyourstate.com',
#  'paradox.ai',
#  'parents.com',
#  'paypay.ne.jp',
#  'pcapredict.com',
#  'people.com',
#  'pge.com',
#  'phoenix.edu',
#  'pinknews.co.uk',
#  'politico.com',
#  'principal.com',
#  'prweb.com',
#  'rd.com',
#  'realsimple.com',
#  'ringcentral.com',
#  'rollout.io',
#  'royalacademy.org.uk',
#  'salliemae.com',
#  'samaritans.org',
#  'sanofi-synthelabo.com',
#  'sanofi.com',
#  'santander.co.uk',
#  'sciam.com',
#  'scientificamerican.com',
#  'senderscore.com',
#  'seon.io',
#  'sho.com',
#  'shuttercloud.org',
#  'shutterstock.com',
#  'signifyd.com',
#  'solvvy.com',
#  'sonos.com',
#  'sony.co.uk',
#  'sourcefire.com',
#  'sparknotes.com',
#  'square-enix-games.com',
#  'statista.com',
#  'suse.com',
#  'tasteofhome.com',
#  'telerik.com',
#  'thedailybeast.com',
#  'thedodo.com',
#  'thomsonreuters.com',
#  'thomsonreuters.net',
#  'travelandleisure.com',
#  'treasuredata.com',
#  'tripadvisor.in',
#  'typeform.com',
#  'typekit.com',
#  'uipath.com',
#  'ulta.com',
#  'umbrella.com',
#  'universe.com',
#  'urbanairship.com',
#  'vfsglobal.com',
#  'viber.com',
#  'visma.com',
#  'vmware.com',
#  'vmwareidentity.com',
#  'webmd.com',
#  'wfmz.com',
#  'whirlpool.com',
#  'workspaceoneaccess.com',
#  'worldoftanks.com',
#  'wwf.org.uk',
#  'yousendit.com',
#  'zdnet.com',
#  'zebra.com',
#  'zeiss.com',
#  'zennioptical.com',
#  'zoom.com',
#  'zoom.us'}

# %%
# Way 2: compute contra sites by DataFrame group by
contra_cookies_dfs = []
for _, same_cookies in cookie_prefs.groupby(['name', 'domain', 'site']):
    consent_modes = same_cookies.consent_mode.unique()
    if len(consent_modes) >= 2 and same_cookies.category.nunique() > 1: # and 'always active' in consent_modes:
        contra_cookies_dfs.append(same_cookies)
contra_cookies = pd.concat(contra_cookies_dfs).drop_duplicates()

# %%
print("Number sites with contra cookies:", contra_cookies.site.nunique())
# Out:
# Number sites with contra cookies: 184

# %%
# set(contra_cookies.site) - set(contra_sites.site)

# %%
print("Num contra cookie settings (double categories):", len(contra_cookies), f"settings  on {contra_cookies.site.nunique()} sites")
print("Contras with 1 always-active:", contra_sites.site.nunique())
print("Contras with both editable:", len(set(contra_cookies.site) - set(contra_sites.site)))
# Out:
# Num contra cookie settings (double categories): 648 settings  on 184 sites
# Contras with 1 always-active: 192
# Contras with both editable: 0

# %%
contra_cookies[contra_cookies.site == 'elsevier.nl']
# Out:
# Empty DataFrame
# Columns: [name, domain, duration, category_id, category, consent_mode, site, lib_name, pattern_name, consent]
# Index: []

# %%
# assert len(detected_contra_sites) <= contra_sites.site.nunique() < len(detected_contra_sites) + 2

# %%
complies[complies.comply == 'ambiguous']
# Out:
#                  name                  domain                   site  \
# 173        TS013559a7       www.mastercard.us         mastercard.com
# 1236    _qubitTracker         .www.very.co.uk             very.co.uk
# 2365   G_ENABLED_IDPS      .www.glassdoor.com          glassdoor.com
# 2372              trs       www.glassdoor.com          glassdoor.com
# 2375             _gid          .glassdoor.com          glassdoor.com
# ...               ...                     ...                    ...
# 59468         ak_bmsc           .mulesoft.com           mulesoft.com
# 59481      JSESSIONID   training.mulesoft.com           mulesoft.com
# 60397          TLTSID              .bkstr.com              bkstr.com
# 60412            dtSa              .bkstr.com              bkstr.com
# 60622       shortHash  .square-enix-games.com  square-enix-games.com
#
#           comply
# 173    ambiguous
# 1236   ambiguous
# 2365   ambiguous
# 2372   ambiguous
# 2375   ambiguous
# ...          ...
# 59468  ambiguous
# 59481  ambiguous
# 60397  ambiguous
# 60412  ambiguous
# 60622  ambiguous
#
# [116 rows x 4 columns]

# %%
cookie_prefs[ (cookie_prefs.site == 'michaels.com') & (cookie_prefs.name == 'utag_main') ]
# Out:
#           name         domain  duration category_id  \
# 88   utag_main  .michaels.com  365 days       C0001
# 148  utag_main   michaels.com  365 days       C0002
#
#                        category   consent_mode          site  lib_name  \
# 88   Strictly Necessary Cookies  always active  michaels.com  onetrust
# 148         Performance Cookies         active  michaels.com  onetrust
#
#     pattern_name consent
# 88       en.json    True
# 148      en.json   False

# %%
cookie_prefs[ (cookie_prefs.site == 'statista.com') & (cookie_prefs.name == 'id') ]
# Out:
#     name  domain duration category_id           category   consent_mode  \
# 74    id  m6r.eu  90 days       C0001  Necessary Cookies  always active
# 131   id  m6r.eu   0 days       C0004  Targeting Cookies       inactive
#
#              site  lib_name pattern_name consent
# 74   statista.com  onetrust      en.json    True
# 131  statista.com  onetrust      en.json   False

# %%
# contra_cookies.name.value_counts()[:10]
# contra_cookies[contra_cookies.name == '__cf_bm'].reset_index(drop=True) # .site.nunique()

# %% [markdown]
# # Analyze ambiguous flows

# %%
ambi_cookies = complies[complies.comply == 'ambiguous']
print("Num ambiguous cookies:", len(ambi_cookies), "on num sites:", ambi_cookies.site.nunique())
assert len(ambi_cookies) == len(ambi_cookies.drop_duplicates()), "there is some duplicate cookies"

# %% [markdown]
# ## Analyze no-way-to-opt-out

# %%
# Way 1: compute contra sites by DataFrame group by
nwtoo_cookies_dfs = []
for _, site_cookies in cookie_prefs.groupby(['site']):
    consent_modes = site_cookies.consent_mode.unique().tolist()
    if len(consent_modes) == 1 and consent_modes[0] == 'always active':
        nwtoo_cookies_dfs.append(site_cookies)
nwtoo_cookies = pd.concat(nwtoo_cookies_dfs).drop_duplicates()
nwtoo_cookies.head()

# %%
nwtoo_cookies.site.nunique()

# %% [markdown]
# # Analyze inconsistent flows/cookies

# %%
def plot_inconsis_types():
    sns.set(rc={'figure.figsize':(9,9),"font.size":30,"axes.titlesize":30,"axes.labelsize":30},style="white", font_scale = 2.5)

    ax = sns.barplot(x='comply_type', y='num_sites_percent', data=noncomply_sites)
    ax.tick_params(left=True, bottom=True, direction="in")
    ax.set_ylabel('# Websites (%)')
    ax.set_xlabel('Noncompliance Types')
    xticks = [x.get_text().title() for x in ax.get_xticklabels()]
    ax.set(xticklabels=xticks)

    out_file = FIG_DIR / 'noncomply_types_per_site.png'
    # plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
## Plot distribution of omitted cookie declarations

# %%
omit_complies = complies[(complies.comply == 'omit')] #  & ~complies.name.isin(['OptanonAlertBoxClosed', 'OptanonConsent']) ]
omit_complies.site.nunique()

# %%
omit_complies.site.value_counts()[:7]

# %%
omit_cookies = omit_complies.name.value_counts()[:5].to_frame().reset_index().rename(columns={'index': 'cookie_name'})
omit_cookies['num_sites'] = omit_cookies['cookie_name'].map(lambda cookie_name: omit_complies[omit_complies.name == cookie_name].site.nunique())
print(omit_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %%
# set(cookielist_sites) - set(omit_complies.site.unique())
omit_counts = omit_complies.site.value_counts().to_frame().rename(columns={'site': 'num_omit_cookies'})
print("Num omitted sites:", omit_complies.site.nunique())
omit_counts.num_omit_cookies.mean(), omit_counts.num_omit_cookies.std(), omit_counts.num_omit_cookies.min(), omit_counts.num_omit_cookies.max()

# %%
sns.set(rc={'figure.figsize':(12,8),"font.size":35,"axes.titlesize":30,"axes.labelsize":50},style="white", font_scale = 4.5)
sns.set_style("ticks", {"xtick.direction": "in", "ytick.direction": "in"})
plt.rcParams['xtick.major.size'] = 15
plt.rcParams['ytick.major.size'] = 15

ax = sns.ecdfplot(data=omit_counts, x=omit_counts.num_omit_cookies, linewidth=8)
ax.set(xlim=(0, 350))

plt.xlabel('# Omitted Cookies/Website')
plt.ylabel('CDF')
# out_file = FIG_DIR / 'eu_omit_cookie_cdf.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
plot_df = omit_counts[:50]

sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x=plot_df.index, y=plot_df.num_omit_cookies)
ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=False, direction="in")
ax.set_ylabel('# Omitted Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'omit_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
def plot_histogram_omit():
    sns.set(rc={'figure.figsize':(9,6),"font.size":25,"axes.titlesize":25,"axes.labelsize":15},style="white", font_scale = 1)
    omit_counts_histo = omit_complies.site.value_counts().value_counts()
    sns.barplot(x=omit_counts_histo.index, y=omit_counts_histo.values)
    ticks = plt.xticks(rotation=45, ha='right')

# %% [markdown]
# ## Plot distribution of incorrectly enforced cookies

# %%
incor_complies = complies[complies.comply == 'incorrect']
# set(cookielist_sites) - set(omit_complies.site.unique())
incor_counts = incor_complies.site.value_counts().iloc[:50]
incor_counts = incor_counts.to_frame().reset_index().sort_values(by=['site', 'index'], ascending=[False, True])
incor_counts.columns

# %%
sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x='index', y='site', data=incor_counts)

ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=True, direction="in")
ax.set_ylabel('# Incorrectly Enforced Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'incor_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
# len(incor_counts)

# %%
incor_counts[incor_counts.site == 33].reset_index(drop=True)

# %% [markdown]
# ### Top incorrect cookies

# %%
incor_cookies = complies[complies.comply == 'incorrect']

# %%
# site = 'onetrust.com'
# complies[complies.site == site].reset_index(drop=True)
# cookie_prefs[(cookie_prefs.site == site) & (cookie_prefs.name == '_gid')]

# %%
top_incor_cookies = incor_cookies.name.value_counts().sort_values(ascending=False).to_frame().reset_index().rename(columns={'index':'cookie_name', 'name': 'num_occur'})

# %%
top_incor_cookies['num_sites'] = top_incor_cookies.cookie_name.map(lambda cookie_name: incor_cookies[incor_cookies.name == cookie_name].site.nunique())

# %%
print(top_incor_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %% [markdown]
# # Narrow cookie consent preferences

# %%
consent_cookies = sent_cookies[sent_cookies.name.isin(['OptanonConsent', 'CookieConsent'])][['domain', 'name', 'site']].drop_duplicates()
narrow_consent_cookies = consent_cookies[~consent_cookies.domain.str.startswith('.')].reset_index(drop=True)

# %%
set(contra_cookies.site).intersection(set(narrow_consent_cookies.site))

# %%
narrow_consent_cookies

# %% [markdown]
# # Case studies

# %%
incor_df = complies[complies.comply == 'incorrect']
incor_df.site.value_counts().sort_values(ascending=False).head()

# %%
case_site = 'blabbermouth.net'
incor_df[incor_df.site == case_site]

# %%
# cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'MXP_TRACKINGID')]
cookie_prefs[(cookie_prefs.site == case_site) & (cookie_prefs.name == 'IDE')]

# %%
# sent_cookies[(sent_cookies.site == 'scientificamerican.com') & (sent_cookies.name == 'MXP_TRACKINGID')]

# %%
omit_df = complies[complies.comply == 'omit']
omit_df.site.value_counts().sort_values(ascending=False).iloc[20:30]

# %%
print(omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist())

# %%
'uids' in omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist()

# %%
omit_df[(omit_df.site == 'scientificamerican.com') & (omit_df.name == 'cftoken')]

# %%
cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'ADGRX_UID')]

# %%
all_sites = set(complies.site)
nothing_comply_sites = all_sites - set(complies[complies.comply == 'comply'].site)
print("Sites with no compliant cookies:", nothing_comply_sites)

# %%
for site in ['liveperson.com']: # nothing_comply_sites:
    print(site)
site_cookies = postrej_br_cookies[postrej_br_cookies.site == site]

# %%
acookie = site_cookies[site_cookies.name == 'OptanonAlertBoxClosed'].iloc[0]

# %%
site_prefs = cookie_prefs[cookie_prefs.site == site]
consent_cookies = site_prefs[site_prefs.consent]
consent_cookie_names = consent_cookies.name
site_cookies[site_cookies.name.isin(consent_cookie_names)]
# cookie_name = 'OptanonAlertBoxClosed'
# cookie_pref = site_prefs[site_prefs.name == cookie_name].iloc[0]
# cookie_pref

# %%
consent_cookies

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.cookie_pref_match'])
from consent.consistency.cookie_pref_match import cookie_pref_match
cookie_pref_match(acookie, cookie_pref, site, verbose=2)

# %%
# Analyze Contras
