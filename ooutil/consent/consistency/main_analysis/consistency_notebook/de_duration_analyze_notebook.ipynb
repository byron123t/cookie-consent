# %%
from collections import defaultdict, Counter
from multiprocessing import Pool
from pathlib import Path
from typing import Dict
import datetime
import json
import re

from durations_nlp import Duration
from durations_nlp.exceptions import InvalidTokenError
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import urllib
import tldextract

from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import FIG_DIR, get_scan_dirs, get_scan_root_dir
from consent.data.pref_menu_scan.cookie_decl_reader import read_cookie_decls_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans
# from consent.data.site_pref import read_site_prefs
# from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
# from consent.data.pref_menu_scan.log_reader import read_logs_in_scans
# from consent.util.default_path import get_data_dir
# from ooutil.type_util import hashabledict
# from ooutil.url_util import get_suffixed_domain
# from ooutil.cookie_util import get_brower_cookies
# from ooutil.func_util import memoize

# data_dir = get_data_dir('2021-05-01/pref_menu_scan_accept')
location = 'de'
SCAN_DIRS = get_scan_dirs(location)
SCAN_ROOT_DIR = get_scan_root_dir(location)
print(f'SCAN DIRS: {[str(d) for d in SCAN_DIRS]}')
fig_dir = Path.home() / 'local_projects/consent/paper/sp22/figures'
assert fig_dir.exists() and fig_dir.is_dir()
# Out:
# SCAN DIRS: ['/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k', '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k']

# %%
# scanned_sites = [site_dir.name for site_dir in data_dir.glob('*') if site_dir.is_dir()]
# site_dirs = [data_dir / site for site in scanned_sites]
# print("Number of scanned sites:", len(scanned_sites)) # , scanned_sites)

# %% [markdown]
# # Get cookie durations in declarations

# %%
# Get cookie prefs = cookie decls + prefs
# cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS)
# cookie_prefs.head()
# TODO: rerun with cookie decls only, we do not need cookie prefs
raw_cookie_decls = read_cookie_decls_in_scans(SCAN_DIRS)
raw_cookie_decls
# Out:
#                  name              domain   duration category_id  \
# 0                user      www.wework.com    Session       C0001
# 1     __we_request_id      www.wework.com    Session       C0001
# 2    ajs_anonymous_id          wework.com   365 days       C0001
# 3            _gclxxxx          wework.com    90 days       C0001
# 4      __we_bucket_id      www.wework.com   365 days       C0001
# ..                ...                 ...        ...         ...
# 112               YSC         youtube.com    Session       C0004
# 113            _kuid_            krxd.net   179 days       C0004
# 114                A3           yahoo.com   365 days       C0004
# 115        browser_id  www.slideshare.net  1825 days       C0004
# 116      browser_data          dnacdn.net   390 days       C0004
#
#                        category   consent_mode        site  lib_name  \
# 0    Strictly Necessary Cookies  always active  wework.com  onetrust
# 1    Strictly Necessary Cookies  always active  wework.com  onetrust
# 2    Strictly Necessary Cookies  always active  wework.com  onetrust
# 3    Strictly Necessary Cookies  always active  wework.com  onetrust
# 4    Strictly Necessary Cookies  always active  wework.com  onetrust
# ..                          ...            ...         ...       ...
# 112           Targeting Cookies       inactive  loggly.com  onetrust
# 113           Targeting Cookies       inactive  loggly.com  onetrust
# 114           Targeting Cookies       inactive  loggly.com  onetrust
# 115           Targeting Cookies       inactive  loggly.com  onetrust
# 116           Targeting Cookies       inactive  loggly.com  onetrust
#
#     pattern_name
# 0        en.json
# 1        en.json
# 2        en.json
# 3        en.json
# 4        en.json
# ..           ...
# 112      en.json
# 113      en.json
# 114      en.json
# 115      en.json
# 116      en.json
#
# [3066 rows x 9 columns]

# %%
# def _osolete_analysis():
#     pref_menu_data_dir = get_data_dir('2021-05-01/pref_menu_scan')
#     pref_menu_sites = [site_dir.name for site_dir in pref_menu_data_dir.glob('*') if site_dir.is_dir()]
#     pref_menu_site_prefs = read_site_prefs([pref_menu_data_dir / site for site in pref_menu_sites])
#     print("Number of sites in pref-menu scan:", len(pref_menu_sites)) # , scanned_sites)
#     pref_menu_cookielist_sites = pref_menu_site_prefs.site.unique()
#     print("Number of sites with cookie list in pref-menu scan:", len(pref_menu_cookielist_sites)) # , scanned_sites)
#     missings = set(pref_menu_cookielist_sites) - set(site_prefs.site.unique())
#     n_sites_with_sett = site_prefs.site.nunique()
#     print("Missing sites:", missings)
#     redundants = set(site_prefs.site.unique()) - set(pref_menu_cookielist_sites)
#     print("Redudant sites:", redundants)
    # assert len(missings) == len(redundants) == 0, f"There is some mismatch."

# %%
# site_prefs = site_prefs[site_prefs.duration != '']
n_nan_durations = len(raw_cookie_decls[raw_cookie_decls.duration.isna()])
if n_nan_durations > 0:
    print(f"WARNING: Some duration is nan: {n_nan_durations}")
    raw_cookie_decls = raw_cookie_decls[~pd.isna(raw_cookie_decls.duration)]
assert len(raw_cookie_decls[raw_cookie_decls.duration == '']) ==0

# %%
print(f"Most common preference durations:")
pref_dur_counts = raw_cookie_decls.duration.value_counts().to_frame().reset_index()
pref_dur_counts['freq'] = pref_dur_counts['duration'] / len(raw_cookie_decls) * 100
pref_dur_counts.head(10)
pref_dur_counts = pref_dur_counts[['index', 'freq']].rename(columns={'index': 'Duration'}).head(5)  # , 'freq': 'Frequency (%)'
print(pref_dur_counts.to_latex(index=False, float_format="%.2f"))
# Out:
# Most common preference durations:
# \begin{tabular}{lr}
# \toprule
# Duration &  freq \\
# \midrule
#   0 days & 27.95 \\
#  Session & 18.66 \\
# 365 days & 13.67 \\
# 364 days &  6.03 \\
# 730 days &  3.91 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_1359922/2101002780.py:6: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(pref_dur_counts.to_latex(index=False, float_format="%.2f"))

# %%
print(f"Preference durations:")
print(raw_cookie_decls['duration'].unique())
# Out:
# Preference durations:
# ['Session' '365 days' '90 days' '14 days' '730 days' '0 days' '1 days'
#  '729 days' '17 days' '7 days' '364 days' '392 days' '3649 days'
#  '390 days' '2 days' '180 days' '179 days' '89 days' '726 days' '182 days'
#  '29 days' '3650 days' '389 days' '6149 days' '30 days' '731 days'
#  '394 days' '16 days' '395 days' '6168 days' '397 days' '1080 days'
#  '184 days' '6 days' '366 days' '185 days' '60 days' '2914038 days'
#  '1825 days' '181 days' '7304 days' '393 days' '360 days' '1092 days'
#  '4537 days' '1824 days' '6170 days' '3652 days' '183 days' '3998 days'
#  '6156 days' '1000 days' '725 days' '7299 days' '1091 days' '13 days'
#  '59 days' '177 days' '722 days' '31 days' '1487 days' '1095 days'
#  '732 days' '396 days' '270 days' '120 days' '356 days' '214 days'
#  '540 days' '6181 days' '1005 days' '1889 days' '1459 days' '3 days'
#  '7300 days' '1096 days' '19 days' '7014 days' '2914074 days' '6129 days'
#  '710 days' '6015 days' '300 days' '299 days' '1460 days' '18249 days'
#  '728 days' '3999 days' '61 days' '1800 days' '6120 days' '2914043 days'
#  '362 days']

# %%
'Session' in raw_cookie_decls[raw_cookie_decls.lib_name == 'onetrust']['duration'].unique()
# Out:
# True

# %%
cookielist_sites = sorted(raw_cookie_decls.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert raw_cookie_decls.site.nunique() == n_cookielist_sites
# print("Sites with cookie list:", n_cookielist_sites, cookielist_sites)

# %% [markdown]
# # Read in the post-rejection cookies to find the actual cookie durations.

# %%
# raw_postrej_sent_cookies_file = data_dir / 'raw_postrej_sent_cookies.parquet'
# postrej_sent_cookies_file = data_dir / 'postrej_sent_cookies.parquet'
# if raw_postrej_sent_cookies_file.exists():
#     raw_postrej_sent_cookies = pd.read_parquet(raw_postrej_sent_cookies_file)
#     postrej_sent_cookies = pd.read_parquet(postrej_sent_cookies_file)
# else:
#     # postrej_sent_cookies = read_postrej_sent_cookies(site_dirs[:4])
#     raw_postrej_sent_cookies = parallel_read_postrej_sent_cookies(data_dir, keep_sent_cookie=True)
#     postrej_sent_cookies = raw_postrej_sent_cookies.drop_duplicates()
#     raw_postrej_sent_cookies.to_parquet(raw_postrej_sent_cookies_file); print(f"Written to {raw_postrej_sent_cookies_file}")
#     postrej_sent_cookies.to_parquet(postrej_sent_cookies_file); print(f"Written to {postrej_sent_cookies_file}")

# raw_postrej_sent_cookies.head(3)
overwrite = False # True
cookies_cache_file = SCAN_ROOT_DIR / 'scan.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not overwrite and cookies_cache_file and cookies_cache_file.exists():
    sent_cookies = pd.read_parquet(cookies_cache_file)
else:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Unmatch url and consent cookie domain: page_url='https://www.ciriontechnologies.com/es/' consent_cookie.cookie['domain']='.lumen.com' consent_cookie.cookie['path']='/' savvis.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/mens-health-magazine-subscription-website?utm_source=menshealth.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.menshealth.com' consent_cookie.cookie['path']='/' menshealth.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://hrtechprivacy.com/brands/glassdoor#privacypolicy' consent_cookie.cookie['domain']='.glassdoor.com' consent_cookie.cookie['path']='/' glassdoor.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/allergan.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://myaccount.suse.com/' consent_cookie.cookie['domain']='www.suse.com' consent_cookie.cookie['path']='/' suse.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.mylo.id/login?client_id=2vf0vbj1mranhuhvqpdbg761dv&state=S3h3a0ptYWhXMFRlS0xXYmV0d2NzMkZKOTBxOV82REVvRFk1aVhucE1yUT0&redirect_uri=https%3A%2F%2Fwww.elledecor.com%2Fauth%2Flogin' consent_cookie.cookie['domain']='.elledecor.com' consent_cookie.cookie['path']='/' elledecor.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/elle-decoration-magazine-subscription-website?utm_source=elledecor.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.elledecor.com' consent_cookie.cookie['path']='/' elledecor.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, imperva.com/postrej_5.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_3.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, imperva.com/postrej_4.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/ncr.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.salesforce.com/form/quip/contact/?bc=HA' consent_cookie.cookie['domain']='.quip.com' consent_cookie.cookie['path']='/' quip.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/sanofi.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://elearning.ala.org/' consent_cookie.cookie['domain']='.www.ala.org' consent_cookie.cookie['path']='/' ala.org/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/gartner.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/gartner.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='http://validate.perfdrive.com/?ssa=d45509e5-d063-4019-81f1-a885510a4f7d&ssb=43605208510&ssc=https%3A%2F%2Fwww.globaldata.com%2F&ssi=4e156102-bp37-42c5-9e2b-8cfe60c415ef&ssk=support@shieldsquare.com&ssm=18100120148414020409356883293521&ssn=17a89f2dc577258bbff9dd10ffab617421e4a50cde88-8099-4e1c-b047bc&sso=ff07d402-22cb42639ec083b4d3f4642eb199ef71ca431a4404a6c8c5&ssp=60540660221681574250168150347836656&ssq=43762124731142379987347236479644351450122&ssr=MTM4LjY4Ljg2Ljc3&sst=Mozilla/5.0%20(X11;%20Linux%20x86_64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/101.0.4951.64%20Safari/537.36&ssv=&ssw=&ssx=W10=' consent_cookie.cookie['domain']='.globaldata.com' consent_cookie.cookie['path']='/' globaldata.com/postrej_0.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/verizonmedia.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://care.siriusxm.com/makeccpaymentlogin_view.action?isflepzview=true' consent_cookie.cookie['domain']='.www.siriusxm.com' consent_cookie.cookie['path']='/' siriusxm.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/governmentjobs.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .www.basf.com domain's path /us/ not match url https://www.basf.com/global/en/media/news-releases/2021/10/p-21-341.html
# Unmatch url and consent cookie domain: page_url='https://www.basf.com/global/en/media/news-releases/2021/10/p-21-341.html' consent_cookie.cookie['domain']='.www.basf.com' consent_cookie.cookie['path']='/us/' basf.com/postrej_1.har.xz
# Domain path mismatch: .www.basf.com domain's path /us/ not match url https://www.basf.com/global/en/media/news-releases/2020/07/p-20-260.html
# Unmatch url and consent cookie domain: page_url='https://www.basf.com/global/en/media/news-releases/2020/07/p-20-260.html' consent_cookie.cookie['domain']='.www.basf.com' consent_cookie.cookie['path']='/us/' basf.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://na.wargaming.net/id/signin/?next=%2Fid%2Fopenid%2F475126608493160841%2F&trust_root=https%3A%2F%2Fworldoftanks.com%2F' consent_cookie.cookie['domain']='.worldoftanks.com' consent_cookie.cookie['path']='/' worldoftanks.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.kaspersky.com/' consent_cookie.cookie['domain']='usa.kaspersky.com' consent_cookie.cookie['path']='/' avp.ru/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/cosmopolitan-magazine-subscription-website?utm_source=cosmopolitan.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.cosmopolitan.com' consent_cookie.cookie['path']='/' cosmopolitan.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/good-housekeeping-magazine-subscription-website?utm_source=goodhousekeeping.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.goodhousekeeping.com' consent_cookie.cookie['path']='/' goodhousekeeping.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.youngliving.co.kr/' consent_cookie.cookie['domain']='.youngliving.com' consent_cookie.cookie['path']='/' youngliving.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/login/error?client_id=sA34DUmQA4EIrJC7q9QuPCf1T778BfLv&connection=&lang=&error=unauthorized_client&error_description=Callback%20URL%20mismatch.%20https%3A%2F%2Fwww.research.net%2Flogin%2Fcallback%20is%20not%20in%20the%20list%20of%20allowed%20callback%20URLs&tracking=90010380b5e855732b1b' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/login/error?client_id=sA34DUmQA4EIrJC7q9QuPCf1T778BfLv&connection=&lang=&error=unauthorized_client&error_description=Callback%20URL%20mismatch.%20https%3A%2F%2Fwww.research.net%2Flogin%2Fcallback%20is%20not%20in%20the%20list%20of%20allowed%20callback%20URLs&tracking=b868312a91824e6bbf48' consent_cookie.cookie['domain']='.www.research.net' consent_cookie.cookie['path']='/' research.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://asxonline.com/public/documents/asx-schedule-of-fees.html' consent_cookie.cookie['domain']='.www2.asx.com.au' consent_cookie.cookie['path']='/' asx.com.au/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='chrome-error://chromewebdata/' consent_cookie.cookie['domain']='.synchrony.com' consent_cookie.cookie['path']='/' syf.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://jcpenney.syf.com/accounts/login/?token=eyJraWQiOiIyMTZiMTQzMC1mOTc2LTQ1NTktYjRhZi0yMzc3OWExODdjM2YiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..xTOR1jXNkH0Bk4mg8ccUx3qLITyOPn-gIPnzlBMwNvoe2nOWmleKJ8s44iMT4gcPbXi1RRzyKEX8u4_ekaPjmJpmK-LPwfYZStyD_773IrZdL9KrmC4eb485WEvE33EUiEN2jkVC4Cp1rAkOWuBUpj4d6mUkg1hxO1HUU6CHcyFMrxo3rXGz4ejSIOQHLqC0cBoWiIXm8vvUxW88lByTZ41Or-jJY2AHeP0Aq454-rsyVDUmOe5ViCrcUGRJMSUM_9fg5FeXDkS-2ItIrxM5Ctz6hZGC-f9kKBkcCEMH-DsEkCqIgMpvfkG_q8RShqjfKTpkPcezIyQrunLzC2LHSQ' consent_cookie.cookie['domain']='.synchrony.com' consent_cookie.cookie['path']='/' syf.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, worldoftanks.eu/postrej_3.har.xz not have cookie OptanonConsent of .worldoftanks.eu on path /
# Unmatch url and consent cookie domain: page_url='https://crypto.org/defi/swap' consent_cookie.cookie['domain']='.crypto.com' consent_cookie.cookie['path']='/' crypto.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://accounts.vidazoo.com/authorize/ZYp15HED6Sazzq7XLNEDM2c3VTwRH1hLFS4lKiQ%2BJyobRScAHBxTG3o%2FKi4PLTxmDHESHhEuBm50f3BweHJ2BmVXS1gM?callback=https%3A%2F%2Fwww.vidazoo.com%2Femployee-hub' consent_cookie.cookie['domain']='www.vidazoo.com' consent_cookie.cookie['path']='/' vidazoo.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://accounts.skilljar.com/accounts/login/?t=3o181nbdrehj2&d=29wdgw30ipkf2&next=%2Fauth%2Fendpoint%2Flogin%2Fresult%3Fnext%3D%252F%26d%3D29wdgw30ipkf2' consent_cookie.cookie['domain']='.automox.com' consent_cookie.cookie['path']='/' automox.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://zulily.syf.com/accounts/login/?token=eyJraWQiOiIyMTZiMTQzMC1mOTc2LTQ1NTktYjRhZi0yMzc3OWExODdjM2YiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..wdprhYUfiXs6D3dzUbqegoYsFAN4IOfarGpyl2GoB-wCdoNm4YlP4kv4dG_p3Lynee2JFuEqVEDkQP__mUarv7GkYS91NA3ngXfrkWoDtKyo3mY0FBhVgCalM7jtBKxc1zRdt7f3raHgXd3M4MALQzLwgU_6J5SKh-5_9QuOJM11OHKUeNknkxPJtEH--cDF_wsFAtigeQ5uGFoUB4MDGIdXknyxxWbw942YR4P20Jv7Q4POa-BWM6tjFKshfTYscMDvFQbwpYce6mMJY5EXEqAzEJKHv79cs7bw1J1WYq9bctz4qiqmJcKuaDZsaTkgit-KcCgwn0xRb3NGcFFkOA' consent_cookie.cookie['domain']='.synchrony.com' consent_cookie.cookie['path']='/' synchrony.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://lowes.syf.com/accounts/login/?token=eyJraWQiOiIyMTZiMTQzMC1mOTc2LTQ1NTktYjRhZi0yMzc3OWExODdjM2YiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..TeZdf5Z8jU41QT0RXB9qHPXWbv5f0WLagDvQ89mL2Vrx2TMhMWdtRx8A8Ce_5QccGdTmGkXS1yI9HsZhF4PTE9rMnovHSmWyisD15SEhyJL-xQa-W9DfEPOKn1xBqzSsV3yh53ZBcMjlZ2DVB5UBIVGLF7kZftmGrs5aSowD2uN7DC3JO-lx_hus6LzS7CXhzW0Q36lCvPIzk1iHBUbMj1v8aLI0MFYVCyMEY8_jHAK25RGbRK8KNyIrseTCBn92WHCnNFE2YRYZKvgHDfLyjzGtazRSIpNOvvmAtX8ORmNgCnBaIMprdmgk54hE81CuSeRylhNz04RJnbjICcTbfg' consent_cookie.cookie['domain']='.synchrony.com' consent_cookie.cookie['path']='/' synchrony.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://google.syf.com/accounts/login/?token=eyJraWQiOiIyMTZiMTQzMC1mOTc2LTQ1NTktYjRhZi0yMzc3OWExODdjM2YiLCJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..ORwv9NfHhIQaDf9hR2klxEY5z_qznkuP9zr4zLG8-Tv1mowpAdt9fhyaUbMPNC-QliSqy4AVp2NY0VJyGmfJDHAcRxTriwi1tIEQ95gSaMHfqGkegvwKj-hLe8_3QE4-6pmUbiRnpIqpu93Ts0FelHQGnmcZfttJYPCHAuQKAFy2tsdEVj7njOSyjwx1mLjSTKDstQMxjklr7ZXjVY3DOW_xzTYSfPTfsRE7S1wbDOCp0d1RVxU0sdhgYXkEUUGZgHULNctIg9msLCgKXgkwKi3fpP9kH0KIb1_kPawNoP1fE7_q_tQCBy3fZ7q-i36-apiORR_r-K3uU4U91woVAA' consent_cookie.cookie['domain']='.synchrony.com' consent_cookie.cookie['path']='/' synchrony.com/postrej_4.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/incomm.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/incomm.com/log.json'
# Post rej cookie not contain consent cookie, movember.com/postrej_2.har.xz not have cookie OptanonConsent of .movember.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.nortonlifelock.com/us/en/contact-us/report-a-security-vulnerability/' consent_cookie.cookie['domain']='.avast.com' consent_cookie.cookie['path']='/' avast.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://apps.apple.com/us/app/avast-security-photo-vault/id1276551855' consent_cookie.cookie['domain']='.avast.com' consent_cookie.cookie['path']='/' avast.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://investor.gendigital.com//our-story/technology-expertise/' consent_cookie.cookie['domain']='.avast.com' consent_cookie.cookie['path']='/' avast.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://creditcards.chase.com/a1/22Q2b/sapphirepreferred/compare?CELL=6H8X&AFFID=pngc6t7Ewoo-Qa2tbQNyrmrf8yg7nORl6Q&pvid=f46b1d73ab0241d8bc1846db7280a2a4&jp_cmp=cc/1112608/aff/3-10004110/na' consent_cookie.cookie['domain']='.thepointsguy.com' consent_cookie.cookie['path']='/' thepointsguy.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nflgamepass.com/en' consent_cookie.cookie['domain']='.nfl.com' consent_cookie.cookie['path']='/' nfl.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about/careers' consent_cookie.cookie['domain']='.hightail.com' consent_cookie.cookie['path']='/' yousendit.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://battlefy.com/nhl-2023?activeRegion=na&activeStage=1&activeConsole=xboxSeries' consent_cookie.cookie['domain']='.nhl.com' consent_cookie.cookie['path']='/' nhl.com/postrej_5.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/travelchannel.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.bigrock.in/domain-registration/domain-registration-price.php' consent_cookie.cookie['domain']='.bigrock.com' consent_cookie.cookie['path']='/' bigrock.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.thieme.com/de' consent_cookie.cookie['domain']='.thieme.de' consent_cookie.cookie['path']='/' thieme-connect.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about' consent_cookie.cookie['domain']='.hightail.com' consent_cookie.cookie['path']='/' hightail.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about/careers' consent_cookie.cookie['domain']='.hightail.com' consent_cookie.cookie['path']='/' hightail.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://blog.sketchup.com/' consent_cookie.cookie['domain']='.www.sketchup.com' consent_cookie.cookie['path']='/' sketchup.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://eab.com/privacy-policy-2/' consent_cookie.cookie['domain']='.www.youvisit.com' consent_cookie.cookie['path']='/' youvisit.com/postrej_3.har.xz
# Domain path mismatch: .verizon.com domain's path /business not match url https://www.verizon.com/privacy/your-privacy-choices#/
# Unmatch url and consent cookie domain: page_url='https://www.verizon.com/privacy/your-privacy-choices#/' consent_cookie.cookie['domain']='.verizon.com' consent_cookie.cookie['path']='/business' uu.net/postrej_3.har.xz
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_2.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_1.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Post rej cookie not contain consent cookie, haydaygame.com/postrej_0.har.xz not have cookie OptanonConsent of .hayday.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.okta.com/privacy-policy/' consent_cookie.cookie['domain']='.auth0.com' consent_cookie.cookie['path']='/' auth0.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/jostens.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/pa/es/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/pa/es/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' kpmg.com/postrej_2.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/gi/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/gi/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' kpmg.com/postrej_5.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/be/nl/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/be/nl/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' kpmg.com/postrej_1.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/kr/ko/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/kr/ko/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' kpmg.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.atlassian.com/software/bitbucket/bundle' consent_cookie.cookie['domain']='.bitbucket.org' consent_cookie.cookie['path']='/' bitbucket.org/postrej_2.har.xz
# Domain path mismatch: .nuveen.com domain's path /en-us not match url https://www.nuveen.com/global/investment-capabilities/ucits
# Unmatch url and consent cookie domain: page_url='https://www.nuveen.com/global/investment-capabilities/ucits' consent_cookie.cookie['domain']='.nuveen.com' consent_cookie.cookie['path']='/en-us' nuveen.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://marketplace.ivanticloud.com/partners' consent_cookie.cookie['domain']='.ivanti.com' consent_cookie.cookie['path']='/' ivanti.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.anthology.com/services/enhance-and-enable' consent_cookie.cookie['domain']='.blackboard.com' consent_cookie.cookie['path']='/' blackboard.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.anthology.com/integration-partnerships' consent_cookie.cookie['domain']='.blackboard.com' consent_cookie.cookie['path']='/' blackboard.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.anthology.com/en-emea' consent_cookie.cookie['domain']='.blackboard.com' consent_cookie.cookie['path']='/' blackboard.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.anthology.com/contact-us' consent_cookie.cookie['domain']='.blackboard.com' consent_cookie.cookie['path']='/' blackboard.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.twinmotion.com/en-US' consent_cookie.cookie['domain']='.unrealengine.com' consent_cookie.cookie['path']='/' unrealengine.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/paloaltonetworks.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.yelp-press.com/news/default.aspx' consent_cookie.cookie['domain']='.yelp.ca' consent_cookie.cookie['path']='/' yelp.ca/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://secure.planetary.org/site/SPageNavigator/connect.html' consent_cookie.cookie['domain']='www.planetary.org' consent_cookie.cookie['path']='/' planetary.org/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://account.booking.com/sign-in?op_token=...-mhBg' consent_cookie.cookie['domain']='.www.booking.com' consent_cookie.cookie['path']='/' bstatic.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.mylo.id/login?client_id=7c9e3433malhhe1o5asmit2aeb&state=d2x1Y2xsSjZlMlU3WTYxWjZoYVkzMFM1WjR6NUttUzBDczBNVFVueXY5ND0&redirect_uri=https%3A%2F%2Fwww.bicycling.com%2Fauth%2Flogin' consent_cookie.cookie['domain']='.bicycling.com' consent_cookie.cookie['path']='/' bicycling.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/runners-world-magazine-subscription-website?utm_source=runnersworld.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.runnersworld.com' consent_cookie.cookie['path']='/' runnersworld.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://account.samsung.com/membership/policy/terms' consent_cookie.cookie['domain']='.www.smartthings.com' consent_cookie.cookie['path']='/' smartthings.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.care.com/' consent_cookie.cookie['domain']='.www.betreut.de' consent_cookie.cookie['path']='/' care.com/postrej_0.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/gale.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.sony.de/' consent_cookie.cookie['domain']='.www.sony.net' consent_cookie.cookie['path']='/' sony.net/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/2ksports.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://careers.vodafone.com/uk/' consent_cookie.cookie['domain']='.vodafone.co.uk' consent_cookie.cookie['path']='/' vodafone.co.uk/postrej_3.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/funcom.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/funcom.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://www.englandfootball.com/play/home' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.thefa.com/b2cthefa.onmicrosoft.com/b2c_1a_signup_signinactdyn/oauth2/v2.0/authorize?response_type=id_token&scope=https%3A%2F%2Fb2cthefa.onmicrosoft.com%2Factscopeapp%2Fuser_impersonation%20https%3A%2F%2Fb2cthefa.onmicrosoft.com%2Factscopeapp%2Fread%20https%3A%2F%2Fb2cthefa.onmicrosoft.com%2Factscopeapp%2Fwrite%20openid%20profile&client_id=b56cfcf8-856a-45e3-9a25-3fe21463338c&redirect_uri=https%3A%2F%2Fmyaccount.thefa.com%2F&state=eyJpZCI6ImExNWUzMWIzLTY0Y2QtNDZhMC1hMWNhLTNhZDFlYWNiNTRjNSIsInRzIjoxNjgxNTQ2MDA0LCJtZXRob2QiOiJyZWRpcmVjdEludGVyYWN0aW9uIn0%3D&nonce=955470ae-c9c3-4868-b62a-194a36db3708&client_info=1&x-client-SKU=MSAL.JS&x-client-Ver=1.3.4&FAAppToken=AM&client-request-id=6db09b25-3daa-4d9e-8724-721dc91026f3&response_mode=fragment' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.englandfootball.com/play/youth-football' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://learn.englandfootball.com/' consent_cookie.cookie['domain']='.www.thefa.com' consent_cookie.cookie['path']='/' thefa.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/level3.net/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.kaseya.com/careers/jobs/' consent_cookie.cookie['domain']='.www.datto.com' consent_cookie.cookie['path']='/' infocyte.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/gitlab.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://careers.squareup.com/us/en' consent_cookie.cookie['domain']='.weebly.com' consent_cookie.cookie['path']='/' weebly.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/phoenix.edu/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/womens-health-magazine-subscription-website?utm_source=womenshealthmag.com&utm_medium=referral&utm_campaign=us-websites' consent_cookie.cookie['domain']='.womenshealthmag.com' consent_cookie.cookie['path']='/' womenshealthmag.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/thawte.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.digicert.com/legal-repository' consent_cookie.cookie['domain']='.thawte.com' consent_cookie.cookie['path']='/' thawte.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.microsoftonline.com/09fd564e-bf42-4321-8f2d-b8e482f8635c/oauth2/authorize?client%5Fid=00000003%2D0000%2D0ff1%2Dce00%2D000000000000&response%5Fmode=form%5Fpost&response%5Ftype=code%20id%5Ftoken&resource=00000003%2D0000%2D0ff1%2Dce00%2D000000000000&scope=openid&nonce=BE4ED6E4A63AE37391618922038D9E8270FA5324DA88945D%2DA9ABC334332264DCE7959B2750575ED95559F6D0216E1A8BFD5B81605D6B489C&redirect%5Furi=https%3A%2F%2Fhbs%2Esharepoint%2Ecom%2F%5Fforms%2Fdefault%2Easpx&state=OD0w&claims=%7B%22id%5Ftoken%22%3A%7B%22xms%5Fcc%22%3A%7B%22values%22%3A%5B%22CP1%22%5D%7D%7D%7D&wsucxt=1&cobrandid=11bd8083%2D87e0%2D41b5%2Dbb78%2D0bc43c8a8e8a&client%2Drequest%2Did=5b5ca9a0%2Dc071%2D3000%2D6fd7%2D33d4b0ba5089' consent_cookie.cookie['domain']='.hbs.edu' consent_cookie.cookie['path']='/' hbs.edu/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://login3.id.hp.com/login3/sign-up' consent_cookie.cookie['domain']='.hpsmart.com' consent_cookie.cookie['path']='/' hpsmart.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://eu.battle.net/login/en-us/?ref=https://oauth.battle.net/authorize?response_type%3Dcode%26redirect_uri%3Dhttps%253A%252F%252Fwww.blizzard.com%252Fauth%252Fbnet%252Fcallback%26scope%3Dlogout%2520account.licenses%2520email%2520name%2520private_flags%2520primary-address%2520account.full%2520reference.basic%26client_id%3D3d87a4f120754e15840548b68d9ea4db&app=oauth' consent_cookie.cookie['domain']='.blizzard.com' consent_cookie.cookie['path']='/' blizzard.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://resources.rioseo.com/c/vitamin-shoppe-case?x=NQYXLs#page=1' consent_cookie.cookie['domain']='.www.rioseo.com' consent_cookie.cookie['path']='/' rioseo.com/postrej_5.har.xz
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://careers.chubb.com/global/en/north-america
# Unmatch url and consent cookie domain: page_url='https://careers.chubb.com/global/en/north-america' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_5.har.xz
# Domain path mismatch: .chubb.com domain's path /us-en not match url https://www.chubb.com/ch-fr/
# Unmatch url and consent cookie domain: page_url='https://www.chubb.com/ch-fr/' consent_cookie.cookie['domain']='.chubb.com' consent_cookie.cookie['path']='/us-en' chubb.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.kaspersky.com/' consent_cookie.cookie['domain']='usa.kaspersky.com' consent_cookie.cookie['path']='/' kaspersky.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, unilever.com/postrej_2.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Post rej cookie not contain consent cookie, unilever.com/postrej_5.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Post rej cookie not contain consent cookie, unilever.com/postrej_1.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Post rej cookie not contain consent cookie, unilever.com/postrej_0.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Post rej cookie not contain consent cookie, unilever.com/postrej_3.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Post rej cookie not contain consent cookie, unilever.com/postrej_4.har.xz not have cookie OptanonConsent of .unilever.com on path /
# Domain path mismatch: .westernunion.com domain's path /us not match url https://wucare.westernunion.com/s/customer-care-home?language=en_US
# Unmatch url and consent cookie domain: page_url='https://wucare.westernunion.com/s/customer-care-home?language=en_US' consent_cookie.cookie['domain']='.westernunion.com' consent_cookie.cookie['path']='/us' westernunion.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://medium.com/@TechKing' consent_cookie.cookie['domain']='.king.com' consent_cookie.cookie['path']='/' king.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/' consent_cookie.cookie['domain']='.womansday.com' consent_cookie.cookie['path']='/' womansday.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://globalinclusivegrowthsummit.com/?utm_source=institutesite&utm_medium=eventpage&utm_campaign=gigs' consent_cookie.cookie['domain']='.aspeninstitute.org' consent_cookie.cookie['path']='/' aspeninstitute.org/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/uptodate/mobile' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/policies-legal/copyright-trademarks-logos' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wolterskluwer.com/en/solutions/uptodate/resources/learning-forum-webinars' consent_cookie.cookie['domain']='.uptodate.com' consent_cookie.cookie['path']='/' uptodate.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://clever.com/oauth/district-picker?response_type=code&redirect_uri=https%3A%2F%2Fsso.proquest.com%2Flogin%2Fcallback&scope=openid%20read%3Adistrict_admins_basic%20read%3Aschool_admins_basic%20read%3Astudents_basic%20read%3Ateachers_basic%20read%3Auser_id&state=2PRqHpAh5aEprbXaJpX-8meEDhxwtyKu&client_id=2bc7187eb691fb4efa79' consent_cookie.cookie['domain']='.proquest.com' consent_cookie.cookie['path']='/' proquest.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/boeing.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.mulesoft.com/contact' consent_cookie.cookie['domain']='.dataloader.io' consent_cookie.cookie['path']='/' dataloader.io/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://try.joomag.com/create-digital-magazine/' consent_cookie.cookie['domain']='www.joomag.com' consent_cookie.cookie['path']='/' joomag.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wralsportsfan.com/bulls-top-ironpigs-4-3/20812352/' consent_cookie.cookie['domain']='.wral.com' consent_cookie.cookie['path']='/' wral.com/postrej_1.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/ba/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/ba/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' home.kpmg/postrej_2.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/dk/da/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/dk/da/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' home.kpmg/postrej_1.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/sk/en/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/sk/en/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' home.kpmg/postrej_3.har.xz
# Domain path mismatch: .kpmg.com domain's path /xx/en not match url https://kpmg.com/tw/zh/home.html
# Unmatch url and consent cookie domain: page_url='https://kpmg.com/tw/zh/home.html' consent_cookie.cookie['domain']='.kpmg.com' consent_cookie.cookie['path']='/xx/en' home.kpmg/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.dasani.com/' consent_cookie.cookie['domain']='.coca-colacompany.com' consent_cookie.cookie['path']='/' coca-colacompany.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.powerade.com/' consent_cookie.cookie['domain']='.coca-colacompany.com' consent_cookie.cookie['path']='/' coca-colacompany.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/oregonlive.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.opentext.com/about/privacy' consent_cookie.cookie['domain']='.webroot.com' consent_cookie.cookie['path']='/' webrootcloudav.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://accounts.google.com/o/oauth2/auth/identifier?access_type=offline&approval_prompt=force&client_id=250992307284-m88p8nub2ormiak916etcu4ke3o850it.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Frelay.school%2Fusers%2Fauth%2Fgoogle_oauth2%2Fcallback&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile&state=d702d0083ea86e6eb7971784b37e3d64d887e246b6b9b749&service=lso&o2v=1&flowName=GeneralOAuthFlow' consent_cookie.cookie['domain']='.relay.school' consent_cookie.cookie['path']='/' relay.school/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.microsoftonline.com/common/oauth2/authorize?client_id=8a8c7465-fa18-4ca8-aa85-f314a303ddec&redirect_uri=https%3A%2F%2Frelay.school%2Fusers%2Fauth%2Fazure_oauth2%2Fcallback&response_type=code&scope=wl.basic+wl.signin+wl.offline_access&state=c67f5f3ddcafef21f13ccde9cdda136044b42654b29918cf' consent_cookie.cookie['domain']='.relay.school' consent_cookie.cookie['path']='/' relay.school/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nielsen.com/solutions/content-metadata/streaming-video-suite/' consent_cookie.cookie['domain']='.www.gracenote.com' consent_cookie.cookie['path']='/' gracenote.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nielsen.com/about-us/leadership/' consent_cookie.cookie['domain']='.www.gracenote.com' consent_cookie.cookie['path']='/' gracenote.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://paypal.eightfold.ai/careers?Brand=hyperwallet' consent_cookie.cookie['domain']='www.hyperwallet.com' consent_cookie.cookie['path']='/' hyperwallet.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.enartia.com/career' consent_cookie.cookie['domain']='.top.host' consent_cookie.cookie['path']='/' grserver.gr/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.getenrolled.com/' consent_cookie.cookie['domain']='.webassign.net' consent_cookie.cookie['path']='/' webassign.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://myalteryxsso.b2clogin.com/myalteryxsso.onmicrosoft.com/B2C_1A_signup_signin_flexera_ui/api/SelfAsserted/confirmed?csrf_token=&tx=StateProperties=eyJUSUQiOiI4NTNlM2Y2Ny04YjM3LTQ3ZWItYTYyNS1jYjI3N2U5ZTYyNGMifQ&p=B2C_1A_signup_signin_flexera_ui&diags=%7B%22pageViewId%22%3A%2247acee41-0eac-4b95-be17-7c7381b539f5%22%2C%22pageId%22%3A%22SelfAsserted%22%2C%22trace%22%3A%5B%7B%22ac%22%3A%22T005%22%2C%22acST%22%3A1681547245%2C%22acD%22%3A6%7D%2C%7B%22ac%22%3A%22T021%20-%20URL%3Ahttps%3A%2F%2Falteryxb2c.blob.core.windows.net%2Fb2c-custom-files%2FbrowserScan.html%22%2C%22acST%22%3A1681547245%2C%22acD%22%3A1320%7D%2C%7B%22ac%22%3A%22T019%22%2C%22acST%22%3A1681547247%2C%22acD%22%3A5%7D%2C%7B%22ac%22%3A%22T004%22%2C%22acST%22%3A1681547247%2C%22acD%22%3A7%7D%2C%7B%22ac%22%3A%22T003%22%2C%22acST%22%3A1681547247%2C%22acD%22%3A5%7D%2C%7B%22ac%22%3A%22T035%22%2C%22acST%22%3A1681547248%2C%22acD%22%3A0%7D%2C%7B%22ac%22%3A%22T030Online%22%2C%22acST%22%3A1681547248%2C%22acD%22%3A0%7D%2C%7B%22ac%22%3A%22T017T010%22%2C%22acST%22%3A1681547247%2C%22acD%22%3A1070%7D%2C%7B%22ac%22%3A%22T002%22%2C%22acST%22%3A1681547248%2C%22acD%22%3A0%7D%2C%7B%22ac%22%3A%22T017T010%22%2C%22acST%22%3A1681547247%2C%22acD%22%3A1070%7D%5D%7D' consent_cookie.cookie['domain']='.alteryx.com' consent_cookie.cookie['path']='/' alteryx.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://recruiting.adp.com/srccar/public/RTI.home?c=2177119' consent_cookie.cookie['domain']='.ifit.com' consent_cookie.cookie['path']='/' ifit.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/cbsi.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/cbsi.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, edgecast.com/postrej_1.har.xz not have cookie OptanonConsent of .edg.io on path /
# Post rej cookie not contain consent cookie, edgecast.com/postrej_0.har.xz not have cookie OptanonConsent of .edg.io on path /
# Unmatch url and consent cookie domain: page_url='https://secure.blogtalkradio.com/register.aspx?package=free&ReturnUrl=/&f=h' consent_cookie.cookie['domain']='.www.blogtalkradio.com' consent_cookie.cookie['path']='/' blogtalkradio.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/ametek.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login3.id.hp.com/login3/sign-up' consent_cookie.cookie['domain']='.hpsmart.com' consent_cookie.cookie['path']='/' hpconnected.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_2.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_5.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_1.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_0.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_3.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, thebodyshop.com/postrej_4.har.xz not have cookie OptanonConsent of .www.thebodyshop.com on path /en-us/
# Post rej cookie not contain consent cookie, redbull.com/postrej_2.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_5.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_1.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_0.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_3.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.com/postrej_4.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Unmatch url and consent cookie domain: page_url='https://join.codecademy.com/learn/paths/front-end-engineer-career-path-b/' consent_cookie.cookie['domain']='.www.codecademy.com' consent_cookie.cookie['path']='/' codecademy.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://hourofcode.com/de/beyond' consent_cookie.cookie['domain']='.code.org' consent_cookie.cookie['path']='/' code.org/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/Advertising-and-Cookie-Policy?language=en_GB' consent_cookie.cookie['domain']='.nextdoor.co.uk' consent_cookie.cookie['path']='/' nextdoor.co.uk/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/community-guidelines?language=en_GB#guidelines' consent_cookie.cookie['domain']='.nextdoor.co.uk' consent_cookie.cookie['path']='/' nextdoor.co.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.cbsnews.com/' consent_cookie.cookie['domain']='.cbs.com' consent_cookie.cookie['path']='/' cbs.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/italia.it/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/italia.it/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/' consent_cookie.cookie['domain']='.delish.com' consent_cookie.cookie['path']='/' delish.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hearstmagazines.co.uk/' consent_cookie.cookie['domain']='.delish.com' consent_cookie.cookie['path']='/' delish.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.techsmith.com/u/login/identifier?state=hKFo2SBIMWFDMXFPSUFYamZwX0NPVmhYdmpvSVhXM3pLOENRWaFur3VuaXZlcnNhbC1sb2dpbqN0aWTZIFpLN0l1TEtRQm8tUk5XS2RHZDR6TnJSYXFLbVRQUlFzo2NpZNkgMExSQzFJMXhDTFEzajQwSFRUM3ZDMUE4QWh1d2p5MDI&ui_locales=en-US' consent_cookie.cookie['domain']='.screencast.com' consent_cookie.cookie['path']='/' screencast.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.techsmith.com/u/login/identifier?state=hKFo2SA2R2VEWHlpR0FxU1RoZFNPbEJSRF9SS3JSUm82TzQ5M6Fur3VuaXZlcnNhbC1sb2dpbqN0aWTZIFd5TFNhVy1fQ2N0S0M1NDdWSXg2THZpMWs0di05SmhGo2NpZNkgMExSQzFJMXhDTFEzajQwSFRUM3ZDMUE4QWh1d2p5MDI&ui_locales=en-US' consent_cookie.cookie['domain']='.screencast.com' consent_cookie.cookie['path']='/' screencast.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.moodys.com/' consent_cookie.cookie['domain']='www.moodys.com' consent_cookie.cookie['path']='/' moodys.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/liveperson.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .www2.deloitte.com domain's path /us/ not match url https://www2.deloitte.com/lt/en.html?icid=site_selector_lt
# Unmatch url and consent cookie domain: page_url='https://www2.deloitte.com/lt/en.html?icid=site_selector_lt' consent_cookie.cookie['domain']='.www2.deloitte.com' consent_cookie.cookie['path']='/us/' deloitte.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_2.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_5.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_1.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_0.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_3.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Post rej cookie not contain consent cookie, launchdarkly.com/postrej_4.har.xz not have cookie CookieConsent of launchdarkly.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.wego.com/' consent_cookie.cookie['domain']='www.wegoreise.de' consent_cookie.cookie['path']='/' wego.com/postrej_0.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_0k_20k/adtechus.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://app.podigee.com/en/register?__hstc=202057230.6a23a98ccf8ab88f30711bcea2e57a64.1681714606754.1681714606754.1681714606754.1&__hssc=202057230.1.1681714606755&__hsfp=1575905175&hsCtaTracking=8dcc4b3e-a554-498c-89d1-a54d748f7236%7C7b554c28-eb13-4b93-be55-668e44f99863' consent_cookie.cookie['domain']='www.podigee.com' consent_cookie.cookie['path']='/' podigee.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://account.dentsplysirona.com/9502prodidp.onmicrosoft.com/B2C_1A_signup_signin_saml_prod/samlp/sso/login?ui_locales=en' consent_cookie.cookie['domain']='.www.dentsplysirona.com' consent_cookie.cookie['path']='/' dentsplysirona.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://corporate.brenntag.com/en/' consent_cookie.cookie['domain']='.www.brenntag.com' consent_cookie.cookie['path']='/' brenntag.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_2.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_5.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# ...
# Domain path mismatch: .www.kroll.com domain's path /en not match url https://www.kroll.com/es-mx
# Unmatch url and consent cookie domain: page_url='https://www.kroll.com/es-mx' consent_cookie.cookie['domain']='.www.kroll.com' consent_cookie.cookie['path']='/en' kroll.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.instagram.com/accounts/login/?next=https%3A%2F%2Fwww.instagram.com%2Flogin%2F%3Fnext%3Dhttps%253A%252F%252Fwww.instagram.com%252Fmajidalfuttaim%252F%26__coig_login%3D1' consent_cookie.cookie['domain']='.www.majidalfuttaim.com' consent_cookie.cookie['path']='/' majidalfuttaim.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/dealersocket.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://privacy.wmg.com/rhino/privacy-policy' consent_cookie.cookie['domain']='.rhino.com' consent_cookie.cookie['path']='/' rhino.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://grants-search.turn2us.org.uk/' consent_cookie.cookie['domain']='www.turn2us.org.uk' consent_cookie.cookie['path']='/' turn2us.org.uk/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/edg.io/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://corporate.universaldestinationsandexperiences.com/' consent_cookie.cookie['domain']='.universalparks.com' consent_cookie.cookie['path']='/' universalparks.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, redbull.tv/postrej_2.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_5.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_1.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_0.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_3.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_4.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Unmatch url and consent cookie domain: page_url='https://www.nintendo.com/consumer/assets/region_select.jsp?d=3dseshop' consent_cookie.cookie['domain']='.animal-crossing.com' consent_cookie.cookie['path']='/' animal-crossing.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nintendo.com/consumer/assets/region_select.jsp?d=3dseshop' consent_cookie.cookie['domain']='.animal-crossing.com' consent_cookie.cookie['path']='/' animal-crossing.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/Privacy-Policy?language=nl_NL' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/Privacy-Policy?language=nl_NL#omohgjdg4icd' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/EEA-Member-Agreement?language=nl_NL' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_4.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/tw-en/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/tw-en/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_5.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/tw-zh/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/tw-zh/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_1.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/at-de/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/at-de/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.petzldealer.com/B2B_LoginForm?startURL=%2F' consent_cookie.cookie['domain']='.petzl.com' consent_cookie.cookie['path']='/' petzl.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://shop.hettich.com/de_EN/Runner-systems/c/group93961603792' consent_cookie.cookie['domain']='web.hettich.com' consent_cookie.cookie['path']='/' hettich.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schoolprday.com/home' consent_cookie.cookie['domain']='.finalsite.com' consent_cookie.cookie['path']='/' finalsite.net/postrej_1.har.xz
# Post rej cookie not contain consent cookie, firaxis.com/postrej_1.har.xz not have cookie OptanonConsent of .firaxis.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/asthmaandlung.org.uk/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login.fronius.com/authenticationendpoint/login.do?client_id=mf_o9iTAyKemNLQTa6Sp6HYonCIa&commonAuthCallerPath=%2Foauth2%2Fauthorize&forceAuth=false&nonce=638172926299763308.ODNmZTg2NmItM2MxYi00ZjNlLThhYjEtYmIzMzI5ZmM0Nzk1ZjYzNjk1NmMtMTljZi00NWYxLTk1ODMtMjE1Y2I3MDE1ZWFj&passiveAuth=false&redirect_uri=https%3A%2F%2Fwww.solarweb.com%2FAccount%2FExternalLoginCallback&response_mode=form_post&response_type=code+id_token&scope=openid+profile+solarweb+solweb_browserid_2bd01f79cae7de012a0d6dbacb64ce40&state=OpenIdConnect.AuthenticationProperties%3DZdURyZEuPxHnFrisUOz08z8DPRMTJPINnGFL7ieGtFAQ5ricZbcsOb8P7WGa0OC2ls2rH7jZPyJPWn_mGbTgpdGVzJHkHScA9-FCa4DeWelqaEXsp6SH4GGSDCwK8qv5h5V7NjWZvJYk4EiJMyXGFrE8JtjS7g0vSyZfyp3d0cJKZ6KphLPBWWKXCscmgNWSrSNbLlQvHru9CA9lteYWLq4iBW6YV3L1aCVF-TizWg3EbAXdUPnd5O9S3nfg7akd8g48NA&tenantDomain=carbon.super&x-client-SKU=ID_NET461&x-client-ver=6.9.0.0&sessionDataKey=205a242e-066a-480c-bbf5-1b9800a13fc5&relyingParty=mf_o9iTAyKemNLQTa6Sp6HYonCIa&type=oidc&sp=Solar.web+-+Portals&isSaaSApp=false&authenticators=SAMLSSOAuthenticator:Fronius%20Login;CustomAuthenticatorLocalMain:LOCAL:LOCAL' consent_cookie.cookie['domain']='www.solarweb.com' consent_cookie.cookie['path']='/' solarweb.com/postrej_2.har.xz
# Domain path mismatch: .pro.sony domain's path /en_GB not match url https://pro.sony/productregistration?l=en_GB
# Unmatch url and consent cookie domain: page_url='https://pro.sony/productregistration?l=en_GB' consent_cookie.cookie['domain']='.pro.sony' consent_cookie.cookie['path']='/en_GB' pro.sony/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/telkomsa.net/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://support.piriform.com/hc/en-us' consent_cookie.cookie['domain']='.ccleaner.com' consent_cookie.cookie['path']='/' ccleanerbrowser.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.afp.com/en/contact' consent_cookie.cookie['domain']='.www.afpforum.com' consent_cookie.cookie['path']='/' afpforum.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://soundbran.ch/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webanywhere.com/about-us/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schooljotter.com/products' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webanywhere.com/career/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schooljotter.com/free-resources' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.harmankardon.com/' consent_cookie.cookie['domain']='.harmankardon.de' consent_cookie.cookie['path']='/' harmankardon.com/postrej_0.har.xz
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_2.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_5.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_1.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_3.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_4.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/signin?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2Flogin%3FiesCode%3DsA45H3aXtz' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/forgot-unpw?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2Flogin' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='chrome-error://chromewebdata/' consent_cookie.cookie['domain']='.embarkvet.com' consent_cookie.cookie['path']='/' embarkvet.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://twitter.com/arista_channels?utm_source=site_footer' consent_cookie.cookie['domain']='.edge.arista.com' consent_cookie.cookie['path']='/' untangle.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.myq.com/facility' consent_cookie.cookie['domain']='.liftmaster.com' consent_cookie.cookie['path']='/' liftmaster.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, incapsula.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_4.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Unmatch url and consent cookie domain: page_url='https://accounts.google.com/o/oauth2/auth/identifier?client_id=355692466809-vkvrr3bues96uatk4j6fq62g8kc0grcg.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsso.holded.cloud%2Fcallback&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile&state=google%253ae073d3559c3e79f13f7999b90aeec718%253aweb%253aholded%253ahttps%253a%252f%252fapp.holded.com&service=lso&o2v=1&flowName=GeneralOAuthFlow' consent_cookie.cookie['domain']='.holded.com' consent_cookie.cookie['path']='/' holded.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/biamp.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/biamp.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_4.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/za/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/za/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_5.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/vn/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/vn/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_1.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/au/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/au/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_3.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/ru/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/ru/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_4.har.xz
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/scan.parquet
# Number sent cookies read: 13,055,212
#                   name                                 value          domain  \
# 0     ajs_anonymous_id  8b883f8e-dd49-4ffa-bc01-56e536e0e19c     .wework.com
# 1     ajs_anonymous_id  8b883f8e-dd49-4ffa-bc01-56e536e0e19c     .wework.com
# 2  we_referring_domain                                        www.wework.com
#
#   path       expires  size  httpOnly  secure  session sameSite priority  \
# 0    /  1.713082e+09    52     False   False    False      Lax   Medium
# 1    /  1.713082e+09    52     False   False    False      Lax   Medium
# 2    /  1.682755e+09    19     False   False    False      NaN   Medium
#
#    sameParty sourceScheme  sourcePort  \
# 0      False       Secure         443
# 1      False       Secure         443
# 2      False       Secure         443
#
#                                          request_url        site  \
# 0                            https://www.wework.com/  wework.com
# 1    https://www-static.wework.com/apercu/apercu.css  wework.com
# 2  https://www.wework.com/l/commercial-real-estat...  wework.com
#
#                                             page_url
# 0  https://www.wework.com/l/commercial-real-estat...
# 1  https://www.wework.com/l/commercial-real-estat...
# 2  https://www.wework.com/l/commercial-real-estat...

# %%
postrej_sent_cookies = sent_cookies.drop_duplicates()
print(f"Num raw captured cookies: {len(sent_cookies):,d}")
print(f"Num unique captured cookies: {len(postrej_sent_cookies):,d}")
# Out:
# Num raw captured cookies: 13,055,212
# Num unique captured cookies: 12,982,601

# %% [markdown]
# # Combine the actual and declared durations

# %%
def find_pref(cookie, site_pref_dicts, site):
    def match(acookie, site_pref):
        # print(f"{acookie=}")
        # print(f"{site_pref=}")
        return cookie_pref_match(acookie, site_pref, site, fuzzy_name=True)  #  Germany: turn on fuzzy name due to a large number of errors.

    # found = site_pref_df[ site_pref_df.apply(match, axis=1) ]
    found = [site_pref_dict for site_pref_dict in site_pref_dicts if match(cookie, site_pref_dict)]
    if len(found) > 1:
        # print(f"WARNING: multiple site pref found (contradictory pref) {found=}")
        found = found[0:1]
    return found

def combine_cookie_pref(cookies, site_pref_df: pd.DataFrame, site):
    """Combine cookie to decl. TODO: rename pref to decl"""
    new_rows = []
    # site_pref_dicts = tuple(hashabledict(d) for d in site_pref_df.to_dict('records'))
    site_pref_dicts = site_pref_df.to_dict('records')
    for _, cookie in cookies.iterrows():       
        cookie = cookie.to_dict()

        # Only needs these attributes; reduce to memoize
        # cookie_to_match = hashabledict({k: cookie[k] for k in ["name", "domain"]})
        cookie_to_match = cookie
        for pref in find_pref(cookie_to_match, site_pref_dicts, site):
            new_row = cookie.copy()
            for pref_k, pref_v in pref.items():
                new_row['decl_' + pref_k] = pref_v
            new_rows.append(new_row)

    return pd.DataFrame(new_rows)

def get_combine_cookie_decls():
    combine_dfs = []
    for site in tqdm(postrej_sent_cookies.site.unique()[:10]):
        cookies = postrej_sent_cookies[postrej_sent_cookies.site == site]
        site_decl_df = raw_cookie_decls[raw_cookie_decls.site == site]
        if len(cookies) > 10000:
            print(f'WARNING: skip processing site due to too many cookies: {site=}, {len(cookies)=} {len(site_decl_df)=}')
            continue
        combine_dfs.append(combine_cookie_pref(cookies, site_decl_df, site))
        
    return pd.concat(combine_dfs, ignore_index=True)

# cookie_prefs_file = data_dir / 'cookie_prefs.parquet'
# if False: # cookie_prefs_file.exists():
#     cookie_prefs = pd.read_parquet(cookie_prefs_file)
# else:
# TODO: change pref to decl
cookie_decls = get_combine_cookie_decls()
#     cookie_prefs.to_parquet(cookie_prefs_file); print(f"Written to {cookie_prefs_file}")
cookie_decls # 26 mins
# Out:
# 100%|██████████| 10/10 [01:14<00:00,  7.46s/it]
#                    name                                              value  \
# 0      we_search_params                                             %7B%7D
# 1      ajs_anonymous_id               8b883f8e-dd49-4ffa-bc01-56e536e0e19c
# 2      we_search_params                                             %7B%7D
# 3       __we_request_id               1d797cd9-0b08-4789-a586-459f0dcaff82
# 4                  user  {%22formUUID%22:%2267d89ca5-bacb-41d7-9841-34b...
# ...                 ...                                                ...
# 18432  _parsely_visitor  {%22id%22:%22pid=3dc5e053-5fe8-4f58-a6ef-72136...
# 18433     location_data        {"country_code":"DE","postal_code":"60323"}
# 18434    OptanonConsent  isGpcEnabled=0&datestamp=Sat+Apr+15+2023+06%3A...
# 18435    OptanonConsent  isGpcEnabled=0&datestamp=Sat+Apr+15+2023+06%3A...
# 18436  _parsely_visitor  {%22id%22:%22pid=3dc5e053-5fe8-4f58-a6ef-72136...
#
#                domain path       expires  size  httpOnly  secure  session  \
# 0      www.wework.com    /  1.682755e+09    22     False   False    False
# 1         .wework.com    /  1.713082e+09    52     False   False    False
# 2      www.wework.com    /  1.682755e+09    22     False   False    False
# 3      www.wework.com    / -1.000000e+00    51     False    True     True
# 4      www.wework.com    / -1.000000e+00    63     False    True     True
# ...               ...  ...           ...   ...       ...     ...      ...
# 18432       .elle.com    /  1.715704e+09   135     False   False    False
# 18433    www.elle.com    / -1.000000e+00    56     False   False     True
# 18434       .elle.com    /  1.713077e+09   365     False   False    False
# 18435       .elle.com    /  1.713076e+09   365     False   False    False
# 18436       .elle.com    /  1.715704e+09   135     False   False    False
#
#       sameSite  ...                                           page_url  \
# 0         None  ...  https://www.wework.com/l/commercial-real-estat...
# 1          Lax  ...  https://www.wework.com/l/commercial-real-estat...
# 2         None  ...  https://www.wework.com/l/commercial-real-estat...
# 3          Lax  ...  https://www.wework.com/l/commercial-real-estat...
# 4          Lax  ...  https://www.wework.com/l/commercial-real-estat...
# ...        ...  ...                                                ...
# 18432     None  ...  https://www.elle.com/culture/movies-tv/a435217...
# 18433     None  ...  https://www.elle.com/culture/movies-tv/a435217...
# 18434      Lax  ...  https://www.elle.com/culture/movies-tv/a435217...
# 18435      Lax  ...  https://www.elle.com/culture/movies-tv/a435217...
# 18436     None  ...  https://www.elle.com/culture/movies-tv/a435217...
#
#               decl_name     decl_domain  decl_duration decl_category_id  \
# 0      we_search_params  www.wework.com        14 days            C0001
# 1      ajs_anonymous_id      wework.com       365 days            C0001
# 2      we_search_params  www.wework.com        14 days            C0001
# 3       __we_request_id  www.wework.com        Session            C0001
# 4                  user  www.wework.com        Session            C0001
# ...                 ...             ...            ...              ...
# 18432  _parsely_visitor        elle.com       395 days            C0001
# 18433     location_data    www.elle.com        Session            C0001
# 18434    OptanonConsent        elle.com       365 days            C0001
# 18435    OptanonConsent        elle.com       365 days            C0001
# 18436  _parsely_visitor        elle.com       395 days            C0001
#
#                                 decl_category decl_consent_mode   decl_site  \
# 0                  Strictly Necessary Cookies     always active  wework.com
# 1                  Strictly Necessary Cookies     always active  wework.com
# 2                  Strictly Necessary Cookies     always active  wework.com
# 3                  Strictly Necessary Cookies     always active  wework.com
# 4                  Strictly Necessary Cookies     always active  wework.com
# ...                                       ...               ...         ...
# 18432  Strictly Necessary & Analytics Cookies     always active    elle.com
# 18433  Strictly Necessary & Analytics Cookies     always active    elle.com
# 18434  Strictly Necessary & Analytics Cookies     always active    elle.com
# 18435  Strictly Necessary & Analytics Cookies     always active    elle.com
# 18436  Strictly Necessary & Analytics Cookies     always active    elle.com
#
#       decl_lib_name decl_pattern_name
# 0          onetrust           en.json
# 1          onetrust           en.json
# 2          onetrust           en.json
# 3          onetrust           en.json
# 4          onetrust           en.json
# ...             ...               ...
# 18432      onetrust           en.json
# 18433      onetrust           en.json
# 18434      onetrust           en.json
# 18435      onetrust           en.json
# 18436      onetrust           en.json
#
# [18437 rows x 26 columns]

# %%
# No longer analyze cookie durations
import sys; sys.exit(1)

# %%
def get_duration_sec(cookie):
    if cookie['expires'] == -1:
        return -1
    return cookie['expires'] - cookie['load_end_time']

cookie_decls['dur_sec'] = cookie_decls.apply(get_duration_sec, axis=1)
cookie_decls.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'load_end_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
#       3         return -1
#       4     return cookie['expires'] - cookie['load_end_time']
# ----> 6 cookie_decls['dur_sec'] = cookie_decls.apply(get_duration_sec, axis=1)
#       7 cookie_decls.head()
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[13], line 4, in get_duration_sec(cookie)
#       2 if cookie['expires'] == -1:
#       3     return -1
# ----> 4 return cookie['expires'] - cookie['load_end_time']
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'load_end_time'

# %%
# cookie_prefs[(cookie_prefs.name == 'eyeblaster') & (cookie_prefs.site == 'scientificamerican.com') ]
# cookie_decls[(cookie_decls.site == 'scientificamerican.com') ] # & (cookie_decls.domain == 'm6r.eu') ]

# %%
warnings = []
def parse_cookie_dur(pref_dur: str):
    pref_dur = pref_dur.lower().strip()
    if pref_dur == 'session':
        return -1
    if pref_dur == '0 days':  # equivalent to 'a few seconds' in onetrust
        return 100
    if pref_dur == 'persistent':
        return float('inf')
    try:
        return Duration(pref_dur).to_seconds()
    except Exception as e:
        warnings.append(f"Warning: {e} {pref_dur}")
        pass
    # Solve some rare cases:
    parts = pref_dur.split()
    assert len(parts) == 2
    cardinal, unit = float(parts[0]), parts[1]
    if unit == 'years':
        return cardinal * Duration('1 year').to_seconds()
    #     raise ValueError(f"Do not support {pref_dur}")
    return None

def test_parse_pref_dur():
    for dur in cookie_decls.pref_duration.unique():
        print(f'{dur} -> {int(parse_cookie_dur(dur)):,d}')
# test_parse_pref_dur()

# %%
# TODO: change pref_ to decl_ prefix
cookie_decls['decl_dur_sec'] = cookie_decls['decl_duration'].map(parse_cookie_dur)
cookie_decls
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 # TODO: change pref_ to decl_ prefix
# ----> 2 cookie_decls['decl_dur_sec'] = cookie_decls['decl_duration'].map(parse_cookie_dur)
#       3 cookie_decls
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/base.py:890, in IndexOpsMixin._map_values(self, mapper, na_action)
#     887         raise ValueError(msg)
#     889 # mapper is a function
# --> 890 new_values = map_f(values, mapper)
#     892 return new_values
#
# File ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[15], line 17, in parse_cookie_dur(pref_dur)
#      15 # Solve some rare cases:
#      16 parts = pref_dur.split()
# ---> 17 assert len(parts) == 2
#      18 cardinal, unit = float(parts[0]), parts[1]
#      19 if unit == 'years':
#
# AssertionError:

# %%
cookie_decls = cookie_decls[~cookie_decls.decl_dur_sec.isna()]

# %%
len(cookie_decls)
# Out:
# 3002554

# %%
# set(warnings) # these are spanish ...

# %%
declared_durations = cookie_decls.decl_duration.value_counts()

# %%
n_sites_with_dur = cookie_decls.site.nunique()
# print(f"Num sites with duration: {n_sites_with_dur/n_sites_with_sett*100:.2f} ({n_sites_with_dur}/{n_sites_with_sett})")
dur_vios = cookie_decls[cookie_decls.decl_dur_sec < cookie_decls.dur_sec]
n_violate_sites = dur_vios.site.nunique()
print(f"Num sites with duration violations: {n_violate_sites / n_sites_with_dur * 100:.2f}% ({n_violate_sites}/{n_sites_with_dur})")
# Out:
# Num sites with duration violations: 76.49% (1025/1340)

# %%
dur_vios_counts = dur_vios.decl_duration.value_counts().to_frame().reset_index()
dur_vios_counts['nspecified'] = dur_vios_counts['index'].map(declared_durations)
dur_vios_counts['percent_too_short'] = dur_vios_counts['decl_duration'] / dur_vios_counts['nspecified'] * 100
dur_vios_counts.head(5)
# Out:
#       index  decl_duration  nspecified  percent_too_short
# 0    0 days         461319      513081          89.911534
# 1   Session          49107      612401           8.018765
# 2  365 days          35128      602452           5.830838
# 3   16 days          27948       27948         100.000000
# 4  395 days          17166       30622          56.057736

# %%
duration_to_percent_too_short = {row['index']: row['percent_too_short'] for _, row in dur_vios_counts.iterrows()}
pref_dur_counts['percent_too_short'] = pref_dur_counts.Duration.map(duration_to_percent_too_short)
pref_dur_counts_latex = pref_dur_counts.rename(columns={"Duration": "Cookie Duration", "freq": r"Frequency (%)", "percent_too_short": r"% of Declared-too-short Cookies"})
pref_dur_counts_latex.replace({'0 days': 'A few seconds'}, inplace=True)
print(pref_dur_counts_latex.to_latex(float_format="%.2f", index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
# Cookie Duration &  Frequency (\%) &  \% of Declared-too-short Cookies \\
# \midrule
#         Session &          23.27 &                             8.02 \\
#   A few seconds &          22.58 &                            89.91 \\
#        365 days &          11.75 &                             5.83 \\
#        730 days &           4.55 &                             3.81 \\
#         30 days &           3.97 &                            10.49 \\
# \bottomrule
# \end{tabular}

# %%
# Analyze actual duration of "a few seconds"
dur_vios[dur_vios.pref_duration == "a few seconds"].sort_values(by='dur_sec')
# Out:
#                    domain       expires  httpOnly                        name  \
# 24824        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24769        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24772        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24775        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24794        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# ...                   ...           ...       ...                         ...
# 93688  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93708  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93743  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93589  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93535  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
#
#       path sameSite  secure   value  \
# 24824    /      Lax   False       0
# 24769    /      Lax   False       0
# 24772    /      Lax   False       0
# 24775    /      Lax   False       0
# 24794    /      Lax   False       0
# ...    ...      ...     ...     ...
# 93688    /     None   False  google
# 93708    /     None   False  google
# 93743    /     None   False  google
# 93589    /     None   False  google
# 93535    /     None   False  google
#
#                                              request_url  \
# 24824  https://www.cell.com/ssoSessionCheck?callback=...
# 24769  https://www.cell.com/cdn-cgi/scripts/5c5dd728/...
# 24772  https://www.cell.com/products/marlin/fonts/nex...
# 24775  https://www.cell.com/pb-assets/adobe/conversio...
# 24794  https://www.cell.com/products/marlin/fonts/els...
# ...                                                  ...
# 93688  https://www.glassdoor.com/app/static/img/locke...
# 93708  https://www.glassdoor.com/app/static/js/gd-fj-...
# 93743  https://www.glassdoor.com/app/static/js/dist/g...
# 93589  https://www.glassdoor.com/app/static/js/dist/g...
# 93535  https://www.glassdoor.com/app/static/js/gd-con...
#
#                         sent_name  ... load_start_time load_end_time  \
# 24824  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24769  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24772  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24775  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24794  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# ...                           ...  ...             ...           ...
# 93688              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93708              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93743              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93589              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93535              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
#
#        pref_duration          pref_host                   pref_name  \
# 24824  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24769  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24772  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24775  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24794  a few seconds       www.cell.com  _hjIncludedInSessionSample
# ...              ...                ...                         ...
# 93688  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93708  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93743  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93589  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93535  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
#
#       pref_group_id      pref_site pref_consent       dur_sec pref_dur_sec
# 24824             2       cell.com         True  1.092363e+02        100.0
# 24769             2       cell.com         True  1.092363e+02        100.0
# 24772             2       cell.com         True  1.092363e+02        100.0
# 24775             2       cell.com         True  1.092363e+02        100.0
# 24794             2       cell.com         True  1.092363e+02        100.0
# ...             ...            ...          ...           ...          ...
# 93688         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93708         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93743         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93589         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93535         C0001  glassdoor.com         True  2.517824e+11        100.0
#
# [31534 rows x 23 columns]
