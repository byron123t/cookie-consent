# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from consent.consistency.comply_util import site_to_contras, get_comply
from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import get_scan_root_dir, get_scan_dirs # , FIG_DIR uncomment to save fig.
from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cur_set = '20k_100k'
overwrite = True
SCAN_ROOT_DIR = Path('/mnt/sdd/ducbui/projects/data2/consent/2023-04-10/') # get_scan_root_dir('us')
SCAN_DIRS = [SCAN_ROOT_DIR / f'pref_menu_scan_{cur_set}']
# SCAN_DIRS = get_scan_dirs('us')[:]
output_suffix = '_' + cur_set # '0k_20k'  # '20k_100k' #'60k_80k' # '40k_60k' # # '100k_200k'; done: '20k_40k' '0k_20k' 
print('Scan root dir:', SCAN_ROOT_DIR)
print('Output suffix:', output_suffix)
print('Scan dirs:', SCAN_DIRS)
# Out:
# Scan root dir: /mnt/sdd/ducbui/projects/data2/consent/2023-04-10
# Output suffix: _20k_100k
# Scan dirs: [PosixPath('/mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k')]

# %%
# Get cookie prefs = cookie decls + prefs
cookie_prefs_file = SCAN_ROOT_DIR / f'cookie_prefs{output_suffix}.parquet'

if not cookie_prefs_file.exists() or overwrite:
    save_cookie_decls_file = SCAN_ROOT_DIR / f'cookie_decls{output_suffix}.parquet'
    print(f'To save to {save_cookie_decls_file}')
    cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS, save_cookie_decls_file)  # took 2.3min for top 50k-site scan
    cookie_prefs.to_parquet(cookie_prefs_file); print(f'Written to {cookie_prefs_file}')
else:
    cookie_prefs = pd.read_parquet(cookie_prefs_file)
cookie_prefs.head() 
# TODO: add log_file_checker
# Out:
# To save to /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/cookie_decls_20k_100k.parquet
# WARNING: Consent cookie not found gtnexus.com
# WARNING: Found non-unique (not found or >1 instance) tme.eu
# WARNING: Found non-unique (not found or >1 instance) dllgroup.com
# https://cdn-ukwest.onetrust.com/consent/e00c3e10-0e07-461a-94d5-e87b899fa55a/442b5be0-8f10-4555-b6a6-2aa7c2e23dfa/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/bitdefender.co.uk/consent_resources.json: region_block Received an out-of-region response
# https://cdn.cookielaw.org/consent/c570eb43-1169-4222-914c-38a09bd70ca0/35dbbebd-3059-4d43-84d6-439d5255bdd1/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/e59bbdce-b4f8-4ff2-b61b-0e2fd5cdd8eb/d0355fcf-730c-4284-839a-0308035a6585/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/bitdefender.com.au/consent_resources.json: region_block Received an out-of-region response
# https://cookie-cdn.cookiepro.com/consent/b8d5c851-476d-44a8-b314-f31da05a8584/ab656708-d47b-46bf-bf84-65524d609814/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/32c7db80-9d5f-490a-ae76-44fa02fd78c9/07998eed-4c10-4728-a36f-7708eed34314/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/keyfactorpki.com/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/logdna.com/consent_resources.json: region_block Received an out-of-region response
# https://cdn-ukwest.onetrust.com/consent/86f42b6d-7a31-469c-804c-319643173d42/9d40c5cd-66b0-4350-a7c5-dbf2e950474e/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/c570eb43-1169-4222-914c-38a09bd70ca0/35dbbebd-3059-4d43-84d6-439d5255bdd1/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/hackthebox.com/consent_resources.json: region_block Received an out-of-region response
# https://cdn.cookielaw.org/consent/df58fc6e-1766-4286-a9d4-9dba05282282/387dbfd9-91c1-4f4f-8a7c-5e9497048999/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/fhi360.org/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/firaxislive.com/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/supermetrics.com/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/crystalcruises.com/consent_resources.json: region_block Received an out-of-region response
# https://cdn.cookielaw.org/consent/502d0d7b-6014-4373-9c72-879af88d8e53/0c8ceb25-fd06-4229-b6e7-cbce8383a190/en-us.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/c64adbf1-1bf4-42a3-adca-725321c1f6ed/4b53b06d-fff6-48b9-ace7-4ce89967d993/en.json WARNING: Cookie list has session cookie but duration > 0
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/cookie_decls_20k_100k.parquet
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/cookie_prefs_20k_100k.parquet
#                       name                 domain duration category_id  \
# 0                      _NS  secure.paybyphone.com   0 days       C0001
# 1        ASP.NET_SessionId  secure.paybyphone.com  Session       C0001
# 2           ClientSettings  secure.paybyphone.com  30 days       C0001
# 3  cookie-primary-language     www.paybyphone.com  90 days       C0001
# 4       geoip-country-code     www.paybyphone.com  90 days       C0001
#
#                      category   consent_mode            site  lib_name  \
# 0  Strictly Necessary Cookies  always active  paybyphone.com  onetrust
# 1  Strictly Necessary Cookies  always active  paybyphone.com  onetrust
# 2  Strictly Necessary Cookies  always active  paybyphone.com  onetrust
# 3  Strictly Necessary Cookies  always active  paybyphone.com  onetrust
# 4  Strictly Necessary Cookies  always active  paybyphone.com  onetrust
#
#   pattern_name consent
# 0      en.json    True
# 1      en.json    True
# 2      en.json    True
# 3      en.json    True
# 4      en.json    True

# %%
print("Found cookie libraries:")
cookie_prefs[['site', 'lib_name']].drop_duplicates().lib_name.value_counts()
# Out:
# Found cookie libraries:
# onetrust     3042
# cookiebot     378
# termly         14
# Name: lib_name, dtype: int64

# %%
cookielist_sites = sorted(cookie_prefs.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert cookie_prefs.site.nunique() == n_cookielist_sites
n=10
print("Sites with cookie prefs:", n_cookielist_sites, f', first {n} sites:' , cookielist_sites[:n])
# Out:
# Sites with cookie prefs: 3434 , first 10 sites: ['100percentpure.com', '101greatgoals.com', '10fastfingers.com', '123helpme.com', '12build.com', '12up.com', '177milkstreet.com', '1hotels.com', '1v1.lol', '2020spaces.com']

# %%
site_to_libname = {row['site']: row['lib_name'] for row in cookie_prefs[['site', 'lib_name']].drop_duplicates().to_dict('records')}

# %%
# Quick checking the cookie declaration naming
print(len(cookie_prefs[cookie_prefs.name.str.endswith('#')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('xxx')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('XXX')]) / len(cookie_prefs))
cookie_prefs[cookie_prefs.name.str.endswith('#')]
# Out:
# 0.016761847235187526
# 0.02364936419903198
# 0.0032535280874196916
#                      name                     domain  duration   category_id  \
# 44        visitor_id#####           investor.rrd.com  630 days         C0004
# 57        visitor_id#####                 pardot.com  630 days         C0004
# 67        visitor_id#####              pi.pardot.com  630 days         C0004
# 43                  _ga_#                   tempo.io  399 days    statistics
# 44                  _ga_#   www.googletagmanager.com  399 days    statistics
# ..                    ...                        ...       ...           ...
# 89                   REM#  www.gassaferegister.co.uk    1 year  unclassified
# 28                  _ga_#                 clario.com  399 days    statistics
# 29                  _ga_#   www.googletagmanager.com  399 days    statistics
# 65  pagead/1p-user-list/#                 google.com   Session     marketing
# 66  pagead/1p-user-list/#             www.google.com   Session     marketing
#
#              category consent_mode                   site   lib_name  \
# 44  Targeting Cookies     inactive                rrd.com   onetrust
# 57  Targeting Cookies     inactive                rrd.com   onetrust
# 67  Targeting Cookies     inactive                rrd.com   onetrust
# 43         statistics         None               tempo.io  cookiebot
# 44         statistics         None               tempo.io  cookiebot
# ..                ...          ...                    ...        ...
# 89       unclassified         None  gassaferegister.co.uk  cookiebot
# 28         statistics         None                ert.com  cookiebot
# 29         statistics         None                ert.com  cookiebot
# 65          marketing         None                ert.com  cookiebot
# 66          marketing         None                ert.com  cookiebot
#
#    pattern_name consent
# 44      en.json   False
# 57      en.json   False
# 67      en.json   False
# 43        cc.js   False
# 44        cc.js   False
# ..          ...     ...
# 89        cc.js    True
# 28        cc.js   False
# 29        cc.js   False
# 65        cc.js   False
# 66        cc.js   False
#
# [8547 rows x 10 columns]

# %%
# # Distribution of errors
# print("Libs in failed-to-crawl sites")
# errors.consent_lib_name.value_counts()
# from ooutil.df_util import expand_dict_col
# ot_errs = errors[errors.consent_lib_name == 'onetrust']
# errors_dict = pd.DataFrame(ot_errs.error.tolist()).explode('reason')
# # Uncomment to show
# # errors_dict.reason.value_counts()

# %% [markdown]
# # Main analysis

# %%
# import sys; import importlib; importlib.reload(sys.modules['consent.data.pref_menu_scan.postrej_cookie_reader'])
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cookies_cache_file = SCAN_ROOT_DIR / f'scan{output_suffix}.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not cookies_cache_file.exists() or overwrite:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")
else:
    sent_cookies = pd.read_parquet(cookies_cache_file)

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Unmatch url and consent cookie domain: page_url='https://app.podigee.com/en/register?__hstc=202057230.812a9fab86452d13e3bfc9646b6f6fdb.1681776345723.1681776345723.1681776345723.1&__hssc=202057230.1.1681776345724&__hsfp=1575905175&hsCtaTracking=a95ec25d-720e-4195-8eff-ca8b5c6dddac%7C6701c7c9-0cd8-422c-b7af-1ed2c1d48872' consent_cookie.cookie['domain']='www.podigee.com' consent_cookie.cookie['path']='/' podigee.com/postrej_1.har.xz
# Domain path mismatch: .www.rohde-schwarz.com domain's path /us/ not match url https://www.rohde-schwarz.com/no/home_48230.html?change_c=true
# Unmatch url and consent cookie domain: page_url='https://www.rohde-schwarz.com/no/home_48230.html?change_c=true' consent_cookie.cookie['domain']='.www.rohde-schwarz.com' consent_cookie.cookie['path']='/us/' rohde-schwarz.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https
consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en?oc=5&pc=64150&rc=1&kc=&mjv=8&lang=en&loc=USA&FOUR=Y&CMD=P40WEBROOTHOME' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en/page_not_found' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en/legal?oc=226&pc=64150&rc=1&kc=&mjv=8&lang=en&loc=USA&FOUR=Y&CMD=P40LEGAL' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://trailblazer.me/id?uid=strailhead&cmty=trailhead' consent_cookie.cookie['domain']='.trailhead.salesforce.com' consent_cookie.cookie['path']='/' trailhead.com/postrej_2.har.xz
# Domain path mismatch: .sc.com domain's path /en/ not match url https://www.sc.com/bh/
# Unmatch url and consent cookie domain: page_url='https://www.sc.com/bh/' consent_cookie.cookie['domain']='.sc.com' consent_cookie.cookie['path']='/en/' standardchartered.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, codashop.com/postrej_2.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_5.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_3.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Post rej cookie not contain consent cookie, codashop.com/postrej_4.har.xz not have cookie OptanonConsent of .www.codashop.com on path /
# Unmatch url and consent cookie domain: page_url='https://css-arvest-prd.inforcloudsuite.com/hcm/Jobs/page/JobsHomePage?csk_showusingxi=true&csk_JobBoard=EXTERNAL&csk_HROrganization=ARV' consent_cookie.cookie['domain']='.arvest.com' consent_cookie.cookie['path']='/' arvest.com/postrej_2.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/es-ES
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/es-ES' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_2.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/id-ID
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/id-ID' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_5.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/th-TH
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/th-TH' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_1.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/ko-KR
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/ko-KR' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://apps.apple.com/app/gonoodle-kids-videos/id1050712293' consent_cookie.cookie['domain']='.gonoodle.com' consent_cookie.cookie['path']='/' gonoodle.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://cno.jerkmate.com/?transaction_id=FAILED_108124_TS538-999531217_84d2aa04-97c1-4023-a934-e22d44a32584_dfb95bcd-c065-4177-a013-6e7a247afed1__adultsense.net_US&aff_id=108124&actions=5&url=7&img=VZ8ua9&voluum=1&bo=5603,5645&pop=no&cep=PhXiIm5sxeiacAmPbPSBhWIM0rTo2sjvDXxNs6DYeBqx6cR-8QP
0Sb1erE_UaUsWh_N3YPOA3LGlSL-_v7Atl6N0jKTFxVnfkAFmr9tExZc-bIOpZlYsOP-7tZran9hIhA1vSb0EAzeeTTpfwCaVMd6mM2EDrUA_6O3fRMoxLMk4xAyY7wXfC4IzS5kiqUQscqEgov2O9a87Gp-tlQ_NOErWVdZIE3EJjCaturB_DTbt0VHIWFYDw4qxBpTbcfXm4sJ-vkGYnI3atUvUXUfjjrKy7Z0pYI2lWlGpA&x-client-SKU=ID_NET6_0&x-client-ver=6.26.1.0' consent_cookie.cookie['domain']='.smu.edu.sg' consent_cookie.cookie['path']='/' smu.edu.sg/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.net/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://worldline.com/en/home/about-us.html' consent_cookie.cookie['domain']='.six-payment-services.com' consent_cookie.cookie['path']='/' saferpay.com/postrej_5.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/blf.org.uk/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/winzipsystemtools.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/weatherford.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/weatherford.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/weatherford.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/weatherford.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, pehub.com/postrej_2.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_5.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_1.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_0.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_3.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_4.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Unmatch url and consent cookie domain: page_url='https://agape.gr/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='http://www.agapesverige.se/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hkccc.org/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='http://www.tandem.org.nz/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://healowhelp.com/home/healowhelp.html' consent_cookie.cookie['domain']='.healow.com' consent_cookie.cookie['path']='/' healow.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.takedaoncology.com/' consent_cookie.cookie['domain']='.takeda.com' consent_cookie.cookie['path']='/' baxalta.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/come2play.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/mauijim.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/lovoo.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/jasc.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.active.com/running/articles/best-jogging-strollers' consent_cookie.cookie['domain']='.activekids.com' consent_cookie.cookie['path']='/' activekids.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://passport.active.com/v5/auth/realms/active/protocol/openid-connect/auth?client_id=6f410d81-2809-495d-99f2-c2d173de42d1&goSignUp=true&invokeV4Cookie=true&redirect_uri=https%3A%2F%2Fwww.activekids.com%2Fusers%2Fauth%2Factive_passport_registration%2Fcallback&response_type=code&scope=openid&signinOption=act_fb_app&state=07bf9332f516c267eee2e27132d24a5363a524d6ab69fd88' consent_cookie.cookie['domain']='.activekids.com' consent_cookie.cookie['path']='/' activekids.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://whirlpoolcorp.com/privacy-notice-united-states-and-canada/' consent_cookie.cookie['domain']='.kitchenaid.com' consent_cookie.cookie['path']='/' kitchenaid.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://on2it.nl/privacy-statement/' consent_cookie.cookie['domain']='on2it.net' consent_cookie.cookie['path']='/' on2it.net/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/heraeus.cn/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/heraeus.cn/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/heraeus.cn/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/heraeus.cn/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/madametussauds.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/madametussauds.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/woodtv.com/postrej_1.har.xz: Expecting value: line 1 column 228711 (char 228710)
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/allegisgroup.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/honda.co.uk/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_2.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_5.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_1.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_0.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_3.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_4.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/carlsjr.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='www.comlaude.com' consent_cookie.cookie['path']='/' comlaude.co.uk/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='www.comlaude.com' consent_cookie.cookie['path']='/' comlaude.co.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='www.comlaude.com' consent_cookie.cookie['path']='/' comlaude.co.uk/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k
# Post rej cookie not contain consent cookie, movietickets.com/postrej_3.har.xz not have cookie OptanonConsent of .movietickets.com on path /
# Post rej cookie not contain consent cookie, movietickets.com/postrej_4.har.xz not have cookie OptanonConsent of .movietickets.com on path /
# Domain path mismatch: .royalcanin.com domain's path /us not match url https://signin.royalcanin.com/
# Unmatch url and consent cookie domain: page_url='https://signin.royalcanin.com/' consent_cookie.cookie['domain']='.royalcanin.com' consent_cookie.cookie['path']='/us' royalcanin.com/postrej_2.har.xz
# Domain path mismatch: .royalcanin.com domain's path /us not match url https://shop.royalcanin.com/?utm_campaign=2023-rc-us-harvesting-d2CCampaign-shopnownavagationpanel&utm_source=line&utm_medium=po-affiliate-shopnowhomepage&utm_content=link-x
# Unmatch url and consent cookie domain: page_url='https://shop.royalcanin.com/?utm_campaign=2023-rc-us-harvesting-d2CCampaign-shopnownavagationpanel&utm_source=line&utm_medium=po-affiliate-shopnowhomepage&utm_content=link-x' consent_cookie.cookie['domain']='.royalcanin.com' consent_cookie.cookie['path']='/us' royalcanin.com/postrej_1.har.xz
# Domain path mismatch: .royalcanin.com domain's path /us not match url https://preference-center.royalcanin.com/Account/Register?_ga=2.138110704.1741265493.1674469437-1944702798.1670949131&_gl=1*zj4v3k*_ga*MTcyMzEzMDI1Ni4xNjc3MDc3NzU5*_ga_BYDNNWSXGT*MTY3NzY3NjY3NS4zMDkuMS4xNjc3Njc4MDc0LjQ0LjAuMA..
# Unmatch url and consent cookie domain: page_url='https://preference-center.royalcanin.com/Account/Register?_ga=2.138110704.1741265493.1674469437-1944702798.1670949131&_gl=1*zj4v3k*_ga*MTcyMzEzMDI1Ni4xNjc3MDc3NzU5*_ga_BYDNNWSXGT*MTY3NzY3NjY3NS4zMDkuMS4xNjc3Njc4MDc0LjQ0LjAuMA..' consent_cookie.cookie['domain']='.royalcanin.com' consent_cookie.cookie['path']='/us' royalcanin.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, flixster.com/postrej_2.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Post rej cookie not contain consent cookie, flixster.com/postrej_5.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Post rej cookie not contain consent cookie, flixster.com/postrej_1.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Post rej cookie not contain consent cookie, flixster.com/postrej_0.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Post rej cookie not contain consent cookie, flixster.com/postrej_3.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Post rej cookie not contain consent cookie, flixster.com/postrej_4.har.xz not have cookie OptanonConsent of .flixster.com on path /
# Unmatch url and consent cookie domain: page_url='https://emerilsrestaurants.com/about-emeril/' consent_cookie.cookie['domain']='.emerils.com' consent_cookie.cookie['path']='/' emerils.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/monsterlegendsgame.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, bimobject.com/postrej_2.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_5.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_0.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_3.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_4.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/lee.net/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/msdvetmanual.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/steris.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://work4.northumbria.ac.uk/#en/sites/CX_1001' consent_cookie.cookie['domain']='.www.northumbria.ac.uk' consent_cookie.cookie['path']='/' northumbria.ac.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.bmilatvija.lv/' consent_cookie.cookie['domain']='www.bmigroup.com' consent_cookie.cookie['path']='/' bmigroup.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/bakermckenzie.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://minehut.zendesk.com/hc/en-us' consent_cookie.cookie['domain']='.minehut.com' consent_cookie.cookie['path']='/' minehut.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_2.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_1.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_0.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_3.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_4.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_2.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_5.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_1.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_0.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_3.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Post rej cookie not contain consent cookie, tennistv.com/postrej_4.har.xz not have cookie OptanonConsent of www.tennistv.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/legrandav.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.amazon.com/dp/B00XKFGBD2' consent_cookie.cookie['domain']='.wgt.com' consent_cookie.cookie['path']='/' wgt.com/postrej_4.har.xz
# Domain path mismatch: .www.ferrerorocher.com domain's path /us/en/ not match url https://www.ferrerorocher.com/uk/en/cookie-policy
# Unmatch url and consent cookie domain: page_url='https://www.ferrerorocher.com/uk/en/cookie-policy' consent_cookie.cookie['domain']='.www.ferrerorocher.com' consent_cookie.cookie['path']='/us/en/' ferrerorocherusa.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://identity.monster.com/login?state=hKFo2SA1MVlKWlp2dXpMN09LQlpvNm5qU1pXSUpQNldPbklrbaFupWxvZ2luo3RpZNkgeDk3T3JSdThCRk5HU3d4eXhReXcwWmVFc1NuVTNPQVCjY2lk2SB4ZjVUaTJsV2FiZDVsNk5lYnllNVNwb1dnMnJrSzdGTA&client=xf5Ti2lWabd5l6Nebye5SpoWg2rkK7FL&protocol=oauth2&redirect_uri=https%3A%2F%2Fwww.monster.co.uk%2Fprofile%2Fauth%2Fcallback&response_type=code&audience=profiles-profile-app-service&scope=openid%20profile%20email%20offline_access&monsterProps=eyJsYW5ndWFnZVRhZyI6ImVuLUdCIiwicmVjb2duaXplZFVzZXIiOmZhbHNlfQ' consent_cookie.cookie['domain']='.monster.co.uk' consent_cookie.cookie['path']='/' monster.co.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zdnet.com/article/best-home-security-monitoring-companies/' consent_cookie.cookie['domain']='.reviews.com' consent_cookie.cookie['path']='/' reviews.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.zdnet.com/article/simplisafe-vs-ring-review/' consent_cookie.cookie['domain']='.reviews.com' consent_cookie.cookie['path']='/' reviews.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.cnet.com/personal-finance/insurance/life/' consent_cookie.cookie['domain']='.reviews.com' consent_cookie.cookie['path']='/' reviews.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/aciworldwide.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://join.sweat.com/en/signup/new?campaign=2017_launch_campaign_sweat&utm_source=sweat&utm_medium=website' consent_cookie.cookie['domain']='www.sweat.com' consent_cookie.cookie['path']='/' sweat.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/viacomcbs.digital/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# ...
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/ch-de/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/ch-de/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_5.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/mm-en/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/mm-en/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_1.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/pa-es/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/pa-es/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.messenger.com/login.php?next=https%3A%2F%2Fwww.messenger.com%2Ft%2F654960281784070%2F%3Fmessaging_source%3Dsource%253Apages%253Amessage_shortlink%26source_id%3D1441792%26recurring_notification%3D0' consent_cookie.cookie['domain']='.trendmicro.com' consent_cookie.cookie['path']='/' mustcheck.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://shop.hettich.com/de_EN/Folding-door-systems/c/group6164362375932' consent_cookie.cookie['domain']='web.hettich.com' consent_cookie.cookie['path']='/' hettich.com/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/mastercard.com.au/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/aerohive.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.tritondigital.com/copyright-policy' consent_cookie.cookie['domain']='.omnystudio.com' consent_cookie.cookie['path']='/' omnystudio.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.fronius.com/authenticationendpoint/login.do?client_id=mf_o9iTAyKemNLQTa6Sp6HYonCIa&commonAuthCallerPath=%2Foauth2%2Fauthorize&forceAuth=false&nonce=638173536894256144.MzFkYTczOTQtMGYyOS00ZDBiLTlkNTQtYWNjZDgyNWZlMGFmNTc5OTM3ZjItNDk2ZS00ZWUwLWI1YjItYmU0NjUwZmE0Y2Nl&passiveAuth=false&redirect_uri=https%3A%2F%2Fwww.solarweb.com%2FAccount%2FExternalLoginCallback&response_mode=form_post&response_type=code+id_token&scope=openid+profile+solarweb+solweb_browserid_dd4ef7731a6a60c4d92a8eb6910ca180&state=OpenIdConnect.AuthenticationProperties%3DRXp7988gfT1EBQ8ouPImIQNeE7RwkJvKdPa-kGoIsTPNNdxh9326RsqAx09Jes4rquXvFJRFM-UQzNlJZEKB98gbwkAfIstXQEMkC_gwPsUuaYnehezN8kQWDHWKB0C31hzTuYDXX8LaOaG4WNZbrwTe7wdRfTxW3bLudxVFyutWyL53J8JVpiE_07v0ZpdVp5uqGamPuAo__yDzu8RgZetj9SquIp_lG-iynOtDwntvlYI7eZvRkXL-7cf2FdOcCry2Wg&tenantDomain=carbon.super&x-client-SKU=ID_NET461&x-client-ver=6.9.0.0&sessionDataKey=90559112-70ce-4e52-a3fa-77874c17288c&relyingParty=mf_o9iTAyKemNLQTa6Sp6HYonCIa&type=oidc&sp=Solar.web+-+Portals&isSaaSApp=false&authenticators=SAMLSSOAuthenticator:Fronius%20Login;CustomAuthenticatorLocalMain:LOCAL:LOCAL' consent_cookie.cookie['domain']='www.solarweb.com' consent_cookie.cookie['path']='/' solarweb.com/postrej_1.har.xz
# Domain path mismatch: .pro.sony domain's path /en_GB not match url https://pro.sony/en_HR/
# Unmatch url and consent cookie domain: page_url='https://pro.sony/en_HR/' consent_cookie.cookie['domain']='.pro.sony' consent_cookie.cookie['path']='/en_GB' pro.sony/postrej_1.har.xz
# Domain path mismatch: .pro.sony domain's path /en_GB not match url https://pro.sony/en_GR/
# Unmatch url and consent cookie domain: page_url='https://pro.sony/en_GR/' consent_cookie.cookie['domain']='.pro.sony' consent_cookie.cookie['path']='/en_GB' pro.sony/postrej_3.har.xz
# Domain path mismatch: .pro.sony domain's path /en_GB not match url https://pro.sony/en_MX/
# Unmatch url and consent cookie domain: page_url='https://pro.sony/en_MX/' consent_cookie.cookie['domain']='.pro.sony' consent_cookie.cookie['path']='/en_GB' pro.sony/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://sso.metartnetwork.com/login' consent_cookie.cookie['domain']='.metart.com' consent_cookie.cookie['path']='/' metart.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.bhg.com/account/profile?#/newsletter-preferences?brand=magcom' consent_cookie.cookie['domain']='.magazines.com' consent_cookie.cookie['path']='/' magazines.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, broadsign.com/postrej_2.har.xz not have cookie OptanonConsent of .broadsign.com on path /
# Post rej cookie not contain consent cookie, broadsign.com/postrej_5.har.xz not have cookie OptanonConsent of .broadsign.com on path /
# Post rej cookie not contain consent cookie, broadsign.com/postrej_1.har.xz not have cookie OptanonConsent of .broadsign.com on path /
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/bongino.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/bongino.com/log.json'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/academyart.edu/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/telkomsa.net/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://scoutsbrand.org.uk/' consent_cookie.cookie['domain']='.scouts.org.uk' consent_cookie.cookie['path']='/' scouts.org.uk/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.brendanvacations.com/vacation-search/?q=Ireland&m=&type=0&budget=&style=Guided%20Vacations&searchType=Undefined&utm_medium=pertnership&utm_source=tourismireland&utm_campaign=100off' consent_cookie.cookie['domain']='.ireland.com' consent_cookie.cookie['path']='/' ireland.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schooljotter.com/case-studies/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://soundbran.ch/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webanywhere.com/success-stories/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_3.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/link-hub.net/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/link-hub.net/log.json'
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_2.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_5.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_1.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_3.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_4.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Unmatch url and consent cookie domain: page_url='https://na.wotblitz.com/en/#/' consent_cookie.cookie['domain']='.eu.wotblitz.com' consent_cookie.cookie['path']='/' wotblitz.eu/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/mantech.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/signin?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2FRegister%3FiesCode%3DVwBlIdii4M' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/signin?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2FSecurity%2FUnknownError%3FiesCode%3D1MkF20DVH1' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/getcatchon.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://auth.verygoodsecurity.com/auth/realms/vgs/protocol/openid-connect/auth?client_id=docs&redirect_uri=https%3A%2F%2Fwww.verygoodsecurity.com%2Fdocs%2Fdashboard%2F&state=9d2bb664-3bb4-4c8f-8dc0-6d716b9a45e2&response_mode=fragment&response_type=code&scope=openid&nonce=d6a9ed54-6195-4313-8e65-acc07015debd&prompt=none' consent_cookie.cookie['domain']='.www.verygoodsecurity.com' consent_cookie.cookie['path']='/' verygoodsecurity.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.g2.com/products/arista-ng-firewall/reviews' consent_cookie.cookie['domain']='.edge.arista.com' consent_cookie.cookie['path']='/' untangle.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/verisign.net/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_2.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_1.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_3.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_4.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/carters.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, incapsula.com/postrej_2.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_5.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_1.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_3.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Unmatch url and consent cookie domain: page_url='https://investors.terex.com/investor-relations/governance/board-of-directors/default.aspx' consent_cookie.cookie['domain']='www.terex.com' consent_cookie.cookie['path']='/' terex.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.scopely.com/en/legal?id=tos&langSection=en' consent_cookie.cookie['domain']='.marvelstrikeforce.com' consent_cookie.cookie['path']='/' marvelstrikeforce.com/postrej_3.har.xz
# Domain path mismatch: .www.protiviti.com domain's path /us-en not match url https://www.protiviti.com/cn-zh
# Unmatch url and consent cookie domain: page_url='https://www.protiviti.com/cn-zh' consent_cookie.cookie['domain']='.www.protiviti.com' consent_cookie.cookie['path']='/us-en' protiviti.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/biamp.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/biamp.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://parent-support.parentpaygroup.com/hc/en-gb/categories/4407704072081-ParentPay' consent_cookie.cookie['domain']='.parentpay.com' consent_cookie.cookie['path']='/' parentpay.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_2.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/ae/ar/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/ae/ar/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_5.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/de/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/de/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_1.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/id/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/id/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/pref_menu_scan_20k_100k/ngc.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://applyboardindia.zendesk.com/hc/en-us/articles/6478276149901' consent_cookie.cookie['domain']='.applyboard.com' consent_cookie.cookie['path']='/' applyboard.com/postrej_5.har.xz
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/scan_20k_100k.parquet
# Number sent cookies read: 12,900,739
#     name                                     value        domain path  \
# 0    mus                                         0  .addthis.com    /
# 1    loc  OTUwNTFOQVVTQ0EyMTczMDU4MDgwNzAwMDBDSA==  .addthis.com    /
# 2  na_id              2023041721550405700324066264  .addthis.com    /
#
#         expires  size  httpOnly  secure  session sameSite priority  sameParty  \
# 0  1.715465e+09     4     False    True    False     None   Medium      False
# 1  1.715983e+09    43     False    True    False     None   Medium      False
# 2  1.715465e+09    33     False    True    False     None   Medium      False
#
#   sourceScheme  sourcePort                                        request_url  \
# 0       Secure         443  https://m.addthis.com/live/red_lojson/300lo.js...
# 1       Secure         443  https://m.addthis.com/live/red_lojson/300lo.js...
# 2       Secure         443  https://su.addthis.com/red/usync?pid=11156&ssr...
#
#              site                                           page_url
# 0  paybyphone.com  https://www.paybyphone.com/drivers/stories?cat...
# 1  paybyphone.com  https://www.paybyphone.com/drivers/stories?cat...
# 2  paybyphone.com  https://www.paybyphone.com/drivers/stories?cat...

# %%
# prj = post-rejection
# Old way: consider all flows
# prj_sent_cookies = sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
# prj_br_cookies = prj_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
# New way: consider cookies only (ignore the request url, which is not nused in get_comply cookie matching anyway)
prj_sent_cookies = sent_cookies[['name', 'domain', 'path', 'site']].drop_duplicates()

# %%
# print(f"Num captured sent cookies: {len(sent_cookies):,d}")
# print(f"Num unique captured cookies: {len(prj_sent_cookies):,d}")
# n_br_cookies = len(prj_br_cookies)
# print(f"Num unique browser cookies: {n_br_cookies:,d} on {prj_br_cookies.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")

# %% [markdown]
# ## Analyze cookies compliance

# %%
sites = set(cookie_prefs.site)
print(f"Num sent cookies in the cookie prefs sites: {len(prj_sent_cookies[prj_sent_cookies.site.isin(sites)]):,d}")
# Out:
# Num sent cookies in the cookie prefs sites: 115,731

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.comply_util'])
from consent.consistency.comply_util import get_comply

print("faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:")
all_complies = get_comply(cookie_prefs, prj_sent_cookies)
all_complies.head()
# Out:
# faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:
#  41%|████      | 1400/3434 [02:09<02:45, 12.32it/s]
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clsk' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clsk' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clsk' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clsk' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CookieConsent' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CookieConsent' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CookieConsent' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.store-api.proxy]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.store-api.proxy]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.store-api.proxy]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.store-api.proxy]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='sw-cache-hash' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='sw-cache-hash' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='sw-cache-hash' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='sw-cache-hash' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='__kla_id' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='__kla_id' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='__kla_id' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='__kla_id' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clck' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clck' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clck' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clck' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.register.save]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.register.save]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.register.save]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.register.save]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='session-' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='session-' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='session-' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='session-' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='MUID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='MUID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='MUID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='MUID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.login]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.login]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.login]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.login]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CLID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CLID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CLID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CLID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='x-ms-routing-name' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='x-ms-routing-name' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='TiPMix' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='TiPMix' bad character range e-a at position 22
#  66%|██████▌   | 2275/3434 [03:50<01:23, 13.86it/s]
# Big cookie pref benetton.com 3738 skip this site
#  82%|████████▏ | 2820/3434 [04:56<00:42, 14.61it/s]
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='OptanonAlertBoxClosed' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjSessionUser_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='bcookie' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_visitor' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vuid_l' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_ga_B77L7L8FZ3' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gcl_au' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__hssrc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_ma_cookie' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_sid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vid_l' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjSession_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_first_visit' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='oribili_user_guid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_fbp' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='hubspotutk' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__hssc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='OptanonConsent' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_svisitor' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjIncludedInSessionSample_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjFirstSeen' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_ga' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__hstc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vid_1878' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='ln_or' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_dc_gtm_UA-49969775-9' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_pws' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_gvid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_cid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='AnalyticsSyncHistory' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_pw' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_session' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='UserMatchHistory' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='6suuid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='lidc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__cf_bm' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='li_sugr' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='IDE' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_gavid_1878' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='YSC' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='NID' bad character range r-C at position 137
# 100%|█████████▉| 3433/3434 [06:00<00:00,  9.52it/s]
#     name        domain path            site comply
# 0    mus  .addthis.com    /  paybyphone.com   omit
# 1    loc  .addthis.com    /  paybyphone.com   omit
# 2  na_id  .addthis.com    /  paybyphone.com   omit
# 3   ouid  .addthis.com    /  paybyphone.com   omit
# 4   bkpa  .bluekai.com    /  paybyphone.com   omit

# %%
# Analyze complies here
complies = all_complies[['name', 'domain', 'path', 'site', 'comply']].drop_duplicates()
comply_sites_data = defaultdict(list)
for comply_type, comply_group in complies.groupby('comply'):
    n_sites = comply_group.site.nunique()
    comply_sites_data['comply_type'].append(comply_type)
    comply_sites_data['num_sites'].append(n_sites)
    comply_sites = pd.DataFrame(comply_sites_data).sort_values(by=['num_sites'], ascending=False)
    
nsites = all_complies.site.nunique()
comply_counts = complies.comply.value_counts()
comply_sites['num_sites_percent'] = comply_sites['num_sites'] / nsites * 100
comply_sites['num_cookies'] = comply_sites['comply_type'].map(comply_counts)
comply_sites['num_cookies_percent'] = comply_sites['num_cookies'] / comply_sites['num_cookies'].sum() * 100  # need to read scan_*.parquet for n_br_cookies, but may be unnecessary
comply_sites['num_cookies_per_site'] = comply_sites['num_cookies'] / comply_sites['num_sites'] 

# Do not count comply/correct enforcement: which require detecting all possible
comply_sites = comply_sites[comply_sites.comply_type != 'comply']
comply_sites
# Out:
#   comply_type  num_sites  num_sites_percent  num_cookies  num_cookies_percent  \
# 3        omit       3051          89.419695        60594            52.377536
# 2   incorrect       2954          86.576788        35628            30.796892
# 0   ambiguous        134           3.927315          271             0.234253
#
#    num_cookies_per_site
# 3             19.860374
# 2             12.060934
# 0              2.022388

# %%
# Record the analysis results
all_complies_file = SCAN_ROOT_DIR / f'all_complies{output_suffix}.parquet'
all_complies.to_parquet(all_complies_file); print(f"Written {len(all_complies):,d} records of all_complies to {all_complies_file}")
# Out:
# Written 115,687 records of all_complies to /mnt/sdd/ducbui/projects/data2/consent/2023-04-10/all_complies_20k_100k.parquet

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

raise StopExecution
import sys; sys.exit(0)

# %%
complies.comply
# Out:
# 0              omit
# 1              omit
# 2              omit
# 3              omit
# 4              omit
#             ...
# 115682    incorrect
# 115683    incorrect
# 115684         omit
# 115685       comply
# 115686       comply
# Name: comply, Length: 115687, dtype: object

# %%
nsites = all_complies.site.nunique(); nsites
# all_complies.site.unique()
# Out:
# 3412

# %%
detected_contra_sites = [s for s, contras in site_to_contras.items() if len(contras) > 0]; len(detected_contra_sites)
# Out:
# 0

# %%
complies = all_complies[ ['name', 'domain', 'site', 'comply',]].drop_duplicates()
comply_counts = complies.comply.value_counts()
comply_counts
# Out:
# omit         60214
# incorrect    35575
# comply       19067
# ambiguous      271
# Name: comply, dtype: int64

# %%
complies_sites = set(all_complies.site)
sent_cookies_com = sent_cookies[sent_cookies.site.isin(complies_sites)]
prj_sent_cookies_com = sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
prj_br_cookies_com = prj_sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
print(f"Num captured sent cookies: {len(sent_cookies_com):,d}")
print(f"Num unique captured cookies: {len(prj_sent_cookies_com):,d}")

n_br_cookies_com = len(prj_br_cookies_com)
print(f"Num unique browser cookies: {n_br_cookies_com:,d} on {prj_br_cookies_com.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")
# Out:
# Num captured sent cookies: 12,865,663
# Num unique captured cookies: 6,925,444
# Num unique browser cookies: 276,967 on 3,412 websites

# %% [markdown]
# # Analyze contras

# %%
# Way 1: compute contra sites by dynamic analysis: this should be lower than statically analyzing prefs
# because we cannot check all combinations of consent modes.
from consent.consistency.comply_util import get_appr_rej_sets
contra_data = []
for asite in cookie_prefs.site.unique():
    site_prefs = cookie_prefs[cookie_prefs.site == asite]
    _, _, contras = get_appr_rej_sets(site_prefs)
    for contra in contras:
        contra['site'] = asite
        contra_data.append(contra)
contra_sites = pd.DataFrame(contra_data)
contra_sites.head()
# Out:
#                   domain                         name                site
# 0  www.libertylondon.com         dwanonymous_xxxxxxxx   libertylondon.com
# 1      script.hotjar.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 2     tartecosmetics.com  _hjIncludedInPageviewSample  tartecosmetics.com
# 3     tartecosmetics.com                 _hjFirstSeen  tartecosmetics.com
# 4      script.hotjar.com   _hjIncludedInSessionSample  tartecosmetics.com

# %%
assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
#
# AssertionError: this is the same method with above, so the result

# %%
set(detected_contra_sites) - set(contra_sites.site)
set(contra_sites.site) - set(detected_contra_sites) 
# This may be the sites excluded due to testing cookies in the preferences.
# Out:
# {'247sports.com',
#  'abbvie.com',
#  'acquia.com',
#  'adobe.io',
#  'adweek.com',
#  'aljazeera.com',
#  'allaboutvision.com',
#  'allegiantair.com',
#  'allergan.com',
#  'alteryx.com',
#  'americanbar.org',
#  'aon.com',
#  'ariel.co.uk',
#  'asos.com',
#  'autosport.com',
#  'avalara.com',
#  'avast.com',
#  'avastbrowser.com',
#  'barnesandnoble.com',
#  'bazaarvoice.com',
#  'bbva.com',
#  'bd.com',
#  'behance.net',
#  'belkin.com',
#  'betsson.com',
#  'bitdefender.com',
#  'bitdefender.net',
#  'bkstr.com',
#  'blackboard.com',
#  'bplans.com',
#  'brightside.me',
#  'bromium-online.com',
#  'callofduty.com',
#  'cambridge.org',
#  'carbonite.com',
#  'cheapoair.com',
#  'chrysler.com',
#  'cisco.com',
#  'citationmachine.net',
#  'clickmeeting.com',
#  'clicktale.net',
#  'cloudbees.com',
#  'cnet.com',
#  'colt.net',
#  'commonsensemedia.org',
#  'contentsquare.com',
#  'conviva.com',
#  'creighton.edu',
#  'curalate.com',
#  'dc.com',
#  'dccomics.com',
#  'discogs.com',
#  'dynamicyield.com',
#  'easybib.com',
#  'eidos.com',
#  'elderscrollsonline.com',
#  'evri.com',
#  'ew.com',
#  'fabfitfun.com',
#  'fotolia.com',
#  'fourseasons.com',
#  'frontlineeducation.com',
#  'geappliances.com',
#  'geforce.com',
#  'genial.ly',
#  'getdbt.com',
#  'glip.com',
#  'gmu.edu',
#  'gopro.com',
#  'grainger.com',
#  'halfords.com',
#  'hallmark.com',
#  'hightail.com',
#  'hm.com',
#  'howstuffworks.com',
#  'hp.com',
#  'illumina.com',
#  'instyle.com',
#  'ipl.org',
#  'irishcentral.com',
#  'ironman.com',
#  'janes.com',
#  'jbl.com',
#  'jeep.com',
#  'jobvite.com',
#  'kew.org',
#  'lastline.com',
#  'launchdarkly.com',
#  'levi.com',
#  'liverpoolfc.com',
#  'logi.com',
#  'logitech.com',
#  'logitechg.com',
#  'mastercard.com',
#  'mastercard.us',
#  'mcgraw-hill.com',
#  'mckesson.com',
#  'meraki.com',
#  'mheducation.com',
#  'michaels.com',
#  'mlb.com',
#  'mongodb.com',
#  'mongodb.org',
#  'morningconsult.com',
#  'morrisons.com',
#  'motorsport.com',
#  'mtv.com',
#  'myportfolio.com',
#  'name.com',
#  'nba.com',
#  'ncaa.com',
#  'newsday.com',
#  'newsweaver.com',
#  'next.co.uk',
#  'nhl.com',
#  'ni.com',
#  'nspcc.org.uk',
#  'nvidia.com',
#  'ocado.com',
#  'omnitracs.com',
#  'onlyinyourstate.com',
#  'paradox.ai',
#  'parents.com',
#  'paypay.ne.jp',
#  'pcapredict.com',
#  'people.com',
#  'pge.com',
#  'phoenix.edu',
#  'pinknews.co.uk',
#  'politico.com',
#  'principal.com',
#  'prweb.com',
#  'rd.com',
#  'realsimple.com',
#  'ringcentral.com',
#  'rollout.io',
#  'royalacademy.org.uk',
#  'salliemae.com',
#  'samaritans.org',
#  'sanofi-synthelabo.com',
#  'sanofi.com',
#  'santander.co.uk',
#  'sciam.com',
#  'scientificamerican.com',
#  'senderscore.com',
#  'seon.io',
#  'sho.com',
#  'shuttercloud.org',
#  'shutterstock.com',
#  'signifyd.com',
#  'solvvy.com',
#  'sonos.com',
#  'sony.co.uk',
#  'sourcefire.com',
#  'sparknotes.com',
#  'square-enix-games.com',
#  'statista.com',
#  'suse.com',
#  'tasteofhome.com',
#  'telerik.com',
#  'thedailybeast.com',
#  'thedodo.com',
#  'thomsonreuters.com',
#  'thomsonreuters.net',
#  'travelandleisure.com',
#  'treasuredata.com',
#  'tripadvisor.in',
#  'typeform.com',
#  'typekit.com',
#  'uipath.com',
#  'ulta.com',
#  'umbrella.com',
#  'universe.com',
#  'urbanairship.com',
#  'vfsglobal.com',
#  'viber.com',
#  'visma.com',
#  'vmware.com',
#  'vmwareidentity.com',
#  'webmd.com',
#  'wfmz.com',
#  'whirlpool.com',
#  'workspaceoneaccess.com',
#  'worldoftanks.com',
#  'wwf.org.uk',
#  'yousendit.com',
#  'zdnet.com',
#  'zebra.com',
#  'zeiss.com',
#  'zennioptical.com',
#  'zoom.com',
#  'zoom.us'}

# %%
# Way 2: compute contra sites by DataFrame group by
contra_cookies_dfs = []
for _, same_cookies in cookie_prefs.groupby(['name', 'domain', 'site']):
    consent_modes = same_cookies.consent_mode.unique()
    if len(consent_modes) >= 2 and same_cookies.category.nunique() > 1: # and 'always active' in consent_modes:
        contra_cookies_dfs.append(same_cookies)
contra_cookies = pd.concat(contra_cookies_dfs).drop_duplicates()

# %%
print("Number sites with contra cookies:", contra_cookies.site.nunique())
# Out:
# Number sites with contra cookies: 184

# %%
# set(contra_cookies.site) - set(contra_sites.site)

# %%
print("Num contra cookie settings (double categories):", len(contra_cookies), f"settings  on {contra_cookies.site.nunique()} sites")
print("Contras with 1 always-active:", contra_sites.site.nunique())
print("Contras with both editable:", len(set(contra_cookies.site) - set(contra_sites.site)))
# Out:
# Num contra cookie settings (double categories): 648 settings  on 184 sites
# Contras with 1 always-active: 192
# Contras with both editable: 0

# %%
contra_cookies[contra_cookies.site == 'elsevier.nl']
# Out:
# Empty DataFrame
# Columns: [name, domain, duration, category_id, category, consent_mode, site, lib_name, pattern_name, consent]
# Index: []

# %%
# assert len(detected_contra_sites) <= contra_sites.site.nunique() < len(detected_contra_sites) + 2

# %%
complies[complies.comply == 'ambiguous']
# Out:
#                  name                  domain                   site  \
# 173        TS013559a7       www.mastercard.us         mastercard.com
# 1236    _qubitTracker         .www.very.co.uk             very.co.uk
# 2365   G_ENABLED_IDPS      .www.glassdoor.com          glassdoor.com
# 2372              trs       www.glassdoor.com          glassdoor.com
# 2375             _gid          .glassdoor.com          glassdoor.com
# ...               ...                     ...                    ...
# 59468         ak_bmsc           .mulesoft.com           mulesoft.com
# 59481      JSESSIONID   training.mulesoft.com           mulesoft.com
# 60397          TLTSID              .bkstr.com              bkstr.com
# 60412            dtSa              .bkstr.com              bkstr.com
# 60622       shortHash  .square-enix-games.com  square-enix-games.com
#
#           comply
# 173    ambiguous
# 1236   ambiguous
# 2365   ambiguous
# 2372   ambiguous
# 2375   ambiguous
# ...          ...
# 59468  ambiguous
# 59481  ambiguous
# 60397  ambiguous
# 60412  ambiguous
# 60622  ambiguous
#
# [116 rows x 4 columns]

# %%
cookie_prefs[ (cookie_prefs.site == 'michaels.com') & (cookie_prefs.name == 'utag_main') ]
# Out:
#           name         domain  duration category_id  \
# 88   utag_main  .michaels.com  365 days       C0001
# 148  utag_main   michaels.com  365 days       C0002
#
#                        category   consent_mode          site  lib_name  \
# 88   Strictly Necessary Cookies  always active  michaels.com  onetrust
# 148         Performance Cookies         active  michaels.com  onetrust
#
#     pattern_name consent
# 88       en.json    True
# 148      en.json   False

# %%
cookie_prefs[ (cookie_prefs.site == 'statista.com') & (cookie_prefs.name == 'id') ]
# Out:
#     name  domain duration category_id           category   consent_mode  \
# 74    id  m6r.eu  90 days       C0001  Necessary Cookies  always active
# 131   id  m6r.eu   0 days       C0004  Targeting Cookies       inactive
#
#              site  lib_name pattern_name consent
# 74   statista.com  onetrust      en.json    True
# 131  statista.com  onetrust      en.json   False

# %%
# contra_cookies.name.value_counts()[:10]
# contra_cookies[contra_cookies.name == '__cf_bm'].reset_index(drop=True) # .site.nunique()

# %% [markdown]
# # Analyze ambiguous flows

# %%
ambi_cookies = complies[complies.comply == 'ambiguous']
print("Num ambiguous cookies:", len(ambi_cookies), "on num sites:", ambi_cookies.site.nunique())
assert len(ambi_cookies) == len(ambi_cookies.drop_duplicates()), "there is some duplicate cookies"

# %% [markdown]
# ## Analyze no-way-to-opt-out

# %%
# Way 1: compute contra sites by DataFrame group by
nwtoo_cookies_dfs = []
for _, site_cookies in cookie_prefs.groupby(['site']):
    consent_modes = site_cookies.consent_mode.unique().tolist()
    if len(consent_modes) == 1 and consent_modes[0] == 'always active':
        nwtoo_cookies_dfs.append(site_cookies)
nwtoo_cookies = pd.concat(nwtoo_cookies_dfs).drop_duplicates()
nwtoo_cookies.head()

# %%
nwtoo_cookies.site.nunique()

# %% [markdown]
# # Analyze inconsistent flows/cookies

# %%
def plot_inconsis_types():
    sns.set(rc={'figure.figsize':(9,9),"font.size":30,"axes.titlesize":30,"axes.labelsize":30},style="white", font_scale = 2.5)

    ax = sns.barplot(x='comply_type', y='num_sites_percent', data=noncomply_sites)
    ax.tick_params(left=True, bottom=True, direction="in")
    ax.set_ylabel('# Websites (%)')
    ax.set_xlabel('Noncompliance Types')
    xticks = [x.get_text().title() for x in ax.get_xticklabels()]
    ax.set(xticklabels=xticks)

    out_file = FIG_DIR / 'noncomply_types_per_site.png'
    # plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
## Plot distribution of omitted cookie declarations

# %%
omit_complies = complies[(complies.comply == 'omit')] #  & ~complies.name.isin(['OptanonAlertBoxClosed', 'OptanonConsent']) ]
omit_complies.site.nunique()

# %%
omit_complies.site.value_counts()[:7]

# %%
omit_cookies = omit_complies.name.value_counts()[:5].to_frame().reset_index().rename(columns={'index': 'cookie_name'})
omit_cookies['num_sites'] = omit_cookies['cookie_name'].map(lambda cookie_name: omit_complies[omit_complies.name == cookie_name].site.nunique())
print(omit_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %%
# set(cookielist_sites) - set(omit_complies.site.unique())
omit_counts = omit_complies.site.value_counts().to_frame().rename(columns={'site': 'num_omit_cookies'})
print("Num omitted sites:", omit_complies.site.nunique())
omit_counts.num_omit_cookies.mean(), omit_counts.num_omit_cookies.std(), omit_counts.num_omit_cookies.min(), omit_counts.num_omit_cookies.max()

# %%
sns.set(rc={'figure.figsize':(12,8),"font.size":35,"axes.titlesize":30,"axes.labelsize":50},style="white", font_scale = 4.5)
sns.set_style("ticks", {"xtick.direction": "in", "ytick.direction": "in"})
plt.rcParams['xtick.major.size'] = 15
plt.rcParams['ytick.major.size'] = 15

ax = sns.ecdfplot(data=omit_counts, x=omit_counts.num_omit_cookies, linewidth=8)
ax.set(xlim=(0, 350))

plt.xlabel('# Omitted Cookies/Website')
plt.ylabel('CDF')
# out_file = FIG_DIR / 'eu_omit_cookie_cdf.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
plot_df = omit_counts[:50]

sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x=plot_df.index, y=plot_df.num_omit_cookies)
ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=False, direction="in")
ax.set_ylabel('# Omitted Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'omit_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
def plot_histogram_omit():
    sns.set(rc={'figure.figsize':(9,6),"font.size":25,"axes.titlesize":25,"axes.labelsize":15},style="white", font_scale = 1)
    omit_counts_histo = omit_complies.site.value_counts().value_counts()
    sns.barplot(x=omit_counts_histo.index, y=omit_counts_histo.values)
    ticks = plt.xticks(rotation=45, ha='right')

# %% [markdown]
# ## Plot distribution of incorrectly enforced cookies

# %%
incor_complies = complies[complies.comply == 'incorrect']
# set(cookielist_sites) - set(omit_complies.site.unique())
incor_counts = incor_complies.site.value_counts().iloc[:50]
incor_counts = incor_counts.to_frame().reset_index().sort_values(by=['site', 'index'], ascending=[False, True])
incor_counts.columns

# %%
sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x='index', y='site', data=incor_counts)

ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=True, direction="in")
ax.set_ylabel('# Incorrectly Enforced Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'incor_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
# len(incor_counts)

# %%
incor_counts[incor_counts.site == 33].reset_index(drop=True)

# %% [markdown]
# ### Top incorrect cookies

# %%
incor_cookies = complies[complies.comply == 'incorrect']

# %%
# site = 'onetrust.com'
# complies[complies.site == site].reset_index(drop=True)
# cookie_prefs[(cookie_prefs.site == site) & (cookie_prefs.name == '_gid')]

# %%
top_incor_cookies = incor_cookies.name.value_counts().sort_values(ascending=False).to_frame().reset_index().rename(columns={'index':'cookie_name', 'name': 'num_occur'})

# %%
top_incor_cookies['num_sites'] = top_incor_cookies.cookie_name.map(lambda cookie_name: incor_cookies[incor_cookies.name == cookie_name].site.nunique())

# %%
print(top_incor_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %% [markdown]
# # Narrow cookie consent preferences

# %%
consent_cookies = sent_cookies[sent_cookies.name.isin(['OptanonConsent', 'CookieConsent'])][['domain', 'name', 'site']].drop_duplicates()
narrow_consent_cookies = consent_cookies[~consent_cookies.domain.str.startswith('.')].reset_index(drop=True)

# %%
set(contra_cookies.site).intersection(set(narrow_consent_cookies.site))

# %%
narrow_consent_cookies

# %% [markdown]
# # Case studies

# %%
incor_df = complies[complies.comply == 'incorrect']
incor_df.site.value_counts().sort_values(ascending=False).head()

# %%
case_site = 'blabbermouth.net'
incor_df[incor_df.site == case_site]

# %%
# cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'MXP_TRACKINGID')]
cookie_prefs[(cookie_prefs.site == case_site) & (cookie_prefs.name == 'IDE')]

# %%
# sent_cookies[(sent_cookies.site == 'scientificamerican.com') & (sent_cookies.name == 'MXP_TRACKINGID')]

# %%
omit_df = complies[complies.comply == 'omit']
omit_df.site.value_counts().sort_values(ascending=False).iloc[20:30]

# %%
print(omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist())

# %%
'uids' in omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist()

# %%
omit_df[(omit_df.site == 'scientificamerican.com') & (omit_df.name == 'cftoken')]

# %%
cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'ADGRX_UID')]

# %%
all_sites = set(complies.site)
nothing_comply_sites = all_sites - set(complies[complies.comply == 'comply'].site)
print("Sites with no compliant cookies:", nothing_comply_sites)

# %%
for site in ['liveperson.com']: # nothing_comply_sites:
    print(site)
site_cookies = postrej_br_cookies[postrej_br_cookies.site == site]

# %%
acookie = site_cookies[site_cookies.name == 'OptanonAlertBoxClosed'].iloc[0]

# %%
site_prefs = cookie_prefs[cookie_prefs.site == site]
consent_cookies = site_prefs[site_prefs.consent]
consent_cookie_names = consent_cookies.name
site_cookies[site_cookies.name.isin(consent_cookie_names)]
# cookie_name = 'OptanonAlertBoxClosed'
# cookie_pref = site_prefs[site_prefs.name == cookie_name].iloc[0]
# cookie_pref

# %%
consent_cookies

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.cookie_pref_match'])
from consent.consistency.cookie_pref_match import cookie_pref_match    
cookie_pref_match(acookie, cookie_pref, site, verbose=2)

# %%
# Analyze Contras
