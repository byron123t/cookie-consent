# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from consent.consistency.comply_util import site_to_contras, get_comply
from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import get_scan_root_dir, get_scan_dirs # , FIG_DIR uncomment to save fig.
from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cur_set = '20k_100k'
overwrite = True
SCAN_ROOT_DIR = get_scan_root_dir('de')
SCAN_DIRS = [SCAN_ROOT_DIR / f'pref_menu_scan_{cur_set}']
# SCAN_DIRS = get_scan_dirs('us')[:]
output_suffix = '_' + cur_set # '0k_20k'  # '20k_100k' #'60k_80k' # '40k_60k' # # '100k_200k'; done: '20k_40k' '0k_20k' 
print('Scan root dir:', SCAN_ROOT_DIR)
print('Output suffix:', output_suffix)
print('Scan dirs:', SCAN_DIRS)
# Out:
# Scan root dir: /mnt/sdd/ducbui/projects/data2/consent/2023-04-14
# Output suffix: _20k_100k
# Scan dirs: [PosixPath('/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k')]

# %%
# Get cookie prefs = cookie decls + prefs
cookie_prefs_file = SCAN_ROOT_DIR / f'cookie_prefs{output_suffix}.parquet'

if not cookie_prefs_file.exists() or overwrite:
    save_cookie_decls_file = SCAN_ROOT_DIR / f'cookie_decls{output_suffix}.parquet'
    print(f'To save to {save_cookie_decls_file}')
    cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS, save_cookie_decls_file)  # took 2.3min for top 50k-site scan
    cookie_prefs.to_parquet(cookie_prefs_file); print(f'Written to {cookie_prefs_file}')
else:
    cookie_prefs = pd.read_parquet(cookie_prefs_file)
cookie_prefs.head() 
# TODO: add log_file_checker
# Out:
# To save to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/cookie_decls_20k_100k.parquet
# WARNING: Consent cookie not found gtnexus.com
# WARNING: Found non-unique (not found or >1 instance) tme.eu
# https://cdn-ukwest.onetrust.com/consent/e00c3e10-0e07-461a-94d5-e87b899fa55a/442b5be0-8f10-4555-b6a6-2aa7c2e23dfa/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/c570eb43-1169-4222-914c-38a09bd70ca0/a1f914ac-390b-484b-9577-7c7ad52c8361/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/chromedata.com/consent_resources.json: consent_js not supported yet.
# https://cdn.cookielaw.org/consent/e59bbdce-b4f8-4ff2-b61b-0e2fd5cdd8eb/580de968-9e99-4ea0-b2cd-0facb2dfec08/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/keyfactorpki.com/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# https://cookie-cdn.cookiepro.com/consent/b8d5c851-476d-44a8-b314-f31da05a8584/e2664ad1-b808-4766-a4b0-7bebbcb48c5a/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/32c7db80-9d5f-490a-ae76-44fa02fd78c9/07998eed-4c10-4728-a36f-7708eed34314/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn-ukwest.onetrust.com/consent/86f42b6d-7a31-469c-804c-319643173d42/09011ced-ecb6-4fa7-bd0b-30149d23ca54/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/workforcesoftware.com/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# https://cdn.cookielaw.org/consent/c570eb43-1169-4222-914c-38a09bd70ca0/a1f914ac-390b-484b-9577-7c7ad52c8361/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/mediaforce.com/consent_resources.json: 'NoneType' object has no attribute 'IsSession'
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/fhi360.org/consent_resources.json: consent_js not supported yet.
# https://cdn.cookielaw.org/consent/c64adbf1-1bf4-42a3-adca-725321c1f6ed/947fe58f-7764-46a7-bcca-e6bd6562f66a/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/firaxis.com/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/appsolid.net/consent_resources.json: No objects to concatenate
# WARNING: error decoding /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/appsolid.net/consent_resources.json: No objects to concatenate
# https://cdn.cookielaw.org/consent/502d0d7b-6014-4373-9c72-879af88d8e53/13cd4ce4-5bc0-47a0-811a-e6e5823805b6/en-gb.json WARNING: Cookie list has session cookie but duration > 0
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/cookie_decls_20k_100k.parquet
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/cookie_prefs_20k_100k.parquet
#                          name            domain duration category_id  \
# 0                      __cflb  secure.accor.com   1 days       C0001
# 1  __RequestVerificationToken   group.accor.com  Session       C0001
# 2         _dc_gtm_UA-xxxxxxxx         accor.com   0 days       C0001
# 3                      _Hw2h_         accor.com  Session       C0001
# 4                 _integrity_     all.accor.com  Session       C0001
#
#                      category   consent_mode      site  lib_name pattern_name  \
# 0  Strictly Necessary Cookies  always active  ibis.com  onetrust      en.json
# 1  Strictly Necessary Cookies  always active  ibis.com  onetrust      en.json
# 2  Strictly Necessary Cookies  always active  ibis.com  onetrust      en.json
# 3  Strictly Necessary Cookies  always active  ibis.com  onetrust      en.json
# 4  Strictly Necessary Cookies  always active  ibis.com  onetrust      en.json
#
#   consent
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
print("Found cookie libraries:")
cookie_prefs[['site', 'lib_name']].drop_duplicates().lib_name.value_counts()
# Out:
# Found cookie libraries:
# onetrust     2835
# cookiebot     472
# termly         27
# Name: lib_name, dtype: int64

# %%
cookielist_sites = sorted(cookie_prefs.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert cookie_prefs.site.nunique() == n_cookielist_sites
n=10
print("Sites with cookie prefs:", n_cookielist_sites, f', first {n} sites:' , cookielist_sites[:n])
# Out:
# Sites with cookie prefs: 3334 , first 10 sites: ['100percentpure.com', '101greatgoals.com', '10fastfingers.com', '123helpme.com', '12build.com', '1hotels.com', '1v1.lol', '2020spaces.com', '2go.com', '2kgames.com']

# %%
site_to_libname = {row['site']: row['lib_name'] for row in cookie_prefs[['site', 'lib_name']].drop_duplicates().to_dict('records')}

# %%
# Quick checking the cookie declaration naming
print(len(cookie_prefs[cookie_prefs.name.str.endswith('#')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('xxx')]) / len(cookie_prefs))
print(len(cookie_prefs[cookie_prefs.name.str.endswith('XXX')]) / len(cookie_prefs))
cookie_prefs[cookie_prefs.name.str.endswith('#')]
# Out:
# 0.021832936593810862
# 0.024165764985933782
# 0.0031356849166847005
#                       name                    domain  duration category_id  \
# 109       _gd#############                 accor.com   Session       C0003
# 149       _gd#############              fairmont.com   Session       C0003
# 163       _gd#############             swissotel.com   Session       C0003
# 189         _utmv#########           press.accor.com    0 days       C0007
# 353       _gd#############             hypemarks.com   Session       C0004
# ..                     ...                       ...       ...         ...
# 20          _utmv#########           shop.mondly.com    0 days       C0001
# 28                   _ga_#                clario.com  399 days  statistics
# 29                   _ga_#  www.googletagmanager.com  399 days  statistics
# 65   pagead/1p-user-list/#                google.com   Session   marketing
# 66   pagead/1p-user-list/#            www.google.com   Session   marketing
#
#                        category   consent_mode        site   lib_name  \
# 109          Functional Cookies       inactive    ibis.com   onetrust
# 149          Functional Cookies       inactive    ibis.com   onetrust
# 163          Functional Cookies       inactive    ibis.com   onetrust
# 189           Analytics cookies       inactive    ibis.com   onetrust
# 353           Targeting Cookies       inactive    ibis.com   onetrust
# ..                          ...            ...         ...        ...
# 20   Strictly Necessary Cookies  always active  mondly.com   onetrust
# 28                   statistics           None     ert.com  cookiebot
# 29                   statistics           None     ert.com  cookiebot
# 65                    marketing           None     ert.com  cookiebot
# 66                    marketing           None     ert.com  cookiebot
#
#     pattern_name consent
# 109      en.json   False
# 149      en.json   False
# 163      en.json   False
# 189      en.json   False
# 353      en.json   False
# ..           ...     ...
# 20       en.json    True
# 28         cc.js   False
# 29         cc.js   False
# 65         cc.js   False
# 66         cc.js   False
#
# [10089 rows x 10 columns]

# %%
# # Distribution of errors
# print("Libs in failed-to-crawl sites")
# errors.consent_lib_name.value_counts()
# from ooutil.df_util import expand_dict_col
# ot_errs = errors[errors.consent_lib_name == 'onetrust']
# errors_dict = pd.DataFrame(ot_errs.error.tolist()).explode('reason')
# # Uncomment to show
# # errors_dict.reason.value_counts()

# %% [markdown]
# # Main analysis

# %%
# import sys; import importlib; importlib.reload(sys.modules['consent.data.pref_menu_scan.postrej_cookie_reader'])
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans

cookies_cache_file = SCAN_ROOT_DIR / f'scan{output_suffix}.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not cookies_cache_file.exists() or overwrite:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")
else:
    sent_cookies = pd.read_parquet(cookies_cache_file)

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Unmatch url and consent cookie domain: page_url='https://app.podigee.com/en/register?__hstc=202057230.6a23a98ccf8ab88f30711bcea2e57a64.1681714606754.1681714606754.1681714606754.1&__hssc=202057230.1.1681714606755&__hsfp=1575905175&hsCtaTracking=8dcc4b3e-a554-498c-89d1-a54d748f7236%7C7b554c28-eb13-4b93-be55-668e44f99863' consent_cookie.cookie['domain']='www.podigee.com' consent_cookie.cookie['path']='/' podigee.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://account.dentsplysirona.com/9502prodidp.onmicrosoft.com/B2C_1A_signup_signin_saml_prod/samlp/sso/login?ui_locales=en' consent_cookie.cookie['domain']='.www.dentsplysirona.com' consent_cookie.cookie['path']='/' dentsplysirona.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://corporate.brenntag.com/en/' consent_cookie.cookie['domain']='.www.brenntag.com' consent_cookie.cookie['path']='/' brenntag.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_2.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_5.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_1.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_0.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_3.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Post rej cookie not contain consent cookie, ryobitools.com/postrej_4.har.xz not have cookie OptanonConsent of .www.ryobitools.com on path /
# Unmatch url and consent cookie domain: page_url='https://help.meundies.com/' consent_cookie.cookie['domain']='.www.meundies.com' consent_cookie.cookie['path']='/' meundies.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, gopenske.com/postrej_2.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Post rej cookie not contain consent cookie, gopenske.com/postrej_5.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Post rej cookie not contain consent cookie, gopenske.com/postrej_1.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Post rej cookie not contain consent cookie, gopenske.com/postrej_0.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Post rej cookie not contain consent cookie, gopenske.com/postrej_3.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Post rej cookie not contain consent cookie, gopenske.com/postrej_4.har.xz not have cookie OptanonConsent of .gopenske.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/ln-cc.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://daddariob2c.b2clogin.com/daddariob2c.onmicrosoft.com/oauth2/v2.0/authorize?p=b2c_1_sign-in&client_id=5c0b83dc-e49d-4022-a0ed-f25c3b842eed&redirect_uri=https%3A%2F%2Fwww.daddario.com%2F&response_mode=form_post&response_type=id_token&scope=openid%20profile%20offline_access%20email&state=OpenIdConnect.AuthenticationProperties%3DNLYnJGO3-tp8vBtHr9qM_MxVdbzYcby-5hojU5nUBBLDuMtJBKtHJ0fw9UfVsW4Szb4qqDIq9wMS2QhGUmiNgfdvAK1t-NPHNPqC6lqgXT3ehXlmYP9lZw0BysCdZU33aSsYN0xPVV1XO6uevf_gj3-sThEJhXKP8LKRZFXGRb8lDmx-vqzyV4THMuupKBxcQATquZ8w3rkuKjNW0XrVTmj5wor8cbZY3nutxIp9j8PZ8XaY4zVS_-pAlkjIUmeK&nonce=638173194653754801.MGEyNzJjY2YtODJhOS00NjViLTgyOGItMTg1MTVlNjQ2Mzc5MWFmYTNmYTQtZjM5Yi00ODdmLWI0NDgtZjUyN2I0YTQyZTU1&x-client-SKU=ID_NET461&x-client-ver=5.4.0.0' consent_cookie.cookie['domain']='.www.daddario.com' consent_cookie.cookie['path']='/' daddario.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://preview.codecanyon.net/item/bedrive-file-sharing-and-cloud-storage/full_screen_preview/12700384' consent_cookie.cookie['domain']='codecanyon.net' consent_cookie.cookie['path']='/' vebto.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.gtnexus.com/' consent_cookie.cookie['domain']='.www.infor.com' consent_cookie.cookie['path']='/' gtnexus.com/postrej_0.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.microsoftonline.com/e2123d26-0287-44eb-9c79-eb1d8fbe2ac2/oauth2/authorize?client_id=80c6b182-ede4-45e7-9a6d-597b96836c47&redirect_uri=https%3a%2f%2fwww.aent.com%2f&response_mode=form_post&response_type=code+id_token&scope=openid+profile&state=OpenIdConnect.AuthenticationProperties%3d2X28TwkCa76NGLYm0uGphsA9ugqAHfS2K-M_RYDE3GYIp7CGKw7Z3y5Ea-6rd7itojSRMSoNQlyjF617GGHsdbH_c44DIgMjOJZTMK92RyxbBQP12iZBOJaTa6XGdQxrwAkQYuga4n48OVuvdbFMaXkIrrjbKORgVX4KNHpiHSA&nonce=638173213345556954.MDJjNzIwZjItOGQxNC00N2RlLTgyMTAtNWJmMWY4ZDNhYjMyNDA5MzQ2MmQtM2ZlOS00MjM4LTllZDEtYTA3NThiYjg0Zjcy' consent_cookie.cookie['domain']='www.aent.com' consent_cookie.cookie['path']='/' aent.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.travelzoo.com/es/blog/secret-escapes-by-travelzoo-faq' consent_cookie.cookie['domain']='.secretescapes.com' consent_cookie.cookie['path']='/' secretescapes.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.mastercard.us/en-us/business/issuers/grow-your-business.html' consent_cookie.cookie['domain']='.mastercard.co.uk' consent_cookie.cookie['path']='/' mastercard.co.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.priceless.com/' consent_cookie.cookie['domain']='.mastercard.co.uk' consent_cookie.cookie['path']='/' mastercard.co.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.mastercard.us/en-us/business/overview/safety-and-security/authentication-services/biometrics.html' consent_cookie.cookie['domain']='.mastercard.co.uk' consent_cookie.cookie['path']='/' mastercard.co.uk/postrej_4.har.xz
# Post rej cookie not contain consent cookie, clifbar.com/postrej_2.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Post rej cookie not contain consent cookie, clifbar.com/postrej_5.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Post rej cookie not contain consent cookie, clifbar.com/postrej_1.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Post rej cookie not contain consent cookie, clifbar.com/postrej_0.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Post rej cookie not contain consent cookie, clifbar.com/postrej_3.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Post rej cookie not contain consent cookie, clifbar.com/postrej_4.har.xz not have cookie OptanonConsent of .clifbar.com on path /
# Unmatch url and consent cookie domain: page_url='https://secure.scalable.capital/u/login?state=hKFo2SBOTXpuNTZvelZ4UE1xbm16VXFHTmRvQXJGVU9KQzRVZKFur3VuaXZlcnNhbC1sb2dpbqN0aWTZIHZVdmltdm9wbVhab2VjS0l1a1JwTlRuczFiT1JYTGtGo2NpZNkgelJXUFhxeTkyUjJicko4ZnF2cklWTEZ0WERnbWhwYWs&ui_locales=de' consent_cookie.cookie['domain']='de.scalable.capital' consent_cookie.cookie['path']='/' scalable.capital/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.wmg.com/emerging-talent' consent_cookie.cookie['domain']='.atlanticrecords.com' consent_cookie.cookie['path']='/' atlanticrecords.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.amcnetworks.com/privacy-policy/' consent_cookie.cookie['domain']='.ifc.com' consent_cookie.cookie['path']='/' ifc.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en/legal?oc=226&pc=64150&rc=1&kc=&mjv=8&lang=en&loc=USA&FOUR=Y&CMD=P40LEGAL' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en/about/contact-us?oc=254&pc=64150&rc=1&kc=&mjv=8&lang=en&loc=USA&FOUR=Y&CMD=P40CONTACT' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en?oc=5&pc=64150&rc=1&kc=&mjv=8&lang=en&loc=USA&FOUR=Y&CMD=P40WEBROOTHOME' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webroot.com/us/en/page_not_found' consent_cookie.cookie['domain']='.detail.webrootanywhere.com' consent_cookie.cookie['path']='/' webrootmobile.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://trailblazer.me/TrailblazerLogin?startURL=%2Fsetup%2Fsecur%2FRemoteAccessAuthorizationPage.apexp%3Fsource%3DCAAAAYeRwladMDAwMDAwMDAwMDAwMDAwAAAA8lCiEqkKH-L44ehvbgFr-kMuGB6UPuIOXPmrHsJuxTBBq93bvxWGolx2bVj-pqJvYDXBapF6gCbyPXbgSSjC4SejUjgkq5APJt0nOGsVGJrHPoVD4xLFdOr60o_CEDXzPa194UWCRuMgYIRFFjHxOWoyIln6NR15g32d_HkE8dlqdQvZ90NC6jWLL3xE3ePanztxbfGAwKwjEY5dhBpeg3nNMlzhAxes0FBke8vY6tsqCeOx9cbWYwimRH7sbiiasoRGJeBEyBC2AmUZ1GtlokTr6MmFKblTxcxKTuy6PcdNfwU3ThUMh_H3F0Drxh4G8Y9j0hK2NiOfeGRN2owLjT_EOEtHeWr2QTwKWwoW3cQYzSZikb5UgEBF6kDuo5aF6XRs609H_YFFKYrpBFQ4IVJt2TYiHQboTljjxPomTZ0wdh8rkggLQYHkYfAwR7vL8HSTdDufjTV2E7_pWIKNf0k0VJVJ-d8awTfUzzxiQq-cUt1vq8vi5bUZKYqmqAC4AOsEFnQg9RDV9zh1PPicmQgg3uWLTMwK4s58bIP05WWj9hM3OL1FEEhNDMsws3mh-Lp2Hwwml2n9s2XGdW2jus7ln7_nI2M-By8gYoQbUoTZzRlwy1eknHlNsw--N2DcePrE2RuNbnq7TDX0tI7VJhsCVcdQizPB0ZrrGqbqq1Smv4hX6ccX735B85bTo12IecKfQHWMiGzKZrUXcSfCVHNt8HilL0TJmi01mH9IUmxVsl226mJ4EQgDsYiYEOCey5prhdQUaKIps6DjhChz2lc%253D%26display%3Dpage&display=page&sdtd=1' consent_cookie.cookie['domain']='.trailhead.salesforce.com' consent_cookie.cookie['path']='/' trailhead.com/postrej_3.har.xz
# Domain path mismatch: .sc.com domain's path /en/ not match url https://www.sc.com/in/
# Unmatch url and consent cookie domain: page_url='https://www.sc.com/in/' consent_cookie.cookie['domain']='.sc.com' consent_cookie.cookie['path']='/en/' standardchartered.com/postrej_5.har.xz
# Domain path mismatch: .sc.com domain's path /en/ not match url https://www.sc.com/tw/
# Unmatch url and consent cookie domain: page_url='https://www.sc.com/tw/' consent_cookie.cookie['domain']='.sc.com' consent_cookie.cookie['path']='/en/' standardchartered.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://enscape3d.eu.auth0.com/u/login?state=hKFo2SBLQ1FCMmJPTWVLR0wtZTc4R3puc1M0RWx5c2JTZTc5c6Fur3VuaXZlcnNhbC1sb2dpbqN0aWTZIGkxQnJ6SUp2SmZYZHpjZllhTVUtYlVHSG1RUllJaUtoo2NpZNkgUlVpVUNZTzNlUjRPTWFhQ0pldDZvY2lxV3p6UlFlenE' consent_cookie.cookie['domain']='.enscape3d.com' consent_cookie.cookie['path']='/' enscape3d.com/postrej_4.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/zh-TW
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/zh-TW' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_2.har.xz
# Domain path mismatch: .www.zespri.com domain's path /en-US not match url https://www.zespri.com/en-UK
# Unmatch url and consent cookie domain: page_url='https://www.zespri.com/en-UK' consent_cookie.cookie['domain']='.www.zespri.com' consent_cookie.cookie['path']='/en-US' zespri.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://whirlpoolcorp.com/legal-notice/' consent_cookie.cookie['domain']='.maytag.com' consent_cookie.cookie['path']='/' maytag.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://play.google.com/store/apps/details?id=com.gonoodle.gonoodle' consent_cookie.cookie['domain']='.gonoodle.com' consent_cookie.cookie['path']='/' gonoodle.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.pinterest.com/gonoodlebreaks/' consent_cookie.cookie['domain']='.gonoodle.com' consent_cookie.cookie['path']='/' gonoodle.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://creative.xlivrdr.com/widgets/v4/Universal?campaignId=f5beed9cf49bc1588a6fb14a17d2df5e39f62e3f10115bb491ee76800b030259&campaignType=smartpop&creativeId=aff493bb5315d4b0a136b3656126d654397933ef2bdeecfcd03309f5c21fbf0f&design=xh&iterationId=522330&masterSmartpopId=1606&memberId=53fe3419-b717-46ae-9b84-3a8296e80170&p1=60807&ruleId=4&smartpopId=2335&tag=-girls%2Fjapanese%2C-girls%2Fchinese&userId=bc684498176b333995edb931af8989907beedce7e633cfd90a49a6e842a6c09a&variationId=30864' consent_cookie.cookie['domain']='www.freechatnow.com' consent_cookie.cookie['path']='/' freechatnow.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://ssb.ancheim.ie/itc/app/twbkwbis.P_GenMenu?name=homepage' consent_cookie.cookie['domain']='.www.itcarlow.ie' consent_cookie.cookie['path']='/' itcarlow.ie/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.setu.ie/about/setu-governing-body' consent_cookie.cookie['domain']='.www.itcarlow.ie' consent_cookie.cookie['path']='/' itcarlow.ie/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://userguide.m-files.com/user-guide/latest/eng/' consent_cookie.cookie['domain']='www.m-files.com' consent_cookie.cookie['path']='/' m-files.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://hcjm.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1' consent_cookie.cookie['domain']='.equityapartments.com' consent_cookie.cookie['path']='/' equityapartments.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://community.hyland.com/login?returnUrl=/hyland-partners' consent_cookie.cookie['domain']='.alfresco.com' consent_cookie.cookie['path']='/' alfresco.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nielsen.com/solutions/content-metadata/id-distribution-system/' consent_cookie.cookie['domain']='.www.gracenote.com' consent_cookie.cookie['path']='/' cddbp.net/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nielsen.com/solutions/content-metadata/global-video-data/' consent_cookie.cookie['domain']='.www.gracenote.com' consent_cookie.cookie['path']='/' cddbp.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nielsen.com/solutions/content-metadata/studio-solutions/' consent_cookie.cookie['domain']='.www.gracenote.com' consent_cookie.cookie['path']='/' cddbp.net/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.tower-club.com.sg/' consent_cookie.cookie['domain']='.www.millenniumhotels.com' consent_cookie.cookie['path']='/' millenniumhotels.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.smartrecruiters.com/Technicolor113' consent_cookie.cookie['domain']='.technicolor.com' consent_cookie.cookie['path']='/' technicolor.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, rec.net/postrej_2.har.xz not have cookie OptanonConsent of .rec.net on path /
# Post rej cookie not contain consent cookie, rec.net/postrej_5.har.xz not have cookie OptanonConsent of .rec.net on path /
# Post rej cookie not contain consent cookie, rec.net/postrej_1.har.xz not have cookie OptanonConsent of .rec.net on path /
# Post rej cookie not contain consent cookie, rec.net/postrej_0.har.xz not have cookie OptanonConsent of .rec.net on path /
# Post rej cookie not contain consent cookie, rec.net/postrej_3.har.xz not have cookie OptanonConsent of .rec.net on path /
# Post rej cookie not contain consent cookie, rec.net/postrej_4.har.xz not have cookie OptanonConsent of .rec.net on path /
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/uis.edu/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Domain path mismatch: .verizon.com domain's path /business not match url https://www.verizon.com/about/responsibility/giving-and-grants
# Unmatch url and consent cookie domain: page_url='https://www.verizon.com/about/responsibility/giving-and-grants' consent_cookie.cookie['domain']='.verizon.com' consent_cookie.cookie['path']='/business' ans.net/postrej_3.har.xz
# Post rej cookie not contain consent cookie, comicrelief.com/postrej_2.har.xz not have cookie OptanonConsent of .comicrelief.com on path /
# Post rej cookie not contain consent cookie, comicrelief.com/postrej_5.har.xz not have cookie OptanonConsent of .comicrelief.com on path /
# Post rej cookie not contain consent cookie, comicrelief.com/postrej_0.har.xz not have cookie OptanonConsent of .comicrelief.com on path /
# Post rej cookie not contain consent cookie, comicrelief.com/postrej_3.har.xz not have cookie OptanonConsent of .comicrelief.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.pinc-ai.com/' consent_cookie.cookie['domain']='.premierinc.com' consent_cookie.cookie['path']='/' premierinc.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://discord.com/invite/VwWnkG3GWy' consent_cookie.cookie['domain']='.rabbitmq.com' consent_cookie.cookie['path']='/' rabbitmq.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.microsoftonline.com/88404777-f24b-4e1c-ada1-bde9cda22754/saml2?SAMLRequest=nVNLb6MwEL7vr0C%2B8wwBagWqbKpqK3W1UUL30MvKmKG1BDbrMdnsv19DQjeHKqoq%2BWTPfPM9xqvbY9c6B9AolMxJ6AXEAclVLeRLTp7Kezcjt8WXFbKu7el6MK9yB78HQOOsEUEb27ZREocO9B70QXB42j3m5NWYHqnvg0C316r2gHu2hP%2F1oB58rrpOSWbRiHNnsYRkZpo%2Ft7XqRUivE1wrVI1RshUSPNvmZ1kcxGmauk0UV24MIXdZzUK3quGG1yyK0mXsj2wj4twrzWHinJOGtQjEebjLya8kTJfBos6qJWuiEG6qNFkkScXiqsmStIptGW4ZojjA%2F0bEAR4kGiZNTqIgWrhB7IZpGWQ0tCfxLOYzcbZaGcVV%2B1XIk4eDllQxFEgl6wCp4XS%2F%2Fv5IIy%2Bg1akI6bey3LrbH%2FuSOD%2FnLKIxC5uORDq5fx2qP88lxTmribD%2BOACb4yTF1fBoHC8mgxHVyr%2BcNU8%2BLwjUk%2FV2OwwcjbNRXc%2B0wFEaHBk3nxdHL4E3rWW%2Bg%2BYC7cNCr5Zxykdoez3uwh%2Bl6zFb4FZYqZnEXmlzMuBdPsVszrt2vL1efqniHw%3D%3D&RelayState=1d56cf4c-2fa6-44e4-8eff-78c2b173f27b&SigAlg=http%3A%2F%2Fwww.w3.org%2F2001%2F04%2Fxmldsig-more%23rsa-sha256&Signature=ony5xsEUA7ekT1SFHdEU0rv72rxBu%2F2JJGQFpb2GL%2BpoWEq5sLv26KV%2Fe6KLCOorwyF1rgN8YH3a7zpudHAbIewZIcTqj90bKj4MzaB6mHnYaw3vJOG%2Fw64bOPpQRUh1G5qkWSBnx%2FXigu6GU6s63qx05k9fuCagI1b7OuXGIWGaCV47kRfIbRkucHufN%2FoMrTSOkhGaOq1A2UliOGOQ1LaGtT3FM5b4qJVdOso0FpBGpCj1nPgMRSTsLcgsRkfOSJNIb3KdPbwa6BGi3ai%2B%2FxeSd5Fjv4LxQXHyJqCT1CRSzQDIWt2THn8vjRoy6gQjSyYgrVMIXjfDsVXUxR7KRQ%3D%3D' consent_cookie.cookie['domain']='.mercy.edu' consent_cookie.cookie['path']='/' mercy.edu/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/curve.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_2.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_5.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_1.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_3.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, yummly.co.uk/postrej_4.har.xz not have cookie OptanonConsent of .yummly.co.uk on path /
# Post rej cookie not contain consent cookie, nationthailand.com/postrej_0.har.xz not have cookie OptanonConsent of www.nationthailand.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.nbcsportsnext.com/youth-and-rec-sports' consent_cookie.cookie['domain']='.sportsengine.com' consent_cookie.cookie['path']='/' sportssignup.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.epicgames.com/site/en-US/privacypolicy' consent_cookie.cookie['domain']='.psyonix.com' consent_cookie.cookie['path']='/' psyonix.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://sodastream.com/?utm_source=RAN&utm_medium=affiliates&utm_content=1xM9BuqKGU8&utm_campaign=3&ranMID=42748&ranEAID=1xM9BuqKGU8&ranSiteID=1xM9BuqKGU8-PfN90bXnA2BqqlftxbvU5A&LSNSUBSITE=LSNSUBSITE&juneoffer=3087095' consent_cookie.cookie['domain']='.couponcause.com' consent_cookie.cookie['path']='/' couponcause.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.lyft.com/' consent_cookie.cookie['domain']='.couponcause.com' consent_cookie.cookie['path']='/' couponcause.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kantata.com/success-story/rsm' consent_cookie.cookie['domain']='www.mavenlink.com' consent_cookie.cookie['path']='/' mavenlink.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kantata.com/services#customer-success' consent_cookie.cookie['domain']='www.mavenlink.com' consent_cookie.cookie['path']='/' mavenlink.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kantata.com/product' consent_cookie.cookie['domain']='www.mavenlink.com' consent_cookie.cookie['path']='/' mavenlink.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kantata.com/customer-resources/kantata-ox' consent_cookie.cookie['domain']='www.mavenlink.com' consent_cookie.cookie['path']='/' mavenlink.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.kantata.com/why-kantata' consent_cookie.cookie['domain']='www.mavenlink.com' consent_cookie.cookie['path']='/' mavenlink.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://account.cengage.com/login?SAMLRequest=fZJdT8IwFIb%2FytL7fXVsjIZhiMSEBIlBNMa7pjvMxu109nQg%2F94xwOiF3jbnPO%2Bb53R689nU3h4saYMFi4OIeYDKlBqrgj1t7%2Fyc3cymJJuat2LeuTfcwEcH5Lw5EVjXr90apK4B%2Bwh2rxU8bVYFe3OuJRGGst8IFGAlKwiUaUIiEw60MDKSZ2ke75DWL%2Bm6mifpmHmLHq1RuqHON0Up06H7BapNpZF5d8YqGHoVbCdrAuYtFwXTJY8SniXpKM8m2TjNx0nOEz6JoqwPWRJ1sERyEl3BeMQTPxr58XgbpSLOxSgL%2BCR5Zd7z1Qs%2FeelNIYmzioJ1FoWRpEmgbICEU%2BJxfr8S%2FahorXFGmZpdzIkh0P4k%2FA%2BQV7dsdnVwOBwC8%2B7k2eJgkM7C%2FT5ur0uwIbV7LBtAeTStrT5keSzdNPxZ4fuU6z5zuXgwtVbHk8RGur8rxUE8vOjS3w2jokNqQemdhpKFs0vG7w8y%2BwI%3D&RelayState=%252Foauth2%252Fv1%252Fauthorize%252Fredirect%253Fokta_key%253D4ER2VmO3zm79fmh-syUqpKDKnOgHed_P_joqopBaHhI&SigAlg=http%3A%2F%2Fwww.w3.org%2F2001%2F04%2Fxmldsig-more%23rsa-sha256&Signature=JYBOxEDu7Ltnetrbh3784yZZFJMq333HalFmAxHNRd3RZz6sWEhteeV4RioHFDdx9gyOPo1A1coVJ4foTGHA6a%2BIvPGdHyrjwrOrreW65m88DF%2FaRpL%2FXBF7V0FJ7zu273JXoWN2OMO5gS3m00GDcdBY5aj%2BktQVTDieYAFlgt27uw%2FX4iRggba8OLWPy6OYjwdWONtA2zYRjtsp3gp0xC1VLkn8kiTTMiQ5SaJ7dBFU4o9%2BhV5SmBV2CfAVslHb9C6IlS2QRoq5j%2FVS3zgjAOwJ41AuzWrRkS1lGtWF6NN87nfC6VYA9M7pWetGMG74tZ6wTvCoZysen%2FZpTgvhvQ%3D%3D' consent_cookie.cookie['domain']='.cengage.uk' consent_cookie.cookie['path']='/' cengagebrain.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, burtsbees.com/postrej_2.har.xz not have cookie OptanonConsent of .burtsbees.com on path /
# Post rej cookie not contain consent cookie, burtsbees.com/postrej_1.har.xz not have cookie OptanonConsent of .burtsbees.com on path /
# Post rej cookie not contain consent cookie, burtsbees.com/postrej_0.har.xz not have cookie OptanonConsent of .burtsbees.com on path /
# Post rej cookie not contain consent cookie, burtsbees.com/postrej_3.har.xz not have cookie OptanonConsent of .burtsbees.com on path /
# Unmatch url and consent cookie domain: page_url='https://streamlabs.com/terms' consent_cookie.cookie['domain']='.wlo.link' consent_cookie.cookie['path']='/' wlo.link/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nbcsportsnext.com/youth-and-rec-sports' consent_cookie.cookie['domain']='.sportsengine.com' consent_cookie.cookie['path']='/' ngin.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.intel.com/content/www/us/en/developer/tools/software-catalog/overview.html' consent_cookie.cookie['domain']='.intel.co.uk' consent_cookie.cookie['path']='/' intel.co.uk/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.intel.com/content/www/us/en/developer/topic-technology/cloud/overview.html' consent_cookie.cookie['domain']='.intel.co.uk' consent_cookie.cookie['path']='/' intel.co.uk/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/xirrus.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/usopen.org/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/usopen.org/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/usopen.org/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/usopen.org/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/usopen.org/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, voodoo.io/postrej_2.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Post rej cookie not contain consent cookie, voodoo.io/postrej_5.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Post rej cookie not contain consent cookie, voodoo.io/postrej_1.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Post rej cookie not contain consent cookie, voodoo.io/postrej_0.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Post rej cookie not contain consent cookie, voodoo.io/postrej_3.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Post rej cookie not contain consent cookie, voodoo.io/postrej_4.har.xz not have cookie CookieConsent of www.voodoo.io on path /
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/artgrid.io/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/artgrid.io/log.json'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/merckvetmanual.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/eprod.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/eprod.com/log.json'
# Unmatch url and consent cookie domain: page_url='https://www.adesa.ca/auction_location/adesa-kitchener/' consent_cookie.cookie['domain']='.adesa.com' consent_cookie.cookie['path']='/' adesa.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://banki.tpay.com/' consent_cookie.cookie['domain']='tpay.com' consent_cookie.cookie['path']='/' tpay.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.net/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude-dns.net/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://wes-idp.six-group.com/payments/authorize/?scope=openid+roles&claims=%7B%22id_token%22%3A%7B%22acr%22%3A%7B%22value%22%3A%221%3Apassword%22%2C%22essential%22%3Atrue%7D%7D%7D&response_type=code&redirect_uri=https%3A%2F%2Fweb.six-payment-services.com%2Ftopas2p%2F&state=dbZejEdts2vCgLWdXY_hGhW5hy6eQcvCeWTxdbzi2-o&nonce=DqIYjhrjfHbB0VV6-K3Oo-MmqLhPe6hufr-4qayKAJ8&client_id=wdlweb&response_mode=query&valid_before=2023-04-17T05%3A17%3A50.626Z&prompt=login' consent_cookie.cookie['domain']='.six-payment-services.com' consent_cookie.cookie['path']='/' saferpay.com/postrej_5.har.xz
# Post rej cookie not contain consent cookie, themighty.com/postrej_0.har.xz not have cookie OptanonConsent of .themighty.com on path /
# Post rej cookie not contain consent cookie, themighty.com/postrej_3.har.xz not have cookie OptanonConsent of .themighty.com on path /
# Post rej cookie not contain consent cookie, themighty.com/postrej_4.har.xz not have cookie OptanonConsent of .themighty.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/weatherford.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/weatherford.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/weatherford.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, pehub.com/postrej_2.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_5.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_1.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_0.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_3.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Post rej cookie not contain consent cookie, pehub.com/postrej_4.har.xz not have cookie CookieConsent of www.pehub.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.mongoliaccc.org/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_2.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/cru.org/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.lmmalawi.org/' consent_cookie.cookie['domain']='.cru.org' consent_cookie.cookie['path']='/' cru.org/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/cru.org/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.fullbeauty.com/' consent_cookie.cookie['domain']='.roamans.com' consent_cookie.cookie['path']='/' roamans.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://pages.joomag.com/create-digital-brochure' consent_cookie.cookie['domain']='www.joomag.com' consent_cookie.cookie['path']='/' joom.ag/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://careers.aegon.com/en/vacancies/?page=1' consent_cookie.cookie['domain']='.www.aegon.com' consent_cookie.cookie['path']='/' aegon.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://app.convercent.com/en-us/LandingPage/8848861a-8794-ea11-a974-000d3ab9f062?_=1621361250018' consent_cookie.cookie['domain']='.ab-inbev.com' consent_cookie.cookie['path']='/' ab-inbev.com/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/travelchannel.co.uk/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/danaher.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://signal.thirdbridge.com/podcasts/episode-14-ivan-peytchev-private-equity-reaches-an-inflection-point/?utm_source=linkedin-organic&utm_medium=social&utm_campaign=2023_signal_podcast&utm_content=28/02/2023--signal-14-socialpost' consent_cookie.cookie['domain']='.brookfield.com' consent_cookie.cookie['path']='/' brookfield.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hellosign.com/integrations/google-docs' consent_cookie.cookie['domain']='.www.hellofax.com' consent_cookie.cookie['path']='/' hellofax.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hellosign.com/integrations/google-drive' consent_cookie.cookie['domain']='.www.hellofax.com' consent_cookie.cookie['path']='/' hellofax.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://app.hellofax.com/account/signUp' consent_cookie.cookie['domain']='.www.hellofax.com' consent_cookie.cookie['path']='/' hellofax.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.hellosign.com/products/dropbox-fax' consent_cookie.cookie['domain']='.www.hellofax.com' consent_cookie.cookie['path']='/' hellofax.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://app.hellofax.com/info/pricing' consent_cookie.cookie['domain']='.www.hellofax.com' consent_cookie.cookie['path']='/' hellofax.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/jasc.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/2kgames.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://www.active.com/running/articles/best-jogging-strollers' consent_cookie.cookie['domain']='.activekids.com' consent_cookie.cookie['path']='/' activekids.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://on2it.nl/privacy-statement/' consent_cookie.cookie['domain']='on2it.net' consent_cookie.cookie['path']='/' on2it.net/postrej_5.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/heraeus.cn/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/heraeus.cn/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/heraeus.cn/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://notifications.three.ie/maintenance/my3-and-shop?mobileCartItem=%7B%22selectedDevice%22%3A%7B%22id%22%3A%229840871_9840851%22%7D%7D&mobileDeviceOfferingId=9840871_9840851&flowData=%7B%7D&contractPath=Bill%20Pay&viewMode=deviceDetailsDevices' consent_cookie.cookie['domain']='.www.three.ie' consent_cookie.cookie['path']='/' three.ie/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://notifications.three.ie/maintenance/my3-and-shop?mobileCartItem=%7B%22selectedDevice%22%3A%7B%22id%22%3A%229791281_9791261%22%7D%7D&mobileDeviceOfferingId=9791431_9791411&flowData=%7B%7D&contractPath=Bill%20Pay&viewMode=deviceDetailsDevices' consent_cookie.cookie['domain']='.www.three.ie' consent_cookie.cookie['path']='/' three.ie/postrej_4.har.xz
# Post rej cookie not contain consent cookie, fusionfabric.cloud/postrej_2.har.xz not have cookie CookieConsent of store.fusionfabric.cloud on path /
# Post rej cookie not contain consent cookie, fusionfabric.cloud/postrej_1.har.xz not have cookie CookieConsent of store.fusionfabric.cloud on path /
# Post rej cookie not contain consent cookie, fusionfabric.cloud/postrej_0.har.xz not have cookie CookieConsent of store.fusionfabric.cloud on path /
# Post rej cookie not contain consent cookie, fusionfabric.cloud/postrej_3.har.xz not have cookie CookieConsent of store.fusionfabric.cloud on path /
# Post rej cookie not contain consent cookie, fusionfabric.cloud/postrej_4.har.xz not have cookie CookieConsent of store.fusionfabric.cloud on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/life.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/honda.co.uk/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://iprefer.com/page/iprefer-i-prefer-meeting-planners' consent_cookie.cookie['domain']='.preferredhotels.com' consent_cookie.cookie['path']='/' preferredhotels.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_2.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_5.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_1.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_0.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_3.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Post rej cookie not contain consent cookie, knorr-bremse.com/postrej_4.har.xz not have cookie OptanonConsent of .www.knorr-bremse.com on path /
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='www.comlaude.com' consent_cookie.cookie['path']='/' comlaude.co.uk/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='www.comlaude.com' consent_cookie.cookie['path']='/' comlaude.co.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://ryancohelp.zendesk.com/auth/v2/login/signin?return_to=https%3A%2F%2Fsoftwaresupport.ryan.com%2Fhc%2Fen-us&theme=hc&locale=en-us&brand_id=124927&auth_origin=124927%2Ctrue%2Ctrue' consent_cookie.cookie['domain']='.ryan.com' consent_cookie.cookie['path']='/' ryan.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.snapware.com/' consent_cookie.cookie['domain']='.instanthome.com' consent_cookie.cookie['path']='/' instantpot.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FDialpadhq%2F' consent_cookie.cookie['domain']='.dialpad.com' consent_cookie.cookie['path']='/' dialpad.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/superantispyware.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/superantispyware.com/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://identity.na.vwgroup.io/signin-service/v1/signin/92ba657d-696f-4f22-8be3-fe22ed2a5428@apps_vw-dilab_com?relayState=327860147c3083b63c617c55d95f29e94f45d8d6' consent_cookie.cookie['domain']='.audiusa.com' consent_cookie.cookie['path']='/' audiusa.com/postrej_5.har.xz
# Cannot read /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/onshape.com/log.json: [Errno 2] No such file or directory: '/mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/onshape.com/log.json'
# Domain path mismatch: .westernunion.com domain's path /us not match url https://agentportal.westernunion.com/ap/agentregister.do?pid=usFtBecomeAgent
# Unmatch url and consent cookie domain: page_url='https://agentportal.westernunion.com/ap/agentregister.do?pid=usFtBecomeAgent' consent_cookie.cookie['domain']='.westernunion.com' consent_cookie.cookie['path']='/us' wu.com/postrej_2.har.xz
# Domain path mismatch: .westernunion.com domain's path /us not match url https://www.westernunionfoundation.org/
# Unmatch url and consent cookie domain: page_url='https://www.westernunionfoundation.org/' consent_cookie.cookie['domain']='.westernunion.com' consent_cookie.cookie['path']='/us' wu.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://forms.aramark.com/other/contact-us/consumer-request' consent_cookie.cookie['domain']='.campusdish.com' consent_cookie.cookie['path']='/' campusdish.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.aramark.com/privacy-policy' consent_cookie.cookie['domain']='.campusdish.com' consent_cookie.cookie['path']='/' campusdish.com/postrej_3.har.xz
# Domain path mismatch: .www.kinder.com domain's path /us/ not match url https://www.kinder.com/int/en/
# Unmatch url and consent cookie domain: page_url='https://www.kinder.com/int/en/' consent_cookie.cookie['domain']='.www.kinder.com' consent_cookie.cookie['path']='/us/' magic-kinder.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.surveymonkey.com/mp/legal/terms-of-use/' consent_cookie.cookie['domain']='.wufoo.com' consent_cookie.cookie['path']='/' wufoo.eu/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://government.kellyservices.us/?GAKUSCID=GA1.2.631615351.1681706079' consent_cookie.cookie['domain']='www.kellyservices.com' consent_cookie.cookie['path']='/' kellyservices.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://pi.kellyservices.us/find-talent/professional-industrial-staffing/contact-center-outsourcing-staffing/?GAKUSCID=GA1.2.631615351.1681706079' consent_cookie.cookie['domain']='www.kellyservices.com' consent_cookie.cookie['path']='/' kellyservices.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://rc.my.site.com/RCPartnerProgram/s/login/?language=en_US' consent_cookie.cookie['domain']='.ringcentral.com' consent_cookie.cookie['path']='/' ringcentral.biz/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://newsroom.geocaching.com/' consent_cookie.cookie['domain']='www.geocaching.com' consent_cookie.cookie['path']='/' groundspeak.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://identity.macmillaneducationeverywhere.com/authentication/login?ReturnUrl=%2Fconnect%2Fauthorize%2Fcallback%3Fclient_id%3D21%26redirect_uri%3Dhttps%253A%252F%252Fliveapi.macmillaneducationeverywhere.com%252Fapi%252Foidcintegration%252Fcode%26response_type%3Dcode%26scope%3Dopenid%2520profile%2520offline_access%26code_challenge_method%3DS256%26code_challenge%3DWbOKJ-DFRQdz-GBSwt1W8z3dwXZjUnph1ln8jzT8_gU%26state%3D969ce176-d642-4b40-aac7-c6b648f10276' consent_cookie.cookie['domain']='www.macmillaneducationeverywhere.com' consent_cookie.cookie['path']='/' macmillaneducationeverywhere.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.iamexpat.com/login?destination=oauth2/authorize&action=sign-up' consent_cookie.cookie['domain']='.www.iamexpat.de' consent_cookie.cookie['path']='/' iamexpat.de/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://littlecaesars.fbmta.com/members/UpdateProfile.aspx?Action=Subscribe&_Theme=21474836687&InputSource=W' consent_cookie.cookie['domain']='.littlecaesars.com' consent_cookie.cookie['path']='/' littlecaesars.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.mycit.ie/medical' consent_cookie.cookie['domain']='.www.cit.ie' consent_cookie.cookie['path']='/' cit.ie/postrej_3.har.xz
# Domain path mismatch: .royalcanin.com domain's path /us not match url https://careers.royalcanin.com/?_ga=2.138456947.1741265493.1674469437-1944702798.1670949131&_gl=1*9zk12r*_ga*MTcyMzEzMDI1Ni4xNjc3MDc3NzU5*_ga_BYDNNWSXGT*MTY3NzIzMDc4Mi4yOTAuMS4xNjc3MjMyMjY5LjUzLjAuMA..
# Unmatch url and consent cookie domain: page_url='https://careers.royalcanin.com/?_ga=2.138456947.1741265493.1674469437-1944702798.1670949131&_gl=1*9zk12r*_ga*MTcyMzEzMDI1Ni4xNjc3MDc3NzU5*_ga_BYDNNWSXGT*MTY3NzIzMDc4Mi4yOTAuMS4xNjc3MjMyMjY5LjUzLjAuMA..' consent_cookie.cookie['domain']='.royalcanin.com' consent_cookie.cookie['path']='/us' royalcanin.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://myhippo.com/account/login' consent_cookie.cookie['domain']='.www.hippo.com' consent_cookie.cookie['path']='/' hippo.com/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/sinch.com/postrej_4.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://openinfra.dev/ptg/' consent_cookie.cookie['domain']='www.openstack.org' consent_cookie.cookie['path']='/' openstack.org/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://mobil.abus.com/ch_de' consent_cookie.cookie['domain']='.www.abus.com' consent_cookie.cookie['path']='/' abus.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/monsterlegendsgame.com/postrej_2.har.xz: 'DataFrame' object has no attribute 'request'
# Post rej cookie not contain consent cookie, bimobject.com/postrej_5.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_0.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_3.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Post rej cookie not contain consent cookie, bimobject.com/postrej_4.har.xz not have cookie OptanonConsent of .bimobject.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.intel.com/content/www/us/en/developer/topic-technology/edge-5g/overview.html' consent_cookie.cookie['domain']='.intel.sg' consent_cookie.cookie['path']='/' intel.sg/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.intel.com/content/www/us/en/products/details/discrete-gpus/data-center-gpu.html' consent_cookie.cookie['domain']='.intel.sg' consent_cookie.cookie['path']='/' intel.sg/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://ir.markel.com/overview/default.aspx' consent_cookie.cookie['domain']='.www.markel.com' consent_cookie.cookie['path']='/' markel.com/postrej_4.har.xz
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_2.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_1.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_0.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_3.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# Post rej cookie not contain consent cookie, vcentertainment.com/postrej_4.har.xz not have cookie OptanonConsent of .vcentertainment.com on path /
# ...
# Domain path mismatch: .www.kroll.com domain's path /en not match url https://www.kroll.com/es-mx
# Unmatch url and consent cookie domain: page_url='https://www.kroll.com/es-mx' consent_cookie.cookie['domain']='.www.kroll.com' consent_cookie.cookie['path']='/en' kroll.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.instagram.com/accounts/login/?next=https%3A%2F%2Fwww.instagram.com%2Flogin%2F%3Fnext%3Dhttps%253A%252F%252Fwww.instagram.com%252Fmajidalfuttaim%252F%26__coig_login%3D1' consent_cookie.cookie['domain']='.www.majidalfuttaim.com' consent_cookie.cookie['path']='/' majidalfuttaim.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/dealersocket.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://privacy.wmg.com/rhino/privacy-policy' consent_cookie.cookie['domain']='.rhino.com' consent_cookie.cookie['path']='/' rhino.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://grants-search.turn2us.org.uk/' consent_cookie.cookie['domain']='www.turn2us.org.uk' consent_cookie.cookie['path']='/' turn2us.org.uk/postrej_1.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/edg.io/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://corporate.universaldestinationsandexperiences.com/' consent_cookie.cookie['domain']='.universalparks.com' consent_cookie.cookie['path']='/' universalparks.com/postrej_1.har.xz
# Post rej cookie not contain consent cookie, redbull.tv/postrej_2.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_5.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_1.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_0.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_3.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Post rej cookie not contain consent cookie, redbull.tv/postrej_4.har.xz not have cookie OptanonConsent of .www.redbull.com on path /us-en
# Unmatch url and consent cookie domain: page_url='https://www.nintendo.com/consumer/assets/region_select.jsp?d=3dseshop' consent_cookie.cookie['domain']='.animal-crossing.com' consent_cookie.cookie['path']='/' animal-crossing.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.nintendo.com/consumer/assets/region_select.jsp?d=3dseshop' consent_cookie.cookie['domain']='.animal-crossing.com' consent_cookie.cookie['path']='/' animal-crossing.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/Privacy-Policy?language=nl_NL' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/Privacy-Policy?language=nl_NL#omohgjdg4icd' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://help.nextdoor.com/s/article/EEA-Member-Agreement?language=nl_NL' consent_cookie.cookie['domain']='.nextdoor.nl' consent_cookie.cookie['path']='/' nextdoor.nl/postrej_4.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/tw-en/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/tw-en/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_5.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/tw-zh/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/tw-zh/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_1.har.xz
# Domain path mismatch: www.tkelevator.com domain's path /global-en/ not match url https://www.tkelevator.com/at-de/#0
# Unmatch url and consent cookie domain: page_url='https://www.tkelevator.com/at-de/#0' consent_cookie.cookie['domain']='www.tkelevator.com' consent_cookie.cookie['path']='/global-en/' tkelevator.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.petzldealer.com/B2B_LoginForm?startURL=%2F' consent_cookie.cookie['domain']='.petzl.com' consent_cookie.cookie['path']='/' petzl.com/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://shop.hettich.com/de_EN/Runner-systems/c/group93961603792' consent_cookie.cookie['domain']='web.hettich.com' consent_cookie.cookie['path']='/' hettich.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schoolprday.com/home' consent_cookie.cookie['domain']='.finalsite.com' consent_cookie.cookie['path']='/' finalsite.net/postrej_1.har.xz
# Post rej cookie not contain consent cookie, firaxis.com/postrej_1.har.xz not have cookie OptanonConsent of .firaxis.com on path /
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/asthmaandlung.org.uk/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://login.fronius.com/authenticationendpoint/login.do?client_id=mf_o9iTAyKemNLQTa6Sp6HYonCIa&commonAuthCallerPath=%2Foauth2%2Fauthorize&forceAuth=false&nonce=638172926299763308.ODNmZTg2NmItM2MxYi00ZjNlLThhYjEtYmIzMzI5ZmM0Nzk1ZjYzNjk1NmMtMTljZi00NWYxLTk1ODMtMjE1Y2I3MDE1ZWFj&passiveAuth=false&redirect_uri=https%3A%2F%2Fwww.solarweb.com%2FAccount%2FExternalLoginCallback&response_mode=form_post&response_type=code+id_token&scope=openid+profile+solarweb+solweb_browserid_2bd01f79cae7de012a0d6dbacb64ce40&state=OpenIdConnect.AuthenticationProperties%3DZdURyZEuPxHnFrisUOz08z8DPRMTJPINnGFL7ieGtFAQ5ricZbcsOb8P7WGa0OC2ls2rH7jZPyJPWn_mGbTgpdGVzJHkHScA9-FCa4DeWelqaEXsp6SH4GGSDCwK8qv5h5V7NjWZvJYk4EiJMyXGFrE8JtjS7g0vSyZfyp3d0cJKZ6KphLPBWWKXCscmgNWSrSNbLlQvHru9CA9lteYWLq4iBW6YV3L1aCVF-TizWg3EbAXdUPnd5O9S3nfg7akd8g48NA&tenantDomain=carbon.super&x-client-SKU=ID_NET461&x-client-ver=6.9.0.0&sessionDataKey=205a242e-066a-480c-bbf5-1b9800a13fc5&relyingParty=mf_o9iTAyKemNLQTa6Sp6HYonCIa&type=oidc&sp=Solar.web+-+Portals&isSaaSApp=false&authenticators=SAMLSSOAuthenticator:Fronius%20Login;CustomAuthenticatorLocalMain:LOCAL:LOCAL' consent_cookie.cookie['domain']='www.solarweb.com' consent_cookie.cookie['path']='/' solarweb.com/postrej_2.har.xz
# Domain path mismatch: .pro.sony domain's path /en_GB not match url https://pro.sony/productregistration?l=en_GB
# Unmatch url and consent cookie domain: page_url='https://pro.sony/productregistration?l=en_GB' consent_cookie.cookie['domain']='.pro.sony' consent_cookie.cookie['path']='/en_GB' pro.sony/postrej_4.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/telkomsa.net/postrej_3.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://support.piriform.com/hc/en-us' consent_cookie.cookie['domain']='.ccleaner.com' consent_cookie.cookie['path']='/' ccleanerbrowser.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.afp.com/en/contact' consent_cookie.cookie['domain']='.www.afpforum.com' consent_cookie.cookie['path']='/' afpforum.com/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://soundbran.ch/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webanywhere.com/about-us/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schooljotter.com/products' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.webanywhere.com/career/' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.schooljotter.com/free-resources' consent_cookie.cookie['domain']='www.webanywhere.co.uk' consent_cookie.cookie['path']='/' webanywhere.co.uk/postrej_4.har.xz
# Unmatch url and consent cookie domain: page_url='https://www.harmankardon.com/' consent_cookie.cookie['domain']='.harmankardon.de' consent_cookie.cookie['path']='/' harmankardon.com/postrej_0.har.xz
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_2.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_5.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_1.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_0.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_3.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Post rej cookie not contain consent cookie, uktv.co.uk/postrej_4.har.xz not have cookie OptanonConsent of .uktvplay.co.uk on path /
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/signin?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2Flogin%3FiesCode%3DsA45H3aXtz' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_2.har.xz
# Unmatch url and consent cookie domain: page_url='https://login.pearson.com/v1/piapi/piui/forgot-unpw?client_id=BRSIcPHr2Iq0NV8AQP99zDZau8IPUxgy&login_success_url=https:%2F%2Fwww.pearsonactivelearn.com%2Fapp%2Flogin' consent_cookie.cookie['domain']='.pearsonactivelearn.com' consent_cookie.cookie['path']='/' pearsonactivelearn.com/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='chrome-error://chromewebdata/' consent_cookie.cookie['domain']='.embarkvet.com' consent_cookie.cookie['path']='/' embarkvet.com/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://twitter.com/arista_channels?utm_source=site_footer' consent_cookie.cookie['domain']='.edge.arista.com' consent_cookie.cookie['path']='/' untangle.com/postrej_2.har.xz
# Post rej cookie not contain consent cookie, cloudvector.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Unmatch url and consent cookie domain: page_url='https://www.myq.com/facility' consent_cookie.cookie['domain']='.liftmaster.com' consent_cookie.cookie['path']='/' liftmaster.com/postrej_3.har.xz
# Post rej cookie not contain consent cookie, incapsula.com/postrej_0.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Post rej cookie not contain consent cookie, incapsula.com/postrej_4.har.xz not have cookie OptanonConsent of .imperva.com on path /
# Unmatch url and consent cookie domain: page_url='https://accounts.google.com/o/oauth2/auth/identifier?client_id=355692466809-vkvrr3bues96uatk4j6fq62g8kc0grcg.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsso.holded.cloud%2Fcallback&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile&state=google%253ae073d3559c3e79f13f7999b90aeec718%253aweb%253aholded%253ahttps%253a%252f%252fapp.holded.com&service=lso&o2v=1&flowName=GeneralOAuthFlow' consent_cookie.cookie['domain']='.holded.com' consent_cookie.cookie['path']='/' holded.com/postrej_3.har.xz
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/biamp.com/postrej_5.har.xz: 'DataFrame' object has no attribute 'request'
# Error reading har file /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/pref_menu_scan_20k_100k/biamp.com/postrej_1.har.xz: 'DataFrame' object has no attribute 'request'
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_5.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_1.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_3.har.xz
# Unmatch url and consent cookie domain: page_url='https://valideus.com/' consent_cookie.cookie['domain']='comlaude.com' consent_cookie.cookie['path']='/' comlaude.net/postrej_4.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/za/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/za/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_5.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/vn/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/vn/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_1.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/au/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/au/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_3.har.xz
# Domain path mismatch: .cleanipedia.com domain's path /gb not match url https://www.cleanipedia.com/ru/home.html
# Unmatch url and consent cookie domain: page_url='https://www.cleanipedia.com/ru/home.html' consent_cookie.cookie['domain']='.cleanipedia.com' consent_cookie.cookie['path']='/gb' cleanipedia.com/postrej_4.har.xz
# Written to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/scan_20k_100k.parquet
# Number sent cookies read: 8,978,796
#          name                                              value      domain  \
# 0  JSESSIONID  5B58A8575467E01A4B05397DC199A5CAB61A1E193C8ADD...  .accor.com
# 1      _Hw2h_                                             .evy5d  .accor.com
# 2       xtvrn                                           $577671$  .accor.com
#
#   path       expires  size  httpOnly  secure  session sameSite priority  \
# 0    / -1.000000e+00    62     False    True     True     None   Medium
# 1    / -1.000000e+00    12     False    True     True     None   Medium
# 2    /  1.716282e+09    13     False   False    False      NaN   Medium
#
#    sameParty sourceScheme  sourcePort  \
# 0      False       Secure         443
# 1      False       Secure         443
# 2      False       Secure         443
#
#                                          request_url      site  \
# 0  https://all.accor.com/components/header/assets...  ibis.com
# 1  https://all.accor.com/ssr/_nuxt/80a51c4.modern.js  ibis.com
# 2  https://all.accor.com/assets/fonts/lato/regula...  ibis.com
#
#                                             page_url
# 0  https://all.accor.com/ssr/app/ibis/hotels/hong...
# 1  https://all.accor.com/ssr/app/ibis/hotels/hong...
# 2  https://all.accor.com/ssr/app/ibis/hotels/hong...

# %%
# prj = post-rejection
# Old way: consider all flows
# prj_sent_cookies = sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
# prj_br_cookies = prj_sent_cookies[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
# New way: consider cookies only (ignore the request url, which is not nused in get_comply cookie matching anyway)
prj_sent_cookies = sent_cookies[['name', 'domain', 'path', 'site']].drop_duplicates()

# %%
# print(f"Num captured sent cookies: {len(sent_cookies):,d}")
# print(f"Num unique captured cookies: {len(prj_sent_cookies):,d}")
# n_br_cookies = len(prj_br_cookies)
# print(f"Num unique browser cookies: {n_br_cookies:,d} on {prj_br_cookies.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")

# %% [markdown]
# ## Analyze cookies compliance

# %%
sites = set(cookie_prefs.site)
print(f"Num sent cookies in the cookie prefs sites: {len(prj_sent_cookies[prj_sent_cookies.site.isin(sites)]):,d}")
# Out:
# Num sent cookies in the cookie prefs sites: 68,867

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.comply_util'])
from consent.consistency.comply_util import get_comply

print("faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:")
all_complies = get_comply(cookie_prefs, prj_sent_cookies)
all_complies.head()
# Out:
# faster: for cookie_pref in cookie_pref_set[cookie_pref_set.name == acookie['name']]:
#  40%|███▉      | 1318/3334 [01:37<01:34, 21.26it/s]
# Big cookie pref moneyunder30.com 4795 skip this site
#  41%|████      | 1372/3334 [01:40<01:51, 17.62it/s]
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CookieConsent' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CookieConsent' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clsk' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clsk' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clsk' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clsk' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.store-api.proxy]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.store-api.proxy]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.store-api.proxy]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.store-api.proxy]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='__cflb' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.mediameetsFbPixel.conversionApi]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.checkout.switch-language]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.login]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.login]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.login]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.login]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[moorl.sign-in.get-url]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='__kla_id' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='__kla_id' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='__kla_id' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='__kla_id' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clck' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clck' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_clck' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_clck' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='session-' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='session-' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='session-' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='session-' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='MUID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='MUID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='MUID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='MUID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CLID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CLID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='CLID' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='CLID' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_fbp' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_fbp' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='_fbp' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='_fbp' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='sw-cache-hash' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='sw-cache-hash' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='sw-cache-hash' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='sw-cache-hash' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.register.save]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.register.save]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='csrf[frontend.account.register.save]' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='csrf[frontend.account.register.save]' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='YSC' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='YSC' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='YSC' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='YSC' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='timezone' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='timezone' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='timezone' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='timezone' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='VISITOR_INFO1_LIVE' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='VISITOR_INFO1_LIVE' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='VISITOR_INFO1_LIVE' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[frontend.store-api.proxy]' cookie_name='VISITOR_INFO1_LIVE' bad character range e-a at position 22
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='TiPMix' bad character range n-i at position 18
# Error fuzzy name match pref_name='csrf[moorl.sign-in.get-url]' cookie_name='x-ms-routing-name' bad character range n-i at position 18
#  66%|██████▋   | 2212/3334 [02:45<01:09, 16.12it/s]
# Big cookie pref benetton.com 3738 skip this site
#  83%|████████▎ | 2753/3334 [03:30<00:32, 18.00it/s]
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_pws' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='hubspotutk' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjSessionUser_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='oribili_user_guid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_ma_cookie' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='OptanonConsent' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjIncludedInSessionSample_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__hstc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_svisitor' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_sid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_pw' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_session' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_first_visit' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_ga' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gcl_au' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjAbsoluteSessionInProgress' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_hjSession_2869500' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vuid_l' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='OptanonAlertBoxClosed' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__hssrc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vid_l' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='bcookie' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='ln_or' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_dc_gtm_UA-49969775-9' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='6suuid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_cid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_ga_B77L7L8FZ3' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='_gd_visitor' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='lidc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_gavid_1878' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='__cf_bm' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='AnalyticsSyncHistory' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_vid_1878' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='li_gc' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='trd_gvid' bad character range r-C at position 137
# Error fuzzy name match pref_name='HotJar (detailed description of the cookies is available here [https://help.hotjar.com/hc/en-us/articles/115011789248-Hotjar-Cookie-Information])' cookie_name='UserMatchHistory' bad character range r-C at position 137
# 100%|█████████▉| 3332/3334 [04:06<00:00, 13.53it/s]
#                       name      domain path      site     comply
# 0               JSESSIONID  .accor.com    /  ibis.com     comply
# 1                   _Hw2h_  .accor.com    /  ibis.com     comply
# 2                    xtvrn  .accor.com    /  ibis.com  incorrect
# 3  userLocalizationInitial  .accor.com    /  ibis.com  incorrect
# 4     kameleoonVisitorCode  .accor.com    /  ibis.com       omit

# %%
# Analyze complies here
complies = all_complies[['name', 'domain', 'path', 'site', 'comply']].drop_duplicates()
comply_sites_data = defaultdict(list)
for comply_type, comply_group in complies.groupby('comply'):
    n_sites = comply_group.site.nunique()
    comply_sites_data['comply_type'].append(comply_type)
    comply_sites_data['num_sites'].append(n_sites)
    comply_sites = pd.DataFrame(comply_sites_data).sort_values(by=['num_sites'], ascending=False)
    
nsites = all_complies.site.nunique()
comply_counts = complies.comply.value_counts()
comply_sites['num_sites_percent'] = comply_sites['num_sites'] / nsites * 100
comply_sites['num_cookies'] = comply_sites['comply_type'].map(comply_counts)
comply_sites['num_cookies_percent'] = comply_sites['num_cookies'] / comply_sites['num_cookies'].sum() * 100  # need to read scan_*.parquet for n_br_cookies, but may be unnecessary
comply_sites['num_cookies_per_site'] = comply_sites['num_cookies'] / comply_sites['num_sites'] 

# Do not count comply/correct enforcement: which require detecting all possible
comply_sites = comply_sites[comply_sites.comply_type != 'comply']
comply_sites
# Out:
#   comply_type  num_sites  num_sites_percent  num_cookies  num_cookies_percent  \
# 3        omit       2770          83.635266        28585            41.551589
# 2   incorrect       2757          83.242754        23937            34.795186
# 0   ambiguous        116           3.502415          240             0.348868
#
#    num_cookies_per_site
# 3             10.319495
# 2              8.682263
# 0              2.068966

# %%
# Record the analysis results
all_complies_file = SCAN_ROOT_DIR / f'all_complies{output_suffix}.parquet'
all_complies.to_parquet(all_complies_file); print(f"Written {len(all_complies):,d} records of all_complies to {all_complies_file}")
# Out:
# Written 68,794 records of all_complies to /mnt/sdd/ducbui/projects/data2/consent/2023-04-14/all_complies_20k_100k.parquet

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

raise StopExecution
import sys; sys.exit(0)

# %%
complies.comply
# Out:
# 0           comply
# 1           comply
# 2        incorrect
# 3        incorrect
# 4             omit
#            ...
# 68789    incorrect
# 68790         omit
# 68791         omit
# 68792       comply
# 68793       comply
# Name: comply, Length: 68794, dtype: object

# %%
nsites = all_complies.site.nunique(); nsites
# all_complies.site.unique()
# Out:
# 3312

# %%
detected_contra_sites = [s for s, contras in site_to_contras.items() if len(contras) > 0]; len(detected_contra_sites)
# Out:
# 0

# %%
complies = all_complies[ ['name', 'domain', 'site', 'comply',]].drop_duplicates()
comply_counts = complies.comply.value_counts()
comply_counts
# Out:
# omit         28468
# incorrect    23913
# comply       15927
# ambiguous      240
# Name: comply, dtype: int64

# %%
complies_sites = set(all_complies.site)
sent_cookies_com = sent_cookies[sent_cookies.site.isin(complies_sites)]
prj_sent_cookies_com = sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'value', 'request_url', 'site']].drop_duplicates()
prj_br_cookies_com = prj_sent_cookies_com[['domain', 'expires', 'name', 'path', 'sameSite', 'secure', 'site']].drop_duplicates()
print(f"Num captured sent cookies: {len(sent_cookies_com):,d}")
print(f"Num unique captured cookies: {len(prj_sent_cookies_com):,d}")

n_br_cookies_com = len(prj_br_cookies_com)
print(f"Num unique browser cookies: {n_br_cookies_com:,d} on {prj_br_cookies_com.site.nunique():,d} websites") # and {sent_cookies.page_url.nunique():,d} pages")
# Out:
# Num captured sent cookies: 8,737,924
# Num unique captured cookies: 4,883,080
# Num unique browser cookies: 166,607 on 3,312 websites

# %% [markdown]
# # Analyze contras

# %%
# Way 1: compute contra sites by dynamic analysis: this should be lower than statically analyzing prefs
# because we cannot check all combinations of consent modes.
from consent.consistency.comply_util import get_appr_rej_sets
contra_data = []
for asite in cookie_prefs.site.unique():
    site_prefs = cookie_prefs[cookie_prefs.site == asite]
    _, _, contras = get_appr_rej_sets(site_prefs)
    for contra in contras:
        contra['site'] = asite
        contra_data.append(contra)
contra_sites = pd.DataFrame(contra_data)
contra_sites.head()
# Out:
#                      domain                          name                site
# 0                 force.com                     BrowserId        polestar.com
# 1  spekstaging.wpengine.com                    hubspotutk           spekit.co
# 2                spekit.com                    hubspotutk           spekit.co
# 3     www.libertylondon.com          dwanonymous_xxxxxxxx   libertylondon.com
# 4        tartecosmetics.com  _hjAbsoluteSessionInProgress  tartecosmetics.com

# %%
assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 assert set(detected_contra_sites) == set(contra_sites.site), "this is the same method with above, so the result"
#
# AssertionError: this is the same method with above, so the result

# %%
set(detected_contra_sites) - set(contra_sites.site)
set(contra_sites.site) - set(detected_contra_sites) 
# This may be the sites excluded due to testing cookies in the preferences.
# Out:
# {'247sports.com',
#  'abbvie.com',
#  'acquia.com',
#  'adobe.io',
#  'adweek.com',
#  'aljazeera.com',
#  'allaboutvision.com',
#  'allegiantair.com',
#  'allergan.com',
#  'alteryx.com',
#  'americanbar.org',
#  'aon.com',
#  'ariel.co.uk',
#  'asos.com',
#  'autosport.com',
#  'avalara.com',
#  'avast.com',
#  'avastbrowser.com',
#  'barnesandnoble.com',
#  'bazaarvoice.com',
#  'bbva.com',
#  'bd.com',
#  'behance.net',
#  'belkin.com',
#  'betsson.com',
#  'bitdefender.com',
#  'bitdefender.net',
#  'bkstr.com',
#  'blackboard.com',
#  'bplans.com',
#  'brightside.me',
#  'bromium-online.com',
#  'callofduty.com',
#  'cambridge.org',
#  'carbonite.com',
#  'cheapoair.com',
#  'chrysler.com',
#  'cisco.com',
#  'citationmachine.net',
#  'clickmeeting.com',
#  'clicktale.net',
#  'cloudbees.com',
#  'cnet.com',
#  'colt.net',
#  'commonsensemedia.org',
#  'contentsquare.com',
#  'conviva.com',
#  'creighton.edu',
#  'curalate.com',
#  'dc.com',
#  'dccomics.com',
#  'discogs.com',
#  'dynamicyield.com',
#  'easybib.com',
#  'eidos.com',
#  'elderscrollsonline.com',
#  'evri.com',
#  'ew.com',
#  'fabfitfun.com',
#  'fotolia.com',
#  'fourseasons.com',
#  'frontlineeducation.com',
#  'geappliances.com',
#  'geforce.com',
#  'genial.ly',
#  'getdbt.com',
#  'glip.com',
#  'gmu.edu',
#  'gopro.com',
#  'grainger.com',
#  'halfords.com',
#  'hallmark.com',
#  'hightail.com',
#  'hm.com',
#  'howstuffworks.com',
#  'hp.com',
#  'illumina.com',
#  'instyle.com',
#  'ipl.org',
#  'irishcentral.com',
#  'ironman.com',
#  'janes.com',
#  'jbl.com',
#  'jeep.com',
#  'jobvite.com',
#  'kew.org',
#  'lastline.com',
#  'launchdarkly.com',
#  'levi.com',
#  'liverpoolfc.com',
#  'logi.com',
#  'logitech.com',
#  'logitechg.com',
#  'mastercard.com',
#  'mastercard.us',
#  'mcgraw-hill.com',
#  'mckesson.com',
#  'meraki.com',
#  'mheducation.com',
#  'michaels.com',
#  'mlb.com',
#  'mongodb.com',
#  'mongodb.org',
#  'morningconsult.com',
#  'morrisons.com',
#  'motorsport.com',
#  'mtv.com',
#  'myportfolio.com',
#  'name.com',
#  'nba.com',
#  'ncaa.com',
#  'newsday.com',
#  'newsweaver.com',
#  'next.co.uk',
#  'nhl.com',
#  'ni.com',
#  'nspcc.org.uk',
#  'nvidia.com',
#  'ocado.com',
#  'omnitracs.com',
#  'onlyinyourstate.com',
#  'paradox.ai',
#  'parents.com',
#  'paypay.ne.jp',
#  'pcapredict.com',
#  'people.com',
#  'pge.com',
#  'phoenix.edu',
#  'pinknews.co.uk',
#  'politico.com',
#  'principal.com',
#  'prweb.com',
#  'rd.com',
#  'realsimple.com',
#  'ringcentral.com',
#  'rollout.io',
#  'royalacademy.org.uk',
#  'salliemae.com',
#  'samaritans.org',
#  'sanofi-synthelabo.com',
#  'sanofi.com',
#  'santander.co.uk',
#  'sciam.com',
#  'scientificamerican.com',
#  'senderscore.com',
#  'seon.io',
#  'sho.com',
#  'shuttercloud.org',
#  'shutterstock.com',
#  'signifyd.com',
#  'solvvy.com',
#  'sonos.com',
#  'sony.co.uk',
#  'sourcefire.com',
#  'sparknotes.com',
#  'square-enix-games.com',
#  'statista.com',
#  'suse.com',
#  'tasteofhome.com',
#  'telerik.com',
#  'thedailybeast.com',
#  'thedodo.com',
#  'thomsonreuters.com',
#  'thomsonreuters.net',
#  'travelandleisure.com',
#  'treasuredata.com',
#  'tripadvisor.in',
#  'typeform.com',
#  'typekit.com',
#  'uipath.com',
#  'ulta.com',
#  'umbrella.com',
#  'universe.com',
#  'urbanairship.com',
#  'vfsglobal.com',
#  'viber.com',
#  'visma.com',
#  'vmware.com',
#  'vmwareidentity.com',
#  'webmd.com',
#  'wfmz.com',
#  'whirlpool.com',
#  'workspaceoneaccess.com',
#  'worldoftanks.com',
#  'wwf.org.uk',
#  'yousendit.com',
#  'zdnet.com',
#  'zebra.com',
#  'zeiss.com',
#  'zennioptical.com',
#  'zoom.com',
#  'zoom.us'}

# %%
# Way 2: compute contra sites by DataFrame group by
contra_cookies_dfs = []
for _, same_cookies in cookie_prefs.groupby(['name', 'domain', 'site']):
    consent_modes = same_cookies.consent_mode.unique()
    if len(consent_modes) >= 2 and same_cookies.category.nunique() > 1: # and 'always active' in consent_modes:
        contra_cookies_dfs.append(same_cookies)
contra_cookies = pd.concat(contra_cookies_dfs).drop_duplicates()

# %%
print("Number sites with contra cookies:", contra_cookies.site.nunique())
# Out:
# Number sites with contra cookies: 184

# %%
# set(contra_cookies.site) - set(contra_sites.site)

# %%
print("Num contra cookie settings (double categories):", len(contra_cookies), f"settings on {contra_cookies.site.nunique()} sites")
print("Contras with 1 always-active:", contra_sites.site.nunique())
print("Contras with both editable:", len(set(contra_cookies.site) - set(contra_sites.site)))
# Out:
# Num contra cookie settings (double categories): 648 settings  on 184 sites
# Contras with 1 always-active: 192
# Contras with both editable: 0

# %%
contra_cookies[contra_cookies.site == 'elsevier.nl']
# Out:
# Empty DataFrame
# Columns: [name, domain, duration, category_id, category, consent_mode, site, lib_name, pattern_name, consent]
# Index: []

# %%
# assert len(detected_contra_sites) <= contra_sites.site.nunique() < len(detected_contra_sites) + 2

# %%
complies[complies.comply == 'ambiguous']
# Out:
#                  name                  domain                   site  \
# 173        TS013559a7       www.mastercard.us         mastercard.com
# 1236    _qubitTracker         .www.very.co.uk             very.co.uk
# 2365   G_ENABLED_IDPS      .www.glassdoor.com          glassdoor.com
# 2372              trs       www.glassdoor.com          glassdoor.com
# 2375             _gid          .glassdoor.com          glassdoor.com
# ...               ...                     ...                    ...
# 59468         ak_bmsc           .mulesoft.com           mulesoft.com
# 59481      JSESSIONID   training.mulesoft.com           mulesoft.com
# 60397          TLTSID              .bkstr.com              bkstr.com
# 60412            dtSa              .bkstr.com              bkstr.com
# 60622       shortHash  .square-enix-games.com  square-enix-games.com
#
#           comply
# 173    ambiguous
# 1236   ambiguous
# 2365   ambiguous
# 2372   ambiguous
# 2375   ambiguous
# ...          ...
# 59468  ambiguous
# 59481  ambiguous
# 60397  ambiguous
# 60412  ambiguous
# 60622  ambiguous
#
# [116 rows x 4 columns]

# %%
cookie_prefs[ (cookie_prefs.site == 'michaels.com') & (cookie_prefs.name == 'utag_main') ]
# Out:
#           name         domain  duration category_id  \
# 88   utag_main  .michaels.com  365 days       C0001
# 148  utag_main   michaels.com  365 days       C0002
#
#                        category   consent_mode          site  lib_name  \
# 88   Strictly Necessary Cookies  always active  michaels.com  onetrust
# 148         Performance Cookies         active  michaels.com  onetrust
#
#     pattern_name consent
# 88       en.json    True
# 148      en.json   False

# %%
cookie_prefs[ (cookie_prefs.site == 'statista.com') & (cookie_prefs.name == 'id') ]
# Out:
#     name  domain duration category_id           category   consent_mode  \
# 74    id  m6r.eu  90 days       C0001  Necessary Cookies  always active
# 131   id  m6r.eu   0 days       C0004  Targeting Cookies       inactive
#
#              site  lib_name pattern_name consent
# 74   statista.com  onetrust      en.json    True
# 131  statista.com  onetrust      en.json   False

# %%
# contra_cookies.name.value_counts()[:10]
# contra_cookies[contra_cookies.name == '__cf_bm'].reset_index(drop=True) # .site.nunique()

# %% [markdown]
# # Analyze ambiguous flows

# %%
ambi_cookies = complies[complies.comply == 'ambiguous']
print("Num ambiguous cookies:", len(ambi_cookies), "on num sites:", ambi_cookies.site.nunique())
assert len(ambi_cookies) == len(ambi_cookies.drop_duplicates()), "there is some duplicate cookies"

# %% [markdown]
# ## Analyze no-way-to-opt-out

# %%
# Way 1: compute contra sites by DataFrame group by
nwtoo_cookies_dfs = []
for _, site_cookies in cookie_prefs.groupby(['site']):
    consent_modes = site_cookies.consent_mode.unique().tolist()
    if len(consent_modes) == 1 and consent_modes[0] == 'always active':
        nwtoo_cookies_dfs.append(site_cookies)
nwtoo_cookies = pd.concat(nwtoo_cookies_dfs).drop_duplicates()
nwtoo_cookies.head()

# %%
nwtoo_cookies.site.nunique()

# %% [markdown]
# # Analyze inconsistent flows/cookies

# %%
def plot_inconsis_types():
    sns.set(rc={'figure.figsize':(9,9),"font.size":30,"axes.titlesize":30,"axes.labelsize":30},style="white", font_scale = 2.5)

    ax = sns.barplot(x='comply_type', y='num_sites_percent', data=noncomply_sites)
    ax.tick_params(left=True, bottom=True, direction="in")
    ax.set_ylabel('# Websites (%)')
    ax.set_xlabel('Noncompliance Types')
    xticks = [x.get_text().title() for x in ax.get_xticklabels()]
    ax.set(xticklabels=xticks)

    out_file = FIG_DIR / 'noncomply_types_per_site.png'
    # plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
## Plot distribution of omitted cookie declarations

# %%
omit_complies = complies[(complies.comply == 'omit')] #  & ~complies.name.isin(['OptanonAlertBoxClosed', 'OptanonConsent']) ]
omit_complies.site.nunique()

# %%
omit_complies.site.value_counts()[:7]

# %%
omit_cookies = omit_complies.name.value_counts()[:5].to_frame().reset_index().rename(columns={'index': 'cookie_name'})
omit_cookies['num_sites'] = omit_cookies['cookie_name'].map(lambda cookie_name: omit_complies[omit_complies.name == cookie_name].site.nunique())
print(omit_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %%
# set(cookielist_sites) - set(omit_complies.site.unique())
omit_counts = omit_complies.site.value_counts().to_frame().rename(columns={'site': 'num_omit_cookies'})
print("Num omitted sites:", omit_complies.site.nunique())
omit_counts.num_omit_cookies.mean(), omit_counts.num_omit_cookies.std(), omit_counts.num_omit_cookies.min(), omit_counts.num_omit_cookies.max()

# %%
sns.set(rc={'figure.figsize':(12,8),"font.size":35,"axes.titlesize":30,"axes.labelsize":50},style="white", font_scale = 4.5)
sns.set_style("ticks", {"xtick.direction": "in", "ytick.direction": "in"})
plt.rcParams['xtick.major.size'] = 15
plt.rcParams['ytick.major.size'] = 15

ax = sns.ecdfplot(data=omit_counts, x=omit_counts.num_omit_cookies, linewidth=8)
ax.set(xlim=(0, 350))

plt.xlabel('# Omitted Cookies/Website')
plt.ylabel('CDF')
# out_file = FIG_DIR / 'eu_omit_cookie_cdf.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
plot_df = omit_counts[:50]

sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x=plot_df.index, y=plot_df.num_omit_cookies)
ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=False, direction="in")
ax.set_ylabel('# Omitted Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'omit_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
def plot_histogram_omit():
    sns.set(rc={'figure.figsize':(9,6),"font.size":25,"axes.titlesize":25,"axes.labelsize":15},style="white", font_scale = 1)
    omit_counts_histo = omit_complies.site.value_counts().value_counts()
    sns.barplot(x=omit_counts_histo.index, y=omit_counts_histo.values)
    ticks = plt.xticks(rotation=45, ha='right')

# %% [markdown]
# ## Plot distribution of incorrectly enforced cookies

# %%
incor_complies = complies[complies.comply == 'incorrect']
# set(cookielist_sites) - set(omit_complies.site.unique())
incor_counts = incor_complies.site.value_counts().iloc[:50]
incor_counts = incor_counts.to_frame().reset_index().sort_values(by=['site', 'index'], ascending=[False, True])
incor_counts.columns

# %%
sns.set(rc={'figure.figsize':(24,8),"font.size":35,"axes.titlesize":35,"axes.labelsize":25},style="white", font_scale=1.5)
ax = sns.barplot(x='index', y='site', data=incor_counts)

ticks = plt.xticks(rotation=45, ha='right')

ax.tick_params(left=True, bottom=True, direction="in")
ax.set_ylabel('# Incorrectly Enforced Cookies')
ax.set_xlabel('Website')

# out_file = FIG_DIR / 'incor_site.png'
# plt.savefig(out_file, dpi=200, bbox_inches='tight'); print(f"Written to {out_file}")

# %%
# len(incor_counts)

# %%
incor_counts[incor_counts.site == 33].reset_index(drop=True)

# %% [markdown]
# ### Top incorrect cookies

# %%
incor_cookies = complies[complies.comply == 'incorrect']

# %%
# site = 'onetrust.com'
# complies[complies.site == site].reset_index(drop=True)
# cookie_prefs[(cookie_prefs.site == site) & (cookie_prefs.name == '_gid')]

# %%
top_incor_cookies = incor_cookies.name.value_counts().sort_values(ascending=False).to_frame().reset_index().rename(columns={'index':'cookie_name', 'name': 'num_occur'})

# %%
top_incor_cookies['num_sites'] = top_incor_cookies.cookie_name.map(lambda cookie_name: incor_cookies[incor_cookies.name == cookie_name].site.nunique())

# %%
print(top_incor_cookies.head(5)[['cookie_name', 'num_sites']].rename(columns={'cookie_name': 'Cookie Name', 'num_sites': '# Websites'}).to_latex(index=False))

# %% [markdown]
# # Narrow cookie consent preferences

# %%
consent_cookies = sent_cookies[sent_cookies.name.isin(['OptanonConsent', 'CookieConsent'])][['domain', 'name', 'site']].drop_duplicates()
narrow_consent_cookies = consent_cookies[~consent_cookies.domain.str.startswith('.')].reset_index(drop=True)

# %%
set(contra_cookies.site).intersection(set(narrow_consent_cookies.site))

# %%
narrow_consent_cookies

# %% [markdown]
# # Case studies

# %%
incor_df = complies[complies.comply == 'incorrect']
incor_df.site.value_counts().sort_values(ascending=False).head()

# %%
case_site = 'blabbermouth.net'
incor_df[incor_df.site == case_site]

# %%
# cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'MXP_TRACKINGID')]
cookie_prefs[(cookie_prefs.site == case_site) & (cookie_prefs.name == 'IDE')]

# %%
# sent_cookies[(sent_cookies.site == 'scientificamerican.com') & (sent_cookies.name == 'MXP_TRACKINGID')]

# %%
omit_df = complies[complies.comply == 'omit']
omit_df.site.value_counts().sort_values(ascending=False).iloc[20:30]

# %%
print(omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist())

# %%
'uids' in omit_df[omit_df.site == 'scientificamerican.com'].reset_index().name.tolist()

# %%
omit_df[(omit_df.site == 'scientificamerican.com') & (omit_df.name == 'cftoken')]

# %%
cookie_prefs[(cookie_prefs.site == 'scientificamerican.com') & (cookie_prefs.name == 'ADGRX_UID')]

# %%
all_sites = set(complies.site)
nothing_comply_sites = all_sites - set(complies[complies.comply == 'comply'].site)
print("Sites with no compliant cookies:", nothing_comply_sites)

# %%
for site in ['liveperson.com']: # nothing_comply_sites:
    print(site)
site_cookies = postrej_br_cookies[postrej_br_cookies.site == site]

# %%
acookie = site_cookies[site_cookies.name == 'OptanonAlertBoxClosed'].iloc[0]

# %%
site_prefs = cookie_prefs[cookie_prefs.site == site]
consent_cookies = site_prefs[site_prefs.consent]
consent_cookie_names = consent_cookies.name
site_cookies[site_cookies.name.isin(consent_cookie_names)]
# cookie_name = 'OptanonAlertBoxClosed'
# cookie_pref = site_prefs[site_prefs.name == cookie_name].iloc[0]
# cookie_pref

# %%
consent_cookies

# %%
import sys; import importlib; importlib.reload(sys.modules['consent.consistency.cookie_pref_match'])
from consent.consistency.cookie_pref_match import cookie_pref_match    
cookie_pref_match(acookie, cookie_pref, site, verbose=2)

# %%
# Analyze Contras
