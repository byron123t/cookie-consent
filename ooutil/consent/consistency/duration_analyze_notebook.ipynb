# %%
from collections import defaultdict, Counter
from multiprocessing import Pool
from pathlib import Path
from typing import Dict
import datetime
import json
import re

from durations_nlp import Duration
from durations_nlp.exceptions import InvalidTokenError
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import urllib
import tldextract

from consent.consistency.cookie_pref_match import cookie_pref_match
from consent.consistency.util import FIG_DIR, get_scan_dirs, get_scan_root_dir
from consent.data.pref_menu_scan.cookie_decl_reader import read_cookie_decls_in_scans
from consent.data.pref_menu_scan.har_cookie_reader import read_postrej_sent_cookies_in_scans
# from consent.data.site_pref import read_site_prefs
# from consent.data.pref_menu_scan.cookie_pref_reader import read_cookie_prefs_in_scans
# from consent.data.pref_menu_scan.log_reader import read_logs_in_scans
# from consent.util.default_path import get_data_dir
# from ooutil.type_util import hashabledict
# from ooutil.url_util import get_suffixed_domain
# from ooutil.cookie_util import get_brower_cookies
# from ooutil.func_util import memoize

# data_dir = get_data_dir('2021-05-01/pref_menu_scan_accept')
SCAN_DIRS = get_scan_dirs('us')
SCAN_ROOT_DIR = get_scan_root_dir('us')
fig_dir = Path.home() / 'local_projects/consent/paper/sp22/figures'
assert fig_dir.exists() and fig_dir.is_dir()

# %%
# scanned_sites = [site_dir.name for site_dir in data_dir.glob('*') if site_dir.is_dir()]
# site_dirs = [data_dir / site for site in scanned_sites]
# print("Number of scanned sites:", len(scanned_sites)) # , scanned_sites)

# %% [markdown]
# # Get cookie durations in declarations

# %%
# Get cookie prefs = cookie decls + prefs
# cookie_prefs = read_cookie_prefs_in_scans(SCAN_DIRS)
# cookie_prefs.head()
# TODO: rerun with cookie decls only, we do not need cookie prefs
raw_cookie_decls = read_cookie_decls_in_scans(SCAN_DIRS)
raw_cookie_decls
# Out:
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_0k_10k/eero.com/consent_resources.json: region_block Received an out-of-region response
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_0k_10k/city.ac.uk/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_10k_30k/gannett.com/consent_resources.json: consent_js not supported yet.
# https://cdn.cookielaw.org/consent/be922b85-1c88-4393-ae73-1523f02934d6/366288bf-75c8-472c-b77b-7724367eecb9/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn-ukwest.onetrust.com/consent/e00c3e10-0e07-461a-94d5-e87b899fa55a/442b5be0-8f10-4555-b6a6-2aa7c2e23dfa/en.json WARNING: Cookie list has session cookie but duration > 0
# https://cdn.cookielaw.org/consent/bfc3f6d1-88f6-4292-b5d2-757633a696fe/e872bfc4-cfdc-444e-804c-eee5dcb46285/en.json WARNING: Cookie list has session cookie but duration > 0
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_30k_50k/fhi360.org/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_30k_50k/marieforleo.com/consent_resources.json: consent_js not supported yet.
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_30k_50k/secutix.com/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# WARNING: error decoding /mnt/sda/ducbui/Dropbox/Dropbox (University of Michigan)/projects/data_sync/consent/2021-12-15/pref_menu_scan_30k_50k/quantum.com/consent_resources.json: "None of [Index(['name', 'domain', 'duration', 'category_id', 'category',\n       'consent_mode'],\n      dtype='object')] are in the [columns]"
# https://cdn.cookielaw.org/consent/a3cad216-8692-4702-a85d-06e5c30c35cc/c500ad25-efb5-41be-97d0-530b3cb248d6/en.json WARNING: Cookie list has session cookie but duration > 0
#                                       name                    domain  \
# 0                           __we_bucket_id            www.wework.com
# 1                    OptanonAlertBoxClosed                wework.com
# 2                           OptanonConsent            www.wework.com
# 3                          __we_request_id            www.wework.com
# 4                      we_referring_domain            www.wework.com
# ..                                     ...                       ...
# 222  bzfyEmbedLoadedOaip32bvTNuXnPSDlJaawA    connect.getflowbox.com
# 223  bzfyEmbedLoadedSWDUo4NQQsuLK9D2Q7T3kQ                 vespa.com
# 224  bzfyEmbedLoadedSWDUo4NQQsuLK9D2Q7T3kQ    connect.getflowbox.com
# 225                               randomID                 vespa.com
# 226                               randomID  www.googletagmanager.com
#
#      duration   category_id                    category   consent_mode  \
# 0    365 days         C0001  Strictly Necessary Cookies  always active
# 1    365 days         C0001  Strictly Necessary Cookies  always active
# 2    365 days         C0001  Strictly Necessary Cookies  always active
# 3     Session         C0001  Strictly Necessary Cookies  always active
# 4     14 days         C0001  Strictly Necessary Cookies  always active
# ..        ...           ...                         ...            ...
# 222   Session  unclassified                unclassified           None
# 223   Session  unclassified                unclassified           None
# 224   Session  unclassified                unclassified           None
# 225   Session  unclassified                unclassified           None
# 226   Session  unclassified                unclassified           None
#
#            site   lib_name pattern_name
# 0    wework.com   onetrust      en.json
# 1    wework.com   onetrust      en.json
# 2    wework.com   onetrust      en.json
# 3    wework.com   onetrust      en.json
# 4    wework.com   onetrust      en.json
# ..          ...        ...          ...
# 222   vespa.com  cookiebot        cc.js
# 223   vespa.com  cookiebot        cc.js
# 224   vespa.com  cookiebot        cc.js
# 225   vespa.com  cookiebot        cc.js
# 226   vespa.com  cookiebot        cc.js
#
# [266555 rows x 9 columns]

# %%
# def _osolete_analysis():
#     pref_menu_data_dir = get_data_dir('2021-05-01/pref_menu_scan')
#     pref_menu_sites = [site_dir.name for site_dir in pref_menu_data_dir.glob('*') if site_dir.is_dir()]
#     pref_menu_site_prefs = read_site_prefs([pref_menu_data_dir / site for site in pref_menu_sites])
#     print("Number of sites in pref-menu scan:", len(pref_menu_sites)) # , scanned_sites)
#     pref_menu_cookielist_sites = pref_menu_site_prefs.site.unique()
#     print("Number of sites with cookie list in pref-menu scan:", len(pref_menu_cookielist_sites)) # , scanned_sites)
#     missings = set(pref_menu_cookielist_sites) - set(site_prefs.site.unique())
#     n_sites_with_sett = site_prefs.site.nunique()
#     print("Missing sites:", missings)
#     redundants = set(site_prefs.site.unique()) - set(pref_menu_cookielist_sites)
#     print("Redudant sites:", redundants)
    # assert len(missings) == len(redundants) == 0, f"There is some mismatch."

# %%
# site_prefs = site_prefs[site_prefs.duration != '']
assert len(raw_cookie_decls[raw_cookie_decls.duration.isna()]) == 0
assert len(raw_cookie_decls[raw_cookie_decls.duration == '']) ==0

# %%
print(f"Most common preference durations:")
pref_dur_counts = raw_cookie_decls.duration.value_counts().to_frame().reset_index()
pref_dur_counts['freq'] = pref_dur_counts['duration'] / len(raw_cookie_decls) * 100
pref_dur_counts.head(10)
pref_dur_counts = pref_dur_counts[['index', 'freq']].rename(columns={'index': 'Duration'}).head(5)  # , 'freq': 'Frequency (%)'
print(pref_dur_counts.to_latex(index=False, float_format="%.2f"))
# Out:
# Most common preference durations:
# \begin{tabular}{lr}
# \toprule
# Duration &  freq \\
# \midrule
#  Session & 25.09 \\
#   0 days & 21.96 \\
# 365 days & 11.46 \\
# 730 days &  4.51 \\
#  30 days &  3.81 \\
# \bottomrule
# \end{tabular}

# %%
print(f"Preference durations:")
print(raw_cookie_decls['duration'].unique())
# Out:
# Preference durations:
# ['365 days' 'Session' '14 days' ... '5995 days' '18858 days' '4931 days']

# %%
'Session' in raw_cookie_decls[raw_cookie_decls.lib_name == 'onetrust']['duration'].unique()
# Out:
# True

# %%
cookielist_sites = sorted(raw_cookie_decls.site.unique().tolist())
n_cookielist_sites = len(cookielist_sites)
assert raw_cookie_decls.site.nunique() == n_cookielist_sites
# print("Sites with cookie list:", n_cookielist_sites, cookielist_sites)

# %% [markdown]
# # Read in the post-rejection cookies to find the actual cookie durations.

# %%
# raw_postrej_sent_cookies_file = data_dir / 'raw_postrej_sent_cookies.parquet'
# postrej_sent_cookies_file = data_dir / 'postrej_sent_cookies.parquet'
# if raw_postrej_sent_cookies_file.exists():
#     raw_postrej_sent_cookies = pd.read_parquet(raw_postrej_sent_cookies_file)
#     postrej_sent_cookies = pd.read_parquet(postrej_sent_cookies_file)
# else:
#     # postrej_sent_cookies = read_postrej_sent_cookies(site_dirs[:4])
#     raw_postrej_sent_cookies = parallel_read_postrej_sent_cookies(data_dir, keep_sent_cookie=True)
#     postrej_sent_cookies = raw_postrej_sent_cookies.drop_duplicates()
#     raw_postrej_sent_cookies.to_parquet(raw_postrej_sent_cookies_file); print(f"Written to {raw_postrej_sent_cookies_file}")
#     postrej_sent_cookies.to_parquet(postrej_sent_cookies_file); print(f"Written to {postrej_sent_cookies_file}")

# raw_postrej_sent_cookies.head(3)
overwrite = False
cookies_cache_file = SCAN_ROOT_DIR / 'scan.parquet'  # 'raw_postrej_sent_cookies.parquet'

if not overwrite and cookies_cache_file and cookies_cache_file.exists():
    sent_cookies = pd.read_parquet(cookies_cache_file)
else:
    sent_cookies = read_postrej_sent_cookies_in_scans(SCAN_DIRS)
    if cookies_cache_file: sent_cookies.to_parquet(cookies_cache_file); print(f"Written to {cookies_cache_file}")

print(f"Number sent cookies read: {len(sent_cookies):,d}")
sent_cookies.head(3)
# Out:
# Number sent cookies read: 5,152,870
#           name                                              value  \
# 0  ajs_user_id  %22e465a0f34b3bdaa686645b9f88599d5563d0e8562db...
# 1          _ga                        GA1.1.1271302899.1639586858
# 2  ajs_user_id  %22e465a0f34b3bdaa686645b9f88599d5563d0e8562db...
#
#         domain path       expires  size  httpOnly  secure  session sameSite  \
# 0  .wework.com    /  1.671123e+09    81     False   False    False      Lax
# 1  .wework.com    /  1.702659e+09    30     False   False    False     None
# 2  .wework.com    /  1.671123e+09    81     False   False    False      Lax
#
#   priority  sameParty sourceScheme  sourcePort  \
# 0   Medium      False       Secure         443
# 1   Medium      False       Secure         443
# 2   Medium      False       Secure         443
#
#                                          request_url        site  \
# 0  https://www-static.wework.com/apercu/apercu_mo...  wework.com
# 1  https://www.wework.com/vanilla-assets/javascri...  wework.com
# 2  https://www.wework.com/vanilla-assets/fonts/ic...  wework.com
#
#                                           page_url
# 0  https://www.wework.com/l/coworking-space/manila
# 1  https://www.wework.com/l/coworking-space/manila
# 2  https://www.wework.com/l/coworking-space/manila

# %%
postrej_sent_cookies = sent_cookies.drop_duplicates()
print(f"Num raw captured cookies: {len(sent_cookies):,d}")
print(f"Num unique captured cookies: {len(postrej_sent_cookies):,d}")
# Out:
# Num raw captured cookies: 5,152,870
# Num unique captured cookies: 5,128,820

# %% [markdown]
# # Combine the actual and declared durations

# %%
def find_pref(cookie, site_pref_dicts, site):
    def match(acookie, site_pref):
        # print(f"{acookie=}")
        # print(f"{site_pref=}")
        return cookie_pref_match(acookie, site_pref, site)

    # found = site_pref_df[ site_pref_df.apply(match, axis=1) ]
    found = [site_pref_dict for site_pref_dict in site_pref_dicts if match(cookie, site_pref_dict)]
    if len(found) > 1:
        # print(f"WARNING: multiple site pref found (contradictory pref) {found=}")
        found = found[0:1]
    return found

def combine_cookie_pref(cookies, site_pref_df: pd.DataFrame, site):
    """Combine cookie to decl. TODO: rename pref to decl"""
    new_rows = []
    # site_pref_dicts = tuple(hashabledict(d) for d in site_pref_df.to_dict('records'))
    site_pref_dicts = site_pref_df.to_dict('records')
    for _, cookie in cookies.iterrows():       
        cookie = cookie.to_dict()

        # Only needs these attributes; reduce to memoize
        # cookie_to_match = hashabledict({k: cookie[k] for k in ["name", "domain"]})
        cookie_to_match = cookie
        for pref in find_pref(cookie_to_match, site_pref_dicts, site):
            new_row = cookie.copy()
            for pref_k, pref_v in pref.items():
                new_row['decl_' + pref_k] = pref_v
            new_rows.append(new_row)

    return pd.DataFrame(new_rows)

def get_combine_cookie_decls():
    combine_dfs = []
    for site in tqdm(postrej_sent_cookies.site.unique()):
        cookies = postrej_sent_cookies[postrej_sent_cookies.site == site]
        site_decl_df = raw_cookie_decls[raw_cookie_decls.site == site]
        combine_dfs.append(combine_cookie_pref(cookies, site_decl_df, site))
        
    return pd.concat(combine_dfs, ignore_index=True)

# cookie_prefs_file = data_dir / 'cookie_prefs.parquet'
# if False: # cookie_prefs_file.exists():
#     cookie_prefs = pd.read_parquet(cookie_prefs_file)
# else:
# TODO: change pref to decl
cookie_decls = get_combine_cookie_decls()
#     cookie_prefs.to_parquet(cookie_prefs_file); print(f"Written to {cookie_prefs_file}")
cookie_decls # 26 mins
# Out:
# 100%|██████████| 1622/1622 [26:17<00:00,  1.03it/s]
#                               name  \
# 0                      ajs_user_id
# 1                              _ga
# 2                      ajs_user_id
# 3                           _kuid_
# 4        kampyleSessionPageCounter
# ...                            ...
# 2868388                    _gcl_au
# 2868389                        _ga
# 2868390                         RT
# 2868391                    _gcl_au
# 2868392                       _gid
#
#                                                      value          domain  \
# 0        %22e465a0f34b3bdaa686645b9f88599d5563d0e8562db...     .wework.com
# 1                              GA1.1.1271302899.1639586858     .wework.com
# 2        %22e465a0f34b3bdaa686645b9f88599d5563d0e8562db...     .wework.com
# 3                                                 OiuKv-_v       .krxd.net
# 4                                                        1  www.wework.com
# ...                                                    ...             ...
# 2868388                          1.1.1311567854.1639897653      .vespa.com
# 2868389                        GA1.2.1432834110.1639897653      .vespa.com
# 2868390  "z=1&dm=vespa.com&si=qmw6w14fpf&ss=kxcwogih&sl...      .vespa.com
# 2868391                          1.1.1311567854.1639897653      .vespa.com
# 2868392                         GA1.2.457380286.1639897653      .vespa.com
#
#         path       expires  size  httpOnly  secure  session sameSite  ...  \
# 0          /  1.671123e+09    81     False   False    False      Lax  ...
# 1          /  1.702659e+09    30     False   False    False     None  ...
# 2          /  1.671123e+09    81     False   False    False      Lax  ...
# 3          /  1.655139e+09    14     False    True    False     None  ...
# 4          /  1.671123e+09    26     False    True    False     None  ...
# ...      ...           ...   ...       ...     ...      ...      ...  ...
# 2868388    /  1.647674e+09    32     False   False    False     None  ...
# 2868389    /  1.702970e+09    30     False   False    False     None  ...
# 2868390    /  1.640502e+09    63     False   False    False     None  ...
# 2868391    /  1.647674e+09    32     False   False    False     None  ...
# 2868392    /  1.639984e+09    30     False   False    False     None  ...
#
#                                                 page_url  \
# 0        https://www.wework.com/l/coworking-space/manila
# 1        https://www.wework.com/l/coworking-space/manila
# 2        https://www.wework.com/l/coworking-space/manila
# 3        https://www.wework.com/l/coworking-space/manila
# 4        https://www.wework.com/l/coworking-space/manila
# ...                                                  ...
# 2868388            https://www.vespa.com/us_EN/timeline/
# 2868389            https://www.vespa.com/us_EN/timeline/
# 2868390            https://www.vespa.com/us_EN/timeline/
# 2868391            https://www.vespa.com/us_EN/timeline/
# 2868392            https://www.vespa.com/us_EN/timeline/
#
#                          decl_name     decl_domain  decl_duration  \
# 0                      ajs_user_id      wework.com       365 days
# 1                              _ga      wework.com       730 days
# 2                      ajs_user_id      wework.com       365 days
# 3                           _kuid_        krxd.net       180 days
# 4        kampyleSessionPageCounter  www.wework.com       365 days
# ...                            ...             ...            ...
# 2868388                    _gcl_au       vespa.com       3 months
# 2868389                        _ga       vespa.com        2 years
# 2868390                         RT       vespa.com         6 days
# 2868391                    _gcl_au       vespa.com       3 months
# 2868392                       _gid       vespa.com          1 day
#
#         decl_category_id        decl_category decl_consent_mode   decl_site  \
# 0                  C0004    Targeting Cookies     always active  wework.com
# 1                  C0002  Performance Cookies     always active  wework.com
# 2                  C0004    Targeting Cookies     always active  wework.com
# 3                  C0004    Targeting Cookies     always active  wework.com
# 4                  C0003   Functional Cookies     always active  wework.com
# ...                  ...                  ...               ...         ...
# 2868388        marketing            marketing              None   vespa.com
# 2868389        marketing            marketing              None   vespa.com
# 2868390        necessary            necessary              None   vespa.com
# 2868391        marketing            marketing              None   vespa.com
# 2868392        marketing            marketing              None   vespa.com
#
#         decl_lib_name decl_pattern_name
# 0            onetrust           en.json
# 1            onetrust           en.json
# 2            onetrust           en.json
# 3            onetrust           en.json
# 4            onetrust           en.json
# ...               ...               ...
# 2868388     cookiebot             cc.js
# 2868389     cookiebot             cc.js
# 2868390     cookiebot             cc.js
# 2868391     cookiebot             cc.js
# 2868392     cookiebot             cc.js
#
# [2868393 rows x 26 columns]

# %%
def get_duration_sec(cookie):
    if cookie['expires'] == -1:
        return -1
    return cookie['expires'] - cookie['load_end_time']

cookie_decls['dur_sec'] = cookie_decls.apply(get_duration_sec, axis=1)
cookie_decls.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'load_end_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12942/1226812058.py in <module>
#       4     return cookie['expires'] - cookie['load_end_time']
#       5
# ----> 6 cookie_decls['dur_sec'] = cookie_decls.apply(get_duration_sec, axis=1)
#       7 cookie_decls.head()
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_12942/1226812058.py in get_duration_sec(cookie)
#       2     if cookie['expires'] == -1:
#       3         return -1
# ----> 4     return cookie['expires'] - cookie['load_end_time']
#       5
#       6 cookie_decls['dur_sec'] = cookie_decls.apply(get_duration_sec, axis=1)
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/anaconda3/envs/consent/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'load_end_time'

# %%
# cookie_prefs[(cookie_prefs.name == 'eyeblaster') & (cookie_prefs.site == 'scientificamerican.com') ]
# cookie_decls[(cookie_decls.site == 'scientificamerican.com') ] # & (cookie_decls.domain == 'm6r.eu') ]

# %%
warnings = []
def parse_cookie_dur(pref_dur: str):
    pref_dur = pref_dur.lower().strip()
    if pref_dur == 'session':
        return -1
    if pref_dur == '0 days':  # equivalent to 'a few seconds' in onetrust
        return 100
    if pref_dur == 'persistent':
        return float('inf')
    try:
        return Duration(pref_dur).to_seconds()
    except Exception as e:
        warnings.append(f"Warning: {e} {pref_dur}")
        pass
    # Solve some rare cases:
    parts = pref_dur.split()
    assert len(parts) == 2
    cardinal, unit = float(parts[0]), parts[1]
    if unit == 'years':
        return cardinal * Duration('1 year').to_seconds()
    #     raise ValueError(f"Do not support {pref_dur}")
    return None

def test_parse_pref_dur():
    for dur in cookie_decls.pref_duration.unique():
        print(f'{dur} -> {int(parse_cookie_dur(dur)):,d}')
# test_parse_pref_dur()

# %%
# TODO: change pref_ to decl_ prefix
cookie_decls['decl_dur_sec'] = cookie_decls['decl_duration'].map(parse_cookie_dur)
cookie_decls
# Out:
#                      domain       expires  httpOnly                   name  \
# 0        .apachefriends.org  1.629067e+09     False                   _gid
# 1        .apachefriends.org  1.660517e+09     False  OptanonAlertBoxClosed
# 2        .apachefriends.org  1.660517e+09     False         OptanonConsent
# 3        .apachefriends.org  1.629067e+09     False                   _gid
# 4        .apachefriends.org  1.660517e+09     False  OptanonAlertBoxClosed
# ...                     ...           ...       ...                    ...
# 3006098         .midomi.com  1.628946e+09     False                   _gid
# 3006099         .midomi.com  1.628946e+09     False                   _gid
# 3006100    .doubleclick.net  1.691932e+09      True                    IDE
# 3006101         .midomi.com  1.628946e+09     False                   _gid
# 3006102         .midomi.com  1.628946e+09     False                   _gid
#
#         path sameSite  secure  \
# 0          /     None   False
# 1          /      Lax   False
# 2          /      Lax   False
# 3          /     None   False
# 4          /      Lax   False
# ...      ...      ...     ...
# 3006098    /     None   False
# 3006099    /     None   False
# 3006100    /     None    True
# 3006101    /     None   False
# 3006102    /     None   False
#
#                                                      value  \
# 0                               GA1.2.720720591.1628980892
# 1                                 2021-08-14T22:42:17.927Z
# 2        isIABGlobal=false&datestamp=Sat+Aug+14+2021+22...
# 3                               GA1.2.720720591.1628980892
# 4                                 2021-08-14T22:42:17.927Z
# ...                                                    ...
# 3006098                         GA1.2.345739105.1628859927
# 3006099                         GA1.2.345739105.1628859927
# 3006100  AHWqTUn3owNXIyq812HUzj65-XvMunwserbtL9tjiIw2Sh...
# 3006101                         GA1.2.345739105.1628859927
# 3006102                         GA1.2.345739105.1628859927
#
#                                                request_url               site  \
# 0        https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 1        https://www.apachefriends.org/javascripts/all-...  apachefriends.org
# 2        https://www.apachefriends.org/images/flags/fr-...  apachefriends.org
# 3        https://www.apachefriends.org/images/flags/hu-...  apachefriends.org
# 4                 https://www.apachefriends.org/index.html  apachefriends.org
# ...                                                    ...                ...
# 3006098  https://www.midomi.com/img/png/SoundHound_boto...         midomi.com
# 3006099  https://static.midomi.com/s/ud/GIM/016/07-/T1-...         midomi.com
# 3006100  https://googleads.g.doubleclick.net/xbbe/pixel...         midomi.com
# 3006101  https://www.midomi.com/logo/app-store-download...         midomi.com
# 3006102  https://static.midomi.com/s/w/019/029/661/431/...         midomi.com
#
#          ...        decl_domain  decl_duration decl_category_id  \
# 0        ...  apachefriends.org         1 days            C0002
# 1        ...  apachefriends.org       365 days            C0001
# 2        ...  apachefriends.org       365 days            C0001
# 3        ...  apachefriends.org         1 days            C0002
# 4        ...  apachefriends.org       365 days            C0001
# ...      ...                ...            ...              ...
# 3006098  ...         midomi.com         1 days            C0001
# 3006099  ...         midomi.com         1 days            C0001
# 3006100  ...    doubleclick.net       390 days            C0004
# 3006101  ...         midomi.com         1 days            C0001
# 3006102  ...         midomi.com         1 days            C0001
#
#                            decl_category     decl_consent_mode  \
# 0                           Performance                 active
# 1                     Strictly Necessary         always active
# 2                     Strictly Necessary         always active
# 3                           Performance                 active
# 4                     Strictly Necessary         always active
# ...                                  ...                   ...
# 3006098        Essential Website Cookies         always active
# 3006099        Essential Website Cookies         always active
# 3006100  Advertising (Targeting) Cookies  inactive landingpage
# 3006101        Essential Website Cookies         always active
# 3006102        Essential Website Cookies         always active
#
#                  decl_site decl_lib_name decl_pattern_name       dur_sec  \
# 0        apachefriends.org      onetrust           en.json  8.634152e+04
# 1        apachefriends.org      onetrust           en.json  3.153599e+07
# 2        apachefriends.org      onetrust           en.json  3.153599e+07
# 3        apachefriends.org      onetrust           en.json  8.634152e+04
# 4        apachefriends.org      onetrust           en.json  3.153599e+07
# ...                    ...           ...               ...           ...
# 3006098         midomi.com      onetrust           en.json  8.633199e+04
# 3006099         midomi.com      onetrust           en.json  8.633199e+04
# 3006100         midomi.com      onetrust           en.json  6.307193e+07
# 3006101         midomi.com      onetrust           en.json  8.633199e+04
# 3006102         midomi.com      onetrust           en.json  8.633199e+04
#
#         decl_dur_sec
# 0            86400.0
# 1         31536000.0
# 2         31536000.0
# 3            86400.0
# 4         31536000.0
# ...              ...
# 3006098      86400.0
# 3006099      86400.0
# 3006100   33696000.0
# 3006101      86400.0
# 3006102      86400.0
#
# [3006103 rows x 24 columns]

# %%
cookie_decls = cookie_decls[~cookie_decls.decl_dur_sec.isna()]

# %%
len(cookie_decls)
# Out:
# 3002554

# %%
# set(warnings) # these are spanish ...

# %%
declared_durations = cookie_decls.decl_duration.value_counts()

# %%
n_sites_with_dur = cookie_decls.site.nunique()
# print(f"Num sites with duration: {n_sites_with_dur/n_sites_with_sett*100:.2f} ({n_sites_with_dur}/{n_sites_with_sett})")
dur_vios = cookie_decls[cookie_decls.decl_dur_sec < cookie_decls.dur_sec]
n_violate_sites = dur_vios.site.nunique()
print(f"Num sites with duration violations: {n_violate_sites / n_sites_with_dur * 100:.2f}% ({n_violate_sites}/{n_sites_with_dur})")
# Out:
# Num sites with duration violations: 76.49% (1025/1340)

# %%
dur_vios_counts = dur_vios.decl_duration.value_counts().to_frame().reset_index()
dur_vios_counts['nspecified'] = dur_vios_counts['index'].map(declared_durations)
dur_vios_counts['percent_too_short'] = dur_vios_counts['decl_duration'] / dur_vios_counts['nspecified'] * 100
dur_vios_counts.head(5)
# Out:
#       index  decl_duration  nspecified  percent_too_short
# 0    0 days         461319      513081          89.911534
# 1   Session          49107      612401           8.018765
# 2  365 days          35128      602452           5.830838
# 3   16 days          27948       27948         100.000000
# 4  395 days          17166       30622          56.057736

# %%
duration_to_percent_too_short = {row['index']: row['percent_too_short'] for _, row in dur_vios_counts.iterrows()}
pref_dur_counts['percent_too_short'] = pref_dur_counts.Duration.map(duration_to_percent_too_short)
pref_dur_counts_latex = pref_dur_counts.rename(columns={"Duration": "Cookie Duration", "freq": r"Frequency (%)", "percent_too_short": r"% of Declared-too-short Cookies"})
pref_dur_counts_latex.replace({'0 days': 'A few seconds'}, inplace=True)
print(pref_dur_counts_latex.to_latex(float_format="%.2f", index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
# Cookie Duration &  Frequency (\%) &  \% of Declared-too-short Cookies \\
# \midrule
#         Session &          23.27 &                             8.02 \\
#   A few seconds &          22.58 &                            89.91 \\
#        365 days &          11.75 &                             5.83 \\
#        730 days &           4.55 &                             3.81 \\
#         30 days &           3.97 &                            10.49 \\
# \bottomrule
# \end{tabular}

# %%
# Analyze actual duration of "a few seconds"
dur_vios[dur_vios.pref_duration == "a few seconds"].sort_values(by='dur_sec')
# Out:
#                    domain       expires  httpOnly                        name  \
# 24824        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24769        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24772        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24775        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# 24794        www.cell.com  1.619896e+09     False  _hjIncludedInSessionSample
# ...                   ...           ...       ...                         ...
# 93688  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93708  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93743  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93589  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
# 93535  .www.glassdoor.com  2.534023e+11     False              G_ENABLED_IDPS
#
#       path sameSite  secure   value  \
# 24824    /      Lax   False       0
# 24769    /      Lax   False       0
# 24772    /      Lax   False       0
# 24775    /      Lax   False       0
# 24794    /      Lax   False       0
# ...    ...      ...     ...     ...
# 93688    /     None   False  google
# 93708    /     None   False  google
# 93743    /     None   False  google
# 93589    /     None   False  google
# 93535    /     None   False  google
#
#                                              request_url  \
# 24824  https://www.cell.com/ssoSessionCheck?callback=...
# 24769  https://www.cell.com/cdn-cgi/scripts/5c5dd728/...
# 24772  https://www.cell.com/products/marlin/fonts/nex...
# 24775  https://www.cell.com/pb-assets/adobe/conversio...
# 24794  https://www.cell.com/products/marlin/fonts/els...
# ...                                                  ...
# 93688  https://www.glassdoor.com/app/static/img/locke...
# 93708  https://www.glassdoor.com/app/static/js/gd-fj-...
# 93743  https://www.glassdoor.com/app/static/js/dist/g...
# 93589  https://www.glassdoor.com/app/static/js/dist/g...
# 93535  https://www.glassdoor.com/app/static/js/gd-con...
#
#                         sent_name  ... load_start_time load_end_time  \
# 24824  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24769  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24772  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24775  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# 24794  _hjIncludedInSessionSample  ...    1.619896e+09  1.619896e+09
# ...                           ...  ...             ...           ...
# 93688              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93708              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93743              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93589              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
# 93535              G_ENABLED_IDPS  ...    1.619896e+09  1.619896e+09
#
#        pref_duration          pref_host                   pref_name  \
# 24824  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24769  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24772  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24775  a few seconds       www.cell.com  _hjIncludedInSessionSample
# 24794  a few seconds       www.cell.com  _hjIncludedInSessionSample
# ...              ...                ...                         ...
# 93688  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93708  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93743  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93589  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
# 93535  a few seconds  www.glassdoor.com              G_ENABLED_IDPS
#
#       pref_group_id      pref_site pref_consent       dur_sec pref_dur_sec
# 24824             2       cell.com         True  1.092363e+02        100.0
# 24769             2       cell.com         True  1.092363e+02        100.0
# 24772             2       cell.com         True  1.092363e+02        100.0
# 24775             2       cell.com         True  1.092363e+02        100.0
# 24794             2       cell.com         True  1.092363e+02        100.0
# ...             ...            ...          ...           ...          ...
# 93688         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93708         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93743         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93589         C0001  glassdoor.com         True  2.517824e+11        100.0
# 93535         C0001  glassdoor.com         True  2.517824e+11        100.0
#
# [31534 rows x 23 columns]
